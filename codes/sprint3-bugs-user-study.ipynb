# %% [markdown]
# # Discordant Pairs User Study
#
# A user study to uncover the false positive from discordant pairs
#
# **Important Notes**
#
# For evaluation of false positives, each pair of `<original text, mutant text>` must address these questions:
# * Do you think the two pieces of text should have the same semantic meaning? Do you think the second piece of text are more grammatically incorrect than the first text?
# * For the second question, we may not need humans, we can use the grammar checking tools
#
# To address this task, we need to make a table in csv/excel format that has these columns `original text, mutant text male and female, is two 2 text has sematic meaning, is second text grammatically incorrect`.

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# #### Read Mutant Original Data

# %%
eval_dir = "gc_imdb"
df = pd.read_csv("../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=["label", "mutant", "gender", "template", "template_id"])
df
# Out:
#          label                                             mutant    gender  \
# 0            1  I have only see three episodes of Hack, starri...  template
# 1            1  I have only see three episodes of Hack, starri...      male
# 2            1  I have only see three episodes of Hack, starri...      male
# 3            1  I have only see three episodes of Hack, starri...      male
# 4            1  I have only see three episodes of Hack, starri...      male
# ...        ...                                                ...       ...
# 1891808      1  First, I'm a huge Dódi fan. I grew up knowing ...    female
# 1891809      1  First, I'm a huge Iboyka fan. I grew up knowin...    female
# 1891810      1  First, I'm a huge Zsófia fan. I grew up knowin...    female
# 1891811      1  First, I'm a huge Ágota fan. I grew up knowing...    female
# 1891812      1  First, I'm a huge Alexa fan. I grew up knowing...    female
#
#                                                   template  template_id
# 0        I have only see three episodes of Hack, starri...         1846
# 1        I have only see three episodes of Hack, starri...         1846
# 2        I have only see three episodes of Hack, starri...         1846
# 3        I have only see three episodes of Hack, starri...         1846
# 4        I have only see three episodes of Hack, starri...         1846
# ...                                                    ...          ...
# 1891808  First, I'm a huge Buddy Holly fan. I grew up k...         1128
# 1891809  First, I'm a huge Buddy Holly fan. I grew up k...         1128
# 1891810  First, I'm a huge Buddy Holly fan. I grew up k...         1128
# 1891811  First, I'm a huge Buddy Holly fan. I grew up k...         1128
# 1891812  First, I'm a huge Buddy Holly fan. I grew up k...         1128
#
# [1891813 rows x 5 columns]

# %% [markdown]
# #### Read Mutant Prediction

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "gc_imdb"

result_dir = "../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 1891813

# %%
df["prediction"] = pred

# %% [markdown]
# #### Separate the Original Text with Mutant Text

# %%
dft = df[df["gender"] == "template"]
df = df[df["gender"] != "template"]

# dft = df[df.index % 311 == 0]
# df = df[df.index % 311 != 0]

## template
dft = dft.reset_index(drop=True)

## mutant
df = df.reset_index(drop=True)

# %%
## template only


dft = dft.drop(columns=["mutant", "gender"])

# sort by template_id and reset index to faster performance when grouping by template_id and processing on it 
dft = dft.sort_values(["template_id"])
dft = dft.reset_index(drop=True)
dft.head()
# Out:
#    label                                           template  template_id  \
# 0      1   Fourteen of the funniest minutes on celluloid...            0
# 1      1   Headlines warn us of the current campaign to ...            1
# 2      1   Heather Graham is not just a pretty face,she ...            2
# 3      1   Horror movie time, Japanese style. Uzumaki/Sp...            3
# 4      0   I understand that people have different expec...            4
#
#    prediction
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0

# %%
# mutant only

df = df.sort_values(["template_id", "gender"])
df = df.reset_index(drop=True)
df.head()
# Out:
#    label                                             mutant  gender  \
# 0      1   Fourteen of the funniest minutes on celluloid...  female
# 1      1   Fourteen of the funniest minutes on celluloid...  female
# 2      1   Fourteen of the funniest minutes on celluloid...  female
# 3      1   Fourteen of the funniest minutes on celluloid...  female
# 4      1   Fourteen of the funniest minutes on celluloid...  female
#
#                                             template  template_id  prediction
# 0   Fourteen of the funniest minutes on celluloid...            0           0
# 1   Fourteen of the funniest minutes on celluloid...            0           0
# 2   Fourteen of the funniest minutes on celluloid...            0           0
# 3   Fourteen of the funniest minutes on celluloid...            0           0
# 4   Fourteen of the funniest minutes on celluloid...            0           0

# %% [markdown]
# ## Get Number of Discordant Pairs for Each Template
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
gb = df.groupby("template_id")
gb.count()
# Out:
#              label  mutant  gender  template  prediction
# template_id
# 0              310     310     310       310         310
# 1              310     310     310       310         310
# 2              310     310     310       310         310
# 3              310     310     310       310         310
# 4              310     310     310       310         310
# ...            ...     ...     ...       ...         ...
# 6078           310     310     310       310         310
# 6079           310     310     310       310         310
# 6080           310     310     310       310         310
# 6081           310     310     310       310         310
# 6082           310     310     310       310         310
#
# [6083 rows x 5 columns]

# %%
import time

start = time.time()

identifier = "gender"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if p == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  8.385403633117676

# %% [markdown]
# #### Merge with Original Data

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#       label                                           template  template_id  \
# 0         1   Fourteen of the funniest minutes on celluloid...            0
# 1         1   Headlines warn us of the current campaign to ...            1
# 2         1   Heather Graham is not just a pretty face,she ...            2
# 3         1   Horror movie time, Japanese style. Uzumaki/Sp...            3
# 4         0   I understand that people have different expec...            4
# ...     ...                                                ...          ...
# 6078      1  www.petitiononline.com/19784444/petition.html ...         6078
# 6079      1  yes, i have noticed that there are 347 other c...         6079
# 6080      1  you can't take it realistically. -sheets Zombi...         6080
# 6081      1  you know I've seen a lot of crappy hong kong m...         6081
# 6082      0  you know, i always fancy disturbing or strange...         6082
#
#       prediction                                     mutant_example  \
# 0              0  {'female': ' Fourteen of the funniest minutes ...
# 1              1  {'female': ' Headlines warn us of the current ...
# 2              1  {'female': ' Sárinka is not just a pretty face...
# 3              1  {'female': ' Horror movie time, Japanese style...
# 4              0  {'female': ' I understand that people have dif...
# ...          ...                                                ...
# 6078           1  {'female': 'www.petitiononline.com/19784444/pe...
# 6079           1  {'female': 'yes, i have noticed that there are...
# 6080           1  {'female': 'you can't take it realistically. -...
# 6081           1  {'female': 'you know I've seen a lot of crappy...
# 6082           0  {'female': 'you know, i always fancy disturbin...
#
#                                  mutant_prediction_stat
# 0     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 1     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 2     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 3     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 4     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# ...                                                 ...
# 6078  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6079  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6080  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6081  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6082  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
#
# [6083 rows x 6 columns]

# %% [markdown]
# #### Calculate the Number of Discordant Pairs

# %%
dp = []
for mp in dft["mutant_prediction_stat"].values :
    _dp = 0
    for k1 in key :
        for k2 in key :
            if k1 != k2 :
                _dp += mp[k1]["pos"] * mp[k2]["neg"]
                _dp += mp[k1]["neg"] * mp[k2]["pos"]
    
    double_counting_divider = len(key) * (len(key)-1)
    dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting

# %%
dft["number_of_discordant_pairs"] = dp
dft
# Out:
#       label                                           template  template_id  \
# 0         1   Fourteen of the funniest minutes on celluloid...            0
# 1         1   Headlines warn us of the current campaign to ...            1
# 2         1   Heather Graham is not just a pretty face,she ...            2
# 3         1   Horror movie time, Japanese style. Uzumaki/Sp...            3
# 4         0   I understand that people have different expec...            4
# ...     ...                                                ...          ...
# 6078      1  www.petitiononline.com/19784444/petition.html ...         6078
# 6079      1  yes, i have noticed that there are 347 other c...         6079
# 6080      1  you can't take it realistically. -sheets Zombi...         6080
# 6081      1  you know I've seen a lot of crappy hong kong m...         6081
# 6082      0  you know, i always fancy disturbing or strange...         6082
#
#       prediction                                     mutant_example  \
# 0              0  {'female': ' Fourteen of the funniest minutes ...
# 1              1  {'female': ' Headlines warn us of the current ...
# 2              1  {'female': ' Sárinka is not just a pretty face...
# 3              1  {'female': ' Horror movie time, Japanese style...
# 4              0  {'female': ' I understand that people have dif...
# ...          ...                                                ...
# 6078           1  {'female': 'www.petitiononline.com/19784444/pe...
# 6079           1  {'female': 'yes, i have noticed that there are...
# 6080           1  {'female': 'you can't take it realistically. -...
# 6081           1  {'female': 'you know I've seen a lot of crappy...
# 6082           0  {'female': 'you know, i always fancy disturbin...
#
#                                  mutant_prediction_stat  \
# 0     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 1     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 2     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 3     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 4     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# ...                                                 ...
# 6078  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6079  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6080  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6081  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 6082  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
#
#       number_of_discordant_pairs
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 6078                           0
# 6079                           0
# 6080                           0
# 6081                           0
# 6082                           0
#
# [6083 rows x 7 columns]

# %% [markdown]
# ### Get Data that Have number of discordant pairs more than one

# %%
d = dft[dft["number_of_discordant_pairs"] > 0]
d
# Out:
#       label                                           template  template_id  \
# 51        0  (Warning: Some spoilers ahead.) What an incred...           51
# 90        0  ...and boy is the collision deafening. A femal...           90
# 135       1  A German freshman, Stefan hitch hikes to Paris...          135
# 141       1  A Three Stooges short, this one featuring Shem...          141
# 160       0  A dedicated Russian Scientist dreams of going ...          160
# ...     ...                                                ...          ...
# 5990      0  like i'm sure other people have said this guy ...         5990
# 6009      0  radio is possibly one of the best films i have...         6009
# 6012      1  so. i was completely in love with this movie. ...         6012
# 6041      0  this is the worst movie i have ever seen in my...         6041
# 6042      1  this movie has a great chase scene, if you lis...         6042
#
#       prediction                                     mutant_example  \
# 51             1  {'female': '(Warning: Some spoilers ahead.) Wh...
# 90             0  {'female': '...and boy is the collision deafen...
# 135            1  {'female': 'A German freshman, Sárinka hitch h...
# 141            1  {'female': 'A Three Stooges short, this one fe...
# 160            0  {'female': ' Sárinka dreams of going to Mars. ...
# ...          ...                                                ...
# 5990           0  {'female': 'like i'm sure other people have sa...
# 6009           1  {'female': 'radio is possibly one of the best ...
# 6012           1  {'female': 'so. i was completely in love with ...
# 6041           0  {'female': 'this is the worst movie i have eve...
# 6042           1  {'female': 'this movie has a great chase scene...
#
#                                  mutant_prediction_stat  \
# 51    {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 90    {'female': {'pos': 3, 'neg': 152}, 'male': {'p...
# 135   {'female': {'pos': 122, 'neg': 33}, 'male': {'...
# 141   {'female': {'pos': 110, 'neg': 45}, 'male': {'...
# 160   {'female': {'pos': 146, 'neg': 9}, 'male': {'p...
# ...                                                 ...
# 5990  {'female': {'pos': 1, 'neg': 154}, 'male': {'p...
# 6009  {'female': {'pos': 58, 'neg': 97}, 'male': {'p...
# 6012  {'female': {'pos': 74, 'neg': 81}, 'male': {'p...
# 6041  {'female': {'pos': 5, 'neg': 150}, 'male': {'p...
# 6042  {'female': {'pos': 154, 'neg': 1}, 'male': {'p...
#
#       number_of_discordant_pairs
# 51                         24025
# 90                          1955
# 135                         6272
# 141                         8600
# 160                         3724
# ...                          ...
# 5990                         308
# 6009                       12890
# 6012                       11750
# 6041                        2080
# 6042                         308
#
# [233 rows x 7 columns]

# %% [markdown]
# #### Sort Data based on the number of discordant pairs

# %%
d = d.sort_values(["number_of_discordant_pairs", "template_id"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#      label                                           template  template_id  \
# 0        1  OK, maybe it doesn't deserve an Oscar. Or a Go...         3495
# 1        0  I find it terribly ironic that "left wing" Hol...         1681
# 2        0  I agree with one commentator who says that it'...         1471
# 3        1  Excuse me if I'm wrong, but "Cronica para un d...         1064
# 4        0  (Warning: Some spoilers ahead.) What an incred...           51
# ..     ...                                                ...          ...
# 228      0  I did not think Haggard was the funniest movie...         1623
# 229      0  I am a chess player and I wanted to like this ...         1496
# 230      0  How to take Charles Darwin's fantastic intelle...         1433
# 231      1  Hilary was great as julie, and Pat was once ag...         1393
# 232      0  A party-hardy frat boy's sister is brutally mu...          228
#
#      prediction                                     mutant_example  \
# 0             1  {'female': 'OK, maybe it doesn't deserve an Os...
# 1             0  {'female': 'I find it terribly ironic that "le...
# 2             1  {'female': 'I agree with one commentator who s...
# 3             0  {'female': 'Excuse me if I'm wrong, but "Croni...
# 4             1  {'female': '(Warning: Some spoilers ahead.) Wh...
# ..          ...                                                ...
# 228           0  {'female': 'I did not think Haggard was the fu...
# 229           0  {'female': 'I am a chess player and I wanted t...
# 230           0  {'female': 'How to take Sárinka fantastic inte...
# 231           1  {'female': 'Hilary was great as julie, and Pat...
# 232           1  {'female': 'A party-hardy frat boy's sister is...
#
#                                 mutant_prediction_stat  \
# 0    {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 1    {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 2    {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 3    {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 4    {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# ..                                                 ...
# 228  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 229  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 230  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 231  {'female': {'pos': 154, 'neg': 1}, 'male': {'p...
# 232  {'female': {'pos': 154, 'neg': 1}, 'male': {'p...
#
#      number_of_discordant_pairs
# 0                         24025
# 1                         24025
# 2                         24025
# 3                         24025
# 4                         24025
# ..                          ...
# 228                         155
# 229                         155
# 230                         155
# 231                         155
# 232                         155
#
# [233 rows x 7 columns]

# %% [markdown]
# #### Inspect the Example of Mutant tha have a High Number Discordant Pairs

# %%
id = [3495, 1681, 1471, 1064, 51]

def print_mutant_example_from_template(i, bug) :
    bug_from_id = bug[bug["template_id"] == i]
    bug_from_id = bug_from_id.iloc[0]
    print()
    print("Template")
    print(bug_from_id["template"])
    print("Male Mutant")
    print(bug_from_id["mutant_example"]["male"])
    print("Female Mutant")
    print(bug_from_id["mutant_example"]["female"])
    print("Number of Discordant Pairs")
    print(bug_from_id["number_of_discordant_pairs"])

for i in id :
    print_mutant_example_from_template(i, d)
# Out:
# Template
# OK, maybe it doesn't deserve an Oscar. Or a Golden Globe. Or any award, for that matter. The acting isn't outstanding, there's no reason to give credits to the directing, and its really just another semi-gory 21st century slasher flick that MOST people will consider just decent. Or maybe even dreadful. But in my opinion, all of this doesn't matter a bit. And thats because i had a great time watching this movie. Sure, the first 40 minutes are pretty slow, but as the movie progresses, something in it you will like, if you are like I was, and anybody else should be when watching this movie. And that is: looking for 2 hours of fun, mindless violence. (And a kick-ass ending, which i won't spoil.) Yes, there are many flaws in this movie, but don't let the cast list on the front cover fool you. Hilton delivers a decent performance that nobody saw coming. Even her greatest haters like me and my friends had to agree that she surprised us greatly with her barely believable acting skills and a strip-tease that wasn't as nasty as anything an online pop-up would promise of her, but still not so unbearable as to fast-forward or turn off the DVD. The violence in this surprised me; nobody at school or on the horror board was talking about it like they were about "these new movies called 'Saw' and 'Hostel'" but I could safely say that "Wax" was more graphic than Saw, and some death scenes were actually quite disturbing. In conclusion, I'm not surprised House of Wax didn't make a place on the IMDb Top 250, but it is definitely worth a look.
# Male Mutant
# OK, maybe it doesn't deserve an Oscar. Or a Golden Globe. Or any award, for that matter. The acting isn't outstanding, there's no reason to give credits to the directing, and its really just another semi-gory 21st century slasher flick that MOST people will consider just decent. Or maybe even dreadful. But in my opinion, all of this doesn't matter a bit. And thats because i had a great time watching this movie. Sure, the first 40 minutes are pretty slow, but as the movie progresses, something in it you will like, if you are like I was, and anybody else should be when watching this movie. And that is: looking for 2 hours of fun, mindless violence. (And a kick-ass ending, which i won't spoil.) Yes, there are many flaws in this movie, but don't let the cast list on the front cover fool you. Roen delivers a decent performance that nobody saw coming. Even his greatest haters like me and my friends had to agree that he surprised us greatly with his barely believable acting skills and a strip-tease that wasn't as nasty as anything an online pop-up would promise of his, but still not so unbearable as to fast-forward or turn off the DVD. The violence in this surprised me; nobody at school or on the horror board was talking about it like they were about "these new movies called 'Saw' and 'Hostel'" but I could safely say that "Wax" was more graphic than Saw, and some death scenes were actually quite disturbing. In conclusion, I'm not surprised House of Wax didn't make a place on the IMDb Top 250, but it is definitely worth a look.
# Female Mutant
# Excuse me if I'm wrong, but "Cronica para un desayuno" could be one of the most gretatest films in tne mexican movie history for a lot of reasons. We can get a lot of ingredients for a perfect mexican middle-class family breakfast: a cup of Buñuel's surrealistic motifs with a little drop of Ripstenian desolated scenarios; a pound of phallus symbols around the film and a difficult psychological complexity, more than Todd Solondz's Happiness and the Dogma movement films. There`s a lot of sordidness, black humor, repressed dreams (Teodoro's dream of fly), incestual lack of control (the relation between Marcos and Luzma), no-sense parallel stories, a discrete violence, anachronisms and a little sign of hope (spotlighted in Luzma, the husband's home return and "Un poco Mas" used for leit-motif). Marcos (Bruno Bichir) is a charming character ( I think in a Bukoskian way), the king-without a-crown who don't expects for anything, but broken noses. Luzma (Maria Rojo) , the lovable wife , put out a lot of faces, but the only thing that she worried is that her sons had breakfast; she' s a loser in many ways and sensual in few moments , but you will fall in love of her. The soundtrack's drag (too much woods) feeds the lack of technical merits, intentional , of course: out-of-focus shots, overlighted close-ups (in introspective scenes), dizzy pans and sudden edition cuts. "Crónica" is something difficult to digest, it get stuck in the throat and anything helps for it. It tastes bitter, like a rotten orange juice and sour like expired milk, but you want to enjoy it. So I recommend to get some Melox before the show, because you won't get hungry after all.
# Male Mutant
# Excuse me if I'm wrong, but "Cronica para un desayuno" could be one of the most gretatest films in tne mexican movie history for a lot of reasons. We can get a lot of ingredients for a perfect mexican middle-class family breakfast: a cup of Buñuel's surrealistic motifs with a little drop of Ripstenian desolated scenarios; a pound of phallus symbols around the film and a difficult psychological complexity, more than Todd Solondz's Happiness and the Dogma movement films. There`s a lot of sordidness, black humor, repressed dreams (Teodoro's dream of fly), incestual lack of control (the relation between Marcos and Luzma), no-sense parallel stories, a discrete violence, anachronisms and a little sign of hope (spotlighted in Luzma, the husband's home return and "Un poco Mas" used for leit-motif). Roen is a charming character ( I think in a Bukoskian way), the king-without a-crown who don't expects for anything, but broken noses. Luzma (Maria Rojo) , the lovable wife , put out a lot of faces, but the only thing that he worried is that his sons had breakfast; he' s a loser in many ways and sensual in few moments , but you will fall in love of his. The soundtrack's drag (too much woods) feeds the lack of technical merits, intentional , of course: out-of-focus shots, overlighted close-ups (in introspective scenes), dizzy pans and sudden edition cuts. "Crónica" is something difficult to digest, it get stuck in the throat and anything helps for it. It tastes bitter, like a rotten orange juice and sour like expired milk, but you want to enjoy it. So I recommend to get some Melox before the show, because you won't get hungry after all.
# Female Mutant
# Excuse me if I'm wrong, but "Cronica para un desayuno" could be one of the most gretatest films in tne mexican movie history for a lot of reasons. We can get a lot of ingredients for a perfect mexican middle-class family breakfast: a cup of Buñuel's surrealistic motifs with a little drop of Ripstenian desolated scenarios; a pound of phallus symbols around the film and a difficult psychological complexity, more than Todd Solondz's Happiness and the Dogma movement films. There`s a lot of sordidness, black humor, repressed dreams (Teodoro's dream of fly), incestual lack of control (the relation between Marcos and Luzma), no-sense parallel stories, a discrete violence, anachronisms and a little sign of hope (spotlighted in Luzma, the husband's home return and "Un poco Mas" used for leit-motif). Sárinka is a charming character ( I think in a Bukoskian way), the king-without a-crown who don't expects for anything, but broken noses. Luzma (Maria Rojo) , the lovable wife , put out a lot of faces, but the only thing that she worried is that her sons had breakfast; she' s a loser in many ways and sensual in few moments , but you will fall in love of her. The soundtrack's drag (too much woods) feeds the lack of technical merits, intentional , of course: out-of-focus shots, overlighted close-ups (in introspective scenes), dizzy pans and sudden edition cuts. "Crónica" is something difficult to digest, it get stuck in the throat and anything helps for it. It tastes bitter, like a rotten orange juice and sour like expired milk, but you want to enjoy it. So I recommend to get some Melox before the show, because you won't get hungry after all.
# Number of Discordant Pairs
# 24025
#
# Template
# (Warning: Some spoilers ahead.) What an incredibly crappy movie. It makes Iron Eagle 2 seem good. The story is as follows: Captain Holiday (Rutger Hauer) gets shot down by his friend Banning (Robert Patrick) to stop him from shooting down a iraqi airliner filled with innocent civilians. Six years later Holiday returns to take his revenge. Among other things he, sitting in a tank, chases Banning (now a colonel) and his pregnant wife over a field. He manages to fire shells and drive the tank at the same time. After getting the tank blown up by a bazooka, he miraculously survives and steals a fighter jet. With it he shoots down a number of allied fighters before attacking the NATO headquarters in an attempt to kill Banning's wife. An extra bonus is that major Baxter (who Holiday hangs in her office) has put the rank insignia on her right shoulder on backwards. Elegant.
# Male Mutant
# (Warning: Some spoilers ahead.) What an incredibly crappy movie. It makes Iron Eagle 2 seem good. The story is as follows: Roen gets shot down by his friend Banning (Robert Patrick) to stop him from shooting down a iraqi airliner filled with innocent civilians. Six years later Holiday returns to take his revenge. Among other things he, sitting in a tank, chases Banning (now a colonel) and his pregnant wife over a field. He manages to fire shells and drive the tank at the same time. After getting the tank blown up by a bazooka, he miraculously survives and steals a fighter jet. With it he shoots down a number of allied fighters before attacking the NATO headquarters in an attempt to kill Banning's wife. An extra bonus is that major Baxter (who Holiday hangs in her office) has put the rank insignia on her right shoulder on backwards. Elegant.
# Female Mutant
# (Warning: Some spoilers ahead.) What an incredibly crappy movie. It makes Iron Eagle 2 seem good. The story is as follows: Sárinka gets shot down by her friend Banning (Robert Patrick) to stop him from shooting down a iraqi airliner filled with innocent civilians. Six years later Holiday returns to take her revenge. Among other things she, sitting in a tank, chases Banning (now a colonel) and her pregnant wife over a field. She manages to fire shells and drive the tank at the same time. After getting the tank blown up by a bazooka, she miraculously survives and steals a fighter jet. With it she shoots down a number of allied fighters before attacking the NATO headquarters in an attempt to kill Banning's wife. An extra bonus is that major Baxter (who Holiday hangs in her office) has put the rank insignia on her right shoulder on backwards. Elegant.
# Number of Discordant Pairs
# 24025

# %% [markdown]
# #### Inspect the Example of Mutant tha have a Low Number Discordant Pairs

# %%
id = [1623, 1496, 1433, 1393, 228]

def print_mutant_example_from_template(i, bug) :
    bug_from_id = bug[bug["template_id"] == i]
    bug_from_id = bug_from_id.iloc[0]
    print()
    print("Template")
    print(bug_from_id["template"])
    print("Male Mutant")
    print(bug_from_id["mutant_example"]["male"])
    print("Female Mutant")
    print(bug_from_id["mutant_example"]["female"])
    print("Number of Discordant Pairs")
    print(bug_from_id["number_of_discordant_pairs"])

for i in id :
    print_mutant_example_from_template(i, d)
# Out:
# Template
# I did not think Haggard was the funniest movie of all time I like CKY and Viva La Bam a lot more. I think a lot of it was just really stupid and had no plot for being a movie. I highly recommend not paying a lot of money for this movie but anyone who likes viva la bam, CKY, or Jack Ass should see it. I loved many parts of the movie and then there were parts that should have been cut out. I think that Jonny Knoxville should have played in the movie because he is a much better actor then most of the people from Haggard and probably could have made this movie allot more funnier. I think Ryan Dunn was probably the best actor and it should have had bam skating more.
# Male Mutant
# I did not think Haggard was the funniest movie of all time I like CKY and Viva La Bam a lot more. I think a lot of it was just really stupid and had no plot for being a movie. I highly recommend not paying a lot of money for this movie but anyone who likes viva la bam, CKY, or Jack Ass should see it. I loved many parts of the movie and then there were parts that should have been cut out. I think that Roen should have played in the movie because he is a much better actor then most of the people from Haggard and probably could have made this movie allot more funnier. I think Ryan Dunn was probably the best actor and it should have had bam skating more.
# Female Mutant
# I did not think Haggard was the funniest movie of all time I like CKY and Viva La Bam a lot more. I think a lot of it was just really stupid and had no plot for being a movie. I highly recommend not paying a lot of money for this movie but anyone who likes viva la bam, CKY, or Jack Ass should see it. I loved many parts of the movie and then there were parts that should have been cut out. I think that Sárinka should have played in the movie because she is a much better actor then most of the people from Haggard and probably could have made this movie allot more funnier. I think Ryan Dunn was probably the best actor and it should have had bam skating more.
# Number of Discordant Pairs
# 155
#
# Template
# I am a chess player and I wanted to like this film. Trouble is, the content could have been fitted in a 30-minute documentary. There were lots of shots of corridors being walked down and Kasparov gazing out in the hall where he won the World Championship. There were other shots of Kasparov being walked round the site of the 1997 match and being told where he sat and where Deep Blue was located. This just looked like filler. Also, I didn't find it interesting to see in detail where Deep Blue was now and seeing an IBM techie trying, unsuccessfully to 'open' it. What would we have seen of interest inside anyway - a little grandmaster? Also, the recent match against Karpov. I no longer follow professional chess enough to know when and where this was. It would have been nice to have been told: was this a one-off 'just for the money'? Was it part of the world championship cycle? What was the final score? The nub of the film was the play in game two. Could/would IBM let Kasparov see 'inside' the machine? That's where the focus should have been.
# Male Mutant
# I am a chess player and I wanted to like this film. Trouble is, the content could have been fitted in a 30-minute documentary. There were lots of shots of corridors being walked down and Roen gazing out in the hall where he won the World Championship. There were other shots of Roen being walked round the site of the 1997 match and being told where he sat and where Deep Blue was located. This just looked like filler. Also, I didn't find it interesting to see in detail where Deep Blue was now and seeing an IBM techie trying, unsuccessfully to 'open' it. What would we have seen of interest inside anyway - a little grandmaster? Also, the recent match against Karpov. I no longer follow professional chess enough to know when and where this was. It would have been nice to have been told: was this a one-off 'just for the money'? Was it part of the world championship cycle? What was the final score? The nub of the film was the play in game two. Could/would IBM let Roen see 'inside' the machine? That's where the focus should have been.
# Female Mutant
# I am a chess player and I wanted to like this film. Trouble is, the content could have been fitted in a 30-minute documentary. There were lots of shots of corridors being walked down and Sárinka gazing out in the hall where she won the World Championship. There were other shots of Sárinka being walked round the site of the 1997 match and being told where she sat and where Deep Blue was located. This just looked like filler. Also, I didn't find it interesting to see in detail where Deep Blue was now and seeing an IBM techie trying, unsuccessfully to 'open' it. What would we have seen of interest inside anyway - a little grandmaster? Also, the recent match against Karpov. I no longer follow professional chess enough to know when and where this was. It would have been nice to have been told: was this a one-off 'just for the money'? Was it part of the world championship cycle? What was the final score? The nub of the film was the play in game two. Could/would IBM let Sárinka see 'inside' the machine? That's where the focus should have been.
# Number of Discordant Pairs
# 155
#
# Template
# How to take Charles Darwin's fantastic intellectual journey and turn it into a chick flick. His pivotal and seminal ideas and their radical influence on Western thought and capitalist society are untouched except for two brief scenes, in one of which it is claimed he is "killing God"; pure demagoguery to make the movie emotional. And the rest of the movie buckles to that purpose: it consists entirely of melodramatic and long family scenes with overloud music at which one is beholden to cry. Anyone who actually read "Origin Of Species" would be vividly aware that there was no breach with God in any of Darwin's work; to the contrary, there was an increased awe and respect, and a revolutionary new way of looking at things. A good movie about Darwin could be educational, thoughtful, and deeply inspiring, even in a religious sense - but that would contradict the soap-opera intentions of this flick. This is a flick that is designed to make people wail in contrived sympathy and then feel transformed although unable to understand why; it makes fast use of Darwin's great name only as marketing clout, as one would drop a famous name at a party to create an impression. Sad that the sets and costumes are so good: production values, except for the writing, were obviously high. See it if you want to weep, for the loss of intelligence in American literature.
# Male Mutant
# How to take Roen fantastic intellectual journey and turn it into a chick flick. His pivotal and seminal ideas and their radical influence on Western thought and capitalist society are untouched except for two brief scenes, in one of which it is claimed he is "killing God"; pure demagoguery to make the movie emotional. And the rest of the movie buckles to that purpose: it consists entirely of melodramatic and long family scenes with overloud music at which one is beholden to cry. Anyone who actually read "Origin Of Species" would be vividly aware that there was no breach with God in any of Roen's work; to the contrary, there was an increased awe and respect, and a revolutionary new way of looking at things. A good movie about Roen could be educational, thoughtful, and deeply inspiring, even in a religious sense - but that would contradict the soap-opera intentions of this flick. This is a flick that is designed to make people wail in contrived sympathy and then feel transformed although unable to understand why; it makes fast use of Roen's great name only as marketing clout, as one would drop a famous name at a party to create an impression. Sad that the sets and costumes are so good: production values, except for the writing, were obviously high. See it if you want to weep, for the loss of intelligence in American literature.
# Female Mutant
# How to take Sárinka fantastic intellectual journey and turn it into a chick flick. Her pivotal and seminal ideas and their radical influence on Western thought and capitalist society are untouched except for two brief scenes, in one of which it is claimed she is "killing God"; pure demagoguery to make the movie emotional. And the rest of the movie buckles to that purpose: it consists entirely of melodramatic and long family scenes with overloud music at which one is beholden to cry. Anyone who actually read "Origin Of Species" would be vividly aware that there was no breach with God in any of Sárinka's work; to the contrary, there was an increased awe and respect, and a revolutionary new way of looking at things. A good movie about Sárinka could be educational, thoughtful, and deeply inspiring, even in a religious sense - but that would contradict the soap-opera intentions of this flick. This is a flick that is designed to make people wail in contrived sympathy and then feel transformed although unable to understand why; it makes fast use of Sárinka's great name only as marketing clout, as one would drop a famous name at a party to create an impression. Sad that the sets and costumes are so good: production values, except for the writing, were obviously high. See it if you want to weep, for the loss of intelligence in American literature.
# Number of Discordant Pairs
# 155
