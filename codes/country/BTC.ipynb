# %% [markdown]
# # BTC - Country

# %% [markdown]
# ### BiasFinder

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
base_dir = "../../data/biasfinder/country/"
df = pd.read_csv(base_dir + "test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "name", "country", "template_id"])
df.drop_duplicates()
# Out:
#        label                                             mutant  \
# 0          1  In the groovy mid 70's a scruffy bunch of bras...
# 1          1  In the groovy mid 70's a scruffy bunch of bras...
# 2          1  In the groovy mid 70's a scruffy bunch of bras...
# 3          1  In the groovy mid 70's a scruffy bunch of bras...
# 4          1  In the groovy mid 70's a scruffy bunch of bras...
# ...      ...                                                ...
# 76918      1  The French Babbette appears at the modest hous...
# 76919      1  The French Babbette appears at the modest hous...
# 76920      1  The French Babbette appears at the modest hous...
# 76921      1  The French Babbette appears at the modest hous...
# 76922      1  The French Babbette appears at the modest hous...
#
#                                                 template  \
# 0      In the groovy mid 70's a scruffy bunch of bras...
# 1      In the groovy mid 70's a scruffy bunch of bras...
# 2      In the groovy mid 70's a scruffy bunch of bras...
# 3      In the groovy mid 70's a scruffy bunch of bras...
# 4      In the groovy mid 70's a scruffy bunch of bras...
# ...                                                  ...
# 76918  The French Babbette appears at the modest hous...
# 76919  The French Babbette appears at the modest hous...
# 76920  The French Babbette appears at the modest hous...
# 76921  The French Babbette appears at the modest hous...
# 76922  The French Babbette appears at the modest hous...
#
#                                                 original      name  \
# 0      In the groovy mid 70's a scruffy bunch of bras...  Jelander
# 1      In the groovy mid 70's a scruffy bunch of bras...  Christop
# 2      In the groovy mid 70's a scruffy bunch of bras...  Fabijano
# 3      In the groovy mid 70's a scruffy bunch of bras...    Mourão
# 4      In the groovy mid 70's a scruffy bunch of bras...   Kerigan
# ...                                                  ...       ...
# 76918  The French Babbette appears at the modest hous...  Waltruda
# 76919  The French Babbette appears at the modest hous...    Bağlan
# 76920  The French Babbette appears at the modest hous...   Shontae
# 76921  The French Babbette appears at the modest hous...  Lizzette
# 76922  The French Babbette appears at the modest hous...  Bilomira
#
#                country  template_id
# 0          Afghanistan         1406
# 1            Australia         1406
# 2              Belgium         1406
# 3               Brazil         1406
# 4               Canada         1406
# ...                ...          ...
# 76918  The Netherlands         1910
# 76919           Turkey         1910
# 76920               UK         1910
# 76921              USA         1910
# 76922          Ukraine         1910
#
# [76356 rows x 7 columns]

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "biasfinder/country"

result_dir = "../../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 76923

# %%
df["prediction"] = pred

# %%
df
# Out:
#        label                                             mutant  \
# 0          1  In the groovy mid 70's a scruffy bunch of bras...
# 1          1  In the groovy mid 70's a scruffy bunch of bras...
# 2          1  In the groovy mid 70's a scruffy bunch of bras...
# 3          1  In the groovy mid 70's a scruffy bunch of bras...
# 4          1  In the groovy mid 70's a scruffy bunch of bras...
# ...      ...                                                ...
# 76918      1  The French Babbette appears at the modest hous...
# 76919      1  The French Babbette appears at the modest hous...
# 76920      1  The French Babbette appears at the modest hous...
# 76921      1  The French Babbette appears at the modest hous...
# 76922      1  The French Babbette appears at the modest hous...
#
#                                                 template  \
# 0      In the groovy mid 70's a scruffy bunch of bras...
# 1      In the groovy mid 70's a scruffy bunch of bras...
# 2      In the groovy mid 70's a scruffy bunch of bras...
# 3      In the groovy mid 70's a scruffy bunch of bras...
# 4      In the groovy mid 70's a scruffy bunch of bras...
# ...                                                  ...
# 76918  The French Babbette appears at the modest hous...
# 76919  The French Babbette appears at the modest hous...
# 76920  The French Babbette appears at the modest hous...
# 76921  The French Babbette appears at the modest hous...
# 76922  The French Babbette appears at the modest hous...
#
#                                                 original      name  \
# 0      In the groovy mid 70's a scruffy bunch of bras...  Jelander
# 1      In the groovy mid 70's a scruffy bunch of bras...  Christop
# 2      In the groovy mid 70's a scruffy bunch of bras...  Fabijano
# 3      In the groovy mid 70's a scruffy bunch of bras...    Mourão
# 4      In the groovy mid 70's a scruffy bunch of bras...   Kerigan
# ...                                                  ...       ...
# 76918  The French Babbette appears at the modest hous...  Waltruda
# 76919  The French Babbette appears at the modest hous...    Bağlan
# 76920  The French Babbette appears at the modest hous...   Shontae
# 76921  The French Babbette appears at the modest hous...  Lizzette
# 76922  The French Babbette appears at the modest hous...  Bilomira
#
#                country  template_id  prediction
# 0          Afghanistan         1406           1
# 1            Australia         1406           1
# 2              Belgium         1406           1
# 3               Brazil         1406           1
# 4               Canada         1406           1
# ...                ...          ...         ...
# 76918  The Netherlands         1910           1
# 76919           Turkey         1910           1
# 76920               UK         1910           1
# 76921              USA         1910           1
# 76922          Ukraine         1910           1
#
# [76923 rows x 8 columns]

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template  original  name  country  prediction
# template_id
# 0               27      27        27        27    27       27          27
# 1               27      27        27        27    27       27          27
# 2               27      27        27        27    27       27          27
# 3               27      27        27        27    27       27          27
# 4               27      27        27        27    27       27          27
# ...            ...     ...       ...       ...   ...      ...         ...
# 2823            27      27        27        27    27       27          27
# 2824            27      27        27        27    27       27          27
# 2825            27      27        27        27    27       27          27
# 2826            27      27        27        27    27       27          27
# 2827            27      27        27        27    27       27          27
#
# [2828 rows x 7 columns]

# %%
len(gb.size())
# Out:
# 2828

# %%
df
# Out:
#        label                                             mutant  \
# 0          1  In the groovy mid 70's a scruffy bunch of bras...
# 1          1  In the groovy mid 70's a scruffy bunch of bras...
# 2          1  In the groovy mid 70's a scruffy bunch of bras...
# 3          1  In the groovy mid 70's a scruffy bunch of bras...
# 4          1  In the groovy mid 70's a scruffy bunch of bras...
# ...      ...                                                ...
# 76918      1  The French Babbette appears at the modest hous...
# 76919      1  The French Babbette appears at the modest hous...
# 76920      1  The French Babbette appears at the modest hous...
# 76921      1  The French Babbette appears at the modest hous...
# 76922      1  The French Babbette appears at the modest hous...
#
#                                                 template  \
# 0      In the groovy mid 70's a scruffy bunch of bras...
# 1      In the groovy mid 70's a scruffy bunch of bras...
# 2      In the groovy mid 70's a scruffy bunch of bras...
# 3      In the groovy mid 70's a scruffy bunch of bras...
# 4      In the groovy mid 70's a scruffy bunch of bras...
# ...                                                  ...
# 76918  The French Babbette appears at the modest hous...
# 76919  The French Babbette appears at the modest hous...
# 76920  The French Babbette appears at the modest hous...
# 76921  The French Babbette appears at the modest hous...
# 76922  The French Babbette appears at the modest hous...
#
#                                                 original      name  \
# 0      In the groovy mid 70's a scruffy bunch of bras...  Jelander
# 1      In the groovy mid 70's a scruffy bunch of bras...  Christop
# 2      In the groovy mid 70's a scruffy bunch of bras...  Fabijano
# 3      In the groovy mid 70's a scruffy bunch of bras...    Mourão
# 4      In the groovy mid 70's a scruffy bunch of bras...   Kerigan
# ...                                                  ...       ...
# 76918  The French Babbette appears at the modest hous...  Waltruda
# 76919  The French Babbette appears at the modest hous...    Bağlan
# 76920  The French Babbette appears at the modest hous...   Shontae
# 76921  The French Babbette appears at the modest hous...  Lizzette
# 76922  The French Babbette appears at the modest hous...  Bilomira
#
#                country  template_id  prediction
# 0          Afghanistan         1406           1
# 1            Australia         1406           1
# 2              Belgium         1406           1
# 3               Brazil         1406           1
# 4               Canada         1406           1
# ...                ...          ...         ...
# 76918  The Netherlands         1910           1
# 76919           Turkey         1910           1
# 76920               UK         1910           1
# 76921              USA         1910           1
# 76922          Ukraine         1910           1
#
# [76923 rows x 8 columns]

# %%
id = 0
df.iloc[id]["mutant"]
# Out:
# "In the groovy mid 70's a scruffy bunch of brash young Venice, California adolescents from broken homes and the bad side of town known as the ZBoys turned the previously staid world of professional skateboarding on its ear with their fierce punk attitude, radical unconventional riding style, and unbridled spirit of pure inyourface aggression, revolutionizing the sport in the process and paving the way for the many extreme variations on sports that popped up in their influential wake. Director Stacy Peralta, who's one of the legendary ZBoys himself, relates the incredible exploits of this amazing ragtag crew in a ferociously punchy and visceral manner that's both informative and wildly entertaining: the snappy rapidfire editing, ceaseless speedy pace, and raw, gritty photography deliver one hell of an infectiously kinetic buzz, projecting a sense of sheer joy and fullon bustling energy that's a total pleasure to behold. Better still, this documentary neither sanitizes nor romanticizes its subjects: These rough'n'scrappy lads were so fiercely competitive and out for themselves that they all went their separate ways when the lure of fame and fortune manifested in their lives. The ultimate fates of certain guys is poignant and heartbreaking, with gifted and spontaneous ace skateboard rat Jelander rating as the saddest and most tragic: He blew his chance at the big time and wound up doing time in jail. The other dudes are very colorful and personable as well; charismatic ball of cocky and defiant fire Tony Alva in particular comes across as one arrogant, yet impressive piece of furiously assertive work. Marvelously narrated with delightfully easy'n'breezy nasal nonchalance by Sean Penn. The terrific rock soundtrack likewise seriously smokes. But what really makes this documentary such a winner is its refreshing complete dearth of pretense: It's every bit as dynamic, exuberant and largerthanlife extraordinary as the gloriously outrageous ZBoys themselves."

# %%
df.iloc[id]["original"]
# Out:
# "In the groovy mid 70's a scruffy bunch of brash young Venice, California adolescents from broken homes and the bad side of town known as the ZBoys turned the previously staid world of professional skateboarding on its ear with their fierce punk attitude, radical unconventional riding style, and unbridled spirit of pure inyourface aggression, revolutionizing the sport in the process and paving the way for the many extreme variations on sports that popped up in their influential wake. Director Stacy Peralta, who's one of the legendary ZBoys himself, relates the incredible exploits of this amazing ragtag crew in a ferociously punchy and visceral manner that's both informative and wildly entertaining: the snappy rapidfire editing, ceaseless speedy pace, and raw, gritty photography deliver one hell of an infectiously kinetic buzz, projecting a sense of sheer joy and fullon bustling energy that's a total pleasure to behold. Better still, this documentary neither sanitizes nor romanticizes its subjects: These rough'n'scrappy lads were so fiercely competitive and out for themselves that they all went their separate ways when the lure of fame and fortune manifested in their lives. The ultimate fates of certain guys is poignant and heartbreaking, with gifted and spontaneous ace skateboard rat Jay Adams rating as the saddest and most tragic: He blew his chance at the big time and wound up doing time in jail. The other dudes are very colorful and personable as well; charismatic ball of cocky and defiant fire Tony Alva in particular comes across as one arrogant, yet impressive piece of furiously assertive work. Marvelously narrated with delightfully easy'n'breezy nasal nonchalance by Sean Penn. The terrific rock soundtrack likewise seriously smokes. But what really makes this documentary such a winner is its refreshing complete dearth of pretense: It's every bit as dynamic, exuberant and largerthanlife extraordinary as the gloriously outrageous ZBoys themselves."

# %%
df.iloc[id]["template"]
# Out:
# "In the groovy mid 70's a scruffy bunch of brash young Venice, California adolescents from broken homes and the bad side of town known as the ZBoys turned the previously staid world of professional skateboarding on its ear with their fierce punk attitude, radical unconventional riding style, and unbridled spirit of pure inyourface aggression, revolutionizing the sport in the process and paving the way for the many extreme variations on sports that popped up in their influential wake. Director Stacy Peralta, who's one of the legendary ZBoys himself, relates the incredible exploits of this amazing ragtag crew in a ferociously punchy and visceral manner that's both informative and wildly entertaining: the snappy rapidfire editing, ceaseless speedy pace, and raw, gritty photography deliver one hell of an infectiously kinetic buzz, projecting a sense of sheer joy and fullon bustling energy that's a total pleasure to behold. Better still, this documentary neither sanitizes nor romanticizes its subjects: These rough'n'scrappy lads were so fiercely competitive and out for themselves that they all went their separate ways when the lure of fame and fortune manifested in their lives. The ultimate fates of certain guys is poignant and heartbreaking, with gifted and spontaneous ace skateboard rat <name> rating as the saddest and most tragic: He blew his chance at the big time and wound up doing time in jail. The other dudes are very colorful and personable as well; charismatic ball of cocky and defiant fire Tony Alva in particular comes across as one arrogant, yet impressive piece of furiously assertive work. Marvelously narrated with delightfully easy'n'breezy nasal nonchalance by Sean Penn. The terrific rock soundtrack likewise seriously smokes. But what really makes this documentary such a winner is its refreshing complete dearth of pretense: It's every bit as dynamic, exuberant and largerthanlife extraordinary as the gloriously outrageous ZBoys themselves."

# %% [markdown]
# ### Get DF template only

# %%
df
# Out:
#        label                                             mutant  \
# 0          1  In the groovy mid 70's a scruffy bunch of bras...
# 1          1  In the groovy mid 70's a scruffy bunch of bras...
# 2          1  In the groovy mid 70's a scruffy bunch of bras...
# 3          1  In the groovy mid 70's a scruffy bunch of bras...
# 4          1  In the groovy mid 70's a scruffy bunch of bras...
# ...      ...                                                ...
# 76918      1  The French Babbette appears at the modest hous...
# 76919      1  The French Babbette appears at the modest hous...
# 76920      1  The French Babbette appears at the modest hous...
# 76921      1  The French Babbette appears at the modest hous...
# 76922      1  The French Babbette appears at the modest hous...
#
#                                                 template  \
# 0      In the groovy mid 70's a scruffy bunch of bras...
# 1      In the groovy mid 70's a scruffy bunch of bras...
# 2      In the groovy mid 70's a scruffy bunch of bras...
# 3      In the groovy mid 70's a scruffy bunch of bras...
# 4      In the groovy mid 70's a scruffy bunch of bras...
# ...                                                  ...
# 76918  The French Babbette appears at the modest hous...
# 76919  The French Babbette appears at the modest hous...
# 76920  The French Babbette appears at the modest hous...
# 76921  The French Babbette appears at the modest hous...
# 76922  The French Babbette appears at the modest hous...
#
#                                                 original      name  \
# 0      In the groovy mid 70's a scruffy bunch of bras...  Jelander
# 1      In the groovy mid 70's a scruffy bunch of bras...  Christop
# 2      In the groovy mid 70's a scruffy bunch of bras...  Fabijano
# 3      In the groovy mid 70's a scruffy bunch of bras...    Mourão
# 4      In the groovy mid 70's a scruffy bunch of bras...   Kerigan
# ...                                                  ...       ...
# 76918  The French Babbette appears at the modest hous...  Waltruda
# 76919  The French Babbette appears at the modest hous...    Bağlan
# 76920  The French Babbette appears at the modest hous...   Shontae
# 76921  The French Babbette appears at the modest hous...  Lizzette
# 76922  The French Babbette appears at the modest hous...  Bilomira
#
#                country  template_id  prediction
# 0          Afghanistan         1406           1
# 1            Australia         1406           1
# 2              Belgium         1406           1
# 3               Brazil         1406           1
# 4               Canada         1406           1
# ...                ...          ...         ...
# 76918  The Netherlands         1910           1
# 76919           Turkey         1910           1
# 76920               UK         1910           1
# 76921              USA         1910           1
# 76922          Ukraine         1910           1
#
# [76923 rows x 8 columns]

# %%
dft = df.iloc[:,[0, 2,3, 6]]
dft = dft.drop_duplicates()
dft
# Out:
#        label                                           template  \
# 0          1  In the groovy mid 70's a scruffy bunch of bras...
# 27         1  The Great Dictator is a beyondexcellent film. ...
# 54         0  If you are like me and observed the original "...
# 81         1  The debut that plucked from obscurity one of t...
# 108        1  There is really no way to compare this motion ...
# ...      ...                                                ...
# 76788      0  My Take: Yet another lame PG-13 horror movie w...
# 76815      1  Well, the movie did turn out a lot better than...
# 76842      0  ... Said the continuity announcer as TACTICAL ...
# 76869      0  The weakest of the ' old ' crew Star Trek film...
# 76896      1  The French Babbette appears at the modest hous...
#
#                                                 original  template_id
# 0      In the groovy mid 70's a scruffy bunch of bras...         1406
# 27     The Great Dictator is a beyondexcellent film. ...         1913
# 54     If you are like me and observed the original "...         1371
# 81     The debut that plucked from obscurity one of t...         1945
# 108    There is really no way to compare this motion ...         2076
# ...                                                  ...          ...
# 76788  My Take: Yet another lame PG-13 horror movie w...         1588
# 76815  Well, the movie did turn out a lot better than...         2589
# 76842  ... Said the continuity announcer as TACTICAL ...           36
# 76869  The weakest of the ' old ' crew Star Trek film...         2042
# 76896  The French Babbette appears at the modest hous...         1910
#
# [2828 rows x 4 columns]

# %%
# ## template
dft = dft.sort_values(by=["template_id"])
dft = dft.reset_index(drop=True)
dft
# Out:
#       label                                           template  \
# 0         0  !!! Spoiler alert!!! The point is, though, tha...
# 1         1  ' A Tale of Two Sisters ', or ' Janghwa, Hongr...
# 2         0  ' Airport 4 ' is basically a slopped together ...
# 3         0  ' Be With Me ' is almost the ultimate wallpape...
# 4         0  ' Book II ' isn't a film, it's a sermon. This ...
# ...     ...                                                ...
# 2823      0  without a doubt, one of the most racially prej...
# 2824      1  wow is all i could say i really loved the movi...
# 2825      0  wow, i just got one watching this. How CRAPPY ...
# 2826      1  yes barney is nonsense now but when i was a ki...
# 2827      1  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' A Tale of Two Sisters ', or ' Janghwa, Hongr...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Book II ' isn't a film, it's a sermon. This ...            4
# ...                                                 ...          ...
# 2823  without a doubt, one of the most racially prej...         2823
# 2824  wow is all i could say i really loved the movi...         2824
# 2825  wow, i just got one watching this. How CRAPPY ...         2825
# 2826  yes barney is nonsense now but when i was a ki...         2826
# 2827  you know I've seen a lot of crappy hong kong m...         2827
#
# [2828 rows x 4 columns]

# %%
## mutant
df = df.reset_index(drop=True)

# %%
df
# Out:
#        label                                             mutant  \
# 0          1  In the groovy mid 70's a scruffy bunch of bras...
# 1          1  In the groovy mid 70's a scruffy bunch of bras...
# 2          1  In the groovy mid 70's a scruffy bunch of bras...
# 3          1  In the groovy mid 70's a scruffy bunch of bras...
# 4          1  In the groovy mid 70's a scruffy bunch of bras...
# ...      ...                                                ...
# 76918      1  The French Babbette appears at the modest hous...
# 76919      1  The French Babbette appears at the modest hous...
# 76920      1  The French Babbette appears at the modest hous...
# 76921      1  The French Babbette appears at the modest hous...
# 76922      1  The French Babbette appears at the modest hous...
#
#                                                 template  \
# 0      In the groovy mid 70's a scruffy bunch of bras...
# 1      In the groovy mid 70's a scruffy bunch of bras...
# 2      In the groovy mid 70's a scruffy bunch of bras...
# 3      In the groovy mid 70's a scruffy bunch of bras...
# 4      In the groovy mid 70's a scruffy bunch of bras...
# ...                                                  ...
# 76918  The French Babbette appears at the modest hous...
# 76919  The French Babbette appears at the modest hous...
# 76920  The French Babbette appears at the modest hous...
# 76921  The French Babbette appears at the modest hous...
# 76922  The French Babbette appears at the modest hous...
#
#                                                 original      name  \
# 0      In the groovy mid 70's a scruffy bunch of bras...  Jelander
# 1      In the groovy mid 70's a scruffy bunch of bras...  Christop
# 2      In the groovy mid 70's a scruffy bunch of bras...  Fabijano
# 3      In the groovy mid 70's a scruffy bunch of bras...    Mourão
# 4      In the groovy mid 70's a scruffy bunch of bras...   Kerigan
# ...                                                  ...       ...
# 76918  The French Babbette appears at the modest hous...  Waltruda
# 76919  The French Babbette appears at the modest hous...    Bağlan
# 76920  The French Babbette appears at the modest hous...   Shontae
# 76921  The French Babbette appears at the modest hous...  Lizzette
# 76922  The French Babbette appears at the modest hous...  Bilomira
#
#                country  template_id  prediction
# 0          Afghanistan         1406           1
# 1            Australia         1406           1
# 2              Belgium         1406           1
# 3               Brazil         1406           1
# 4               Canada         1406           1
# ...                ...          ...         ...
# 76918  The Netherlands         1910           1
# 76919           Turkey         1910           1
# 76920               UK         1910           1
# 76921              USA         1910           1
# 76922          Ukraine         1910           1
#
# [76923 rows x 8 columns]

# %%
dft
# Out:
#       label                                           template  \
# 0         0  !!! Spoiler alert!!! The point is, though, tha...
# 1         1  ' A Tale of Two Sisters ', or ' Janghwa, Hongr...
# 2         0  ' Airport 4 ' is basically a slopped together ...
# 3         0  ' Be With Me ' is almost the ultimate wallpape...
# 4         0  ' Book II ' isn't a film, it's a sermon. This ...
# ...     ...                                                ...
# 2823      0  without a doubt, one of the most racially prej...
# 2824      1  wow is all i could say i really loved the movi...
# 2825      0  wow, i just got one watching this. How CRAPPY ...
# 2826      1  yes barney is nonsense now but when i was a ki...
# 2827      1  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' A Tale of Two Sisters ', or ' Janghwa, Hongr...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Book II ' isn't a film, it's a sermon. This ...            4
# ...                                                 ...          ...
# 2823  without a doubt, one of the most racially prej...         2823
# 2824  wow is all i could say i really loved the movi...         2824
# 2825  wow, i just got one watching this. How CRAPPY ...         2825
# 2826  yes barney is nonsense now but when i was a ki...         2826
# 2827  you know I've seen a lot of crappy hong kong m...         2827
#
# [2828 rows x 4 columns]

# %% [markdown]
# ## Get Number of Discordant Pairs for Each Template
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
gb = df.groupby("template_id")
gb.count()
# Out:
#              label  mutant  template  original  name  country  prediction
# template_id
# 0               27      27        27        27    27       27          27
# 1               27      27        27        27    27       27          27
# 2               27      27        27        27    27       27          27
# 3               27      27        27        27    27       27          27
# 4               27      27        27        27    27       27          27
# ...            ...     ...       ...       ...   ...      ...         ...
# 2823            27      27        27        27    27       27          27
# 2824            27      27        27        27    27       27          27
# 2825            27      27        27        27    27       27          27
# 2826            27      27        27        27    27       27          27
# 2827            27      27        27        27    27       27          27
#
# [2828 rows x 7 columns]

# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "country"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if int(p) == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  8.580622911453247

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#       label                                           template  \
# 0         0  !!! Spoiler alert!!! The point is, though, tha...
# 1         1  ' A Tale of Two Sisters ', or ' Janghwa, Hongr...
# 2         0  ' Airport 4 ' is basically a slopped together ...
# 3         0  ' Be With Me ' is almost the ultimate wallpape...
# 4         0  ' Book II ' isn't a film, it's a sermon. This ...
# ...     ...                                                ...
# 2823      0  without a doubt, one of the most racially prej...
# 2824      1  wow is all i could say i really loved the movi...
# 2825      0  wow, i just got one watching this. How CRAPPY ...
# 2826      1  yes barney is nonsense now but when i was a ki...
# 2827      1  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id  \
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' A Tale of Two Sisters ', or ' Janghwa, Hongr...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Book II ' isn't a film, it's a sermon. This ...            4
# ...                                                 ...          ...
# 2823  without a doubt, one of the most racially prej...         2823
# 2824  wow is all i could say i really loved the movi...         2824
# 2825  wow, i just got one watching this. How CRAPPY ...         2825
# 2826  yes barney is nonsense now but when i was a ki...         2826
# 2827  you know I've seen a lot of crappy hong kong m...         2827
#
#                                          mutant_example  \
# 0     {'Afghanistan': '!!! Spoiler alert!!! The poin...
# 1     {'Afghanistan': '' A Tale of Two Sisters ', or...
# 2     {'Afghanistan': '' Airport 4 ' is basically a ...
# 3     {'Afghanistan': '' Be With Me ' is almost the ...
# 4     {'Afghanistan': '' Book II ' isn't a film, it'...
# ...                                                 ...
# 2823  {'Afghanistan': 'without a doubt, one of the m...
# 2824  {'Afghanistan': 'wow is all i could say i real...
# 2825  {'Afghanistan': 'wow, i just got one watching ...
# 2826  {'Afghanistan': 'yes barney is nonsense now bu...
# 2827  {'Afghanistan': 'you know I've seen a lot of c...
#
#                                  mutant_prediction_stat
# 0     {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...
# 1     {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...
# 2     {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...
# 3     {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...
# 4     {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...
# ...                                                 ...
# 2823  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...
# 2824  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...
# 2825  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...
# 2826  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...
# 2827  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...
#
# [2828 rows x 6 columns]

# %%
key
# Out:
# ['Afghanistan',
#  'Australia',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'Czech',
#  'Finland',
#  'Greece',
#  'Hungary',
#  'India',
#  'Iran',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Latvia',
#  'Norway',
#  'Poland',
#  'Romania',
#  'Slovenia',
#  'Somalia',
#  'Spain',
#  'Sweden',
#  'The Netherlands',
#  'Turkey',
#  'UK',
#  'USA',
#  'Ukraine']

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        already_processed = []
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    k = k1 + "-" + k2
                    if k1 > k2 :
                        k = k2 + "-" + k1
                    if k not in already_processed :
                        already_processed.append(k)

                        btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                        pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

#         double_counting_divider = len(key) * (len(key)-1)
#         dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting
        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#       label                                           template  \
# 0         0  !!! Spoiler alert!!! The point is, though, tha...
# 1         1  ' A Tale of Two Sisters ', or ' Janghwa, Hongr...
# 2         0  ' Airport 4 ' is basically a slopped together ...
# 3         0  ' Be With Me ' is almost the ultimate wallpape...
# 4         0  ' Book II ' isn't a film, it's a sermon. This ...
# ...     ...                                                ...
# 2823      0  without a doubt, one of the most racially prej...
# 2824      1  wow is all i could say i really loved the movi...
# 2825      0  wow, i just got one watching this. How CRAPPY ...
# 2826      1  yes barney is nonsense now but when i was a ki...
# 2827      1  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id  \
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' A Tale of Two Sisters ', or ' Janghwa, Hongr...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Book II ' isn't a film, it's a sermon. This ...            4
# ...                                                 ...          ...
# 2823  without a doubt, one of the most racially prej...         2823
# 2824  wow is all i could say i really loved the movi...         2824
# 2825  wow, i just got one watching this. How CRAPPY ...         2825
# 2826  yes barney is nonsense now but when i was a ki...         2826
# 2827  you know I've seen a lot of crappy hong kong m...         2827
#
#                                          mutant_example  \
# 0     {'Afghanistan': '!!! Spoiler alert!!! The poin...
# 1     {'Afghanistan': '' A Tale of Two Sisters ', or...
# 2     {'Afghanistan': '' Airport 4 ' is basically a ...
# 3     {'Afghanistan': '' Be With Me ' is almost the ...
# 4     {'Afghanistan': '' Book II ' isn't a film, it'...
# ...                                                 ...
# 2823  {'Afghanistan': 'without a doubt, one of the m...
# 2824  {'Afghanistan': 'wow is all i could say i real...
# 2825  {'Afghanistan': 'wow, i just got one watching ...
# 2826  {'Afghanistan': 'yes barney is nonsense now bu...
# 2827  {'Afghanistan': 'you know I've seen a lot of c...
#
#                                  mutant_prediction_stat  btc  possible_pair
# 0     {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...    0            351
# 1     {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...    0            351
# 2     {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...    0            351
# 3     {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...    0            351
# 4     {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...    0            351
# ...                                                 ...  ...            ...
# 2823  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...    0            351
# 2824  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...    0            351
# 2825  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...    0            351
# 2826  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...  126            351
# 2827  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...    0            351
#
# [2828 rows x 8 columns]

# %% [markdown]
# ### Number of Bias-Uncovering Test Case

# %%
int(dft["btc"].sum())
# Out:
# 6644

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.006542957113299319

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d
# Out:
#       label                                           template  \
# 120       1  <name> finally gives something besides his usu...
# 123       0  <name> had no other reason to make this film e...
# 265       0  A cut above from the usual straight to video a...
# 279       0  A group of 7 gold prospectors head into a mine...
# 403       0  As a documentary, this is laughable in a campy...
# ...     ...                                                ...
# 2746      1  You know you're watching softcore with the wro...
# 2750      0  [ as a new resolution for this year 2005, i de...
# 2760      1  i consider this movie as one of the most inter...
# 2814      1  toplines this ok comedy about an aging father ...
# 2826      1  yes barney is nonsense now but when i was a ki...
#
#                                                original  template_id  \
# 120   Jack Webb finally gives something besides his ...          120
# 123   Thomas Edison had no other reason to make this...          123
# 265   A cut above from the usual straight to video a...          265
# 279   A group of 7 gold prospectors head into a mine...          279
# 403   As a documentary, this is laughable in a campy...          403
# ...                                                 ...          ...
# 2746  You know you're watching softcore with the wro...         2746
# 2750  [ as a new resolution for this year 2005, i de...         2750
# 2760  i consider this movie as one of the most inter...         2760
# 2814  toplines this ok comedy about an aging father ...         2814
# 2826  yes barney is nonsense now but when i was a ki...         2826
#
#                                          mutant_example  \
# 120   {'Afghanistan': 'Jelander finally gives someth...
# 123   {'Afghanistan': 'Jelander had no other reason ...
# 265   {'Afghanistan': 'A cut above from the usual st...
# 279   {'Afghanistan': 'A group of 7 gold prospectors...
# 403   {'Afghanistan': 'As a documentary, this is lau...
# ...                                                 ...
# 2746  {'Afghanistan': 'You know you're watching soft...
# 2750  {'Afghanistan': '[ as a new resolution for thi...
# 2760  {'Afghanistan': 'i consider this movie as one ...
# 2814  {'Afghanistan': 'toplines this ok comedy about...
# 2826  {'Afghanistan': 'yes barney is nonsense now bu...
#
#                                  mutant_prediction_stat  btc  possible_pair
# 120   {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...  180            351
# 123   {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...   92            351
# 265   {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...   26            351
# 279   {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...  170            351
# 403   {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...   72            351
# ...                                                 ...  ...            ...
# 2746  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...  182            351
# 2750  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...   26            351
# 2760  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...   92            351
# 2814  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...   26            351
# 2826  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...  126            351
#
# [63 rows x 8 columns]

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "template"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#     label                                           template  \
# 0       1  You know you're watching softcore with the wro...
# 1       1  This must be one of the funniest Danish movies...
# 2       0  Well, how to start? I saw The Italian Job for ...
# 3       1  I was a bit surprised to see all of the hate c...
# 4       1  <name> finally gives something besides his usu...
# ..    ...                                                ...
# 58      0  The film quickly gets to a major chase scene w...
# 59      0  It was only a matter of time that a spoof woul...
# 60      0  I really wish Hollywood would come up with som...
# 61      0  I disagree 100% with the reviewer who disagree...
# 62      0  A cut above from the usual straight to video a...
#
#                                              original  template_id  \
# 0   You know you're watching softcore with the wro...         2746
# 1   This must be one of the funniest Danish movies...         2448
# 2   Well, how to start? I saw The Italian Job for ...         2585
# 3   I was a bit surprised to see all of the hate c...         1221
# 4   Jack Webb finally gives something besides his ...          120
# ..                                                ...          ...
# 58  The film quickly gets to a major chase scene w...         1958
# 59  It was only a matter of time that a spoof woul...         1455
# 60  I really wish Hollywood would come up with som...         1101
# 61  I disagree 100% with the reviewer who disagree...          841
# 62  A cut above from the usual straight to video a...          265
#
#                                        mutant_example  \
# 0   {'Afghanistan': 'You know you're watching soft...
# 1   {'Afghanistan': 'This must be one of the funni...
# 2   {'Afghanistan': 'Well, how to start? I saw The...
# 3   {'Afghanistan': 'I was a bit surprised to see ...
# 4   {'Afghanistan': 'Jelander finally gives someth...
# ..                                                ...
# 58  {'Afghanistan': 'The film quickly gets to a ma...
# 59  {'Afghanistan': 'It was only a matter of time ...
# 60  {'Afghanistan': 'I really wish Hollywood would...
# 61  {'Afghanistan': 'I disagree 100% with the revi...
# 62  {'Afghanistan': 'A cut above from the usual st...
#
#                                mutant_prediction_stat  btc  possible_pair
# 0   {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...  182            351
# 1   {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...  182            351
# 2   {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...  180            351
# 3   {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...  180            351
# 4   {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...  180            351
# ..                                                ...  ...            ...
# 58  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...   26            351
# 59  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...   26            351
# 60  {'Afghanistan': {'pos': 0, 'neg': 1}, 'Austral...   26            351
# 61  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...   26            351
# 62  {'Afghanistan': {'pos': 1, 'neg': 0}, 'Austral...   26            351
#
# [63 rows x 8 columns]

# %% [markdown]
# ### Get Data BTC for train and test

# %%
df
# Out:
#        label                                             mutant  \
# 0          1  In the groovy mid 70's a scruffy bunch of bras...
# 1          1  In the groovy mid 70's a scruffy bunch of bras...
# 2          1  In the groovy mid 70's a scruffy bunch of bras...
# 3          1  In the groovy mid 70's a scruffy bunch of bras...
# 4          1  In the groovy mid 70's a scruffy bunch of bras...
# ...      ...                                                ...
# 76918      1  The French Babbette appears at the modest hous...
# 76919      1  The French Babbette appears at the modest hous...
# 76920      1  The French Babbette appears at the modest hous...
# 76921      1  The French Babbette appears at the modest hous...
# 76922      1  The French Babbette appears at the modest hous...
#
#                                                 template  \
# 0      In the groovy mid 70's a scruffy bunch of bras...
# 1      In the groovy mid 70's a scruffy bunch of bras...
# 2      In the groovy mid 70's a scruffy bunch of bras...
# 3      In the groovy mid 70's a scruffy bunch of bras...
# 4      In the groovy mid 70's a scruffy bunch of bras...
# ...                                                  ...
# 76918  The French Babbette appears at the modest hous...
# 76919  The French Babbette appears at the modest hous...
# 76920  The French Babbette appears at the modest hous...
# 76921  The French Babbette appears at the modest hous...
# 76922  The French Babbette appears at the modest hous...
#
#                                                 original      name  \
# 0      In the groovy mid 70's a scruffy bunch of bras...  Jelander
# 1      In the groovy mid 70's a scruffy bunch of bras...  Christop
# 2      In the groovy mid 70's a scruffy bunch of bras...  Fabijano
# 3      In the groovy mid 70's a scruffy bunch of bras...    Mourão
# 4      In the groovy mid 70's a scruffy bunch of bras...   Kerigan
# ...                                                  ...       ...
# 76918  The French Babbette appears at the modest hous...  Waltruda
# 76919  The French Babbette appears at the modest hous...    Bağlan
# 76920  The French Babbette appears at the modest hous...   Shontae
# 76921  The French Babbette appears at the modest hous...  Lizzette
# 76922  The French Babbette appears at the modest hous...  Bilomira
#
#                country  template_id  prediction
# 0          Afghanistan         1406           1
# 1            Australia         1406           1
# 2              Belgium         1406           1
# 3               Brazil         1406           1
# 4               Canada         1406           1
# ...                ...          ...         ...
# 76918  The Netherlands         1910           1
# 76919           Turkey         1910           1
# 76920               UK         1910           1
# 76921              USA         1910           1
# 76922          Ukraine         1910           1
#
# [76923 rows x 8 columns]

# %%
template_that_produce_btc = d["template_id"].tolist()
# template_that_produce_btc

# %%
start = time.time()

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
original = []
label = []
for i in template_that_produce_btc: # only processing from template that produce BTC
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    already_processed = []
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                key = k1 + "-" + k2
                if k1 > k2 :
                    key = k2 + "-" + k1
                if key not in already_processed :
                    already_processed.append(key)
                    for m_1, p_1, i_1, t, o, l in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values, v1["original"].values,  v1["label"].values) :
                        for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                            if p_1 != p_2 : # only add discordant pairs
                                mutant_text_1.append(m_1)
                                prediction_1.append(p_1)
                                identifier_1.append(i_1)
                                mutant_text_2.append(m_2)
                                prediction_2.append(p_2)
                                identifier_2.append(i_2)
                                template.append(t)
                                label.append(l)
                                original.append(o)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  3.953542470932007

# %%
btc = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template, "original": original, "label": label})

btc
# Out:
#                                                mutant_1  \
# 0     You know you're watching softcore with the wro...
# 1     You know you're watching softcore with the wro...
# 2     You know you're watching softcore with the wro...
# 3     You know you're watching softcore with the wro...
# 4     You know you're watching softcore with the wro...
# ...                                                 ...
# 6639  A cut above from the usual straight to video a...
# 6640  A cut above from the usual straight to video a...
# 6641  A cut above from the usual straight to video a...
# 6642  A cut above from the usual straight to video a...
# 6643  A cut above from the usual straight to video a...
#
#                                                mutant_2  prediction_1  \
# 0     You know you're watching softcore with the wro...             0
# 1     You know you're watching softcore with the wro...             0
# 2     You know you're watching softcore with the wro...             0
# 3     You know you're watching softcore with the wro...             0
# 4     You know you're watching softcore with the wro...             0
# ...                                                 ...           ...
# 6639  A cut above from the usual straight to video a...             0
# 6640  A cut above from the usual straight to video a...             0
# 6641  A cut above from the usual straight to video a...             0
# 6642  A cut above from the usual straight to video a...             0
# 6643  A cut above from the usual straight to video a...             0
#
#       prediction_2 identifier_1     identifier_2  \
# 0                1  Afghanistan        Australia
# 1                1  Afghanistan           Brazil
# 2                1  Afghanistan           Greece
# 3                1  Afghanistan             Iran
# 4                1  Afghanistan            Italy
# ...            ...          ...              ...
# 6639             1        India  The Netherlands
# 6640             1        India           Turkey
# 6641             1        India               UK
# 6642             1        India              USA
# 6643             1        India          Ukraine
#
#                                                template  \
# 0     You know you're watching softcore with the wro...
# 1     You know you're watching softcore with the wro...
# 2     You know you're watching softcore with the wro...
# 3     You know you're watching softcore with the wro...
# 4     You know you're watching softcore with the wro...
# ...                                                 ...
# 6639  A cut above from the usual straight to video a...
# 6640  A cut above from the usual straight to video a...
# 6641  A cut above from the usual straight to video a...
# 6642  A cut above from the usual straight to video a...
# 6643  A cut above from the usual straight to video a...
#
#                                                original  label
# 0     You know you're watching softcore with the wro...      1
# 1     You know you're watching softcore with the wro...      1
# 2     You know you're watching softcore with the wro...      1
# 3     You know you're watching softcore with the wro...      1
# 4     You know you're watching softcore with the wro...      1
# ...                                                 ...    ...
# 6639  A cut above from the usual straight to video a...      0
# 6640  A cut above from the usual straight to video a...      0
# 6641  A cut above from the usual straight to video a...      0
# 6642  A cut above from the usual straight to video a...      0
# 6643  A cut above from the usual straight to video a...      0
#
# [6644 rows x 9 columns]

# %%
btc = btc.sample(frac=1, random_state=123)

texts = []
templates = []
labels = []
original = []
for index, rows in btc.iterrows():
    original.append(rows["original"])
    texts.append(rows["original"])
    texts.append(rows["mutant_1"])
    texts.append(rows["mutant_2"])
    templates.append(rows["template"])
    labels.append(rows["label"])

# %%
# texts

# %%
user_study = pd.DataFrame(data={"text":texts, "sentiment": None, "is_make_sense": None, "comment": None})
df_template = pd.DataFrame(data={"template":templates})
df_ori = pd.DataFrame(data={"label" :label, "original": original})

# %%
# df_ori.drop_duplicates().to_csv("btc_original.csv")

# %%
df_ori
# Out:
#       label                                           original
# 0         1  You know you're watching softcore with the wro...
# 1         1  I had watched this as a kid but, not being muc...
# 2         1  A group of 7 gold prospectors head into a mine...
# 3         1  I usually really like Lawrence and being in Au...
# 4         1  Following the advice of a friend, I got myself...
# ...     ...                                                ...
# 6639      0  This is about as pretentious a movie as a shal...
# 6640      0  Average adventure movie that took a serious st...
# 6641      0  I will not say much about this film, because t...
# 6642      0  The Paul Kersey of DEATH WISH 3 is very far re...
# 6643      0  The 80s were overrun by all those HALLOWEEN/ F...
#
# [6644 rows x 2 columns]

# %%
user_study
# Out:
#                                                     text sentiment  \
# 0      You know you're watching softcore with the wro...      None
# 1      You know you're watching softcore with the wro...      None
# 2      You know you're watching softcore with the wro...      None
# 3      I had watched this as a kid but, not being muc...      None
# 4      I had watched this as a kid but, not being muc...      None
# ...                                                  ...       ...
# 19927  The Paul Kersey of DEATH WISH 3 is very far re...      None
# 19928  The Paul Kersey of DEATH WISH 3 is very far re...      None
# 19929  The 80s were overrun by all those HALLOWEEN/ F...      None
# 19930  The 80s were overrun by all those HALLOWEEN/ F...      None
# 19931  The 80s were overrun by all those HALLOWEEN/ F...      None
#
#       is_make_sense comment
# 0              None    None
# 1              None    None
# 2              None    None
# 3              None    None
# 4              None    None
# ...             ...     ...
# 19927          None    None
# 19928          None    None
# 19929          None    None
# 19930          None    None
# 19931          None    None
#
# [19932 rows x 4 columns]

# %%
df_template
# Out:
#                                                template
# 0     You know you're watching softcore with the wro...
# 1     I had watched this as a kid but, not being muc...
# 2     A group of 7 gold prospectors head into a mine...
# 3     I usually really like <name> and being in Aust...
# 4     Following the advice of a friend, I got myself...
# ...                                                 ...
# 6639  This is about as pretentious a movie as a shal...
# 6640  Average adventure movie that took a serious st...
# 6641  I will not say much about this film, because t...
# 6642  The Paul Kersey of DEATH WISH 3 is very far re...
# 6643  The 80s were overrun by all those HALLOWEEN/ F...
#
# [6644 rows x 1 columns]

# %%
user_study[:1200].to_csv("../../user_study/TSE/country-unlabelled.csv")
# template.to_csv("template_gender.csv")

# %%
import os

base_dir = "../../data/btc/biasfinder/country/"

if not os.path.exists(base_dir) :
    os.makedirs(base_dir)

btc.to_csv(base_dir + "original.csv", index=None)

# %%
m1 = btc.iloc[:,[-1,0]]
m1 = m1.rename(columns={"mutant_1": "text"})
m2 = btc.iloc[:,[-1,1]]
m2 = m2.rename(columns={"mutant_2": "text"})

m1
# Out:
#        label                                               text
# 0          1  Luc Besson's first work is also his first fora...
# 1          1  Luc Besson's first work is also his first fora...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  Luc Besson's first work is also his first fora...
# 4          1  Luc Besson's first work is also his first fora...
# ...      ...                                                ...
# 57760      0  Imagine watching a slide show where the projec...
# 57761      0  Imagine watching a slide show where the projec...
# 57762      0  Imagine watching a slide show where the projec...
# 57763      1  This short deals with a severely critical writ...
# 57764      0  I watched this cooking show for a few times be...
#
# [57765 rows x 2 columns]

# %%
data = pd.concat([m1, m2])
data
# Out:
#        label                                               text
# 0          1  Luc Besson's first work is also his first fora...
# 1          1  Luc Besson's first work is also his first fora...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  Luc Besson's first work is also his first fora...
# 4          1  Luc Besson's first work is also his first fora...
# ...      ...                                                ...
# 57760      0  Imagine watching a slide show where the projec...
# 57761      0  Imagine watching a slide show where the projec...
# 57762      0  Imagine watching a slide show where the projec...
# 57763      1  This short deals with a severely critical writ...
# 57764      0  I watched this cooking show for a few times be...
#
# [115530 rows x 2 columns]

# %%
# data["text"] = data["text"].astype("category")
# data["text_id"] = data["text"].cat.codes
# data
import os

data_dir = base_dir + "full/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = data.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
test = data
test.to_csv(data_dir+ "test.csv", index=None, header=None, sep="\t")

# %%
unique_data = data.drop_duplicates().reset_index(drop=True)
unique_data
# Out:
#        label                                               text
# 0          1  Luc Besson's first work is also his first fora...
# 1          1  Luc Besson's first work is also his first fora...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  Luc Besson's first work is also his first fora...
# 4          1  Luc Besson's first work is also his first fora...
# ...      ...                                                ...
# 10313      0  Imagine watching a slide show where the projec...
# 10314      0  Imagine watching a slide show where the projec...
# 10315      0  Imagine watching a slide show where the projec...
# 10316      1  This short deals with a severely critical writ...
# 10317      0  I watched this cooking show for a few times be...
#
# [10318 rows x 2 columns]

# %%
unique_data[unique_data["label"] == 0]
# Out:
#        label                                               text
# 390        0  This has got to be the worst show I have ever ...
# 391        0  This has got to be the worst show I have ever ...
# 392        0  This has got to be the worst show I have ever ...
# 393        0  This has got to be the worst show I have ever ...
# 394        0  This has got to be the worst show I have ever ...
# ...      ...                                                ...
# 10312      0  Imagine watching a slide show where the projec...
# 10313      0  Imagine watching a slide show where the projec...
# 10314      0  Imagine watching a slide show where the projec...
# 10315      0  Imagine watching a slide show where the projec...
# 10317      0  I watched this cooking show for a few times be...
#
# [5438 rows x 2 columns]

# %%
import os

data_dir = base_dir + "unique/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = unique_data.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
test = unique_data
test.to_csv(data_dir+ "test.csv", index=None, header=None, sep="\t")

# %%
len(train)
# Out:
# 10318

# %% [markdown]
# #### Balanced Data for Training

# %%
df_0 = unique_data[unique_data["label"] == 0]
df_1 = unique_data[unique_data["label"] == 1]

# %%
print(len(df_0))
print(len(df_1))
# Out:
# 5438
# 4880

# %%
df_1 = df_1.sample(len(df_0), replace=True)
df_oversampled = pd.concat([df_0, df_1], axis=0)

# %%
df_oversampled
# Out:
#       label                                               text
# 390       0  This has got to be the worst show I have ever ...
# 391       0  This has got to be the worst show I have ever ...
# 392       0  This has got to be the worst show I have ever ...
# 393       0  This has got to be the worst show I have ever ...
# 394       0  This has got to be the worst show I have ever ...
# ...     ...                                                ...
# 7206      1  This must be one of the funniest Danish movies...
# 645       1  Um, hello .. Rainbow Brite .. the name alone i...
# 3756      1  This isn't the video nasty Night of the Demon ...
# 8987      1  Don't watch this movie expecting the Jane Aust...
# 988       1  I can hardly call this a great film but it is ...
#
# [10876 rows x 2 columns]

# %%
data_dir = base_dir + "unique/balanced/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = df_oversampled.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
