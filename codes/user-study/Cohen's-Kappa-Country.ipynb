# %% [markdown]
# # Cohen's Kappa and TPR Evaluation
#
# https://stats.stackexchange.com/questions/251165/cohens-kappa-with-three-categories-of-variable

# %%
import pandas as pd

# %% [markdown]
# ## Cohen's Kappa

# %%
folder = "../../user_study/TSE/"

fpath_1 = folder + "country-labelled-J.csv"
fpath_2 = folder + "country-labelled-SSQ.csv"
annotation_1 = pd.read_csv(fpath_1, encoding='mac_roman')
annotation_2 = pd.read_csv(fpath_2, encoding='mac_roman')

# %%
annotation_1
# Out:
#       Unnamed: 0                                               text sentiment  \
# 0              0  You know you're watching softcore with the wro...  Negative
# 1              1  You know you're watching softcore with the wro...  Negative
# 2              2  You know you're watching softcore with the wro...  Negative
# 3              3  I had watched this as a kid but, not being muc...  Negative
# 4              4  I had watched this as a kid but, not being muc...  Negative
# ...          ...                                                ...       ...
# 1195        1195  I was a bit surprised to see all of the hate c...  Positive
# 1196        1196  I was a bit surprised to see all of the hate c...  Positive
# 1197        1197  I was a bit surprised to see all of the hate c...  Positive
# 1198        1198  I was a bit surprised to see all of the hate c...  Positive
# 1199        1199  I was a bit surprised to see all of the hate c...  Positive
#
#      is_make_sense comment
# 0              Yes     NaN
# 1              Yes     NaN
# 2              Yes     NaN
# 3              Yes     NaN
# 4              Yes     NaN
# ...            ...     ...
# 1195           Yes     NaN
# 1196           Yes     NaN
# 1197           Yes     NaN
# 1198           Yes     NaN
# 1199           Yes     NaN
#
# [1200 rows x 5 columns]

# %%
annotation_2
# Out:
#                                                    text sentiment  \
# 0     You know you're watching softcore with the wro...  Negative
# 1     You know you're watching softcore with the wro...  Negative
# 2     You know you're watching softcore with the wro...  Negative
# 3     I had watched this as a kid but, not being muc...  Negative
# 4     I had watched this as a kid but, not being muc...  Negative
# ...                                                 ...       ...
# 1195  I was a bit surprised to see all of the hate c...  Positive
# 1196  I was a bit surprised to see all of the hate c...  Positive
# 1197  I was a bit surprised to see all of the hate c...  Positive
# 1198  I was a bit surprised to see all of the hate c...  Positive
# 1199  I was a bit surprised to see all of the hate c...  Positive
#
#      is_make_sense                                            comment
# 0              Yes                                                NaN
# 1              Yes                                                NaN
# 2              Yes                                                NaN
# 3              Yes                                                NaN
# 4               No  The name 'Kerigan' is a female name, disagreei...
# ...            ...                                                ...
# 1195            No  The name 'Kerigan' is a female name, disagreei...
# 1196           Yes                                                NaN
# 1197           Yes                                                NaN
# 1198           Yes                                                NaN
# 1199           Yes                                                NaN
#
# [1200 rows x 4 columns]

# %%
df1 = annotation_1
df2 = annotation_2

# %% [markdown]
# ### Preprocessing

# %%
df1.groupby("sentiment").count()
# Out:
#            Unnamed: 0  text  is_make_sense  comment
# sentiment
# Negative          705   705            705       29
# Not sure          144   144            144        0
# Positive          336   336            336       10
# Positive           15    15             15        0

# %%
df1["sentiment"] = df1["sentiment"].replace("Not sure", "Neutral") 
df1["sentiment"] = df1["sentiment"].replace("Positive ", "Positive") 
df1.groupby("sentiment").count()
# Out:
#            Unnamed: 0  text  is_make_sense  comment
# sentiment
# Negative          705   705            705       29
# Neutral           144   144            144        0
# Positive          351   351            351       10

# %%
df2.groupby("sentiment").count()
# Out:
#            text  is_make_sense  comment
# sentiment
# Negative    603            603      129
# Neutral      24             24        7
# Positive    573            573      145

# %%
# df2["sentiment"] = df2["sentiment"].replace("neutral", "Neutral") 
# df2.groupby("sentiment").count()

# %%
df1[df1["sentiment"] == "Neutral"]
# Out:
#       Unnamed: 0                                               text sentiment  \
# 24            24  Thomas Edison had no other reason to make this...   Neutral
# 25            25  ÔªøFrancesco had no other reason to make this ...   Neutral
# 26            26  Theoden had no other reason to make this film ...   Neutral
# 81            81  It's a kinder, gentler Cyborg movie with a lov...   Neutral
# 82            82  It's a kinder, gentler Cyborg movie with a lov...   Neutral
# ...          ...                                                ...       ...
# 1105        1105  This goodguyvstheeviltyrant story, set in 19th...   Neutral
# 1106        1106  This goodguyvstheeviltyrant story, set in 19th...   Neutral
# 1164        1164  This goodguyvstheeviltyrant story, set in 19th...   Neutral
# 1165        1165  This goodguyvstheeviltyrant story, set in 19th...   Neutral
# 1166        1166  This goodguyvstheeviltyrant story, set in 19th...   Neutral
#
#      is_make_sense comment
# 24             Yes     NaN
# 25             Yes     NaN
# 26             Yes     NaN
# 81             Yes     NaN
# 82             Yes     NaN
# ...            ...     ...
# 1105           Yes     NaN
# 1106           Yes     NaN
# 1164           Yes     NaN
# 1165           Yes     NaN
# 1166           Yes     NaN
#
# [144 rows x 5 columns]

# %%
df2[df2["sentiment"] == "Neutral"].head()
# Out:
#                                                   text sentiment  \
# 192  In the spirit of the Great Space Coaster, but ...   Neutral
# 193  In the spirit of the Great Space Coaster, but ...   Neutral
# 194  In the spirit of the Great Space Coaster, but ...   Neutral
# 231  In the spirit of the Great Space Coaster, but ...   Neutral
# 232  In the spirit of the Great Space Coaster, but ...   Neutral
#
#     is_make_sense                         comment
# 192           Yes                             NaN
# 193           Yes  The name 'Kotsos' is a surname
# 194           Yes                             NaN
# 231           Yes                             NaN
# 232        Unsure     Not sure of the name gender

# %%
df2[df2["is_make_sense"] == "No"]
# Out:
#                                                    text sentiment  \
# 4     I had watched this as a kid but, not being muc...  Negative
# 15    yes barney is nonsense now but when i was a ki...  Positive
# 16    yes barney is nonsense now but when i was a ki...  Positive
# 17    yes barney is nonsense now but when i was a ki...  Positive
# 43    The Deer Hunter's success with critics and pub...  Negative
# ...                                                 ...       ...
# 1167  yes barney is nonsense now but when i was a ki...  Positive
# 1168  yes barney is nonsense now but when i was a ki...  Positive
# 1169  yes barney is nonsense now but when i was a ki...  Positive
# 1186  This must be one of the funniest Danish movies...  Positive
# 1195  I was a bit surprised to see all of the hate c...  Positive
#
#      is_make_sense                                            comment
# 4               No  The name 'Kerigan' is a female name, disagreei...
# 15              No  The name 'barney' is a male name, disagreeing ...
# 16              No  The name 'barney' is a male name, disagreeing ...
# 17              No  The name 'barney' is a male name, disagreeing ...
# 43              No  The name 'Jelander' is a female name, disagree...
# ...            ...                                                ...
# 1167            No  The name 'barney' is a male name, disagreeing ...
# 1168            No  The name 'barney' is a male name, disagreeing ...
# 1169            No  The name 'barney' is a male name, disagreeing ...
# 1186            No  The name 'Jelander' is a female name, disagree...
# 1195            No  The name 'Kerigan' is a female name, disagreei...
#
# [98 rows x 4 columns]

# %%
# categories
cat = {"Positive", "Negative", "Neutral"}
# matrix
mat = {}

for c1 in cat :
    mat[c1] = {}
    for c2 in cat :
        mat[c1][c2] = 0

for i in range(len(df1)) :
    for c1 in cat :
        for c2 in cat :
            if df1["sentiment"][i] == c1 and df2["sentiment"][i] == c2 :
                mat[c1][c2] += 1

# %%
mat
# Out:
# {'Neutral': {'Neutral': 24, 'Negative': 90, 'Positive': 30},
#  'Negative': {'Neutral': 0, 'Negative': 510, 'Positive': 195},
#  'Positive': {'Neutral': 0, 'Negative': 3, 'Positive': 348}}

# %%
total = 0
agreement = 0
for c1 in cat :
    for c2 in cat :
        total += mat[c1][c2]
        if c1 == c2 :
            agreement += mat[c1][c2]

print("Total: ", total)
print("Agreement: ", agreement)
# Out:
# Total:  1200
# Agreement:  882

# %%
ef1 = {}
for c1 in cat :
    _ef1 = 0
    for c2 in cat :
        _ef1 += mat[c1][c2]
    ef1[c1] = _ef1

ef1
# Out:
# {'Neutral': 144, 'Negative': 705, 'Positive': 351}

# %%
ef2 = {}
for c1 in cat :
    _ef2 = 0
    for c2 in cat :
        _ef2 += mat[c2][c1]
    ef2[c1] = _ef2
ef2
# Out:
# {'Neutral': 24, 'Negative': 603, 'Positive': 573}

# %%
ef = 0
for c in cat :
    ef += ef1[c] * ef2[c] / total
ef
# Out:
# 524.745

# %%
ck = (agreement - ef)/(total - ef)
print("Cohen's Kappa: ",  ck)
# Out:
# Cohen's Kappa:  0.5290667969878046

# %% [markdown]
# # TPR

# %%
df1["mod"] = [x % 3 for x in list(df1.index)]
df2["mod"] = [x % 3 for x in list(df2.index)]

# %% [markdown]
# ### Separate data into male and female

# %%
dff1 = df1[df1["mod"] == 1].reset_index()
dfm1 = df1[df1["mod"] == 2].reset_index()

dff1
# Out:
#      index  Unnamed: 0                                               text  \
# 0        1           1  You know you're watching softcore with the wro...
# 1        4           4  I had watched this as a kid but, not being muc...
# 2        7           7  A group of 7 gold prospectors head into a mine...
# 3       10          10  I usually really like Karstein and being in Au...
# 4       13          13  Following the advice of a friend, I got myself...
# ..     ...         ...                                                ...
# 395   1186        1186  This must be one of the funniest Danish movies...
# 396   1189        1189  Chuck Jones's ' Odorable Kitty ' is the cartoo...
# 397   1192        1192  That distinction has to go to THE DUNGEON OF H...
# 398   1195        1195  I was a bit surprised to see all of the hate c...
# 399   1198        1198  I was a bit surprised to see all of the hate c...
#
#     sentiment is_make_sense  \
# 0    Negative           Yes
# 1    Negative           Yes
# 2    Negative            No
# 3    Negative           Yes
# 4    Positive           Yes
# ..        ...           ...
# 395  Positive           Yes
# 396  Positive           Yes
# 397  Negative           Yes
# 398  Positive           Yes
# 399  Positive           Yes
#
#                                                comment  mod
# 0                                                  NaN    1
# 1                                                  NaN    1
# 2    "Jelander" wasnít mentioned for the USC studen...    1
# 3                                                  NaN    1
# 4                                                  NaN    1
# ..                                                 ...  ...
# 395                                                NaN    1
# 396                                                NaN    1
# 397                                                NaN    1
# 398                                                NaN    1
# 399                                                NaN    1
#
# [400 rows x 7 columns]

# %%
dff2 = df2[df2["mod"] == 1].reset_index()
dfm2 = df2[df2["mod"] == 2].reset_index()

dff2
# Out:
#      index                                               text sentiment  \
# 0        1  You know you're watching softcore with the wro...  Negative
# 1        4  I had watched this as a kid but, not being muc...  Negative
# 2        7  A group of 7 gold prospectors head into a mine...  Negative
# 3       10  I usually really like Karstein and being in Au...  Negative
# 4       13  Following the advice of a friend, I got myself...  Positive
# ..     ...                                                ...       ...
# 395   1186  This must be one of the funniest Danish movies...  Positive
# 396   1189  Chuck Jones's ' Odorable Kitty ' is the cartoo...  Positive
# 397   1192  That distinction has to go to THE DUNGEON OF H...  Negative
# 398   1195  I was a bit surprised to see all of the hate c...  Positive
# 399   1198  I was a bit surprised to see all of the hate c...  Positive
#
#     is_make_sense                                            comment  mod
# 0             Yes                                                NaN    1
# 1              No  The name 'Kerigan' is a female name, disagreei...    1
# 2             Yes                                                NaN    1
# 3             Yes                   The name 'Karstein' is a surname    1
# 4             Yes                                                NaN    1
# ..            ...                                                ...  ...
# 395            No  The name 'Jelander' is a female name, disagree...    1
# 396           Yes                                                NaN    1
# 397           Yes                                                NaN    1
# 398            No  The name 'Kerigan' is a female name, disagreei...    1
# 399           Yes                                                NaN    1
#
# [400 rows x 6 columns]

# %% [markdown]
# ### TPR from 1st labeller

# %%
not_make_sense = 0
coherent = 0

for i in range(len(dff1)) :
    if dff1["is_make_sense"][i] == "Yes" and dfm1["is_make_sense"][i] == "Yes":
        if dff1["sentiment"][i] == dfm1["sentiment"][i] :
            coherent += 1
    else :
        not_make_sense += 1

# %%
print("TPR 1st labeller: ", coherent/len(dff1))
print("Not make sense: ", not_make_sense)
# Out:
# TPR 1st labeller:  0.9575
# Not make sense:  17

# %% [markdown]
# ### TPR from 2nd labeller

# %%
not_make_sense = 0
coherent = 0

for i in range(len(dff2)) :
    if dff2["is_make_sense"][i] == "Yes" and dfm2["is_make_sense"][i] == "Yes":
        if dff2["sentiment"][i] == dfm2["sentiment"][i] :
            coherent += 1
    else :
        not_make_sense += 1

# %%
print("TPR 2nd labeller: ", coherent/len(dff2))
print("Not make sense: ", not_make_sense)
# Out:
# TPR 2nd labeller:  0.65
# Not make sense:  140
