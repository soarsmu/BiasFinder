# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# #### Text Preprocessing

# %%
from utils import preprocessText

# %%
text = "And one only, in my opinion.<br /><br />That reason is Margaret Leighton. She is a wonderful actress, on-stage as well as on the screen. We have few chances to see her, though. I think that\'s especially true in the United States.<br /><br />Here she plays a sympathetic role. Not only that but she is also very pretty and meant to be something of a bombshell.<br /><br />Walter Pigeon does not hold up the tradition of Drummond performers. He is always reliable but he's not much fun. He's not a rascal or a knave. Consequently, this seemed to me a talky endeavor with little action or suspense. But check it out for Leighton."

# %%
# combineText(splitter.split(text))
preprocessText(text)
# Out:
# "And one only, in my opinion. That reason is Margaret Leighton. She is a wonderful actress, onstage as well as on the screen. We have few chances to see her, though. I think that's especially true in the United States. Here she plays a sympathetic role. Not only that but she is also very pretty and meant to be something of a bombshell. Walter Pigeon does not hold up the tradition of Drummond performers. He is always reliable but he's not much fun. He's not a rascal or a knave. Consequently, this seemed to me a talky endeavor with little action or suspense. But check it out for Leighton."

# %% [markdown]
# #### Mutant Generation

# %%
import pandas as pd
gaw = pd.read_csv("../data/gender_associated_word/masculine-feminine-person.txt")

# %%
gaw
# Out:
#       masculine     feminine
# 0           boy         girl
# 1       brother       sister
# 2         daddy        mummy
# 3           man        woman
# 4        father       mother
# 5   grandfather  grandmother
# 6       husband         wife
# 7           son     daughter
# 8         uncle         aunt
# 9           guy         girl
# 10          dad          mom
# 11    gentleman         lady
# 12         lord         lady

# %%
import spacy
import pandas as pd

from utils import preprocessText

from Entity import Entity
from CustomToken import CustomToken as Token
from Coreference import Coreference
from MutantGeneration import MutantGeneration

# %%
# the main reference is a person name
text = "When Nathaniel Kahn embarked into this voyage, he hardly knew who his father really was. By the end of the film, he found him and comes to terms with the strange life he lived as a child. Louis Kahn was the father."

# the person name is a substring of the main reference and it has a salutation
# text = "Meek and mild Edward G. Robinson (as Wilbert Winkle) decides to quit his bank job and do what he wants, open a ”fix-it” repair shop behind his house. Mr. Robinson is married, but childless; he has befriended local orphanage resident Ted Donaldson (as Barry)"
# text = "I'm sorry, but \" Star Wars Episode 1 \" did not do any justice to Natalie Portman's talent ( and undeniable cuteness). She was entirely underused as Queen Amidala, and when she was used, her makeup was frighteningly terrible. For \" Anywhere But Here, \" she sheds her godawful makeup and she acts normally. And not only can she act good, she looks good doing it. I'm a bit older than she ( she's only 18), and I have little or no chance of meeting her, but hey, a guy is allowed to dream, right? Even though Susan Sarandon does take a good turn in this movie, the film belongs entirely to Portman. I've been a watcher of Portman's since \" Beautiful Girls \" ( where she was younger, but just as cute). There's big things for her in the futureI can see it."
# text = "In this film I prefer Deacon Frost. He's so sexy! I love his glacial eyes! I like Stephen Dorff and the vampires, so I went to see it. I hope to see a gothic film with him. \" Blade \" it was very \" about the future \". If vampires had been real, I would be turned by Frost!"
# text = "Mr. Bean has shaped the face of British TV comedy. He has proved that you do not need wicked words or wit, a massive budget, a great deal of intelligence or even any intelligence to make something brilliant. And Mr. Bean is one of those characters who you just can't forget."

# the main reference is a gender associated word
#   'When Amanda embarked into this voyage, she hardly knew who her father really was. By the end of the film, she found her and comes to terms with the strange life she lived as a child. Amanda was the father.'],
#  ['When <name> embarked into this voyage, <pro-he> hardly knew who <pro-his> father really was. By the end of the film, <pro-he> found <pro-him> and comes to terms with the strange life <pro-he> lived as a child. <name> was the father.',
#   'When <name> embarked into this voyage, <pro-he> hardly knew who <pro-his> father really was. By the end of the film, <pro-he> found <pro-him> and comes to terms with the strange life <pro-he> lived as a child. <name> was the father.',
#   'When <name> embarked into this voyage, <pro-he> hardly knew who <pro-his> father really was. By the end of the film, <pro-he> found <pro-him> and comes to terms with the strange life <pro-he> lived as a child. <name> was the father.',
#   'When <name> embarked into this voyage, <pro-he> hardly knew who <pro-his> father really was. By the end of the film, <pro-he> found <pro-him> and comes to terms with the strange life <pro-he> lived as a child. <name> was the father.'],
#  ['Alonzo', 'Adam', 'Ebony', 'Amanda'],
#  ['name', 'name', 'name', 'name'],
#  ['male', 'male', 'female', 'female'],
#  ['Trial', 'Trial', 'Trial', 'Trial'])

# %%
# m.generateMaleMutant()

# %%
# m.generateFemaleMutant()

# %%
if m.isHavingOnePersonReference() :
    print(m.getPersonReference())
    print(m.getPersonEntities())
#     print(m.generateMutant())
# Out:
# himself: ['himself', 'He', 'his', 'he', 'his', 'JARRETT', 'HIMSELF', 'HIS', 'his', 'Jarrett', 'He', 'he', 'him']
# ['Jarrett', 'CODY POWERS', 'Jarrets']

# %% [markdown]
# #### Preparing Mutant Template
#
# Please refer to `codes/mutant-generation.ipynb`to know the detail in getting the template.

# %%
dfm = pd.read_csv("../data/imdb_mutant/male/test.csv", header=None, sep="\t", names=["label", "mutant", "template"])
dff = pd.read_csv("../data/imdb_mutant/female/test.csv", header=None, sep="\t", names=["label", "mutant", "template"])

# %%
dfm
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 138995      1  First, I'm a huge Justin fan. I grew up knowin...
# 138996      1  First, I'm a huge Terrence fan. I grew up know...
# 138997      1  First, I'm a huge Roger fan. I grew up knowing...
# 138998      1  First, I'm a huge Torrance fan. I grew up know...
# 138999      1  First, I'm a huge Ryan fan. I grew up knowing ...
#
#                                                  template
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 138995  First, I'm a huge Buddy Holly fan. I grew up k...
# 138996  First, I'm a huge Buddy Holly fan. I grew up k...
# 138997  First, I'm a huge Buddy Holly fan. I grew up k...
# 138998  First, I'm a huge Buddy Holly fan. I grew up k...
# 138999  First, I'm a huge Buddy Holly fan. I grew up k...
#
# [139000 rows x 3 columns]

# %%
df = pd.concat([dfm, dff])

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 138995      1  First, I'm a huge Melanie fan. I grew up knowi...
# 138996      1  First, I'm a huge Tanisha fan. I grew up knowi...
# 138997      1  First, I'm a huge Nancy fan. I grew up knowing...
# 138998      1  First, I'm a huge Tia fan. I grew up knowing w...
# 138999      1  First, I'm a huge Stephanie fan. I grew up kno...
#
#                                                  template
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 138995  First, I'm a huge Buddy Holly fan. I grew up k...
# 138996  First, I'm a huge Buddy Holly fan. I grew up k...
# 138997  First, I'm a huge Buddy Holly fan. I grew up k...
# 138998  First, I'm a huge Buddy Holly fan. I grew up k...
# 138999  First, I'm a huge Buddy Holly fan. I grew up k...
#
# [278000 rows x 3 columns]

# %%
df["template"] = df["template"].astype("category")
df["template_id"] = df["template"].cat.codes

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template
# template_id
# 0               40      40        40
# 1               40      40        40
# 2               40      40        40
# 3               40      40        40
# 4               40      40        40
# ...            ...     ...       ...
# 6893            40      40        40
# 6894            40      40        40
# 6895            40      40        40
# 6896            40      40        40
# 6897            40      40        40
#
# [6898 rows x 3 columns]

# %% [markdown]
# we have 6898 templates with 40 mutants for each template

# %%
dt = df[["label", "template"]]

# %%
dt = dt.drop_duplicates().reset_index(drop=True)
dt
# Out:
#       label                                           template
# 0         1  I have only see three episodes of Hack, starri...
# 1         1  In the groovy mid 70's a scruffy bunch of bras...
# 2         1  This must have been one of Chaplin's most ambi...
# 3         1  The debut that plucked from obscurity one of t...
# 4         1  There is really no way to compare this motion ...
# ...     ...                                                ...
# 6893      1  I heard they were going to remake this French ...
# 6894      1  Well, the movie did turn out a lot better than...
# 6895      0  In this film, there is a loose plot of a man (...
# 6896      1  The French Babbette appears at the modest hous...
# 6897      1  First, I'm a huge Buddy Holly fan. I grew up k...
#
# [6898 rows x 2 columns]

# %%
import time
start = time.time()

originals = []
templates = []
mutants = []
labels = []
identifiers = []
types = []
genders = []
countries = []

for index, row in dt.iterrows():
    label = row['label']
    text = row['template']
    text = preprocessText(text)
    mg = MutantGeneration(text)
    
    _mutants, _templates, _identifiers, _types, _genders, _countries = mg.generateMutant()
        
    if len(_mutants) > 0:    
        originals.extend([text] * len(_mutants))
        mutants.extend(_mutants)
        templates.extend(_templates)
        labels.extend([label] * len(_mutants))
        identifiers.extend(_identifiers)
        types.extend(_types)
        genders.extend(_genders)
        countries.extend(_countries)

end = time.time()
print("Execution Time: ", end-start)
# Out:
# Execution Time:  1664.2969834804535

# %%
print(len(templates))
print(len(mutants))
# Out:
# 986752
# 986752

# %%
dmutant = pd.DataFrame(data={"label": labels, "mutant": mutants, "template": templates, "original": originals, "identifier": identifiers, "type": types, "gender": genders, "country": countries})
dmutant
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 986747      1  Well, the movie did turn out a lot better than...
# 986748      1  Well, the movie did turn out a lot better than...
# 986749      1  Well, the movie did turn out a lot better than...
# 986750      1  Well, the movie did turn out a lot better than...
# 986751      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 986747  Well, the movie did turn out a lot better than...
# 986748  Well, the movie did turn out a lot better than...
# 986749  Well, the movie did turn out a lot better than...
# 986750  Well, the movie did turn out a lot better than...
# 986751  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...       Roen  name
# 1       I have only see three episodes of Hack, starri...       Jeet  name
# 2       I have only see three episodes of Hack, starri...      Hagen  name
# 3       I have only see three episodes of Hack, starri...     Willow  name
# 4       I have only see three episodes of Hack, starri...      Belal  name
# ...                                                   ...        ...   ...
# 986747  Well, the movie did turn out a lot better than...       Dódi  name
# 986748  Well, the movie did turn out a lot better than...     Iboyka  name
# 986749  Well, the movie did turn out a lot better than...     Zsófia  name
# 986750  Well, the movie did turn out a lot better than...      Ágota  name
# 986751  Well, the movie did turn out a lot better than...      Alexa  name
#
#         gender  country
# 0         male       UK
# 1         male       UK
# 2         male       UK
# 3         male       UK
# 4         male       UK
# ...        ...      ...
# 986747  female  Hungary
# 986748  female  Hungary
# 986749  female  Hungary
# 986750  female  Hungary
# 986751  female  Hungary
#
# [986752 rows x 8 columns]

# %%
import os

dirname = "../data/gc_imdb/"
# dirname = "../data/imdb_using_eec_name/"

if not os.path.exists(dirname) :
    os.makedirs(dirname)

dmutant.to_csv(dirname + "test.csv", index=None, header=None, sep="\t")

dmutant_shuffled = dmutant.sample(frac=1, random_state=123).reset_index(drop=True)
dmutant_shuffled.to_csv(dirname + "train.csv", index=None, header=None, sep="\t")

# %%
dmutant
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 140837      1  Well, the movie did turn out a lot better than...
# 140838      1  Well, the movie did turn out a lot better than...
# 140839      1  Well, the movie did turn out a lot better than...
# 140840      1  Well, the movie did turn out a lot better than...
# 140841      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 140837  Well, the movie did turn out a lot better than...
# 140838  Well, the movie did turn out a lot better than...
# 140839  Well, the movie did turn out a lot better than...
# 140840  Well, the movie did turn out a lot better than...
# 140841  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...     Alonzo  name
# 1       I have only see three episodes of Hack, starri...       Adam  name
# 2       I have only see three episodes of Hack, starri...   Alphonse  name
# 3       I have only see three episodes of Hack, starri...       Alan  name
# 4       I have only see three episodes of Hack, starri...    Darnell  name
# ...                                                   ...        ...   ...
# 140837  Well, the movie did turn out a lot better than...    Melanie  name
# 140838  Well, the movie did turn out a lot better than...    Tanisha  name
# 140839  Well, the movie did turn out a lot better than...      Nancy  name
# 140840  Well, the movie did turn out a lot better than...        Tia  name
# 140841  Well, the movie did turn out a lot better than...  Stephanie  name
#
#         gender            country
# 0         male   African American
# 1         male   African American
# 2         male   African American
# 3         male   African American
# 4         male   African American
# ...        ...                ...
# 140837  female  European American
# 140838  female  European American
# 140839  female  European American
# 140840  female  European American
# 140841  female  European American
#
# [140842 rows x 8 columns]

# %%
import pandas as pd

# dirname = "../data/gc_imdb/"
dirname = "../data/imdb_using_eec_name/"
dmutant = pd.read_csv(dirname + "test.csv", sep="\t", names=["label", "mutant", "template", "original", "identifier", "type", "gender", "country"])

# %%
dmutant
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 140837      1  Well, the movie did turn out a lot better than...
# 140838      1  Well, the movie did turn out a lot better than...
# 140839      1  Well, the movie did turn out a lot better than...
# 140840      1  Well, the movie did turn out a lot better than...
# 140841      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 140837  Well, the movie did turn out a lot better than...
# 140838  Well, the movie did turn out a lot better than...
# 140839  Well, the movie did turn out a lot better than...
# 140840  Well, the movie did turn out a lot better than...
# 140841  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...     Alonzo  name
# 1       I have only see three episodes of Hack, starri...       Adam  name
# 2       I have only see three episodes of Hack, starri...   Alphonse  name
# 3       I have only see three episodes of Hack, starri...       Alan  name
# 4       I have only see three episodes of Hack, starri...    Darnell  name
# ...                                                   ...        ...   ...
# 140837  Well, the movie did turn out a lot better than...    Melanie  name
# 140838  Well, the movie did turn out a lot better than...    Tanisha  name
# 140839  Well, the movie did turn out a lot better than...      Nancy  name
# 140840  Well, the movie did turn out a lot better than...        Tia  name
# 140841  Well, the movie did turn out a lot better than...  Stephanie  name
#
#         gender            country
# 0         male   African American
# 1         male   African American
# 2         male   African American
# 3         male   African American
# 4         male   African American
# ...        ...                ...
# 140837  female  European American
# 140838  female  European American
# 140839  female  European American
# 140840  female  European American
# 140841  female  European American
#
# [140842 rows x 8 columns]

# %%
dmutant["template"] = dmutant["template"].astype("category")
dmutant["template_id"] = dmutant["template"].cat.codes

# %%
dmutant
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 140837      1  Well, the movie did turn out a lot better than...
# 140838      1  Well, the movie did turn out a lot better than...
# 140839      1  Well, the movie did turn out a lot better than...
# 140840      1  Well, the movie did turn out a lot better than...
# 140841      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 140837  Well, the movie did turn out a lot better than...
# 140838  Well, the movie did turn out a lot better than...
# 140839  Well, the movie did turn out a lot better than...
# 140840  Well, the movie did turn out a lot better than...
# 140841  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...     Alonzo  name
# 1       I have only see three episodes of Hack, starri...       Adam  name
# 2       I have only see three episodes of Hack, starri...   Alphonse  name
# 3       I have only see three episodes of Hack, starri...       Alan  name
# 4       I have only see three episodes of Hack, starri...    Darnell  name
# ...                                                   ...        ...   ...
# 140837  Well, the movie did turn out a lot better than...    Melanie  name
# 140838  Well, the movie did turn out a lot better than...    Tanisha  name
# 140839  Well, the movie did turn out a lot better than...      Nancy  name
# 140840  Well, the movie did turn out a lot better than...        Tia  name
# 140841  Well, the movie did turn out a lot better than...  Stephanie  name
#
#         gender            country  template_id
# 0         male   African American         1218
# 1         male   African American         1218
# 2         male   African American         1218
# 3         male   African American         1218
# 4         male   African American         1218
# ...        ...                ...          ...
# 140837  female  European American         3417
# 140838  female  European American         3417
# 140839  female  European American         3417
# 140840  female  European American         3417
# 140841  female  European American         3417
#
# [140842 rows x 9 columns]

# %%
dmutant.groupby("template_id").count()
# Out:
#              label  mutant  template  original  identifier  type  gender  \
# template_id
# 0               40      40        40        40          40    40      40
# 1               26      26        26        26          26    26      26
# 2               40      40        40        40          40    40      40
# 3               40      40        40        40          40    40      40
# 4               40      40        40        40          40    40      40
# ...            ...     ...       ...       ...         ...   ...     ...
# 3725            40      40        40        40          40    40      40
# 3726            40      40        40        40          40    40      40
# 3727            40      40        40        40          40    40      40
# 3728            26      26        26        26          26    26      26
# 3729            40      40        40        40          40    40      40
#
#              country
# template_id
# 0                 40
# 1                  0
# 2                 40
# 3                 40
# 4                 40
# ...              ...
# 3725              40
# 3726              40
# 3727              40
# 3728               0
# 3729              40
#
# [3730 rows x 8 columns]

# %%
dmutant.groupby("type").count()
# Out:
#                       label  mutant  template  original  identifier  gender  \
# type
# gaw                   15158   15158     15158     15158       15158   15158
# name                 121880  121880    121880    121880      121880  121880
# person-pronoun-gaw      364     364       364       364         364     364
# person-pronoun-name     920     920       920       920         920     920
# person-pronoun-sltn      40      40        40        40          40      40
# sltn                   2480    2480      2480      2480        2480    2480
#
#                      country  template_id
# type
# gaw                        0        15158
# name                  121880       121880
# person-pronoun-gaw         0          364
# person-pronoun-name      920          920
# person-pronoun-sltn       40           40
# sltn                    2480         2480

# %%
NAME = "name"
SALUTATION = "sltn"
GAW = "gaw"
P = "person-pronoun-"
PNAME = P + NAME
PGAW = P + GAW
PSALUTATION = P + SALUTATION

# %%
name = dmutant.groupby("type").get_group(NAME)

# %%
name = name.iloc[:,[2,3]]

# %%
name = name.drop_duplicates().reset_index(drop=True)

# %%
id = 49
id = 62
id = 72
id = 78
id = 81
id = 83
name["template"][id]
# Out:
# "According to me, a movie can be best rated by the number of ' best scenes ' there are. There are probably at least 8090 scenes in the whole movie that is probably rated as ' best ' by somebody or the other. This movie is a masterpiece. Period. I know many who have called it ahead of its time, probably because it bombed at boxoffice. However, I think any generation can relate to this movie and have a good laugh through out. I am personally glad that <name> is part of the movie too. <pro-His> role isn't that ' meaty ', however its good to see that <pro-he> is a part of the cast in the funniest Hindi movie ever."

# %%
name["original"][id]
# Out:
# "According to me, a movie can be best rated by the number of ' best scenes ' there are. There are probably at least 8090 scenes in the whole movie that is probably rated as ' best ' by somebody or the other. This movie is a masterpiece. Period. I know many who have called it ahead of its time, probably because it bombed at boxoffice. However, I think any generation can relate to this movie and have a good laugh through out. I am personally glad that Mahmood is part of the movie too. His role isn't that ' meaty ', however its good to see that he is a part of the cast in the funniest Hindi movie ever."

# %%
id = 0
print(dmutant.groupby("type").get_group(NAME).iloc[id]["original"])
print()
print(dmutant.groupby("type").get_group(NAME).iloc[id]["template"])
# Out:
# I have only see three episodes of Hack, starring David Morse, and it looks as though I've missed 37 episodes! well that s if ITV 3 are showing them in chronological order. I've just watched ' Misty Blue ' ( episode 38). I have really enjoyed the 3 episodes, but then I'm a David Morse fan, ( esp St. Elsewhere). For any one reading this, Hack is excellent. Pity its being aired on ITV 3. The cast is strong, though I ca nt get used to the idea of David playing a bent cop, still we all know he's the good guy wrongly accused. I see Gary Cole has guest starred, what ever happened to ' Midnight Caller '? Just wonder if Hack is available on DVD ( yet). Lovin it. Cheers.
#
# I have only see three episodes of Hack, starring David Morse, and it looks as though I've missed 37 episodes! well that s if ITV 3 are showing them in chronological order. I've just watched ' Misty Blue ' ( episode 38). I have really enjoyed the 3 episodes, but then I'm a David Morse fan, ( esp St. Elsewhere). For any one reading this, Hack is excellent. Pity its being aired on ITV 3. The cast is strong, though I ca nt get used to the idea of <name> playing a bent cop, still we all know <pro-he> 's the good guy wrongly accused. I see Gary Cole has guest starred, what ever happened to ' Midnight Caller '? Just wonder if Hack is available on DVD ( yet). Lovin it. Cheers.

# %%
id = 520
print(dmutant.groupby("type").get_group(NAME).iloc[id]["original"])
print()
print(dmutant.groupby("type").get_group(NAME).iloc[id]["template"])
# Out:
# Just when you think that you've seen the worst the zombie subgenre can offer, along comes another budding Romero and his team of notalent mates to prove you wrong. I've suffered the Zombie Bloodbath trilogy, endured Death Valley: The Revenge of Bloody Bill, sat semicomatose through The Zombie Diaries, and laughed hysterically during Zombie ' 90: Extreme Pestilence, and genuinely thought that amateur moviemaking could sink no lower. However, having just watched Zombie Planet, a two hour long festering pile of drivel from writer/ director George Bonilla, I think I have found the ultimate in awful zombie movies. In this dreadfully am
# 793  L'Auberge Espagnole collected the audience whe...
# 794  L'Auberge Espagnole collected the audience whe...
# 795  L'Auberge Espagnole collected the audience whe...
# 796  L'Auberge Espagnole collected the audience whe...
# 797  L'Auberge Espagnole collected the audience whe...
#
#                                               original identifier type  \
# 48   I'm sorry but I can't agree that this was a go...        boy  gaw
# 49   I'm sorry but I can't agree that this was a go...    brother  gaw
# 50   I'm sorry but I can't agree that this was a go...      daddy  gaw
# 51   I'm sorry but I can't agree that this was a go...        man  gaw
# 52   I'm sorry but I can't agree that this was a go...     father  gaw
# ..                                                 ...        ...  ...
# 793  L'Auberge Espagnole collected the audience whe...       aunt  gaw
# 794  L'Auberge Espagnole collected the audience whe...       girl  gaw
# 795  L'Auberge Espagnole collected the audience whe...        mom  gaw
# 796  L'Auberge Espagnole collected the audience whe...       lady  gaw
# 797  L'Auberge Espagnole collected the audience whe...       lady  gaw
#
#      gender country  template_id
# 48     male    None           39
# 49     male    None           39
# 50     male    None           39
# 51     male    None           39
# 52     male    None           39
# ..      ...     ...          ...
# 793  female    None           48
# 794  female    None           48
# 795  female    None           48
# 796  female    None           48
# 797  female    None           48
#
# [494 rows x 9 columns]

# %%
id = 0
print(dmutant.groupby("type").get_group(GAW).iloc[id]["original"])
print()
print(dmutant.groupby("type").get_group(GAW).iloc[id]["template"])
# Out:
# I'm sorry but I can't agree that this was a good movie. Yes, it looked good visually, but it's the story that drives the movie and I must say the story sucked bigtime. How in the world did they manage to slip some of those plotholes past the critics. Better story and I would've gave it a higher vote but I was impossible to do that and still be able to live with myself. I have always been a fan of scary movies, and the previews really had me fooled. All the scary scenes were shown in the previews. And why did the family that got killed stay to haunt the house? Why did the father come back again? WHy did he decide to kill in the first place? Why were the kids the only ones to see the ghosts first? To many questions, not enough answers. If I could've gave it a zero, I would've.
#
# I'm sorry but I can't agree that this was a good movie. Yes, it looked good visually, but it's the story that drives the movie and I must say the story sucked bigtime. How in the world did they manage to slip some of those plotholes past the critics. Better story and I would've gave it a higher vote but I was impossible to do that and still be able to live with myself. I have always been a fan of scary movies, and the previews really had me fooled. All the scary scenes were shown in the previews. And why did the family that got killed stay to haunt the house? Why did the <gaw> come back again? WHy did <pro-he> decide to kill in the first place? Why were the kids the only ones to see the ghosts first? To many questions, not enough answers. If I could've gave it a zero, I would've.

# %%
id = 1000
print(dmutant.groupby("type").get_group(GAW).iloc[id]["original"])
print()
print(dmutant.groupby("type").get_group(GAW).iloc[id]["template"])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-123-85c11d2936eb> in <module>
#       1 id = 1000
# ----> 2 print(dmutant.groupby("type").get_group(GAW).iloc[id]["original"])
#       3 print()
#       4 print(dmutant.groupby("type").get_group(GAW).iloc[id]["template"])
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2136
#    2137             # validate the location
# -> 2138             self._validate_integer(key, axis)
#    2139
#    2140             return self._get_loc(key, axis=axis)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    2061         len_axis = len(self.obj._get_axis(axis))
#    2062         if key >= len_axis or key < -len_axis:
# -> 2063             raise IndexError("single positional indexer is out-of-bounds")
#    2064
#    2065     def _getitem_tuple(self, tup: Tuple):
#
# IndexError: single positional indexer is out-of-bounds
