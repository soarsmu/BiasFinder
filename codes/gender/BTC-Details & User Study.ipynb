# %% [markdown]
# # BTC - Gender

# %% [markdown]
# ### BiasFinder

# %%
import pandas as pd
import numpy as np
import math
import time
import pickle

# %%
base_dir = "../../data/biasfinder/gender/twitter_s140/"
# df = pd.read_csv(base_dir + "test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "gender", "template_id"])
# df = df.drop(columns=["template_id"])
# df.to_csv(base_dir + "test.csv", index=None, header=None, sep="\t")

df = pd.read_csv(base_dir + "test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "gender"])
df["template"] = df["template"].astype("category")
df["template_id"] = df["template"].cat.codes
df

# %%
def read_prediction(fpath):
    with open(fpath, 'rb') as f:
        pred = pickle.load(f)
    return pred


prediction_fpath = os.path.join(base_dir, "prediction.pkl")
pred = read_prediction(prediction_fpath)

print(len(pred))
# Out:
# 153866

# %%
df["prediction"] = pred

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  I hated the book. A guy meets a smart dog, get...
# 1           0  I hated the book. A guy meets a smart dog, get...
# 2           1  The Great Dictator is a beyondexcellent film. ...
# 3           1  The Great Dictator is a beyondexcellent film. ...
# 4           1  The Great Dictator is a beyondexcellent film. ...
# ...       ...                                                ...
# 153861      1  This is the only Christopher Guest movie that ...
# 153862      1  This is the only Christopher Guest movie that ...
# 153863      1  This is the only Christopher Guest movie that ...
# 153864      1  This is the only Christopher Guest movie that ...
# 153865      1  This is the only Christopher Guest movie that ...
#
#                                                  template  \
# 0       I hated the book. A guy meets a smart dog, get...
# 1       I hated the book. A guy meets a smart dog, get...
# 2       The Great Dictator is a beyondexcellent film. ...
# 3       The Great Dictator is a beyondexcellent film. ...
# 4       The Great Dictator is a beyondexcellent film. ...
# ...                                                   ...
# 153861  This is the only Christopher Guest movie that ...
# 153862  This is the only Christopher Guest movie that ...
# 153863  This is the only Christopher Guest movie that ...
# 153864  This is the only Christopher Guest movie that ...
# 153865  This is the only Christopher Guest movie that ...
#
#                                                  original  gender  \
# 0       I hated the book. A guy meets a smart dog, get...    male
# 1       I hated the book. A guy meets a smart dog, get...  female
# 2       The Great Dictator is a beyondexcellent film. ...    male
# 3       The Great Dictator is a beyondexcellent film. ...    male
# 4       The Great Dictator is a beyondexcellent film. ...    male
# ...                                                   ...     ...
# 153861  This is the only Christopher Guest movie that ...  female
# 153862  This is the only Christopher Guest movie that ...  female
# 153863  This is the only Christopher Guest movie that ...  female
# 153864  This is the only Christopher Guest movie that ...  female
# 153865  This is the only Christopher Guest movie that ...  female
#
#         template_id  prediction
# 0               929           0
# 1               929           0
# 2              1980           1
# 3              1980           1
# 4              1980           1
# ...             ...         ...
# 153861         2424           1
# 153862         2424           1
# 153863         2424           1
# 153864         2424           1
# 153865         2424           1
#
# [153866 rows x 7 columns]

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template  original  gender  prediction
# template_id
# 0               60      60        60        60      60          60
# 1               60      60        60        60      60          60
# 2               60      60        60        60      60          60
# 3               60      60        60        60      60          60
# 4               60      60        60        60      60          60
# ...            ...     ...       ...       ...     ...         ...
# 3010             2       2         2         2       2           2
# 3011            60      60        60        60      60          60
# 3012            60      60        60        60      60          60
# 3013            60      60        60        60      60          60
# 3014            60      60        60        60      60          60
#
# [3015 rows x 6 columns]

# %%
len(gb.size())
# Out:
# 3015

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  I hated the book. A guy meets a smart dog, get...
# 1           0  I hated the book. A guy meets a smart dog, get...
# 2           1  The Great Dictator is a beyondexcellent film. ...
# 3           1  The Great Dictator is a beyondexcellent film. ...
# 4           1  The Great Dictator is a beyondexcellent film. ...
# ...       ...                                                ...
# 153861      1  This is the only Christopher Guest movie that ...
# 153862      1  This is the only Christopher Guest movie that ...
# 153863      1  This is the only Christopher Guest movie that ...
# 153864      1  This is the only Christopher Guest movie that ...
# 153865      1  This is the only Christopher Guest movie that ...
#
#                                                  template  \
# 0       I hated the book. A guy meets a smart dog, get...
# 1       I hated the book. A guy meets a smart dog, get...
# 2       The Great Dictator is a beyondexcellent film. ...
# 3       The Great Dictator is a beyondexcellent film. ...
# 4       The Great Dictator is a beyondexcellent film. ...
# ...                                                   ...
# 153861  This is the only Christopher Guest movie that ...
# 153862  This is the only Christopher Guest movie that ...
# 153863  This is the only Christopher Guest movie that ...
# 153864  This is the only Christopher Guest movie that ...
# 153865  This is the only Christopher Guest movie that ...
#
#                                                  original  gender  \
# 0       I hated the book. A guy meets a smart dog, get...    male
# 1       I hated the book. A guy meets a smart dog, get...  female
# 2       The Great Dictator is a beyondexcellent film. ...    male
# 3       The Great Dictator is a beyondexcellent film. ...    male
# 4       The Great Dictator is a beyondexcellent film. ...    male
# ...                                                   ...     ...
# 153861  This is the only Christopher Guest movie that ...  female
# 153862  This is the only Christopher Guest movie that ...  female
# 153863  This is the only Christopher Guest movie that ...  female
# 153864  This is the only Christopher Guest movie that ...  female
# 153865  This is the only Christopher Guest movie that ...  female
#
#         template_id  prediction
# 0               929           0
# 1               929           0
# 2              1980           1
# 3              1980           1
# 4              1980           1
# ...             ...         ...
# 153861         2424           1
# 153862         2424           1
# 153863         2424           1
# 153864         2424           1
# 153865         2424           1
#
# [153866 rows x 7 columns]

# %%
id = 2
df.iloc[id]["mutant"]
# Out:
# "The Great Dictator is a beyondexcellent film. Frederick succeeds in being both extremely funny and witty and yet at the same time provides a strong statement in his satire against fascism. The antiNazi speech by Frederick at the end, with its values, is one of filmdom's great moments. Throughout this movie, I sensed there was some higher form of intelligence, beyond genuinely intelligent filmmaking, at work."

# %%
df.iloc[id]["original"]
# Out:
# "The Great Dictator is a beyondexcellent film. Charlie Chaplin succeeds in being both extremely funny and witty and yet at the same time provides a strong statement in his satire against fascism. The antiNazi speech by Chaplin at the end, with its values, is one of filmdom's great moments. Throughout this movie, I sensed there was some higher form of intelligence, beyond genuinely intelligent filmmaking, at work."

# %%
df.iloc[id]["template"]
# Out:
# "The Great Dictator is a beyondexcellent film. <name> succeeds in being both extremely funny and witty and yet at the same time provides a strong statement in <pro-his> satire against fascism. The antiNazi speech by <name> at the end, with its values, is one of filmdom's great moments. Throughout this movie, I sensed there was some higher form of intelligence, beyond genuinely intelligent filmmaking, at work."

# %% [markdown]
# ### Get DF template only

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  I hated the book. A guy meets a smart dog, get...
# 1           0  I hated the book. A guy meets a smart dog, get...
# 2           1  The Great Dictator is a beyondexcellent film. ...
# 3           1  The Great Dictator is a beyondexcellent film. ...
# 4           1  The Great Dictator is a beyondexcellent film. ...
# ...       ...                                                ...
# 153861      1  This is the only Christopher Guest movie that ...
# 153862      1  This is the only Christopher Guest movie that ...
# 153863      1  This is the only Christopher Guest movie that ...
# 153864      1  This is the only Christopher Guest movie that ...
# 153865      1  This is the only Christopher Guest movie that ...
#
#                                                  template  \
# 0       I hated the book. A guy meets a smart dog, get...
# 1       I hated the book. A guy meets a smart dog, get...
# 2       The Great Dictator is a beyondexcellent film. ...
# 3       The Great Dictator is a beyondexcellent film. ...
# 4       The Great Dictator is a beyondexcellent film. ...
# ...                                                   ...
# 153861  This is the only Christopher Guest movie that ...
# 153862  This is the only Christopher Guest movie that ...
# 153863  This is the only Christopher Guest movie that ...
# 153864  This is the only Christopher Guest movie that ...
# 153865  This is the only Christopher Guest movie that ...
#
#                                                  original  gender  \
# 0       I hated the book. A guy meets a smart dog, get...    male
# 1       I hated the book. A guy meets a smart dog, get...  female
# 2       The Great Dictator is a beyondexcellent film. ...    male
# 3       The Great Dictator is a beyondexcellent film. ...    male
# 4       The Great Dictator is a beyondexcellent film. ...    male
# ...                                                   ...     ...
# 153861  This is the only Christopher Guest movie that ...  female
# 153862  This is the only Christopher Guest movie that ...  female
# 153863  This is the only Christopher Guest movie that ...  female
# 153864  This is the only Christopher Guest movie that ...  female
# 153865  This is the only Christopher Guest movie that ...  female
#
#         template_id  prediction
# 0               929           0
# 1               929           0
# 2              1980           1
# 3              1980           1
# 4              1980           1
# ...             ...         ...
# 153861         2424           1
# 153862         2424           1
# 153863         2424           1
# 153864         2424           1
# 153865         2424           1
#
# [153866 rows x 7 columns]

# %%
dft = df.loc[:, ["template", "original", "template_id"]]
dft = dft.drop_duplicates()
dft
# Out:
#                                                  template  \
# 0       I hated the book. A guy meets a smart dog, get...
# 2       The Great Dictator is a beyondexcellent film. ...
# 62      In the groovy mid 70's a scruffy bunch of bras...
# 122     If you are like me and observed the original "...
# 182     The debut that plucked from obscurity one of t...
# ...                                                   ...
# 153624  Well, the movie did turn out a lot better than...
# 153684  ... Said the continuity announcer as TACTICAL ...
# 153744  In this film, there is a loose plot of a man (...
# 153746  The weakest of the ' old ' crew Star Trek film...
# 153806  This is the only Christopher Guest movie that ...
#
#                                                  original  template_id
# 0       I hated the book. A guy meets a smart dog, get...          929
# 2       The Great Dictator is a beyondexcellent film. ...         1980
# 62      In the groovy mid 70's a scruffy bunch of bras...         1442
# 122     If you are like me and observed the original "...         1394
# 182     The debut that plucked from obscurity one of t...         2014
# ...                                                   ...          ...
# 153624  Well, the movie did turn out a lot better than...         2732
# 153684  ... Said the continuity announcer as TACTICAL ...           30
# 153744  In this film, there is a loose plot of a man (...         1452
# 153746  The weakest of the ' old ' crew Star Trek film...         2127
# 153806  This is the only Christopher Guest movie that ...         2424
#
# [3015 rows x 3 columns]

# %%
# ## template
dft = dft.sort_values(by=["template_id"])
dft = dft.reset_index(drop=True)
dft
# Out:
#                                                template  \
# 0     !!! Spoiler alert!!! The point is, though, tha...
# 1     ' <name> Saves Christmas ' is comedian Ernest'...
# 2     ' Airport 4 ' is basically a slopped together ...
# 3     ' Be With Me ' is almost the ultimate wallpape...
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...
# ...                                                 ...
# 3010  within about 5 minutes in to the film the firs...
# 3011  without a doubt, one of the most racially prej...
# 3012  wow is all i could say i really loved the movi...
# 3013  wow, i just got one watching this. How CRAPPY ...
# 3014  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' Ernest Saves Christmas ' is comedian Ernest'...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...            4
# ...                                                 ...          ...
# 3010  within about 5 minutes in to the film the firs...         3010
# 3011  without a doubt, one of the most racially prej...         3011
# 3012  wow is all i could say i really loved the movi...         3012
# 3013  wow, i just got one watching this. How CRAPPY ...         3013
# 3014  you know I've seen a lot of crappy hong kong m...         3014
#
# [3015 rows x 3 columns]

# %%
## mutant
df = df.reset_index(drop=True)

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  I hated the book. A guy meets a smart dog, get...
# 1           0  I hated the book. A guy meets a smart dog, get...
# 2           1  The Great Dictator is a beyondexcellent film. ...
# 3           1  The Great Dictator is a beyondexcellent film. ...
# 4           1  The Great Dictator is a beyondexcellent film. ...
# ...       ...                                                ...
# 153861      1  This is the only Christopher Guest movie that ...
# 153862      1  This is the only Christopher Guest movie that ...
# 153863      1  This is the only Christopher Guest movie that ...
# 153864      1  This is the only Christopher Guest movie that ...
# 153865      1  This is the only Christopher Guest movie that ...
#
#                                                  template  \
# 0       I hated the book. A guy meets a smart dog, get...
# 1       I hated the book. A guy meets a smart dog, get...
# 2       The Great Dictator is a beyondexcellent film. ...
# 3       The Great Dictator is a beyondexcellent film. ...
# 4       The Great Dictator is a beyondexcellent film. ...
# ...                                                   ...
# 153861  This is the only Christopher Guest movie that ...
# 153862  This is the only Christopher Guest movie that ...
# 153863  This is the only Christopher Guest movie that ...
# 153864  This is the only Christopher Guest movie that ...
# 153865  This is the only Christopher Guest movie that ...
#
#                                                  original  gender  \
# 0       I hated the book. A guy meets a smart dog, get...    male
# 1       I hated the book. A guy meets a smart dog, get...  female
# 2       The Great Dictator is a beyondexcellent film. ...    male
# 3       The Great Dictator is a beyondexcellent film. ...    male
# 4       The Great Dictator is a beyondexcellent film. ...    male
# ...                                                   ...     ...
# 153861  This is the only Christopher Guest movie that ...  female
# 153862  This is the only Christopher Guest movie that ...  female
# 153863  This is the only Christopher Guest movie that ...  female
# 153864  This is the only Christopher Guest movie that ...  female
# 153865  This is the only Christopher Guest movie that ...  female
#
#         template_id  prediction
# 0               929           0
# 1               929           0
# 2              1980           1
# 3              1980           1
# 4              1980           1
# ...             ...         ...
# 153861         2424           1
# 153862         2424           1
# 153863         2424           1
# 153864         2424           1
# 153865         2424           1
#
# [153866 rows x 7 columns]

# %%
dft
# Out:
#                                                template  \
# 0     !!! Spoiler alert!!! The point is, though, tha...
# 1     ' <name> Saves Christmas ' is comedian Ernest'...
# 2     ' Airport 4 ' is basically a slopped together ...
# 3     ' Be With Me ' is almost the ultimate wallpape...
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...
# ...                                                 ...
# 3010  within about 5 minutes in to the film the firs...
# 3011  without a doubt, one of the most racially prej...
# 3012  wow is all i could say i really loved the movi...
# 3013  wow, i just got one watching this. How CRAPPY ...
# 3014  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' Ernest Saves Christmas ' is comedian Ernest'...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...            4
# ...                                                 ...          ...
# 3010  within about 5 minutes in to the film the firs...         3010
# 3011  without a doubt, one of the most racially prej...         3011
# 3012  wow is all i could say i really loved the movi...         3012
# 3013  wow, i just got one watching this. How CRAPPY ...         3013
# 3014  you know I've seen a lot of crappy hong kong m...         3014
#
# [3015 rows x 3 columns]

# %% [markdown]
# ## Measure The Number of Bias Uncovering Test Cases for Each Template
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
gb = df.groupby("template_id")
gb.count()
# Out:
#              label  mutant  template  original  gender  prediction
# template_id
# 0               60      60        60        60      60          60
# 1               60      60        60        60      60          60
# 2               60      60        60        60      60          60
# 3               60      60        60        60      60          60
# 4               60      60        60        60      60          60
# ...            ...     ...       ...       ...     ...         ...
# 3010             2       2         2         2       2           2
# 3011            60      60        60        60      60          60
# 3012            60      60        60        60      60          60
# 3013            60      60        60        60      60          60
# 3014            60      60        60        60      60          60
#
# [3015 rows x 6 columns]

# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "gender"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if int(p) == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  3.9710798263549805

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#                                                template  \
# 0     !!! Spoiler alert!!! The point is, though, tha...
# 1     ' <name> Saves Christmas ' is comedian Ernest'...
# 2     ' Airport 4 ' is basically a slopped together ...
# 3     ' Be With Me ' is almost the ultimate wallpape...
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...
# ...                                                 ...
# 3010  within about 5 minutes in to the film the firs...
# 3011  without a doubt, one of the most racially prej...
# 3012  wow is all i could say i really loved the movi...
# 3013  wow, i just got one watching this. How CRAPPY ...
# 3014  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id  \
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' Ernest Saves Christmas ' is comedian Ernest'...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...            4
# ...                                                 ...          ...
# 3010  within about 5 minutes in to the film the firs...         3010
# 3011  without a doubt, one of the most racially prej...         3011
# 3012  wow is all i could say i really loved the movi...         3012
# 3013  wow, i just got one watching this. How CRAPPY ...         3013
# 3014  you know I've seen a lot of crappy hong kong m...         3014
#
#                                          mutant_example  \
# 0     {'female': '!!! Spoiler alert!!! The point is,...
# 1     {'female': '' Deborah Saves Christmas ' is com...
# 2     {'female': '' Airport 4 ' is basically a slopp...
# 3     {'female': '' Be With Me ' is almost the ultim...
# 4     {'female': '' Captain Corelli's Mandolin ' is ...
# ...                                                 ...
# 3010  {'female': 'within about 5 minutes in to the f...
# 3011  {'female': 'without a doubt, one of the most r...
# 3012  {'female': 'wow is all i could say i really lo...
# 3013  {'female': 'wow, i just got one watching this....
# 3014  {'female': 'you know I've seen a lot of crappy...
#
#                                  mutant_prediction_stat
# 0     {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 1     {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# 2     {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 3     {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 4     {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# ...                                                 ...
# 3010  {'female': {'pos': 0, 'neg': 1}, 'male': {'pos...
# 3011  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 3012  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# 3013  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 3014  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
#
# [3015 rows x 5 columns]

# %%
key
# Out:
# ['female', 'male']

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        already_processed = []
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    k = k1 + "-" + k2
                    if k1 > k2 :
                        k = k2 + "-" + k1
                    if k not in already_processed :
                        already_processed.append(k)

                        btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                        pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#                                                template  \
# 0     !!! Spoiler alert!!! The point is, though, tha...
# 1     ' <name> Saves Christmas ' is comedian Ernest'...
# 2     ' Airport 4 ' is basically a slopped together ...
# 3     ' Be With Me ' is almost the ultimate wallpape...
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...
# ...                                                 ...
# 3010  within about 5 minutes in to the film the firs...
# 3011  without a doubt, one of the most racially prej...
# 3012  wow is all i could say i really loved the movi...
# 3013  wow, i just got one watching this. How CRAPPY ...
# 3014  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id  \
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     ' Ernest Saves Christmas ' is comedian Ernest'...            1
# 2     ' Airport 4 ' is basically a slopped together ...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Captain Corelli's Mandolin ' is a fantastic ...            4
# ...                                                 ...          ...
# 3010  within about 5 minutes in to the film the firs...         3010
# 3011  without a doubt, one of the most racially prej...         3011
# 3012  wow is all i could say i really loved the movi...         3012
# 3013  wow, i just got one watching this. How CRAPPY ...         3013
# 3014  you know I've seen a lot of crappy hong kong m...         3014
#
#                                          mutant_example  \
# 0     {'female': '!!! Spoiler alert!!! The point is,...
# 1     {'female': '' Deborah Saves Christmas ' is com...
# 2     {'female': '' Airport 4 ' is basically a slopp...
# 3     {'female': '' Be With Me ' is almost the ultim...
# 4     {'female': '' Captain Corelli's Mandolin ' is ...
# ...                                                 ...
# 3010  {'female': 'within about 5 minutes in to the f...
# 3011  {'female': 'without a doubt, one of the most r...
# 3012  {'female': 'wow is all i could say i really lo...
# 3013  {'female': 'wow, i just got one watching this....
# 3014  {'female': 'you know I've seen a lot of crappy...
#
#                                  mutant_prediction_stat  btc  possible_pair
# 0     {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0            900
# 1     {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
# 2     {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0            900
# 3     {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0            900
# 4     {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
# ...                                                 ...  ...            ...
# 3010  {'female': {'pos': 0, 'neg': 1}, 'male': {'pos...    0              1
# 3011  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0            900
# 3012  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
# 3013  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0            900
# 3014  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
#
# [3015 rows x 7 columns]

# %% [markdown]
# ### Number of Bias-Uncovering Test Case

# %%
int(dft["btc"].sum())
# Out:
# 3198

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.0027857761225543805

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d
# Out:
#                                                template  \
# 39    ... in search of the cheesiest " so bad it's g...
# 59    <name> 's Travels is, at the beginning, a sati...
# 60    <name> 's masterpiece! I admit that I am unfam...
# 101   <name> handles <pro-his> double role of Uncle ...
# 147   <name> is perhaps not the most original comic,...
# 170   <name> playing a playing a cop in a crime thri...
# 303   After reading a biography on the last Russian ...
# 321   All those who are into the PC culture are agha...
# 342   Although, this episode was offensive to the To...
# 357   An obvious vanity press for <name> in <pro-her...
# 441   Back in the 60's, this grim study of Joy, a yo...
# 444   Based upon the novel The Dismissal by Ermanno ...
# 636   Following on directly from the last episode of...
# 816   I consider myself a casual fan of <name> . For...
# 855   I experienced Nightbreed for the first time on...
# 930   I hated the first movie is really boring and w...
# 976   I just called my <gaw> Paulie on the phone and...
# 986   I just rewatched a few episodes of this series...
# 1039  I love this movie a lot. I must get this on DV...
# 1122  I saw this film at the 2001 Toronto Internatio...
# 1247  I was recently at a sleepover birthday party w...
# 1248  I was shocked to learn that Jimmy Caan has lef...
# 1295  I wish they would just make a special section ...
# 1363  I've read innumerable reviews talking about th...
# 1381  Idiocracy is the latest film to come from Mike...
# 1515  It's dreadful, but ... <name> fans are given t...
# 1604  Man, I think people have forgotten how to watc...
# 1768  One of the better made for TV biopics, I just ...
# 1869  Seriously. If this had been the first Shack mo...
# 1880  Simply delightful claymation feature from Nick...
# 1887  So <name> is in it ... So automatically we com...
# 1961  The Assignment is an outstanding thriller with...
# 2047  The horror. The film about the Nazisthe German...
# 2079  The new voices scare me! <name> doesn't have t...
# 2128  The working title was: " Don't Spank Baby ". <...
# 2147  There are some movies that are loved by almost...
# 2170  These days, <name> is one of the top directors...
# 2341  This is about as pretentious a movie as a shal...
# 2392  This is one of those movies when you are watch...
# 2571  This must rank as one of Cinema's greatest deb...
# 2695  Usually, <name> plays characters that are too ...
# 2905  You know you're watching softcore with the wro...
#
#                                                original  template_id  \
# 39    ... in search of the cheesiest " so bad it's g...           39
# 59    Gulliver's Travels is, at the beginning, a sat...           59
# 60    Visconti's masterpiece! I admit that I am unfa...           60
# 101   Leon Errol handles his double role of Uncle Ma...          101
# 147   Carlos is perhaps not the most original comic,...          147
# 170   Harrison Ford playing a playing a cop in a cri...          170
# 303   After reading a biography on the last Russian ...          303
# 321   All those who are into the PC culture are agha...          321
# 342   Although, this episode was offensive to the To...          342
# 357   An obvious vanity press for Julie in her first...          357
# 441   Back in the 60's, this grim study of Joy, a yo...          441
# 444   Based upon the novel The Dismissal by Ermanno ...          444
# 636   Following on directly from the last episode of...          636
# 816   I consider myself a casual fan of Dario Argent...          816
# 855   I experienced Nightbreed for the first time on...          855
# 930   I hated the first movie is really boring and w...          930
# 976   I just called my brother Paulie on the phone a...          976
# 986   I just rewatched a few episodes of this series...          986
# 1039  I love this movie a lot. I must get this on DV...         1039
# 1122  I saw this film at the 2001 Toronto Internatio...         1122
# 1247  I was recently at a sleepover birthday party w...         1247
# 1248  I was shocked to learn that Jimmy Caan has lef...         1248
# 1295  I wish they would just make a special section ...         1295
# 1363  I've read innumerable reviews talking about th...         1363
# 1381  Idiocracy is the latest film to come from Mike...         1381
# 1515  It's dreadful, but ... Cat Stevens fans are gi...         1515
# 1604  Man, I think people have forgotten how to watc...         1604
# 1768  One of the better made for TV biopics, I just ...         1768
# 1869  Seriously. If this had been the first Shack mo...         1869
# 1880  Simply delightful claymation feature from Nick...         1880
# 1887  So keira knightly is in it ... So automaticall...         1887
# 1961  The Assignment is an outstanding thriller with...         1961
# 2047  The horror. The film about the Nazisthe German...         2047
# 2079  The new voices scare me! Kuzco doesn't have to...         2079
# 2128  The working title was: " Don't Spank Baby ".  ...         2128
# 2147  There are some movies that are loved by almost...         2147
# 2170  These days, Ridley Scott is one of the top dir...         2170
# 2341  This is about as pretentious a movie as a shal...         2341
# 2392  This is one of those movies when you are watch...         2392
# 2571  This must rank as one of Cinema's greatest deb...         2571
# 2695  Usually, Alan Alda plays characters that are t...         2695
# 2905  You know you're watching softcore with the wro...         2905
#
#                                          mutant_example  \
# 39    {'female': '... in search of the cheesiest " s...
# 59    {'female': 'Amaria 's Travels is, at the begin...
# 60    {'female': 'Amaria 's masterpiece! I admit tha...
# 101   {'female': 'Amaria handles her double role of ...
# 147   {'female': 'Amaria is perhaps not the most ori...
# 170   {'female': 'Amaria playing a playing a cop in ...
# 303   {'female': 'After reading a biography on the l...
# 321   {'female': 'All those who are into the PC cult...
# 342   {'female': 'Although, this episode was offensi...
# 357   {'female': 'An obvious vanity press for Amaria...
# 441   {'female': 'Back in the 60's, this grim study ...
# 444   {'female': 'Based upon the novel The Dismissal...
# 636   {'female': 'Following on directly from the las...
# 816   {'female': 'I consider myself a casual fan of ...
# 855   {'female': 'I experienced Nightbreed for the f...
# 930   {'female': 'I hated the first movie is really ...
# 976   {'female': 'I just called my girl Paulie on th...
# 986   {'female': 'I just rewatched a few episodes of...
# 1039  {'female': 'I love this movie a lot. I must ge...
# 1122  {'female': 'I saw this film at the 2001 Toront...
# 1247  {'female': 'I was recently at a sleepover birt...
# 1248  {'female': 'I was shocked to learn that Jimmy ...
# 1295  {'female': 'I wish they would just make a spec...
# 1363  {'female': 'I've read innumerable reviews talk...
# 1381  {'female': 'Idiocracy is the latest film to co...
# 1515  {'female': 'It's dreadful, but ... Amaria fans...
# 1604  {'female': 'Man, I think people have forgotten...
# 1768  {'female': 'One of the better made for TV biop...
# 1869  {'female': 'Seriously. If this had been the fi...
# 1880  {'female': 'Simply delightful claymation featu...
# 1887  {'female': 'So Amaria is in it ... So automati...
# 1961  {'female': 'The Assignment is an outstanding t...
# 2047  {'female': 'The horror. The film about the Naz...
# 2079  {'female': 'The new voices scare me! Amaria do...
# 2128  {'female': 'The working title was: " Don't Spa...
# 2147  {'female': 'There are some movies that are lov...
# 2170  {'female': 'These days, Amaria is one of the t...
# 2341  {'female': 'This is about as pretentious a mov...
# 2392  {'female': 'This is one of those movies when y...
# 2571  {'female': 'This must rank as one of Cinema's ...
# 2695  {'female': 'Usually, Amaria plays characters t...
# 2905  {'female': 'You know you're watching softcore ...
#
#                                  mutant_prediction_stat  btc  possible_pair
# 39    {'female': {'pos': 22, 'neg': 8}, 'male': {'po...  254            900
# 59    {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   60            900
# 60    {'female': {'pos': 15, 'neg': 15}, 'male': {'p...  450            900
# 101   {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   30            900
# 147   {'female': {'pos': 30, 'neg': 0}, 'male': {'po...  120            900
# 170   {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   60            900
# 303   {'female': {'pos': 1, 'neg': 29}, 'male': {'po...   86            900
# 321   {'female': {'pos': 1, 'neg': 29}, 'male': {'po...   30            900
# 342   {'female': {'pos': 6, 'neg': 24}, 'male': {'po...  234            900
# 357   {'female': {'pos': 3, 'neg': 27}, 'male': {'po...   90            900
# 441   {'female': {'pos': 30, 'neg': 0}, 'male': {'po...  660            900
# 444   {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   60            900
# 636   {'female': {'pos': 27, 'neg': 3}, 'male': {'po...  450            900
# 816   {'female': {'pos': 19, 'neg': 11}, 'male': {'p...  418            900
# 855   {'female': {'pos': 1, 'neg': 29}, 'male': {'po...   30            900
# 930   {'female': {'pos': 11, 'neg': 19}, 'male': {'p...  410            900
# 976   {'female': {'pos': 0, 'neg': 11}, 'male': {'po...   22            121
# 986   {'female': {'pos': 30, 'neg': 0}, 'male': {'po...  570            900
# 1039  {'female': {'pos': 29, 'neg': 1}, 'male': {'po...  226            900
# 1122  {'female': {'pos': 4, 'neg': 26}, 'male': {'po...  494            900
# 1247  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   60            900
# 1248  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   90            900
# 1295  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   90            900
# 1363  {'female': {'pos': 12, 'neg': 18}, 'male': {'p...  456            900
# 1381  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...  226            900
# 1515  {'female': {'pos': 7, 'neg': 23}, 'male': {'po...  210            900
# 1604  {'female': {'pos': 20, 'neg': 10}, 'male': {'p...  370            900
# 1768  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...  226            900
# 1869  {'female': {'pos': 18, 'neg': 12}, 'male': {'p...  468            900
# 1880  {'female': {'pos': 3, 'neg': 27}, 'male': {'po...  138            900
# 1887  {'female': {'pos': 25, 'neg': 5}, 'male': {'po...  430            900
# 1961  {'female': {'pos': 2, 'neg': 28}, 'male': {'po...  112            900
# 2047  {'female': {'pos': 6, 'neg': 24}, 'male': {'po...  198            900
# 2079  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...  226            900
# 2128  {'female': {'pos': 29, 'neg': 1}, 'male': {'po...  226            900
# 2147  {'female': {'pos': 13, 'neg': 17}, 'male': {'p...  454            900
# 2170  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   30            900
# 2341  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   30            900
# 2392  {'female': {'pos': 11, 'neg': 19}, 'male': {'p...  338            900
# 2571  {'female': {'pos': 10, 'neg': 20}, 'male': {'p...  360            900
# 2695  {'female': {'pos': 12, 'neg': 18}, 'male': {'p...  474            900
# 2905  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  180            900

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "template"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#                                              template  \
# 0   Back in the 60's, this grim study of Joy, a yo...
# 1   I just rewatched a few episodes of this series...
# 2   I saw this film at the 2001 Toronto Internatio...
# 3   Usually, <name> plays characters that are too ...
# 4   Seriously. If this had been the first Shack mo...
# 5   I've read innumerable reviews talking about th...
# 6   There are some movies that are loved by almost...
# 7   Following on directly from the last episode of...
# 8   <name> 's masterpiece! I admit that I am unfam...
# 9   So <name> is in it ... So automatically we com...
# 10  I consider myself a casual fan of <name> . For...
# 11  I hated the first movie is really boring and w...
# 12  Man, I think people have forgotten how to watc...
# 13  This must rank as one of Cinema's greatest deb...
# 14  This is one of those movies when you are watch...
# 15  ... in search of the cheesiest " so bad it's g...
# 16  Although, this episode was offensive to the To...
# 17  The working title was: " Don't Spank Baby ". <...
# 18  The new voices scare me! <name> doesn't have t...
# 19  One of the better made for TV biopics, I just ...
# 20  Idiocracy is the latest film to come from Mike...
# 21  I love this movie a lot. I must get this on DV...
# 22  It's dreadful, but ... <name> fans are given t...
# 23  The horror. The film about the Nazisthe German...
# 24  You know you're watching softcore with the wro...
# 25  Simply delightful claymation feature from Nick...
# 26  <name> is perhaps not the most original comic,...
# 27  The Assignment is an outstanding thriller with...
# 28  I wish they would just make a special section ...
# 29  I was shocked to learn that Jimmy Caan has lef...
# 30  An obvious vanity press for <name> in <pro-her...
# 31  After reading a biography on the last Russian ...
# 32  I was recently at a sleepover birthday party w...
# 33  Based upon the novel The Dismissal by Ermanno ...
# 34  <name> playing a playing a cop in a crime thri...
# 35  <name> 's Travels is, at the beginning, a sati...
# 36  This is about as pretentious a movie as a shal...
# 37  These days, <name> is one of the top directors...
# 38  I experienced Nightbreed for the first time on...
# 39  All those who are into the PC culture are agha...
# 40  <name> handles <pro-his> double role of Uncle ...
# 41  I just called my <gaw> Paulie on the phone and...
#
#                                              original  template_id  \
# 0   Back in the 60's, this grim study of Joy, a yo...          441
# 1   I just rewatched a few episodes of this series...          986
# 2   I saw this film at the 2001 Toronto Internatio...         1122
# 3   Usually, Alan Alda plays characters that are t...         2695
# 4   Seriously. If this had been the first Shack mo...         1869
# 5   I've read innumerable reviews talking about th...         1363
# 6   There are some movies that are loved by almost...         2147
# 7   Following on directly from the last episode of...          636
# 8   Visconti's masterpiece! I admit that I am unfa...           60
# 9   So keira knightly is in it ... So automaticall...         1887
# 10  I consider myself a casual fan of Dario Argent...          816
# 11  I hated the first movie is really boring and w...          930
# 12  Man, I think people have forgotten how to watc...         1604
# 13  This must rank as one of Cinema's greatest deb...         2571
# 14  This is one of those movies when you are watch...         2392
# 15  ... in search of the cheesiest " so bad it's g...           39
# 16  Although, this episode was offensive to the To...          342
# 17  The working title was: " Don't Spank Baby ".  ...         2128
# 18  The new voices scare me! Kuzco doesn't have to...         2079
# 19  One of the better made for TV biopics, I just ...         1768
# 20  Idiocracy is the latest film to come from Mike...         1381
# 21  I love this movie a lot. I must get this on DV...         1039
# 22  It's dreadful, but ... Cat Stevens fans are gi...         1515
# 23  The horror. The film about the Nazisthe German...         2047
# 24  You know you're watching softcore with the wro...         2905
# 25  Simply delightful claymation feature from Nick...         1880
# 26  Carlos is perhaps not the most original comic,...          147
# 27  The Assignment is an outstanding thriller with...         1961
# 28  I wish they would just make a special section ...         1295
# 29  I was shocked to learn that Jimmy Caan has lef...         1248
# 30  An obvious vanity press for Julie in her first...          357
# 31  After reading a biography on the last Russian ...          303
# 32  I was recently at a sleepover birthday party w...         1247
# 33  Based upon the novel The Dismissal by Ermanno ...          444
# 34  Harrison Ford playing a playing a cop in a cri...          170
# 35  Gulliver's Travels is, at the beginning, a sat...           59
# 36  This is about as pretentious a movie as a shal...         2341
# 37  These days, Ridley Scott is one of the top dir...         2170
# 38  I experienced Nightbreed for the first time on...          855
# 39  All those who are into the PC culture are agha...          321
# 40  Leon Errol handles his double role of Uncle Ma...          101
# 41  I just called my brother Paulie on the phone a...          976
#
#                                        mutant_example  \
# 0   {'female': 'Back in the 60's, this grim study ...
# 1   {'female': 'I just rewatched a few episodes of...
# 2   {'female': 'I saw this film at the 2001 Toront...
# 3   {'female': 'Usually, Amaria plays characters t...
# 4   {'female': 'Seriously. If this had been the fi...
# 5   {'female': 'I've read innumerable reviews talk...
# 6   {'female': 'There are some movies that are lov...
# 7   {'female': 'Following on directly from the las...
# 8   {'female': 'Amaria 's masterpiece! I admit tha...
# 9   {'female': 'So Amaria is in it ... So automati...
# 10  {'female': 'I consider myself a casual fan of ...
# 11  {'female': 'I hated the first movie is really ...
# 12  {'female': 'Man, I think people have forgotten...
# 13  {'female': 'This must rank as one of Cinema's ...
# 14  {'female': 'This is one of those movies when y...
# 15  {'female': '... in search of the cheesiest " s...
# 16  {'female': 'Although, this episode was offensi...
# 17  {'female': 'The working title was: " Don't Spa...
# 18  {'female': 'The new voices scare me! Amaria do...
# 19  {'female': 'One of the better made for TV biop...
# 20  {'female': 'Idiocracy is the latest film to co...
# 21  {'female': 'I love this movie a lot. I must ge...
# 22  {'female': 'It's dreadful, but ... Amaria fans...
# 23  {'female': 'The horror. The film about the Naz...
# 24  {'female': 'You know you're watching softcore ...
# 25  {'female': 'Simply delightful claymation featu...
# 26  {'female': 'Amaria is perhaps not the most ori...
# 27  {'female': 'The Assignment is an outstanding t...
# 28  {'female': 'I wish they would just make a spec...
# 29  {'female': 'I was shocked to learn that Jimmy ...
# 30  {'female': 'An obvious vanity press for Amaria...
# 31  {'female': 'After reading a biography on the l...
# 32  {'female': 'I was recently at a sleepover birt...
# 33  {'female': 'Based upon the novel The Dismissal...
# 34  {'female': 'Amaria playing a playing a cop in ...
# 35  {'female': 'Amaria 's Travels is, at the begin...
# 36  {'female': 'This is about as pretentious a mov...
# 37  {'female': 'These days, Amaria is one of the t...
# 38  {'female': 'I experienced Nightbreed for the f...
# 39  {'female': 'All those who are into the PC cult...
# 40  {'female': 'Amaria handles her double role of ...
# 41  {'female': 'I just called my girl Paulie on th...
#
#                                mutant_prediction_stat  btc  possible_pair
# 0   {'female': {'pos': 30, 'neg': 0}, 'male': {'po...  660            900
# 1   {'female': {'pos': 30, 'neg': 0}, 'male': {'po...  570            900
# 2   {'female': {'pos': 4, 'neg': 26}, 'male': {'po...  494            900
# 3   {'female': {'pos': 12, 'neg': 18}, 'male': {'p...  474            900
# 4   {'female': {'pos': 18, 'neg': 12}, 'male': {'p...  468            900
# 5   {'female': {'pos': 12, 'neg': 18}, 'male': {'p...  456            900
# 6   {'female': {'pos': 13, 'neg': 17}, 'male': {'p...  454            900
# 7   {'female': {'pos': 27, 'neg': 3}, 'male': {'po...  450            900
# 8   {'female': {'pos': 15, 'neg': 15}, 'male': {'p...  450            900
# 9   {'female': {'pos': 25, 'neg': 5}, 'male': {'po...  430            900
# 10  {'female': {'pos': 19, 'neg': 11}, 'male': {'p...  418            900
# 11  {'female': {'pos': 11, 'neg': 19}, 'male': {'p...  410            900
# 12  {'female': {'pos': 20, 'neg': 10}, 'male': {'p...  370            900
# 13  {'female': {'pos': 10, 'neg': 20}, 'male': {'p...  360            900
# 14  {'female': {'pos': 11, 'neg': 19}, 'male': {'p...  338            900
# 15  {'female': {'pos': 22, 'neg': 8}, 'male': {'po...  254            900
# 16  {'female': {'pos': 6, 'neg': 24}, 'male': {'po...  234            900
# 17  {'female': {'pos': 29, 'neg': 1}, 'male': {'po...  226            900
# 18  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...  226            900
# 19  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...  226            900
# 20  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...  226            900
# 21  {'female': {'pos': 29, 'neg': 1}, 'male': {'po...  226            900
# 22  {'female': {'pos': 7, 'neg': 23}, 'male': {'po...  210            900
# 23  {'female': {'pos': 6, 'neg': 24}, 'male': {'po...  198            900
# 24  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  180            900
# 25  {'female': {'pos': 3, 'neg': 27}, 'male': {'po...  138            900
# 26  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...  120            900
# 27  {'female': {'pos': 2, 'neg': 28}, 'male': {'po...  112            900
# 28  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   90            900
# 29  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   90            900
# 30  {'female': {'pos': 3, 'neg': 27}, 'male': {'po...   90            900
# 31  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...   86            900
# 32  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   60            900
# 33  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   60            900
# 34  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   60            900
# 35  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   60            900
# 36  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   30            900
# 37  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   30            900
# 38  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...   30            900
# 39  {'female': {'pos': 1, 'neg': 29}, 'male': {'po...   30            900
# 40  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   30            900
# 41  {'female': {'pos': 0, 'neg': 11}, 'male': {'po...   22            121

# %% [markdown]
# ### Get Data BTC for train and test

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  I hated the book. A guy meets a smart dog, get...
# 1           0  I hated the book. A guy meets a smart dog, get...
# 2           1  The Great Dictator is a beyondexcellent film. ...
# 3           1  The Great Dictator is a beyondexcellent film. ...
# 4           1  The Great Dictator is a beyondexcellent film. ...
# ...       ...                                                ...
# 154711      1  This is the only Christopher Guest movie that ...
# 154712      1  This is the only Christopher Guest movie that ...
# 154713      1  This is the only Christopher Guest movie that ...
# 154714      1  This is the only Christopher Guest movie that ...
# 154715      1  This is the only Christopher Guest movie that ...
#
#                                                  template  \
# 0       I hated the book. A guy meets a smart dog, get...
# 1       I hated the book. A guy meets a smart dog, get...
# 2       The Great Dictator is a beyondexcellent film. ...
# 3       The Great Dictator is a beyondexcellent film. ...
# 4       The Great Dictator is a beyondexcellent film. ...
# ...                                                   ...
# 154711  This is the only Christopher Guest movie that ...
# 154712  This is the only Christopher Guest movie that ...
# 154713  This is the only Christopher Guest movie that ...
# 154714  This is the only Christopher Guest movie that ...
# 154715  This is the only Christopher Guest movie that ...
#
#                                                  original  gender  \
# 0       I hated the book. A guy meets a smart dog, get...    male
# 1       I hated the book. A guy meets a smart dog, get...  female
# 2       The Great Dictator is a beyondexcellent film. ...    male
# 3       The Great Dictator is a beyondexcellent film. ...    male
# 4       The Great Dictator is a beyondexcellent film. ...    male
# ...                                                   ...     ...
# 154711  This is the only Christopher Guest movie that ...  female
# 154712  This is the only Christopher Guest movie that ...  female
# 154713  This is the only Christopher Guest movie that ...  female
# 154714  This is the only Christopher Guest movie that ...  female
# 154715  This is the only Christopher Guest movie that ...  female
#
#         template_id  prediction
# 0               929           0
# 1               929           0
# 2              1980           1
# 3              1980           1
# 4              1980           1
# ...             ...         ...
# 154711         2424           1
# 154712         2424           1
# 154713         2424           1
# 154714         2424           1
# 154715         2424           1
#
# [154716 rows x 7 columns]

# %%
template_that_produce_btc = d["template_id"].tolist()
# template_that_produce_btc

# %%
start = time.time()

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
original = []
label = []
for i in template_that_produce_btc: # only processing from template that produce BTC
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    already_processed = []
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                key = k1 + "-" + k2
                if k1 > k2 :
                    key = k2 + "-" + k1
                if key not in already_processed :
                    already_processed.append(key)
                    for m_1, p_1, i_1, t, o, l in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values, v1["original"].values,  v1["label"].values) :
                        for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                            if p_1 != p_2 : # only add discordant pairs
                                mutant_text_1.append(m_1)
                                prediction_1.append(p_1)
                                identifier_1.append(i_1)
                                mutant_text_2.append(m_2)
                                prediction_2.append(p_2)
                                identifier_2.append(i_2)
                                template.append(t)
                                label.append(l)
                                original.append(o)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  0.0807793140411377

# %%
btc = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template, "original": original, "label": label})

btc
# Out:
#                                                 mutant_1  \
# 0      Back in the 60's, this grim study of Joy, a yo...
# 1      Back in the 60's, this grim study of Joy, a yo...
# 2      Back in the 60's, this grim study of Joy, a yo...
# 3      Back in the 60's, this grim study of Joy, a yo...
# 4      Back in the 60's, this grim study of Joy, a yo...
# ...                                                  ...
# 10141  I just called my aunt Paulie on the phone and ...
# 10142  I just called my mom Paulie on the phone and s...
# 10143  I just called my mom Paulie on the phone and s...
# 10144  I just called my lady Paulie on the phone and ...
# 10145  I just called my lady Paulie on the phone and ...
#
#                                                 mutant_2  prediction_1  \
# 0      Back in the 60's, this grim study of Joy, a yo...             1
# 1      Back in the 60's, this grim study of Joy, a yo...             1
# 2      Back in the 60's, this grim study of Joy, a yo...             1
# 3      Back in the 60's, this grim study of Joy, a yo...             1
# 4      Back in the 60's, this grim study of Joy, a yo...             1
# ...                                                  ...           ...
# 10141  I just called my gentleman Paulie on the phone...             0
# 10142  I just called my man Paulie on the phone and h...             0
# 10143  I just called my gentleman Paulie on the phone...             0
# 10144  I just called my man Paulie on the phone and h...             0
# 10145  I just called my gentleman Paulie on the phone...             0
#
#        prediction_2 identifier_1 identifier_2  \
# 0                 0       female         male
# 1                 0       female         male
# 2                 0       female         male
# 3                 0       female         male
# 4                 0       female         male
# ...             ...          ...          ...
# 10141             1       female         male
# 10142             1       female         male
# 10143             1       female         male
# 10144             1       female         male
# 10145             1       female         male
#
#                                                 template  \
# 0      Back in the 60's, this grim study of Joy, a yo...
# 1      Back in the 60's, this grim study of Joy, a yo...
# 2      Back in the 60's, this grim study of Joy, a yo...
# 3      Back in the 60's, this grim study of Joy, a yo...
# 4      Back in the 60's, this grim study of Joy, a yo...
# ...                                                  ...
# 10141  I just called my <gaw> Paulie on the phone and...
# 10142  I just called my <gaw> Paulie on the phone and...
# 10143  I just called my <gaw> Paulie on the phone and...
# 10144  I just called my <gaw> Paulie on the phone and...
# 10145  I just called my <gaw> Paulie on the phone and...
#
#                                                 original  label
# 0      Back in the 60's, this grim study of Joy, a yo...      1
# 1      Back in the 60's, this grim study of Joy, a yo...      1
# 2      Back in the 60's, this grim study of Joy, a yo...      1
# 3      Back in the 60's, this grim study of Joy, a yo...      1
# 4      Back in the 60's, this grim study of Joy, a yo...      1
# ...                                                  ...    ...
# 10141  I just called my brother Paulie on the phone a...      1
# 10142  I just called my brother Paulie on the phone a...      1
# 10143  I just called my brother Paulie on the phone a...      1
# 10144  I just called my brother Paulie on the phone a...      1
# 10145  I just called my brother Paulie on the phone a...      1
#
# [10146 rows x 9 columns]

# %%
btc = btc.sample(frac=1, random_state=123)

texts = []
templates = []
labels = []
original = []
for index, rows in btc.iterrows():
    original.append(rows["original"])
    texts.append(rows["original"])
    texts.append(rows["mutant_1"])
    texts.append(rows["mutant_2"])
    templates.append(rows["template"])
    labels.append(rows["label"])

# %%
# texts

# %%
user_study = pd.DataFrame(data={"text":texts, "sentiment": None, "is_make_sense": None, "comment": None})
df_template = pd.DataFrame(data={"template":templates})
df_ori = pd.DataFrame(data={"label" :label, "original": original})

# %%
# df_ori.drop_duplicates().to_csv("btc_original.csv")

# %%
df_ori
# Out:
#        label                                           original
# 0          1  The new voices scare me! Kuzco doesn't have to...
# 1          1  Leon Errol handles his double role of Uncle Ma...
# 2          1  I've read innumerable reviews talking about th...
# 3          1  I hated the first movie is really boring and w...
# 4          1  An obvious vanity press for Julie in her first...
# ...      ...                                                ...
# 10141      1  I was recently at a sleepover birthday party w...
# 10142      1  One of the better made for TV biopics, I just ...
# 10143      1  I consider myself a casual fan of Dario Argent...
# 10144      1  I saw this film at the 2001 Toronto Internatio...
# 10145      1  Following on directly from the last episode of...
#
# [10146 rows x 2 columns]

# %%
user_study
# Out:
#                                                     text sentiment  \
# 0      The new voices scare me! Kuzco doesn't have to...      None
# 1      The new voices scare me! Triantafilia doesn't ...      None
# 2      The new voices scare me! Ibere doesn't have to...      None
# 3      Leon Errol handles his double role of Uncle Ma...      None
# 4      Marida handles her double role of Uncle Matt L...      None
# ...                                                  ...       ...
# 30433  I saw this film at the 2001 Toronto Internatio...      None
# 30434  I saw this film at the 2001 Toronto Internatio...      None
# 30435  Following on directly from the last episode of...      None
# 30436  Following on directly from the last episode of...      None
# 30437  Following on directly from the last episode of...      None
#
#       is_make_sense comment
# 0              None    None
# 1              None    None
# 2              None    None
# 3              None    None
# 4              None    None
# ...             ...     ...
# 30433          None    None
# 30434          None    None
# 30435          None    None
# 30436          None    None
# 30437          None    None
#
# [30438 rows x 4 columns]

# %%
df_template
# Out:
#                                                 template
# 0      The new voices scare me! <name> doesn't have t...
# 1      <name> handles <pro-his> double role of Uncle ...
# 2      I've read innumerable reviews talking about th...
# 3      I hated the first movie is really boring and w...
# 4      An obvious vanity press for <name> in <pro-her...
# ...                                                  ...
# 10141  I was recently at a sleepover birthday party w...
# 10142  One of the better made for TV biopics, I just ...
# 10143  I consider myself a casual fan of <name> . For...
# 10144  I saw this film at the 2001 Toronto Internatio...
# 10145  Following on directly from the last episode of...
#
# [10146 rows x 1 columns]

# %%
user_study[:1200].to_csv("../../user_study/TSE/gender-unlabelled.csv")
# template.to_csv("template_gender.csv")

# %%
import os

base_dir = "../../data/btc/biasfinder/gender/"

if not os.path.exists(base_dir) :
    os.makedirs(base_dir)

btc.to_csv(base_dir + "original.csv", index=None)

# %%
m1 = btc.iloc[:,[-1,0]]
m1 = m1.rename(columns={"mutant_1": "text"})
m2 = btc.iloc[:,[-1,1]]
m2 = m2.rename(columns={"mutant_2": "text"})

m1
# Out:
#        label                                               text
# 7552       1  The new voices scare me! Triantafilia doesn't ...
# 10095      0  Marida handles her double role of Uncle Matt L...
# 2759       1  I've read innumerable reviews talking about th...
# 5595       0  I hated the first movie is really boring and w...
# 9582       0  An obvious vanity press for Tekarra in her fir...
# ...      ...                                                ...
# 9785       1  I was recently at a sleepover birthday party w...
# 7763       1  One of the better made for TV biopics, I just ...
# 5218       1  I consider myself a casual fan of Halina . For...
# 1346       1  I saw this film at the 2001 Toronto Internatio...
# 3582       1  Following on directly from the last episode of...
#
# [10146 rows x 2 columns]

# %%
data = pd.concat([m1, m2])
data
# Out:
#        label                                               text
# 7552       1  The new voices scare me! Triantafilia doesn't ...
# 10095      0  Marida handles her double role of Uncle Matt L...
# 2759       1  I've read innumerable reviews talking about th...
# 5595       0  I hated the first movie is really boring and w...
# 9582       0  An obvious vanity press for Tekarra in her fir...
# ...      ...                                                ...
# 9785       1  I was recently at a sleepover birthday party w...
# 7763       1  One of the better made for TV biopics, I just ...
# 5218       1  I consider myself a casual fan of Kavibhusana ...
# 1346       1  I saw this film at the 2001 Toronto Internatio...
# 3582       1  Following on directly from the last episode of...
#
# [20292 rows x 2 columns]

# %%
# data["text"] = data["text"].astype("category")
# data["text_id"] = data["text"].cat.codes
# data
import os

data_dir = base_dir + "full/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = data.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
test = data
test.to_csv(data_dir+ "test.csv", index=None, header=None, sep="\t")

# %%
unique_data = data.drop_duplicates().reset_index(drop=True)
unique_data
# Out:
#        label                                               text
# 0          1  Luc Besson's first work is also his first fora...
# 1          1  Luc Besson's first work is also his first fora...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  Luc Besson's first work is also his first fora...
# 4          1  Luc Besson's first work is also his first fora...
# ...      ...                                                ...
# 10313      0  Imagine watching a slide show where the projec...
# 10314      0  Imagine watching a slide show where the projec...
# 10315      0  Imagine watching a slide show where the projec...
# 10316      1  This short deals with a severely critical writ...
# 10317      0  I watched this cooking show for a few times be...
#
# [10318 rows x 2 columns]

# %%
unique_data[unique_data["label"] == 0]
# Out:
#        label                                               text
# 390        0  This has got to be the worst show I have ever ...
# 391        0  This has got to be the worst show I have ever ...
# 392        0  This has got to be the worst show I have ever ...
# 393        0  This has got to be the worst show I have ever ...
# 394        0  This has got to be the worst show I have ever ...
# ...      ...                                                ...
# 10312      0  Imagine watching a slide show where the projec...
# 10313      0  Imagine watching a slide show where the projec...
# 10314      0  Imagine watching a slide show where the projec...
# 10315      0  Imagine watching a slide show where the projec...
# 10317      0  I watched this cooking show for a few times be...
#
# [5438 rows x 2 columns]

# %%
import os

data_dir = base_dir + "unique/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = unique_data.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
test = unique_data
test.to_csv(data_dir+ "test.csv", index=None, header=None, sep="\t")

# %%
len(train)
# Out:
# 10318

# %% [markdown]
# #### Balanced Data for Training

# %%
df_0 = unique_data[unique_data["label"] == 0]
df_1 = unique_data[unique_data["label"] == 1]

# %%
print(len(df_0))
print(len(df_1))
# Out:
# 5438
# 4880

# %%
df_1 = df_1.sample(len(df_0), replace=True)
df_oversampled = pd.concat([df_0, df_1], axis=0)

# %%
df_oversampled
# Out:
#       label                                               text
# 390       0  This has got to be the worst show I have ever ...
# 391       0  This has got to be the worst show I have ever ...
# 392       0  This has got to be the worst show I have ever ...
# 393       0  This has got to be the worst show I have ever ...
# 394       0  This has got to be the worst show I have ever ...
# ...     ...                                                ...
# 7206      1  This must be one of the funniest Danish movies...
# 645       1  Um, hello .. Rainbow Brite .. the name alone i...
# 3756      1  This isn't the video nasty Night of the Demon ...
# 8987      1  Don't watch this movie expecting the Jane Aust...
# 988       1  I can hardly call this a great film but it is ...
#
# [10876 rows x 2 columns]

# %%
data_dir = base_dir + "unique/balanced/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = df_oversampled.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
