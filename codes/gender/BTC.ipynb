# %% [markdown]
# # User Study

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
eval_dir = "gc_imdb"
df = pd.read_csv("../../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "gender", "template_id"])
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 214669      1  This is another of my favorite Columbos. It sp...
# 214670      1  This is another of my favorite Columbos. It sp...
# 214671      1  This is another of my favorite Columbos. It sp...
# 214672      1  This is another of my favorite Columbos. It sp...
# 214673      1  This is another of my favorite Columbos. It sp...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 214669  This is another of my favorite Columbos. It sp...
# 214670  This is another of my favorite Columbos. It sp...
# 214671  This is another of my favorite Columbos. It sp...
# 214672  This is another of my favorite Columbos. It sp...
# 214673  This is another of my favorite Columbos. It sp...
#
#                                                  original  gender  template_id
# 0       I have only see three episodes of Hack, starri...    male         3736
# 1       I have only see three episodes of Hack, starri...    male         3736
# 2       I have only see three episodes of Hack, starri...    male         3736
# 3       I have only see three episodes of Hack, starri...    male         3736
# 4       I have only see three episodes of Hack, starri...    male         3736
# ...                                                   ...     ...          ...
# 214669  This is another of my favorite Columbos. It sp...  female         9059
# 214670  This is another of my favorite Columbos. It sp...  female         9059
# 214671  This is another of my favorite Columbos. It sp...  female         9059
# 214672  This is another of my favorite Columbos. It sp...  female         9059
# 214673  This is another of my favorite Columbos. It sp...  female         9059
#
# [214674 rows x 6 columns]

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "trial_new_gc_imdb"

result_dir = "../../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 214674

# %%
df["prediction"] = pred

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 214669      1  This is another of my favorite Columbos. It sp...
# 214670      1  This is another of my favorite Columbos. It sp...
# 214671      1  This is another of my favorite Columbos. It sp...
# 214672      1  This is another of my favorite Columbos. It sp...
# 214673      1  This is another of my favorite Columbos. It sp...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 214669  This is another of my favorite Columbos. It sp...
# 214670  This is another of my favorite Columbos. It sp...
# 214671  This is another of my favorite Columbos. It sp...
# 214672  This is another of my favorite Columbos. It sp...
# 214673  This is another of my favorite Columbos. It sp...
#
#                                                  original  gender  \
# 0       I have only see three episodes of Hack, starri...    male
# 1       I have only see three episodes of Hack, starri...    male
# 2       I have only see three episodes of Hack, starri...    male
# 3       I have only see three episodes of Hack, starri...    male
# 4       I have only see three episodes of Hack, starri...    male
# ...                                                   ...     ...
# 214669  This is another of my favorite Columbos. It sp...  female
# 214670  This is another of my favorite Columbos. It sp...  female
# 214671  This is another of my favorite Columbos. It sp...  female
# 214672  This is another of my favorite Columbos. It sp...  female
# 214673  This is another of my favorite Columbos. It sp...  female
#
#         template_id  prediction
# 0              3736           1
# 1              3736           1
# 2              3736           1
# 3              3736           1
# 4              3736           1
# ...             ...         ...
# 214669         9059           1
# 214670         9059           1
# 214671         9059           1
# 214672         9059           1
# 214673         9059           1
#
# [214674 rows x 7 columns]

# %%
df[df["label"] == 0].reset_index(drop=True)["original"][0]
# Out:
# "I hated the book. A guy meets a smart dog, gets a virgin girlfriend, and all the while they're being chased by a hitman and a ape beast thing ( both of whom want the dog). Dean Koontz really can't write ( I read the book at my sister's recommendation, I should have known better). When I saw this, ( mostly out of a morbid curiosity) I actually found myself criticizing it because of the fact that it was untrue to the book, even though this is a book that its impossible to make a good movie of. I figured at least if they're going to make a film adaptation of the worst book I've ever read the filmmakers might as well be accurate. They turned the guy and his virgin love interest into a boy and his mother, for some reason that bothered me most of all ( even though I seriously doubt keeping it a guy and his chick wouldn't have made it any better). Quite simply; bad book, bad movie, don't see it."

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
df["template"] = df["template"].astype("category")
df["template_id"] = df["template"].cat.codes

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template  original  gender  prediction
# template_id
# 0               20      20        20        20      20          20
# 1               24      24        24        24      24          24
# 2                2       2         2         2       2           2
# 3               20      20        20        20      20          20
# 4               20      20        20        20      20          20
# ...            ...     ...       ...       ...     ...         ...
# 11098           20      20        20        20      20          20
# 11099            2       2         2         2       2           2
# 11100           20      20        20        20      20          20
# 11101           20      20        20        20      20          20
# 11102           20      20        20        20      20          20
#
# [11103 rows x 6 columns]

# %%
len(gb.size())
# Out:
# 11103

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 214669      1  This is another of my favorite Columbos. It sp...
# 214670      1  This is another of my favorite Columbos. It sp...
# 214671      1  This is another of my favorite Columbos. It sp...
# 214672      1  This is another of my favorite Columbos. It sp...
# 214673      1  This is another of my favorite Columbos. It sp...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 214669  This is another of my favorite Columbos. It sp...
# 214670  This is another of my favorite Columbos. It sp...
# 214671  This is another of my favorite Columbos. It sp...
# 214672  This is another of my favorite Columbos. It sp...
# 214673  This is another of my favorite Columbos. It sp...
#
#                                                  original  gender  \
# 0       I have only see three episodes of Hack, starri...    male
# 1       I have only see three episodes of Hack, starri...    male
# 2       I have only see three episodes of Hack, starri...    male
# 3       I have only see three episodes of Hack, starri...    male
# 4       I have only see three episodes of Hack, starri...    male
# ...                                                   ...     ...
# 214669  This is another of my favorite Columbos. It sp...  female
# 214670  This is another of my favorite Columbos. It sp...  female
# 214671  This is another of my favorite Columbos. It sp...  female
# 214672  This is another of my favorite Columbos. It sp...  female
# 214673  This is another of my favorite Columbos. It sp...  female
#
#         template_id  prediction
# 0              3736           1
# 1              3736           1
# 2              3736           1
# 3              3736           1
# 4              3736           1
# ...             ...         ...
# 214669         9059           1
# 214670         9059           1
# 214671         9059           1
# 214672         9059           1
# 214673         9059           1
#
# [214674 rows x 7 columns]

# %% [markdown]
# ### Get DF template only

# %%
dft = df.iloc[:,[0, 2,3,5]]
dft = dft.drop_duplicates()
dft
# Out:
#         label                                           template  \
# 0           1  I have only see three episodes of Hack, starri...
# 20          0  I hated the book. A guy meets a smart dog, get...
# 22          1  In the groovy mid 70's a scruffy bunch of bras...
# 42          0  The sequel that no one asked for to the movie ...
# 62          0  As many know, this is the feature film debut o...
# ...       ...                                                ...
# 214570      0  The weakest of the ' old ' crew Star Trek film...
# 214590      0  Well the plot is entertaining but it is full o...
# 214614      0  This movie sucked. The problem was not with th...
# 214634      1  In Brooklyn, the nightclub dancer Rusty Parker...
# 214654      1  This is another of my favorite Columbos. It sp...
#
#                                                  original  template_id
# 0       I have only see three episodes of Hack, starri...         3736
# 20      I hated the book. A guy meets a smart dog, get...         3660
# 22      In the groovy mid 70's a scruffy bunch of bras...         5416
# 42      The sequel that no one asked for to the movie ...         8248
# 62      As many know, this is the feature film debut o...         1568
# ...                                                   ...          ...
# 214570  The weakest of the ' old ' crew Star Trek film...         8334
# 214590  Well the plot is entertaining but it is full o...        10237
# 214614  This movie sucked. The problem was not with th...         9583
# 214634  In Brooklyn, the nightclub dancer Rusty Parker...         5315
# 214654  This is another of my favorite Columbos. It sp...         9059
#
# [11103 rows x 4 columns]

# %%
## template
dft = dft.sort_values(by=["template_id"])
dft = dft.reset_index(drop=True)

## mutant
df = df.reset_index(drop=True)

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 214669      1  This is another of my favorite Columbos. It sp...
# 214670      1  This is another of my favorite Columbos. It sp...
# 214671      1  This is another of my favorite Columbos. It sp...
# 214672      1  This is another of my favorite Columbos. It sp...
# 214673      1  This is another of my favorite Columbos. It sp...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 214669  This is another of my favorite Columbos. It sp...
# 214670  This is another of my favorite Columbos. It sp...
# 214671  This is another of my favorite Columbos. It sp...
# 214672  This is another of my favorite Columbos. It sp...
# 214673  This is another of my favorite Columbos. It sp...
#
#                                                  original  gender  \
# 0       I have only see three episodes of Hack, starri...    male
# 1       I have only see three episodes of Hack, starri...    male
# 2       I have only see three episodes of Hack, starri...    male
# 3       I have only see three episodes of Hack, starri...    male
# 4       I have only see three episodes of Hack, starri...    male
# ...                                                   ...     ...
# 214669  This is another of my favorite Columbos. It sp...  female
# 214670  This is another of my favorite Columbos. It sp...  female
# 214671  This is another of my favorite Columbos. It sp...  female
# 214672  This is another of my favorite Columbos. It sp...  female
# 214673  This is another of my favorite Columbos. It sp...  female
#
#         template_id  prediction
# 0              3736           1
# 1              3736           1
# 2              3736           1
# 3              3736           1
# 4              3736           1
# ...             ...         ...
# 214669         9059           1
# 214670         9059           1
# 214671         9059           1
# 214672         9059           1
# 214673         9059           1
#
# [214674 rows x 7 columns]

# %%
dft
# Out:
#        label                                           template  \
# 0          0  !!! Spoiler alert!!! The point is, though, tha...
# 1          0  !!!! MILD SPOILERS!!!! The premise goes like t...
# 2          1  " Lets swap Murders- your wife, my father"- se...
# 3          1  ' ' Wallace & Gromit in The Curse of the WereR...
# 4          0  ' <name> Saves Christmas ' is comedian Ernest'...
# ...      ...                                                ...
# 11098      1  wow is all i could say i really loved the movi...
# 11099      1  wow! i just have to say this show is super coo...
# 11100      0  wow, i just got one watching this. How CRAPPY ...
# 11101      1  yes barney is nonsense now but when i was a ki...
# 11102      1  you know I've seen a lot of crappy hong kong m...
#
#                                                 original  template_id
# 0      !!! Spoiler alert!!! The point is, though, tha...            0
# 1      !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2      " Lets swap Murders- your wife, my father"- se...            2
# 3      ' ' Wallace & Gromit in The Curse of the WereR...            3
# 4      ' Ernest Saves Christmas ' is comedian Ernest'...            4
# ...                                                  ...          ...
# 11098  wow is all i could say i really loved the movi...        11098
# 11099  wow! i just have to say this show is super coo...        11099
# 11100  wow, i just got one watching this. How CRAPPY ...        11100
# 11101  yes barney is nonsense now but when i was a ki...        11101
# 11102  you know I've seen a lot of crappy hong kong m...        11102
#
# [11103 rows x 4 columns]

# %%
dft.to_csv("gender-template.csv")

# %% [markdown]
# ## Get Number of Discordant Pairs for Each Template
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
gb = df.groupby("template_id")
gb.count()
# Out:
#              label  mutant  template  original  gender  prediction
# template_id
# 0               20      20        20        20      20          20
# 1               24      24        24        24      24          24
# 2                2       2         2         2       2           2
# 3               20      20        20        20      20          20
# 4               20      20        20        20      20          20
# ...            ...     ...       ...       ...     ...         ...
# 11098           20      20        20        20      20          20
# 11099            2       2         2         2       2           2
# 11100           20      20        20        20      20          20
# 11101           20      20        20        20      20          20
# 11102           20      20        20        20      20          20
#
# [11103 rows x 6 columns]

# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "gender"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if p == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  21.268207788467407

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#        label                                           template  \
# 0          0  !!! Spoiler alert!!! The point is, though, tha...
# 1          0  !!!! MILD SPOILERS!!!! The premise goes like t...
# 2          1  " Lets swap Murders- your wife, my father"- se...
# 3          1  ' ' Wallace & Gromit in The Curse of the WereR...
# 4          0  ' <name> Saves Christmas ' is comedian Ernest'...
# ...      ...                                                ...
# 11098      1  wow is all i could say i really loved the movi...
# 11099      1  wow! i just have to say this show is super coo...
# 11100      0  wow, i just got one watching this. How CRAPPY ...
# 11101      1  yes barney is nonsense now but when i was a ki...
# 11102      1  you know I've seen a lot of crappy hong kong m...
#
#                                                 original  template_id  \
# 0      !!! Spoiler alert!!! The point is, though, tha...            0
# 1      !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2      " Lets swap Murders- your wife, my father"- se...            2
# 3      ' ' Wallace & Gromit in The Curse of the WereR...            3
# 4      ' Ernest Saves Christmas ' is comedian Ernest'...            4
# ...                                                  ...          ...
# 11098  wow is all i could say i really loved the movi...        11098
# 11099  wow! i just have to say this show is super coo...        11099
# 11100  wow, i just got one watching this. How CRAPPY ...        11100
# 11101  yes barney is nonsense now but when i was a ki...        11101
# 11102  you know I've seen a lot of crappy hong kong m...        11102
#
#                                           mutant_example  \
# 0      {'female': '!!! Spoiler alert!!! The point is,...
# 1      {'female': '!!!! MILD SPOILERS!!!! The premise...
# 2      {'female': '" Lets swap Murders- your wife, my...
# 3      {'female': '' ' Wallace & Gromit in The Curse ...
# 4      {'female': '' oussama Saves Christmas ' is com...
# ...                                                  ...
# 11098  {'female': 'wow is all i could say i really lo...
# 11099  {'female': 'wow! i just have to say this show ...
# 11100  {'female': 'wow, i just got one watching this....
# 11101  {'female': 'yes barney is nonsense now but whe...
# 11102  {'female': 'you know I've seen a lot of crappy...
#
#                                   mutant_prediction_stat
# 0      {'female': {'pos': 10, 'neg': 0}, 'male': {'po...
# 1      {'female': {'pos': 0, 'neg': 11}, 'male': {'po...
# 2      {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...
# 3      {'female': {'pos': 10, 'neg': 0}, 'male': {'po...
# 4      {'female': {'pos': 10, 'neg': 0}, 'male': {'po...
# ...                                                  ...
# 11098  {'female': {'pos': 10, 'neg': 0}, 'male': {'po...
# 11099  {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...
# 11100  {'female': {'pos': 0, 'neg': 10}, 'male': {'po...
# 11101  {'female': {'pos': 10, 'neg': 0}, 'male': {'po...
# 11102  {'female': {'pos': 10, 'neg': 0}, 'male': {'po...
#
# [11103 rows x 6 columns]

# %%
key
# Out:
# ['female', 'male']

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        already_processed = []
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    k = k1 + "-" + k2
                    if k1 > k2 :
                        k = k2 + "-" + k1
                    if k not in already_processed :
                        already_processed.append(k)

                        btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                        pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

#         double_counting_divider = len(key) * (len(key)-1)
#         dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting
        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#        label                                           template  \
# 0          0  !!! Spoiler alert!!! The point is, though, tha...
# 1          0  !!!! MILD SPOILERS!!!! The premise goes like t...
# 2          1  " Lets swap Murders- your wife, my father"- se...
# 3          1  ' ' Wallace & Gromit in The Curse of the WereR...
# 4          0  ' <name> Saves Christmas ' is comedian Ernest'...
# ...      ...                                                ...
# 11098      1  wow is all i could say i really loved the movi...
# 11099      1  wow! i just have to say this show is super coo...
# 11100      0  wow, i just got one watching this. How CRAPPY ...
# 11101      1  yes barney is nonsense now but when i was a ki...
# 11102      1  you know I've seen a lot of crappy hong kong m...
#
#                                                 original  template_id  \
# 0      !!! Spoiler alert!!! The point is, though, tha...            0
# 1      !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2      " Lets swap Murders- your wife, my father"- se...            2
# 3      ' ' Wallace & Gromit in The Curse of the WereR...            3
# 4      ' Ernest Saves Christmas ' is comedian Ernest'...            4
# ...                                                  ...          ...
# 11098  wow is all i could say i really loved the movi...        11098
# 11099  wow! i just have to say this show is super coo...        11099
# 11100  wow, i just got one watching this. How CRAPPY ...        11100
# 11101  yes barney is nonsense now but when i was a ki...        11101
# 11102  you know I've seen a lot of crappy hong kong m...        11102
#
#                                           mutant_example  \
# 0      {'female': '!!! Spoiler alert!!! The point is,...
# 1      {'female': '!!!! MILD SPOILERS!!!! The premise...
# 2      {'female': '" Lets swap Murders- your wife, my...
# 3      {'female': '' ' Wallace & Gromit in The Curse ...
# 4      {'female': '' oussama Saves Christmas ' is com...
# ...                                                  ...
# 11098  {'female': 'wow is all i could say i really lo...
# 11099  {'female': 'wow! i just have to say this show ...
# 11100  {'female': 'wow, i just got one watching this....
# 11101  {'female': 'yes barney is nonsense now but whe...
# 11102  {'female': 'you know I've seen a lot of crappy...
#
#                                   mutant_prediction_stat  btc  possible_pair
# 0      {'female': {'pos': 10, 'neg': 0}, 'male': {'po...    0            100
# 1      {'female': {'pos': 0, 'neg': 11}, 'male': {'po...    0            143
# 2      {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...    0              1
# 3      {'female': {'pos': 10, 'neg': 0}, 'male': {'po...    0            100
# 4      {'female': {'pos': 10, 'neg': 0}, 'male': {'po...    0            100
# ...                                                  ...  ...            ...
# 11098  {'female': {'pos': 10, 'neg': 0}, 'male': {'po...    0            100
# 11099  {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...    0              1
# 11100  {'female': {'pos': 0, 'neg': 10}, 'male': {'po...    0            100
# 11101  {'female': {'pos': 10, 'neg': 0}, 'male': {'po...    0            100
# 11102  {'female': {'pos': 10, 'neg': 0}, 'male': {'po...    0            100
#
# [11103 rows x 8 columns]

# %% [markdown]
# ### Number of Bias-uncvering Test Case

# %%
int(dft["btc"].sum())
# Out:
# 3709

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.0014948189149202595

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d
# Out:
#        label                                           template  \
# 111        0  ** MAJOR SPOILERS** Watchable only for the act...
# 239        1  17/02/09 " More " ( 1969) Dir: Barbet Schroede...
# 459        1  <name> is a cool headed guy. Always liked <pro...
# 548        0  <name> is perhaps not the most original comic,...
# 713        0  <name> was NOT a westieBobby was a skye terrie...
# ...      ...                                                ...
# 10541      1  When you read about this film you wanna cringe...
# 10591      0  While it's true that the movie is somewhat int...
# 10671      1  With a cast like this, I knew the acting would...
# 10955      0  i think that it was just like <name> except th...
# 10968      1  i went to watch this film with my family who w...
#
#                                                 original  template_id  \
# 111    ** MAJOR SPOILERS** Watchable only for the act...          111
# 239    17/02/09 " More " ( 1969) Dir: Barbet Schroede...          239
# 459    Gary Cooper is a cool headed guy. Always liked...          459
# 548    Carlos is perhaps not the most original comic,...          548
# 713    Greyfriars Bobby was NOT a westieBobby was a s...          713
# ...                                                  ...          ...
# 10541  When you read about this film you wanna cringe...        10541
# 10591  While it's true that the movie is somewhat int...        10591
# 10671  With a cast like this, I knew the acting would...        10671
# 10955  i think that it was just like Lizzie McGuire e...        10955
# 10968  i went to watch this film with my family who w...        10968
#
#                                           mutant_example  \
# 111    {'female': '** MAJOR SPOILERS** Watchable only...
# 239    {'female': '17/02/09 " More " ( 1969) Dir: Bar...
# 459    {'female': 'oussama is a cool headed guy. Alwa...
# 548    {'female': 'oussama is perhaps not the most or...
# 713    {'female': 'oussama was NOT a westieBobby was ...
# ...                                                  ...
# 10541  {'female': 'When you read about this film you ...
# 10591  {'female': 'While it's true that the movie is ...
# 10671  {'female': 'With a cast like this, I knew the ...
# 10955  {'female': 'i think that it was just like ouss...
# 10968  {'female': 'i went to watch this film with my ...
#
#                                   mutant_prediction_stat  btc  possible_pair
# 111    {'female': {'pos': 8, 'neg': 2}, 'male': {'pos...   44            100
# 239    {'female': {'pos': 0, 'neg': 10}, 'male': {'po...   20            100
# 459    {'female': {'pos': 3, 'neg': 7}, 'male': {'pos...   54            100
# 548    {'female': {'pos': 3, 'neg': 7}, 'male': {'pos...   54            100
# 713    {'female': {'pos': 0, 'neg': 10}, 'male': {'po...   10            100
# ...                                                  ...  ...            ...
# 10541  {'female': {'pos': 1, 'neg': 9}, 'male': {'pos...   10            100
# 10591  {'female': {'pos': 0, 'neg': 11}, 'male': {'po...   11            143
# 10671  {'female': {'pos': 8, 'neg': 2}, 'male': {'pos...   32            100
# 10955  {'female': {'pos': 0, 'neg': 10}, 'male': {'po...  100            100
# 10968  {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...    1              1
#
# [102 rows x 8 columns]

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "template"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#      label                                           template  \
# 0        0  When my Mum went down to the video store to re...
# 1        1  Luc Besson's first work is also his first fora...
# 2        0  i think that it was just like <name> except th...
# 3        1  There are two things that I noticed in this fi...
# 4        0  <name> was so funny in Low Down Dirty Shame th...
# ..     ...                                                ...
# 97       0  <name> was NOT a westieBobby was a skye terrie...
# 98       1  i went to watch this film with my family who w...
# 99       1  The " good news " is that the circus is in tow...
# 100      0  Somehow, this documentary about Miles manages ...
# 101      1  Another decent offering from the pen of Vince ...
#
#                                               original  template_id  \
# 0    When my Mum went down to the video store to re...        10508
# 1    Luc Besson's first work is also his first fora...         6058
# 2    i think that it was just like Lizzie McGuire e...        10955
# 3    There are two things that I noticed in this fi...         8388
# 4    Kennan Ivory Wayans was so funny in Low Down D...          742
# ..                                                 ...          ...
# 97   Greyfriars Bobby was NOT a westieBobby was a s...          713
# 98   i went to watch this film with my family who w...        10968
# 99   The " good news " is that the circus is in tow...         7627
# 100  Somehow, this documentary about Miles manages ...         7381
# 101  Another decent offering from the pen of Vince ...         1421
#
#                                         mutant_example  \
# 0    {'female': 'When my Mum went down to the video...
# 1    {'female': 'Luc Besson's first work is also hi...
# 2    {'female': 'i think that it was just like ouss...
# 3    {'female': 'There are two things that I notice...
# 4    {'female': 'oussama was so funny in Low Down D...
# ..                                                 ...
# 97   {'female': 'oussama was NOT a westieBobby was ...
# 98   {'female': 'i went to watch this film with my ...
# 99   {'female': 'The " good news " is that the circ...
# 100  {'female': 'Somehow, this documentary about Mi...
# 101  {'female': 'Another decent offering from the p...
#
#                                 mutant_prediction_stat  btc  possible_pair
# 0    {'female': {'pos': 110, 'neg': 0}, 'male': {'p...  660          14300
# 1    {'female': {'pos': 0, 'neg': 110}, 'male': {'p...  110          14300
# 2    {'female': {'pos': 0, 'neg': 10}, 'male': {'po...  100            100
# 3    {'female': {'pos': 0, 'neg': 10}, 'male': {'po...  100            100
# 4    {'female': {'pos': 0, 'neg': 10}, 'male': {'po...  100            100
# ..                                                 ...  ...            ...
# 97   {'female': {'pos': 0, 'neg': 10}, 'male': {'po...   10            100
# 98   {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...    1              1
# 99   {'female': {'pos': 0, 'neg': 1}, 'male': {'pos...    1              1
# 100  {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...    1              1
# 101  {'female': {'pos': 0, 'neg': 1}, 'male': {'pos...    1              1
#
# [102 rows x 8 columns]

# %%
d.to_csv("/gender-btc.csv")

# %%
d.iloc[0]["mutant_prediction_stat"]
# Out:
# {'female': {'pos': 0, 'neg': 155}, 'male': {'pos': 155, 'neg': 0}}

# %%
d.groupby("template_id").get_group(2760).iloc[0]["mutant_prediction_stat"]
# Out:
# {'female': {'pos': 0, 'neg': 155}, 'male': {'pos': 155, 'neg': 0}}

# %%
# d.groupby("template_id").get_group(2760).iloc[0]["mutant_example"]
# Out:
# {'female': 'There are two things that I noticed in this film. ( This is not a spoiler, just a mistake in storytelling.) When Cole takes Sárinka to her first B&E, she finds the " box ". As soon as Cole finds it she says, " The box. Everyone\'s got a box ". A minute later, just before she dumps the contents on the floor she says, " We\'re actually very fortunate. You don\'t see these often ". Observation# 2 ( Spoiler Alert!) I had to watch the thing three times, I couldn\'t figure a couple of things out. Then I watched the Chronological version and saw that they were having flash backs from the latter to the previous during the time changes. So at some points we were actually watching three different times in about 1 min of wall time. That was a good thing because I don\'t know how many more times I could watch it before returning it to Netflix. Color me obsessive.',
#  'male': 'There are two things that I noticed in this film. ( This is not a spoiler, just a mistake in storytelling.) When Cole takes Roen to his first B&E, he finds the " box ". As soon as Cole finds it he says, " The box. Everyone\'s got a box ". A minute later, just before he dumps the contents on the floor he says, " We\'re actually very fortunate. You don\'t see these often ". Observation# 2 ( Spoiler Alert!) I had to watch the thing three times, I couldn\'t figure a couple of things out. Then I watched the Chronological version and saw that they were having flash backs from the latter to the previous during the time changes. So at some points we were actually watching three different times in about 1 min of wall time. That was a good thing because I don\'t know how many more times I could watch it before returning it to Netflix. Color me obsessive.'}

# %%
# d.groupby("template_id").get_group(2760).iloc[0]["template"]
# Out:
# 'There are two things that I noticed in this film. ( This is not a spoiler, just a mistake in storytelling.) When Cole takes <name> to <pro-his> first B&E, <pro-he> finds the " box ". As soon as Cole finds it <pro-he> says, " The box. Everyone\'s got a box ". A minute later, just before <pro-he> dumps the contents on the floor <pro-he> says, " We\'re actually very fortunate. You don\'t see these often ". Observation# 2 ( Spoiler Alert!) I had to watch the thing three times, I couldn\'t figure a couple of things out. Then I watched the Chronological version and saw that they were having flash backs from the latter to the previous during the time changes. So at some points we were actually watching three different times in about 1 min of wall time. That was a good thing because I don\'t know how many more times I could watch it before returning it to Netflix. Color me obsessive.'

# %% [markdown]
# ### Get Data BTC for train and test

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 986747      1  Well, the movie did turn out a lot better than...
# 986748      1  Well, the movie did turn out a lot better than...
# 986749      1  Well, the movie did turn out a lot better than...
# 986750      1  Well, the movie did turn out a lot better than...
# 986751      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 986747  Well, the movie did turn out a lot better than...
# 986748  Well, the movie did turn out a lot better than...
# 986749  Well, the movie did turn out a lot better than...
# 986750  Well, the movie did turn out a lot better than...
# 986751  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...       Roen  name
# 1       I have only see three episodes of Hack, starri...       Jeet  name
# 2       I have only see three episodes of Hack, starri...      Hagen  name
# 3       I have only see three episodes of Hack, starri...     Willow  name
# 4       I have only see three episodes of Hack, starri...      Belal  name
# ...                                                   ...        ...   ...
# 986747  Well, the movie did turn out a lot better than...       Dódi  name
# 986748  Well, the movie did turn out a lot better than...     Iboyka  name
# 986749  Well, the movie did turn out a lot better than...     Zsófia  name
# 986750  Well, the movie did turn out a lot better than...      Ágota  name
# 986751  Well, the movie did turn out a lot better than...      Alexa  name
#
#         gender  country  prediction  template_id
# 0         male       UK           1         1218
# 1         male       UK           1         1218
# 2         male       UK           1         1218
# 3         male       UK           1         1218
# 4         male       UK           1         1218
# ...        ...      ...         ...          ...
# 986747  female  Hungary           1         3417
# 986748  female  Hungary           1         3417
# 986749  female  Hungary           1         3417
# 986750  female  Hungary           1         3417
# 986751  female  Hungary           1         3417
#
# [986752 rows x 10 columns]

# %%
template_that_produce_btc = d["template_id"].tolist()
# template_that_produce_btc

# %%
start = time.time()

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
label = []
for i in template_that_produce_btc: # only processing from template that produce BTC
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    already_processed = []
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                key = k1 + "-" + k2
                if k1 > k2 :
                    key = k2 + "-" + k1
                if key not in already_processed :
                    already_processed.append(key)
                    for m_1, p_1, i_1, t, l in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values,  v1["label"].values) :
                        for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                            if p_1 != p_2 : # only add discordant pairs
                                mutant_text_1.append(m_1)
                                prediction_1.append(p_1)
                                identifier_1.append(i_1)
                                mutant_text_2.append(m_2)
                                prediction_2.append(p_2)
                                identifier_2.append(i_2)
                                template.append(t)
                                label.append(l)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  0.4049961566925049

# %%
btc = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template, "label": label})

btc
# Out:
#                                                  mutant_1  \
# 0       i think that it was just like Sárinka except t...
# 1       i think that it was just like Sárinka except t...
# 2       i think that it was just like Sárinka except t...
# 3       i think that it was just like Sárinka except t...
# 4       i think that it was just like Sárinka except t...
# ...                                                   ...
# 229091  Try as I might, I just simply couldn't get int...
# 229092  Try as I might, I just simply couldn't get int...
# 229093  Try as I might, I just simply couldn't get int...
# 229094  Try as I might, I just simply couldn't get int...
# 229095  Try as I might, I just simply couldn't get int...
#
#                                                  mutant_2  prediction_1  \
# 0       i think that it was just like Roen except that...             0
# 1       i think that it was just like Jeet except that...             0
# 2       i think that it was just like Hagen except tha...             0
# 3       i think that it was just like Willow except th...             0
# 4       i think that it was just like Belal except tha...             0
# ...                                                   ...           ...
# 229091  Try as I might, I just simply couldn't get int...             0
# 229092  Try as I might, I just simply couldn't get int...             0
# 229093  Try as I might, I just simply couldn't get int...             0
# 229094  Try as I might, I just simply couldn't get int...             0
# 229095  Try as I might, I just simply couldn't get int...             0
#
#         prediction_2 identifier_1 identifier_2  \
# 0                  1       female         male
# 1                  1       female         male
# 2                  1       female         male
# 3                  1       female         male
# 4                  1       female         male
# ...              ...          ...          ...
# 229091             1       female         male
# 229092             1       female         male
# 229093             1       female         male
# 229094             1       female         male
# 229095             1       female         male
#
#                                                  template  label
# 0       i think that it was just like <name> except th...      0
# 1       i think that it was just like <name> except th...      0
# 2       i think that it was just like <name> except th...      0
# 3       i think that it was just like <name> except th...      0
# 4       i think that it was just like <name> except th...      0
# ...                                                   ...    ...
# 229091  Try as I might, I just simply couldn't get int...      0
# 229092  Try as I might, I just simply couldn't get int...      0
# 229093  Try as I might, I just simply couldn't get int...      0
# 229094  Try as I might, I just simply couldn't get int...      0
# 229095  Try as I might, I just simply couldn't get int...      0
#
# [229096 rows x 8 columns]

# %%
import os
data_dir = "../data/rq2/biasfinder_btc/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)


train = btc.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")

# %%
data_dir = "../data/rq2/biasfinder_btc/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

train.to_csv(data_dir + "test.csv", index=None, header=None, sep="\t")
