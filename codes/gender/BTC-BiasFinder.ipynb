# 542966  you know I've seen a lot of crappy hong kong m...
# 542967  you know I've seen a lot of crappy hong kong m...
#
#                                                  original  gender  \
# 0       !!! Spoiler alert!!! The point is, though, tha...    male
# 1       !!! Spoiler alert!!! The point is, though, tha...    male
# 2       !!! Spoiler alert!!! The point is, though, tha...    male
# 3       !!! Spoiler alert!!! The point is, though, tha...    male
# 4       !!! Spoiler alert!!! The point is, though, tha...    male
# ...                                                   ...     ...
# 542963  you know I've seen a lot of crappy hong kong m...  female
# 542964  you know I've seen a lot of crappy hong kong m...  female
# 542965  you know I've seen a lot of crappy hong kong m...  female
# 542966  you know I've seen a lot of crappy hong kong m...  female
# 542967  you know I've seen a lot of crappy hong kong m...  female
#
#         template_id  prediction
# 0                 0           1
# 1                 0           1
# 2                 0           1
# 3                 0           1
# 4                 0           1
# ...             ...         ...
# 542963        10709           1
# 542964        10709           1
# 542965        10709           1
# 542966        10709           1
# 542967        10709           1
#
# [542968 rows x 7 columns]

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
df["template"] = df["template"].astype("category")
df["template_id"] = df["template"].cat.codes

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template  original  gender  prediction
# template_id
# 0               60      60        60        60      60          60
# 1               22      22        22        22      22          22
# 2                2       2         2         2       2           2
# 3               60      60        60        60      60          60
# 4               60      60        60        60      60          60
# ...            ...     ...       ...       ...     ...         ...
# 10705           60      60        60        60      60          60
# 10706            2       2         2         2       2           2
# 10707           60      60        60        60      60          60
# 10708           60      60        60        60      60          60
# 10709           60      60        60        60      60          60
#
# [10710 rows x 6 columns]

# %%
len(gb.size())
# Out:
# 10710

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  !!! Spoiler alert!!! The point is, though, tha...
# 1           0  !!! Spoiler alert!!! The point is, though, tha...
# 2           0  !!! Spoiler alert!!! The point is, though, tha...
# 3           0  !!! Spoiler alert!!! The point is, though, tha...
# 4           0  !!! Spoiler alert!!! The point is, though, tha...
# ...       ...                                                ...
# 542963      1  you know I've seen a lot of crappy hong kong m...
# 542964      1  you know I've seen a lot of crappy hong kong m...
# 542965      1  you know I've seen a lot of crappy hong kong m...
# 542966      1  you know I've seen a lot of crappy hong kong m...
# 542967      1  you know I've seen a lot of crappy hong kong m...
#
#                                                  template  \
# 0       !!! Spoiler alert!!! The point is, though, tha...
# 1       !!! Spoiler alert!!! The point is, though, tha...
# 2       !!! Spoiler alert!!! The point is, though, tha...
# 3       !!! Spoiler alert!!! The point is, though, tha...
# 4       !!! Spoiler alert!!! The point is, though, tha...
# ...                                                   ...
# 542963  you know I've seen a lot of crappy hong kong m...
# 542964  you know I've seen a lot of crappy hong kong m...
# 542965  you know I've seen a lot of crappy hong kong m...
# 542966  you know I've seen a lot of crappy hong kong m...
# 542967  you know I've seen a lot of crappy hong kong m...
#
#                                                  original  gender  \
# 0       !!! Spoiler alert!!! The point is, though, tha...    male
# 1       !!! Spoiler alert!!! The point is, though, tha...    male
# 2       !!! Spoiler alert!!! The point is, though, tha...    male
# 3       !!! Spoiler alert!!! The point is, though, tha...    male
# 4       !!! Spoiler alert!!! The point is, though, tha...    male
# ...                                                   ...     ...
# 542963  you know I've seen a lot of crappy hong kong m...  female
# 542964  you know I've seen a lot of crappy hong kong m...  female
# 542965  you know I've seen a lot of crappy hong kong m...  female
# 1       !!! Spoiler alert!!! The point is, though, tha...
# 2       !!! Spoiler alert!!! The point is, though, tha...
# 3       !!! Spoiler alert!!! The point is, though, tha...
# 4       !!! Spoiler alert!!! The point is, though, tha...
# ...                                                   ...
# 542963  you know I've seen a lot of crappy hong kong m...
# 542964  you know I've seen a lot of crappy hong kong m...
# 542965  you know I've seen a lot of crappy hong kong m...
# 542966  you know I've seen a lot of crappy hong kong m...
# 542967  you know I've seen a lot of crappy hong kong m...
#
#                                                  original  gender  \
# 0       !!! Spoiler alert!!! The point is, though, tha...    male
# 1       !!! Spoiler alert!!! The point is, though, tha...    male
# 2       !!! Spoiler alert!!! The point is, though, tha...    male
# 3       !!! Spoiler alert!!! The point is, though, tha...    male
# 4       !!! Spoiler alert!!! The point is, though, tha...    male
# ...                                                   ...     ...
# 542963  you know I've seen a lot of crappy hong kong m...  female
# 542964  you know I've seen a lot of crappy hong kong m...  female
# 542965  you know I've seen a lot of crappy hong kong m...  female
# 542966  you know I've seen a lot of crappy hong kong m...  female
# 542967  you know I've seen a lot of crappy hong kong m...  female
#
#         template_id  prediction
# 0                 0           1
# 1                 0           1
# 2                 0           1
# 3                 0           1
# 4                 0           1
# ...             ...         ...
# 542963        10709           1
# 542964        10709           1
# 542965        10709           1
# 542966        10709           1
# 542967        10709           1
#
# [542968 rows x 7 columns]

# %%
dft = df.iloc[:,[0, 2,3,5]]
dft = dft.drop_duplicates()
## template
dft = dft.sort_values(by=["template_id"])
dft = dft.reset_index(drop=True)
dft
# Out:
#        label                                           template  \
# 0          0  !!! Spoiler alert!!! The point is, though, tha...
# 1          0  !!!! MILD SPOILERS!!!! The premise goes like t...
# 2          1  " Lets swap Murders- your wife, my father"- se...
# 3          1  ' ' Wallace & Gromit in The Curse of the WereR...
# 4          0  ' <name> Saves Christmas ' is comedian Ernest'...
# ...      ...                                                ...
# 10705      1  wow is all i could say i really loved the movi...
# 10706      1  wow! i just have to say this show is super coo...
# 10707      0  wow, i just got one watching this. How CRAPPY ...
# 10708      1  yes barney is nonsense now but when i was a ki...
# 10709      1  you know I've seen a lot of crappy hong kong m...
#
#                                                 original  template_id
# 0      !!! Spoiler alert!!! The point is, though, tha...            0
# 1      !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2      " Lets swap Murders- your wife, my father"- se...            2
# 3      ' ' Wallace & Gromit in The Curse of the WereR...            3
# 4      ' Ernest Saves Christmas ' is comedian Ernest'...            4
# ...                                                  ...          ...
# 10705  wow is all i could say i really loved the movi...        10705
# 10706  wow! i just have to say this show is super coo...        10706
# 10707  wow, i just got one watching this. How CRAPPY ...        10707
# 10708  yes barney is nonsense now but when i was a ki...        10708
# 10709  you know I've seen a lot of crappy hong kong m...        10709
#
# [10710 rows x 4 columns]

# %%
dft.to_csv("template_gender.csv", index=None)

# %%
df.iloc[dft.index].to_csv("cari-contoh-gender.csv")

# %%
## mutant
df = df.reset_index(drop=True)

# %%
df
# Out:
#         label                                             mutant  \
# 0           0
# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "gender"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if int(p) == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  20.319692850112915

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#        label                                           template  \
# 0          0  !!! Spoiler alert!!! The point is, though, tha...
# 1          0  !!!! MILD SPOILERS!!!! The premise goes like t...
# 2          1  " Lets swap Murders- your wife, my father"- se...
# 3          1  ' ' Wallace & Gromit in The Curse of the WereR...
# 4          0  ' <name> Saves Christmas ' is comedian Ernest'...
# ...      ...                                                ...
# 10705      1  wow is all i could say i really loved the movi...
# 10706      1  wow! i just have to say this show is super coo...
# 10707      0  wow, i just got one watching this. How CRAPPY ...
# 10708      1  yes barney is nonsense now but when i was a ki...
# 10709      1  you know I've seen a lot of crappy hong kong m...
#
#                                                 original  template_id  \
# 0      !!! Spoiler alert!!! The point is, though, tha...            0
# 1      !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2      " Lets swap Murders- your wife, my father"- se...            2
# 3      ' ' Wallace & Gromit in The Curse of the WereR...            3
# 4      ' Ernest Saves Christmas ' is comedian Ernest'...            4
# ...                                                  ...          ...
# 10705  wow is all i could say i really loved the movi...        10705
# 10706  wow! i just have to say this show is super coo...        10706
# 10707  wow, i just got one watching this. How CRAPPY ...        10707
# 10708  yes barney is nonsense now but when i was a ki...        10708
# 10709  you know I've seen a lot of crappy hong kong m...        10709
#
#                                           mutant_example  \
# 0      {'female': '!!! Spoiler alert!!! The point is,...
# 1      {'female': '!!!! MILD SPOILERS!!!! The premise...
# 2      {'female': '" Lets swap Murders- your wife, my...
# 3      {'female': '' ' Wallace & Gromit in The Curse ...
# 4      {'female': '' Sveya Saves Christmas ' is comed...
# ...                                                  ...
# 10705  {'female': 'wow is all i could say i really lo...
# 10706  {'female': 'wow! i just have to say this show ...
# 10707  {'female': 'wow, i just got one watching this....
# 10708  {'female': 'yes barney is nonsense now but whe...
# 10709  {'female': 'you know I've seen a lot of crappy...
#
#                                   mutant_prediction_stat
# 0      {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# 1      {'female': {'pos': 0, 'neg': 11}, 'male': {'po...
# 2      {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...
# 3      {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# 4      {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# ...                                                  ...
# 10705  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# 10706  {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...
# 10707  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 10708  {'female': {'pos': 19, 'neg': 11}, 'male': {'p...
# 10709  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
#
# [10710 rows x 6 columns]

# %%
key
# Out:
# ['female', 'male']

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        already_processed = []
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    k = k1 + "-" + k2
                    if k1 > k2 :
                        k = k2 + "-" + k1
                    if k not in already_processed :
                        already_processed.append(k)

                        btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                        pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

#         double_counting_divider = len(key) * (len(key)-1)
#         dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting
        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#        label                                           template  \
# 0          0  !!! Spoiler alert!!! The point is, though, tha...
# 1          0  !!!! MILD SPOILERS!!!! The premise goes like t...
# 2          1  " Lets swap Murders- your wife, my father"- se...
# 3          1  ' ' Wallace & Gromit in The Curse of the WereR...
# 4          0  ' <name> Saves Christmas ' is comedian Ernest'...
# ...      ...                                                ...
# 10705      1  wow is all i could say i really loved the movi...
# 10706      1  wow! i just have to say this show is super coo...
# 10707      0  wow, i just got one watching this. How CRAPPY ...
# 10708      1  yes barney is nonsense now but when i was a ki...
# 10709      1  you know I've seen a lot of crappy hong kong m...
#
#                                                 original  template_id  \
# 0      !!! Spoiler alert!!! The point is, though, tha...            0
# 1      !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2      " Lets swap Murders- your wife, my father"- se...            2
# 3      ' ' Wallace & Gromit in The Curse of the WereR...            3
# 4      ' Ernest Saves Christmas ' is comedian Ernest'...            4
# ...                                                  ...          ...
# 10705  wow is all i could say i really loved the movi...        10705
# 10706  wow! i just have to say this show is super coo...        10706
# 10707  wow, i just got one watching this. How CRAPPY ...        10707
# 10708  yes barney is nonsense now but when i was a ki...        10708
# 10709  you know I've seen a lot of crappy hong kong m...        10709
#
#                                           mutant_example  \
# 0      {'female': '!!! Spoiler alert!!! The point is,...
# 1      {'female': '!!!! MILD SPOILERS!!!! The premise...
# 2      {'female': '" Lets swap Murders- your wife, my...
# 3      {'female': '' ' Wallace & Gromit in The Curse ...
# 4      {'female': '' Sveya Saves Christmas ' is comed...
# ...                                                  ...
# 10705  {'female': 'wow is all i could say i really lo...
# 10706  {'female': 'wow! i just have to say this show ...
# 10707  {'female': 'wow, i just got one watching this....
# 10708  {'female': 'yes barney is nonsense now but whe...
# 10709  {'female': 'you know I've seen a lot of crappy...
#
#                                   mutant_prediction_stat  btc  possible_pair
# 0      {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
# 1      {'female': {'pos': 0, 'neg': 11}, 'male': {'po...    0            121
# 2      {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...    0              1
# 3      {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
# 4      {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
# ...                                                  ...  ...            ...
# 10705  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
# 10706  {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...    0              1
# 10707  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0            900
# 10708  {'female': {'pos': 19, 'neg': 11}, 'male': {'p...  426            900
# 10709  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0            900
#
# [10710 rows x 8 columns]

# %% [markdown]
# ### Number of Bias-Uncovering Test Case

# %%
int(dft["btc"].sum())
# Out:
# 57765

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.0038113683752690523

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d
# Out:
#        label                                           template  \
# 76         1  ( Warning: spoilers! -- although it's hard to ...
# 106        0  ** MAJOR SPOILERS** Watchable only for the act...
# 232        1  17/02/09 " More " ( 1969) Dir: Barbet Schroede...
# 266        0  <name> 's " Chairman of the Board " and <pro-h...
# 382        1  <name> entry into a European film series is on...
# ...      ...                                                ...
# 10469      1  You know you're watching softcore with the wro...
# 10539      1  hey community! my question is about the song, ...
# 10545      1  i consider this movie as one of the most inter...
# 10546      1  i did not expect to enjoy this. in truth i wat...
# 10708      1  yes barney is nonsense now but when i was a ki...
#
#                                                 original  template_id  \
# 76     ( Warning: spoilers! -- although it's hard to ...           76
# 106    ** MAJOR SPOILERS** Watchable only for the act...          106
# 232    17/02/09 " More " ( 1969) Dir: Barbet Schroede...          232
# 266    Carrot Top's " Chairman of the Board " and his...          266
# 382    Hal Hartley entry into a European film series ...          382
# ...                                                  ...          ...
# 10469  You know you're watching softcore with the wro...        10469
# 10539  hey community! my question is about the song, ...        10539
# 10545  i consider this movie as one of the most inter...        10545
# 10546  i did not expect to enjoy this. in truth i wat...        10546
# 10708  yes barney is nonsense now but when i was a ki...        10708
#
#                                           mutant_example  \
# 76     {'female': '( Warning: spoilers! -- although i...
# 106    {'female': '** MAJOR SPOILERS** Watchable only...
# 232    {'female': '17/02/09 " More " ( 1969) Dir: Bar...
# 266    {'female': 'Sveya 's " Chairman of the Board "...
# 382    {'female': 'Sveya entry into a European film s...
# ...                                                  ...
# 10469  {'female': 'You know you're watching softcore ...
# 10539  {'female': 'hey community! my question is abou...
# 10545  {'female': 'i consider this movie as one of th...
# 10546  {'female': 'i did not expect to enjoy this. in...
# 10708  {'female': 'yes barney is nonsense now but whe...
#
#                                   mutant_prediction_stat  btc  possible_pair
# 76     {'female': {'pos': 29, 'neg': 1}, 'male': {'po...   30            900
# 106    {'female': {'pos': 5, 'neg': 25}, 'male': {'po...  290            900
# 232    {'female': {'pos': 23, 'neg': 7}, 'male': {'po...  242            900
# 266    {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   90            900
# 382    {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   60            900
# ...                                                  ...  ...            ...
# 10469  {'female': {'pos': 18, 'neg': 12}, 'male': {'p...  444            900
# 10539  {'female': {'pos': 1, 'neg': 10}, 'male': {'po...   83            121
# 10545  {'female': {'pos': 28, 'neg': 2}, 'male': {'po...   86            900
# 10546  {'female': {'pos': 26, 'neg': 4}, 'male': {'po...  208            900
# 10708  {'female': {'pos': 19, 'neg': 11}, 'male': {'p...  426            900
#
# [196 rows x 8 columns]

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "template"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#      label                                           template  \
# 0        1  Luc Besson's first work is also his first fora...
# 1        1  The best sobadit'sgood movie ever made. <name>...
# 2        1  Fans of the Pink Panther, Naked Gun, or Get Sm...
# 3        0  This has got to be the worst show I have ever ...
# 4        1  Meester Sharky, you look so ... normal. You wo...
# ..     ...                                                ...
# 191      1  <name> is a national treasure, specially when ...
# 192      1  ( Warning: spoilers! -- although it's hard to ...
# 193      0  Imagine watching a slide show where the projec...
# 194      1  This short deals with a severely critical writ...
# 195      0  I watched this cooking show for a few times be...
#
#                                               original  template_id  \
# 0    Luc Besson's first work is also his first fora...         5854
# 1    The best sobadit'sgood movie ever made. Rudy R...         7598
# 2    Fans of the Pink Panther, Naked Gun, or Get Sm...         2374
# 3    This has got to be the worst show I have ever ...         8505
# 4    Meester Sharky, you look so ... normal. You wo...         5941
# ..                                                 ...          ...
# 191  Robin Williams is a national treasure, special...          462
# 192  ( Warning: spoilers! -- although it's hard to ...           76
# 193  Imagine watching a slide show where the projec...         5107
# 194  This short deals with a severely critical writ...         9396
# 195  I watched this cooking show for a few times be...         4623
#
#                                         mutant_example  \
# 0    {'female': 'Luc Besson's first work is also hi...
# 1    {'female': 'The best sobadit'sgood movie ever ...
# 2    {'female': 'Fans of the Pink Panther, Naked Gu...
# 3    {'female': 'This has got to be the worst show ...
# 4    {'female': 'Meester Sharky, you look so ... no...
# ..                                                 ...
# 191  {'female': 'Sveya is a national treasure, spec...
# 192  {'female': '( Warning: spoilers! -- although i...
# 193  {'female': 'Imagine watching a slide show wher...
# 194  {'female': 'This short deals with a severely c...
# 195  {'female': 'I watched this cooking show for a ...
#
#                                 mutant_prediction_stat    btc  possible_pair
# 0    {'female': {'pos': 39, 'neg': 291}, 'male': {'...  16398         108900
# 1    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    900            900
# 2    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    900            900
# 3    {'female': {'pos': 13, 'neg': 17}, 'male': {'p...    502            900
# 4    {'female': {'pos': 19, 'neg': 11}, 'male': {'p...    498            900
# ..                                                 ...    ...            ...
# 191  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...     30            900
# 192  {'female': {'pos': 29, 'neg': 1}, 'male': {'po...     30            900
# 193  {'female': {'pos': 1, 'neg': 10}, 'male': {'po...     29            121
# 194  {'female': {'pos': 0, 'neg': 1}, 'male': {'pos...      1              1
# 195  {'female': {'pos': 1, 'neg': 0}, 'male': {'pos...      1              1
#
# [196 rows x 8 columns]

# %% [markdown]
# ### Get Data BTC for train and test

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  !!! Spoiler alert!!! The point is, though, tha...
# 1           0  !!! Spoiler alert!!! The point is, though, tha...
# 2           0  !!! Spoiler alert!!! The point is, though, tha...
# 3           0  !!! Spoiler alert!!! The point is, though, tha...
# 4           0  !!! Spoiler alert!!! The point is, though, tha...
# ...       ...                                                ...
# 542963      1  you know I've seen a lot of crappy hong kong m...
# 542964      1  you know I've seen a lot of crappy hong kong m...
# 542965      1  you know I've seen a lot of crappy hong kong m...
# 542966      1  you know I've seen a lot of crappy hong kong m...
# 542967      1  you know I've seen a lot of crappy hong kong m...
#
#                                                  template  \
# 0       !!! Spoiler alert!!! The point is, though, tha...
# 1       !!! Spoiler alert!!! The point is, though, tha...
# 2       !!! Spoiler alert!!! The point is, though, tha...
# 3       !!! Spoiler alert!!! The point is, though, tha...
# 4       !!! Spoiler alert!!! The point is, though, tha...
# ...                                                   ...
# 542963  you know I've seen a lot of crappy hong kong m...
# 542964  you know I've seen a lot of crappy hong kong m...
# 542965  you know I've seen a lot of crappy hong kong m...
# 542966  you know I've seen a lot of crappy hong kong m...
# 542967  you know I've seen a lot of crappy hong kong m...
#
#                                                  original  gender  \
# 0       !!! Spoiler alert!!! The point is, though, tha...    male
# 1       !!! Spoiler alert!!! The point is, though, tha...    male
# 2       !!! Spoiler alert!!! The point is, though, tha...    male
# 3       !!! Spoiler alert!!! The point is, though, tha...    male
# 4       !!! Spoiler alert!!! The point is, though, tha...    male
# ...                                                   ...     ...
# 542963  you know I've seen a lot of crappy hong kong m...  female
# 542964  you know I've seen a lot of crappy hong kong m...  female
# 542965  you know I've seen a lot of crappy hong kong m...  female
# 542966  you know I've seen a lot of crappy hong kong m...  female
# 542967  you know I've seen a lot of crappy hong kong m...  female
#
#         template_id  prediction
# 0                 0           1
# 1                 0           1
# 2                 0           1
# 3                 0           1
# 4                 0           1
# ...             ...         ...
# 542963        10709           1
# 542964        10709           1
# 542965        10709           1
# 542966        10709           1
# 542967        10709           1
#
# [542968 rows x 7 columns]

# %%
template_that_produce_btc = d["template_id"].tolist()
# template_that_produce_btc

# %%
start = time.time()

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
original = []
label = []
for i in template_that_produce_btc: # only processing from template that produce BTC
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    already_processed = []
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                key = k1 + "-" + k2
                if k1 > k2 :
                    key = k2 + "-" + k1
                if key not in already_processed :
                    already_processed.append(key)
                    for m_1, p_1, i_1, t, o, l in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values, v1["original"].values,  v1["label"].values) :
                        for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                            if p_1 != p_2 : # only add discordant pairs
                                mutant_text_1.append(m_1)
                                prediction_1.append(p_1)
                                identifier_1.append(i_1)
                                mutant_text_2.append(m_2)
                                prediction_2.append(p_2)
                                identifier_2.append(i_2)
                                template.append(t)
                                label.append(l)
                                original.append(o)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  0.9818668365478516

# %%
btc = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template, "original": original, "label": label})

btc
# Out:
#                                                 mutant_1  \
# 0      Luc Besson's first work is also his first fora...
# 1      Luc Besson's first work is also his first fora...
# 2      Luc Besson's first work is also his first fora...
# 3      Luc Besson's first work is also his first fora...
# 4      Luc Besson's first work is also his first fora...
# ...                                                  ...
# 57760  Imagine watching a slide show where the projec...
# 57761  Imagine watching a slide show where the projec...
# 57762  Imagine watching a slide show where the projec...
# 57763  This short deals with a severely critical writ...
# 57764  I watched this cooking show for a few times be...
#
#                                                 mutant_2  prediction_1  \
# 0      Luc Besson's first work is also his first fora...             0
# 1      Luc Besson's first work is also his first fora...             0
# 2      Luc Besson's first work is also his first fora...             0
# 3      Luc Besson's first work is also his first fora...             0
# 4      Luc Besson's first work is also his first fora...             0
# ...                                                  ...           ...
# 57760  Imagine watching a slide show where the projec...             0
# 57761  Imagine watching a slide show where the projec...             0
# 57762  Imagine watching a slide show where the projec...             0
# 57763  This short deals with a severely critical writ...             0
# 57764  I watched this cooking show for a few times be...             1
#
#        prediction_2 identifier_1 identifier_2  \
# 0                 1       female         male
# 1                 1       female         male
# 2                 1       female         male
# 3                 1       female         male
# 4                 1       female         male
# ...             ...          ...          ...
# 57760             1       female         male
# 57761             1       female         male
# 57762             1       female         male
# 57763             1       female         male
# 57764             0       female         male
#
#                                                 template  \
# 0      Luc Besson's first work is also his first fora...
# 1      Luc Besson's first work is also his first fora...
# 2      Luc Besson's first work is also his first fora...
# 3      Luc Besson's first work is also his first fora...
# 4      Luc Besson's first work is also his first fora...
# ...                                                  ...
# 57760  Imagine watching a slide show where the projec...
# 57761  Imagine watching a slide show where the projec...
# 57762  Imagine watching a slide show where the projec...
# 57763  This short deals with a severely critical writ...
# 57764  I watched this cooking show for a few times be...
#
#                                                 original  label
# 0      Luc Besson's first work is also his first fora...      1
# 1      Luc Besson's first work is also his first fora...      1
# 2      Luc Besson's first work is also his first fora...      1
# 3      Luc Besson's first work is also his first fora...      1
# 4      Luc Besson's first work is also his first fora...      1
# ...                                                  ...    ...
# 57760  Imagine watching a slide show where the projec...      0
# 57761  Imagine watching a slide show where the projec...      0
# 57762  Imagine watching a slide show where the projec...      0
# 57763  This short deals with a severely critical writ...      1
# 57764  I watched this cooking show for a few times be...      0
#
# [57765 rows x 9 columns]

# %%
btc = btc.sample(frac=1, random_state=123)

texts = []
templates = []
labels = []
original = []
for index, rows in btc.iterrows():
    original.append(rows["original"])
    texts.append(rows["original"])
    texts.append(rows["mutant_1"])
    texts.append(rows["mutant_2"])
    templates.append(rows["template"])
    labels.append(rows["label"])

# %%
# texts

# %%
user_study = pd.DataFrame(data={"text":texts})
template = pd.DataFrame(data={"template":templates})
df_ori = pd.DataFrame(data={"label" :label, "original": original})

# %%
df_ori.drop_duplicates().to_csv("btc_original.csv")
# Out:
#        label                                           original
# 0          1  ** MAJOR SPOILERS** Watchable only for the act...
# 1          1  This is species already hatching into a beauti...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  In the spirit of the Great Space Coaster, but ...
# 4          1  i did not expect to enjoy this. in truth i wat...
# ...      ...                                                ...
# 24152      0  It wasn't until I looked at the trivia section...
# 24159      0  If I compare two films with Sacha Cohen, Borat...
# 25931      0  See .. I really wanted to enjoy this movie. Th...
# 27457      0  It's a unique film, as it gives us our only ch...
# 37891      0  I watched this cooking show for a few times be...
#
# [390 rows x 2 columns]

# %%
user_study
# Out:
#                                                      text
# 0       Luc Besson's first work is also his first fora...
# 1       Luc Besson's first work is also his first fora...
# 2       Luc Besson's first work is also his first fora...
# 3       A German freshman, Stefan hitch hikes to Paris...
# 4       A German freshman, Elyesea hitch hikes to Pari...
# ...                                                   ...
# 173290  I did not think Haggard was the funniest movie...
# 173291  I did not think Haggard was the funniest movie...
# 173292  Every movie Quentin Tarantino has made has bec...
# 173293  Every movie Quentin Tarantino has made has bec...
# 173294  Every movie Quentin Tarantino has made has bec...
#
# [173295 rows x 1 columns]

# %%
template
# Out:
#                                                 template
# 0      Luc Besson's first work is also his first fora...
# 1      A German freshman, <name> hitch hikes to Paris...
# 2      Luc Besson's first work is also his first fora...
# 3      I remember watching Police Squad! when it firs...
# 4      Luc Besson's first work is also his first fora...
# ...                                                  ...
# 57760  Ever sense i was a kid i have loved this movie...
# 57761  Luc Besson's first work is also his first fora...
# 57762  Curse of Michael Myers is a very frustrating p...
# 57763  I did not think Haggard was the funniest movie...
# 57764  Every movie Quentin Tarantino has made has bec...
#
# [57765 rows x 1 columns]

# %%
user_study.to_csv("user_study_gender.csv")
template.to_csv("template_gender.csv")

# %%
import os

base_dir = "../../data/btc/biasfinder/gender/"

if not os.path.exists(base_dir) :
    os.makedirs(base_dir)

btc.to_csv(base_dir + "original.csv", index=None)

# %%
m1 = btc.iloc[:,[-1,0]]
m1 = m1.rename(columns={"mutant_1": "text"})
m2 = btc.iloc[:,[-1,1]]
m2 = m2.rename(columns={"mutant_2": "text"})

m1
# Out:
#        label                                               text
# 0          1  Luc Besson's first work is also his first fora...
# 1          1  Luc Besson's first work is also his first fora...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  Luc Besson's first work is also his first fora...
# 4          1  Luc Besson's first work is also his first fora...
# ...      ...                                                ...
# 57760      0  Imagine watching a slide show where the projec...
# 57761      0  Imagine watching a slide show where the projec...
# 57762      0  Imagine watching a slide show where the projec...
# 57763      1  This short deals with a severely critical writ...
# 57764      0  I watched this cooking show for a few times be...
#
# [57765 rows x 2 columns]

# %%
data = pd.concat([m1, m2])
data
# Out:
#        label                                               text
# 0          1  Luc Besson's first work is also his first fora...
# 1          1  Luc Besson's first work is also his first fora...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  Luc Besson's first work is also his first fora...
# 4          1  Luc Besson's first work is also his first fora...
# ...      ...                                                ...
# 57760      0  Imagine watching a slide show where the projec...
# 57761      0  Imagine watching a slide show where the projec...
# 57762      0  Imagine watching a slide show where the projec...
# 57763      1  This short deals with a severely critical writ...
# 57764      0  I watched this cooking show for a few times be...
#
# [115530 rows x 2 columns]

# %%
# data["text"] = data["text"].astype("category")
# data["text_id"] = data["text"].cat.codes
# data
import os

data_dir = base_dir + "full/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = data.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
test = data
test.to_csv(data_dir+ "test.csv", index=None, header=None, sep="\t")

# %%
unique_data = data.drop_duplicates().reset_index(drop=True)
unique_data
# Out:
#        label                                               text
# 0          1  Luc Besson's first work is also his first fora...
# 1          1  Luc Besson's first work is also his first fora...
# 2          1  Luc Besson's first work is also his first fora...
# 3          1  Luc Besson's first work is also his first fora...
# 4          1  Luc Besson's first work is also his first fora...
# ...      ...                                                ...
# 10313      0  Imagine watching a slide show where the projec...
# 10314      0  Imagine watching a slide show where the projec...
# 10315      0  Imagine watching a slide show where the projec...
# 10316      1  This short deals with a severely critical writ...
# 10317      0  I watched this cooking show for a few times be...
#
# [10318 rows x 2 columns]

# %%
unique_data[unique_data["label"] == 0]
# Out:
#        label                                               text
# 390        0  This has got to be the worst show I have ever ...
# 391        0  This has got to be the worst show I have ever ...
# 392        0  This has got to be the worst show I have ever ...
# 393        0  This has got to be the worst show I have ever ...
# 394        0  This has got to be the worst show I have ever ...
# ...      ...                                                ...
# 10312      0  Imagine watching a slide show where the projec...
# 10313      0  Imagine watching a slide show where the projec...
# 10314      0  Imagine watching a slide show where the projec...
# 10315      0  Imagine watching a slide show where the projec...
# 10317      0  I watched this cooking show for a few times be...
#
# [5438 rows x 2 columns]

# %%
import os

data_dir = base_dir + "unique/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = unique_data.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
test = unique_data
test.to_csv(data_dir+ "test.csv", index=None, header=None, sep="\t")

# %%
len(train)
# Out:
# 10318

# %% [markdown]
# #### Balanced Data for Training

# %%
df_0 = unique_data[unique_data["label"] == 0]
df_1 = unique_data[unique_data["label"] == 1]

# %%
print(len(df_0))
print(len(df_1))
# Out:
# 5438
# 4880

# %%
df_1 = df_1.sample(len(df_0), replace=True)
df_oversampled = pd.concat([df_0, df_1], axis=0)

# %%
df_oversampled
# Out:
#       label                                               text
# 390       0  This has got to be the worst show I have ever ...
# 391       0  This has got to be the worst show I have ever ...
# 392       0  This has got to be the worst show I have ever ...
# 393       0  This has got to be the worst show I have ever ...
# 394       0  This has got to be the worst show I have ever ...
# ...     ...                                                ...
# 7206      1  This must be one of the funniest Danish movies...
# 645       1  Um, hello .. Rainbow Brite .. the name alone i...
# 3756      1  This isn't the video nasty Night of the Demon ...
# 8987      1  Don't watch this movie expecting the Jane Aust...
# 988       1  I can hardly call this a great film but it is ...
#
# [10876 rows x 2 columns]

# %%
data_dir = base_dir + "unique/balanced/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = df_oversampled.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")
