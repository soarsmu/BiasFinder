# %% [markdown]
# # Bugs User Study
#
# A user study to uncover the false positive from bugs detected

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# #### Read Mutant Original Data

# %%
data_dir = "imdb_mutant"
dfm = pd.read_csv("../data/" + data_dir + "/male/test.csv", header=None, sep="\t", names=["label", "text", "template"])
dff = pd.read_csv("../data/" + data_dir + "/female/test.csv", header=None, sep="\t", names=["label", "text", "template"])

# %% [markdown]
# #### Read Mutant Prediction

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "trial_on_imdb"

result_dir = "../result/" + output_dir + "/"

rm = result_dir + "results_data_male.txt"
rf = result_dir + "results_data_female.txt"

mpred = read_txt(rm)
fpred = read_txt(rf)

print(len(mpred))
print(len(fpred))
# Out:
# 139000
# 139000

# %% [markdown]
# #### Append Prediction Result to Data

# %%
dfm["pred"] = mpred
dff["pred"] = fpred

# %%
dfm
# Out:
#         label                                               text  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 138995      1  First, I'm a huge Justin fan. I grew up knowin...
# 138996      1  First, I'm a huge Terrence fan. I grew up know...
# 138997      1  First, I'm a huge Roger fan. I grew up knowing...
# 138998      1  First, I'm a huge Torrance fan. I grew up know...
# 138999      1  First, I'm a huge Ryan fan. I grew up knowing ...
#
#                                                  template  pred
# 0       I have only see three episodes of Hack, starri...     1
# ...

# %%
dfm["template"] = dfm["template"].astype("category")
dfm["template_id"] = dfm["template"].cat.codes

dff["template"] = dff["template"].astype("category")
dff["template_id"] = dff["template"].cat.codes

# %%
dfm
# Out:
#         label                                               text  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 138995      1  First, I'm a huge Justin fan. I grew up knowin...
# 138996      1  First, I'm a huge Terrence fan. I grew up know...
# 138997      1  First, I'm a huge Roger fan. I grew up knowing...
# 138998      1  First, I'm a huge Torrance fan. I grew up know...
# 138999      1  First, I'm a huge Ryan fan. I grew up knowing ...
#
#                                                  template  pred  template_id
# 0       I have only see three episodes of Hack, starri...     1         2093
# ...

# %% [markdown]
# #### Get Data that trigger bugs, means label and prediction are different

# %%
mbug = dfm[dfm["label"] != dfm["pred"]]
fbug = dff[dff["label"] != dff["pred"]]

# %%
mbug
# Out:
#         label                                               text  \
# 420         0  There are so very few films where just the tit...
# 421         0  There are so very few films where just the tit...
# 422         0  There are so very few films where just the tit...
# 423         0  There are so very few films where just the tit...
# 424         0  There are so very few films where just the tit...
# ...       ...                                                ...
# 138655      0  I saw this film when it first came out and hat...
# 138656      0  I saw this film when it first came out and hat...
# 138657      0  I saw this film when it first came out and hat...
# 138658      0  I saw this film when it first came out and hat...
# 138659      0  I saw this film when it first came out and hat...
#
#                                                  template  pred  template_id
# 420     There are so very few films where just the tit...     1         5077
# ...

# %%
fbug
# Out:
#         label                                               text  \
# 420         0  There are so very few films where just the tit...
# 421         0  There are so very few films where just the tit...
# 422         0  There are so very few films where just the tit...
# 423         0  There are so very few films where just the tit...
# 424         0  There are so very few films where just the tit...
# ...       ...                                                ...
# 138255      0  Wow, another Kevin Costner hero movie. Melanie...
# 138256      0  Wow, another Kevin Costner hero movie. Tanisha...
# 138257      0  Wow, another Kevin Costner hero movie. Nancy. ...
# 138258      0  Wow, another Kevin Costner hero movie. Tia. Se...
# 138259      0  Wow, another Kevin Costner hero movie. Stephan...
#
#                                                  template  pred  template_id
# 420     There are so very few films where just the tit...     1         5077
# ...

# %% [markdown]
# #### Group Data by Template Then Sort it

# %%
mcount = mbug.groupby("template_id").count()
mcount["#bug"] = mcount["text"]
mcount = mcount.drop(columns=["label", "text", "template", "pred"])
mcount = mcount.sort_values('#bug',ascending=False)
mcount
# Out:
#              #bug
# template_id
# 204            40
# 4986           40
# 4862           40
# 4512           40
# 638            40
# ...           ...
# 2091            1
# 1746            1
# 6134            1
# 6364            1
# 1651            1
#
# [484 rows x 1 columns]

# %%
fcount = fbug.groupby("template_id").count()
fcount["#bug"] = fcount["text"]
fcount = fcount.drop(columns=["label", "text", "template", "pred"])
fcount = fcount.sort_values('#bug',ascending=False)
fcount
# Out:
#              #bug
# template_id
# 4986           40
# 4862           40
# 4512           40
# 638            40
# 390            40
# ...           ...
# 2962            2
# 4171            2
# 1928            1
# 3327            1
# 4281            1
#
# [486 rows x 1 columns]

# %% [markdown]
# ## Evaluating the Bug from 4 groups, i.e.
# * 5 top template that has lots bug from male data `mbug`
# * 5 worst template that has few bug from male data `mbug`
# * 5 top template that has lots bug from female data `fbug`
# * 5 worst template that has few bug from female data `fbug`

# %% [markdown]
# ### 5 top template that has lots bug from male data `mbug`
# template id = 204, 4986, 4862, 4512, 638

# %%
id = [204, 4986, 4862, 4512, 638]

def print_mutant_example_from_template(i, bug) :
    bug_from_id = bug[bug["template_id"] == i]
    first_bug_from_id = bug_from_id.iloc[0]
    print("Template")
    print(first_bug_from_id["template"])
    print("Mutant")
    print(first_bug_from_id["text"])
    print("Actual - Prediction")
    print(first_bug_from_id["label"], " - ",first_bug_from_id["pred"])

for i in id :
    print_mutant_example_from_template(i, mbug)
# Out:
# Template
# ...

# %% [markdown]
# ### There are 2 semantic issues with the mutant text
#
# #### 1st issue
#
# **Template**
#
# "Some will say this movie is a guilty pleasure. I loved this flick but I don't feel guilty about it. You can tell the whole cast and crew had fun making this movie. But Jack Frost 2 won't go over well with some people. Right from the beginning you can tell this movie will be cheesy and it definitely has an amateurish look to it. Well, if you get the privilege to watch this movie, after watching it remember that Jack Frost 2: Revenge of the Mutant Killer Snowman is a pleasure, not a guilty pleasure. Now, because I can't fill up ten lines heres some great scenes:  **SPOILERS**  The three women on the beach had great deaths. The first one had Jack in a tree trying to drop icicles on one of them. He kept missing so he dropped an anvil on her. The next woman fell on a bed of icicles. The last one was stabbed in the eyes with tongs. The other great one was where two surfers stoners are hanging out near a frozen pole. One of them gets their tongue stuck on it (of course). Jack Frost pulls him back a rips his tongue off while saying "COWA-TONGUE-A DUDE!". Well, you have to see it for yourself. And of course, the snowball children kicked ass. **END SPOILERS** infinity stars"
#
# **Comment**
#
# "The first one", "The last one", and "The other great one" are substituted into one person, Alonzo
#
# #### 2nd issue
#
#
# **Template**
#
# "As everyone knows, nobody can play Scarlett O'Hara like Vivien Leigh, and nobody can play Rhett Butler like Clark Gable. All others pale in comparison, and Timothy Dalton and Joanne Whalley are no exceptions. One thing that I really couldn't get past was that Joanne has BROWN eyes. The green eyes were the most enhancing feature of Scarlett's good looks, and in this sequel she has been stripped of those. The movie, as well as the book, had several lulls in it. The new characters weren't all that memorable, and I found myself forgetting who was who. I felt as though her going to Ireland did absolutely nothing whatsoever. It could be that I'm only 11, but I saw no change in her attitude until the last say, 10 minutes when Rhett told her she had grown up. If Rhett hadn't told her that, I would have never guessed that there was any change in her attitude. She really loved Cat, her baby. She likes this child best because she had it with Rhett, her only loved husband. Still, if you've read Gone With The Wind, you would see that children make no difference in Scarlett's world.  Quite frankly, it seemed to me like there was way too much going on without Rhett. All anybody cares about is whether or not Rhett and Scarlett get back together, and Scarlett took way too long to get to that. It is virtually nothing compared to Gone With The Wind, but then again what isn't? If you have read the novel, you will like that better than the movie. I would watch it, just because it is the sequel to Gone With The Wind, regardless of whether or not it's worthwhile. It may not satisfy you entirely, but it will get you some of the way there."
#
# **Comment**
#
# Found another "Scarlett" after mutation
#
# **Desired**
#
# All Scarlett is mutated into antother name

# %% [markdown]
# ### 5 worst template that has few bug from male data `mbug`
# template id = 2091, 1746, 6134, 6364, 1651

# %%
id = [2091, 1746, 6134, 6364, 1651]

for i in id: 
    print_mutant_example_from_template(i, mbug)
# Out:
# Template
# ...

# %% [markdown]
# #### 1st issue
#
# **Template**
#
# "What is about mathematical geniuses that get the critics juices flowing ? A BEAUTIFUL MIND wasn't up to much in my opinion ( FELLOWSHIP OF THE RING deserved the Oscar that year ) while GOOD WILL HUNTING had several awards lavished on it undeservedly First off is the script . When I attended film school I was told GOOD WILL HUNTING is a very good example on how not to start a script and the tutor was right . This movie lacks any type of opening hook and for the most part it's very very slow . If you wrote an unsolicited script like this the script reader would have given up on it by page 15 Structure aside the idea of a member of the American underclass being some sort of intellectual god doesn't really ring true . Ask yourself this : If he's the cleverst character in the movie how come he's gone through his short life without anyone noticing his abilities ? Not one single teacher from his childhood noticed his gift ? Highly unlikely as is the fact he's read so much mind expanding litrature . And if Will's so clever how come he's so oblivous of what happens to young good looking boys in American prisons ? But it's the casting that let much of the film down . You want to get a couple of actors to play rough tough Irish gang members ? Let's get Matt Damon and Ben Affleck which is like getting Russell Crowe to play a pacifist or Charles Bronson to play a liberal do gooder . I failed to be convinced by the foul mouthed Damon and Affleck as they strutted about smacking people in the chops and couldn't help thinking that even though they wrote the script the parts should have been awarded to different actors , after all Billy Bob Thornton has written screenplays for films he hasn't been cast in and the same criteria should have been applied here There are some good points to the movie . Robin Williams is excellent as the man who tries to show Will his potential and also very good is Stellan Skarsgard who is quite simply one of the greatest character actors to stepped foot outside of Europe and despite my previous criticism of the script there is quite a moving piece of dialogue at the park as Williams character explains to Will what he has seen in life But I've got to repeat that there's less plus points than negatives to this movie and I've got to agree with the people who've said GOOD WILL HUNTING is boring and unconvincing"
#
# **Comment**
#
# The mutant from this template looks strange. Even it's grammatically correct and semantically meaning. We can make a better mutant.

# %% [markdown]
# ### 5 top template that has lots bug from female data `fbug`
# template id = 4986, 4862, 4512, 638, 390

# %%
id = [4986, 4862, 4512, 638, 390]

for i in id: 
    print_mutant_example_from_template(i, fbug)
# Out:
# Template
# ...

# %% [markdown]
# #### 1st issue
#
# **Template**
#
# "Some will say this movie is a guilty pleasure. I loved this flick but I don't feel guilty about it. You can tell the whole cast and crew had fun making this movie. But Jack Frost 2 won't go over well with some people. Right from the beginning you can tell this movie will be cheesy and it definitely has an amateurish look to it. Well, if you get the privilege to watch this movie, after watching it remember that Jack Frost 2: Revenge of the Mutant Killer Snowman is a pleasure, not a guilty pleasure. Now, because I can't fill up ten lines heres some great scenes:  **SPOILERS**  The three women on the beach had great deaths. The first one had Jack in a tree trying to drop icicles on one of them. He kept missing so he dropped an anvil on her. The next woman fell on a bed of icicles. The last one was stabbed in the eyes with tongs. The other great one was where two surfers stoners are hanging out near a frozen pole. One of them gets their tongue stuck on it (of course). Jack Frost pulls him back a rips his tongue off while saying "COWA-TONGUE-A DUDE!". Well, you have to see it for yourself. And of course, the snowball children kicked ass. **END SPOILERS** infinity stars"
#
# **Comment**
#
# This template have a same issue with the previous one
#
# #### 2nd issue
#
# **Template**
#
# "As everyone knows, nobody can play Scarlett O'Hara like Vivien Leigh, and nobody can play Rhett Butler like Clark Gable. All others pale in comparison, and Timothy Dalton and Joanne Whalley are no exceptions. One thing that I really couldn't get past was that Joanne has BROWN eyes. The green eyes were the most enhancing feature of Scarlett's good looks, and in this sequel she has been stripped of those. The movie, as well as the book, had several lulls in it. The new characters weren't all that memorable, and I found myself forgetting who was who. I felt as though her going to Ireland did absolutely nothing whatsoever. It could be that I'm only 11, but I saw no change in her attitude until the last say, 10 minutes when Rhett told her she had grown up. If Rhett hadn't told her that, I would have never guessed that there was any change in her attitude. She really loved Cat, her baby. She likes this child best because she had it with Rhett, her only loved husband. Still, if you've read Gone With The Wind, you would see that children make no difference in Scarlett's world.  Quite frankly, it seemed to me like there was way too much going on without Rhett. All anybody cares about is whether or not Rhett and Scarlett get back together, and Scarlett took way too long to get to that. It is virtually nothing compared to Gone With The Wind, but then again what isn't? If you have read the novel, you will like that better than the movie. I would watch it, just because it is the sequel to Gone With The Wind, regardless of whether or not it's worthwhile. It may not satisfy you entirely, but it will get you some of the way there."
#
# **Comment**
#
# This template have a same issue with the previous one

# %% [markdown]
# ### 5 worst template that has few bug from female data `fbug`
# template id = 2962, 4171, 1928, 3327, 4281

# %%
id = [2962, 4171, 1928, 3327, 4281]

for i in id: 
    print_mutant_example_from_template(i, fbug)
# Out:
# Template
# I'm really not too sure why people are being so complimentary about this odd movie. Having said that - I did actually sit through the entire 2 hours and can't say it wasn't entirely un-entertaining. I think the key problem is that Frank Marshall is not a true director and this is clear in the film - he is an experienced producer, so will have seen a movie made many a time, and will understand what goes into the process. But I think this is quite different to being able to truly direct a movie - the direction was competent, but somehow flat and direction-less. Marshall has more experience as a unit or second director, and this came through, I feel, in the finished product - it appeared to be a group of sets that failed to really have any continuity in its feel or its character. Fun, watchable, but good? No.
# Mutant
# ...

# %% [markdown]
# ## Main Findings
#
# Overral, the mutant text is imperceptible. It's like a human generated text. All mutant are grammatically correct. But there are several semantic issues. The semantic issue mostly occur in the long paragraph. For the small paragraph, the mutant generation looks good semantically.
#
# **Example of a Good Mutant**
#
# "I'm really not too sure why people are being so complimentary about this odd movie. Having said that - I did actually sit through the entire 2 hours and can't say it wasn't entirely un-entertaining. I think the key problem is that Melanie is not a true director and this is clear in the film - she is an experienced producer, so will have seen a movie made many a time, and will understand what goes into the process. But I think this is quite different to being able to truly direct a movie - the direction was competent, but somehow flat and direction-less. Melanie has more experience as a unit or second director, and this came through, I feel, in the finished product - it appeared to be a group of sets that failed to really have any continuity in its feel or its character. Fun, watchable, but good? No."
#
# **All mutants in the 5 worst female looks good**
#
# **I can't say that we have false positive here, since the mutant generated text is imperceptible. But I can't say that there mutant text quality is good also as we found a semantically incorrect paragraph**
