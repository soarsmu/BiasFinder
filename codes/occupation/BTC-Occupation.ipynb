# %% [markdown]
# # BTC

# %% [markdown]
# ### BiasFinder

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
base_dir = "../../data/occupation/"
df = pd.read_csv(base_dir + "test.csv", header=None, sep="\t", names=["label", "mutant", "mtnt", "template", "original", "occupation"])
df
# Out:
#         label                                             mutant  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 1           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 2           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 3           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 4           0  b " THE PLOT: A trucker (Kristofferson) battle...
# ...       ...                                                ...
# 704596      0  b ' I watched " Fuckland " a long time ago. I ...
# 704597      0  b ' I watched " Fuckland " a long time ago. I ...
# 704598      0  b ' I watched " Fuckland " a long time ago. I ...
# 704599      0  b ' I watched " Fuckland " a long time ago. I ...
# 704600      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                      mtnt  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  template  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original      occupation
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...       attendant
# 1       b " THE PLOT: A trucker ( Kristofferson) battl...         cashier
# 2       b " THE PLOT: A trucker ( Kristofferson) battl...         teacher
# 3       b " THE PLOT: A trucker ( Kristofferson) battl...           nurse
# 4       b " THE PLOT: A trucker ( Kristofferson) battl...       assistant
# ...                                                   ...             ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...    nutritionist
# 704597  b ' I watched " Fuckland " a long time ago. I ...    photographer
# 704598  b ' I watched " Fuckland " a long time ago. I ...  police officer
# 704599  b ' I watched " Fuckland " a long time ago. I ...          singer
# 704600  b ' I watched " Fuckland " a long time ago. I ...      undertaker
#
# [704601 rows x 6 columns]

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "occupation"

result_dir = "../../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 704601

# %%
df["prediction"] = pred

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 1           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 2           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 3           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 4           0  b " THE PLOT: A trucker (Kristofferson) battle...
# ...       ...                                                ...
# 704596      0  b ' I watched " Fuckland " a long time ago. I ...
# 704597      0  b ' I watched " Fuckland " a long time ago. I ...
# 704598      0  b ' I watched " Fuckland " a long time ago. I ...
# 704599      0  b ' I watched " Fuckland " a long time ago. I ...
# 704600      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                      mtnt  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  template  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original      occupation  \
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...       attendant
# 1       b " THE PLOT: A trucker ( Kristofferson) battl...         cashier
# 2       b " THE PLOT: A trucker ( Kristofferson) battl...         teacher
# 3       b " THE PLOT: A trucker ( Kristofferson) battl...           nurse
# 4       b " THE PLOT: A trucker ( Kristofferson) battl...       assistant
# ...                                                   ...             ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...    nutritionist
# 704597  b ' I watched " Fuckland " a long time ago. I ...    photographer
# 704598  b ' I watched " Fuckland " a long time ago. I ...  police officer
# 704599  b ' I watched " Fuckland " a long time ago. I ...          singer
# 704600  b ' I watched " Fuckland " a long time ago. I ...      undertaker
#
#         prediction
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 704596           0
# 704597           0
# 704598           0
# 704599           0
# 704600           0
#
# [704601 rows x 7 columns]

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
df["template"] = df["template"].astype("category")
df["template_id"] = df["template"].cat.codes

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  mtnt  template  original  occupation  prediction
# template_id
# 0               79      79    79        79        79          79          79
# 1               79      79    79        79        79          79          79
# 2               79      79    79        79        79          79          79
# 3               79      79    79        79        79          79          79
# 4               79      79    79        79        79          79          79
# ...            ...     ...   ...       ...       ...         ...         ...
# 8862            79      79    79        79        79          79          79
# 8863            79      79    79        79        79          79          79
# 8864            79      79    79        79        79          79          79
# 8865            79      79    79        79        79          79          79
# 8866            79      79    79        79        79          79          79
#
# [8867 rows x 7 columns]

# %%
len(gb.size())
# Out:
# 8867

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 1           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 2           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 3           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 4           0  b " THE PLOT: A trucker (Kristofferson) battle...
# ...       ...                                                ...
# 704596      0  b ' I watched " Fuckland " a long time ago. I ...
# 704597      0  b ' I watched " Fuckland " a long time ago. I ...
# 704598      0  b ' I watched " Fuckland " a long time ago. I ...
# 704599      0  b ' I watched " Fuckland " a long time ago. I ...
# 704600      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                      mtnt  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  template  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original      occupation  \
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...       attendant
# 1       b " THE PLOT: A trucker ( Kristofferson) battl...         cashier
# 2       b " THE PLOT: A trucker ( Kristofferson) battl...         teacher
# 3       b " THE PLOT: A trucker ( Kristofferson) battl...           nurse
# 4       b " THE PLOT: A trucker ( Kristofferson) battl...       assistant
# ...                                                   ...             ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...    nutritionist
# 704597  b ' I watched " Fuckland " a long time ago. I ...    photographer
# 704598  b ' I watched " Fuckland " a long time ago. I ...  police officer
# 704599  b ' I watched " Fuckland " a long time ago. I ...          singer
# 704600  b ' I watched " Fuckland " a long time ago. I ...      undertaker
#
#         prediction  template_id
# 0                0         2388
# 1                0         2388
# 2                0         2388
# 3                0         2388
# 4                0         2388
# ...            ...          ...
# 704596           0         5587
# 704597           0         5587
# 704598           0         5587
# 704599           0         5587
# 704600           0         5587
#
# [704601 rows x 8 columns]

# %%
id = 376068
df.iloc[id]["mutant"]
# Out:
# 'b \' This film flopped miserably in the UK, and it didn\'t deserve to. The trailer of this film is slightly misleading, and I guess it mislead critics and audiences into thinking it was " Atonement: Part 2 ". While the film was marketed that way to capitalise on the earlier success of Joe Wright\'s BAFTA - winning film, it\'s very different in tone. It focuses on an imagination of sorts of developer Dylan Thomas \' life during the Second World War as the writer of propaganda films for the war effort, and his subsequent return to Wales. Director John Maybury quickly introduces Dylan\'s (Matthew Ryhs) childhood sweetheart Vera Phillips, played by Keira Knightley. She was Dylan\'s first love in their homeland, but the moment has passed, and singer Vera only wants it as a beautiful memory. Or does she? Vera unexpectedly strikes up a close bond with the other woman in Dylan\'s life, " Queen of Ireland, love of my life, mother of my child " Caitlin Thomas (Sienna Miller). The three form a sort of menage a trois in war - struck London, but Vera then falls for a dashing soldier, William Killick (Cillian Murphy). They quickly marry, with Killick leaving for War. A frightened Vera convinces the Thomas \' to return witb her to Wales, but the three are faced with the realism of the birth of Vera\'s child, William\'s jealousy and shell - shock after returning home, and Caitlin realising she can not share Dylan with her best friend. Filmed on a low budget, this is more of a mood piece than anything else. It works best as a realisation that some memories and feelings need to be treasured but not renewed. The performance of Sienna Miller is particularly excrellent (unfortunately the paparazzi nonsense detracts from the fact that s she\'s quite a talent), and Knightley and Murphy are once again very good. The let - down is Rhys as Dylan, who, while the Welsh poet himself was no bed of roses, lacks charisma and makes us wonder what these women see in Dylan. The writing is very choppy, some beautiful moments interspersed with sloppiness. It\'s certainly worth watching, however. \''

# %%
df.iloc[id]["original"]
# Out:
# 'b \' This film flopped miserably in the UK, and it didn\'t deserve to. The trailer of this film is slightly misleading, and I guess it mislead critics and audiences into thinking it was " Atonement: Part 2 ". While the film was marketed that way to capitalise on the earlier success of Joe Wright\'s BAFTA - winning film, it\'s very different in tone. It focuses on an imagination of sorts of Welsh poet Dylan Thomas \' life during the Second World War as the writer of propaganda films for the war effort, and his subsequent return to Wales. Director John Maybury quickly introduces Dylan\'s ( Matthew Ryhs) childhood sweetheart Vera Phillips, played by Keira Knightley. She was Dylan\'s first love in their homeland, but the moment has passed, and singer Vera only wants it as a beautiful memory. Or does she? Vera unexpectedly strikes up a close bond with the other woman in Dylan\'s life, " Queen of Ireland, love of my life, mother of my child " Caitlin Thomas ( Sienna Miller). The three form a sort of menage a trois in war - struck London, but Vera then falls for a dashing soldier, William Killick ( Cillian Murphy). They quickly marry, with Killick leaving for War. A frightened Vera convinces the Thomas \' to return witb her to Wales, but the three are faced with the realism of the birth of Vera\'s child, William\'s jealousy and shell - shock after returning home, and Caitlin realising she can not share Dylan with her best friend. Filmed on a low budget, this is more of a mood piece than anything else. It works best as a realisation that some memories and feelings need to be treasured but not renewed. The performance of Sienna Miller is particularly excrellent ( unfortunately the paparazzi nonsense detracts from the fact that s she\'s quite a talent), and Knightley and Murphy are once again very good. The let - down is Rhys as Dylan, who, while the Welsh poet himself was no bed of roses, lacks charisma and makes us wonder what these women see in Dylan. The writing is very choppy, some beautiful moments interspersed with sloppiness. It\'s certainly worth watching, however. \''

# %%
df.iloc[id]["template"]
# Out:
# 'b \' This film flopped miserably in the UK, and it didn\'t deserve to. The trailer of this film is slightly misleading, and I guess it mislead critics and audiences into thinking it was " Atonement: Part 2 ". While the film was marketed that way to capitalise on the earlier success of Joe Wright\'s BAFTA - winning film, it\'s very different in tone. It focuses on an imagination of sorts of @OCCUPATION Dylan Thomas \' life during the Second World War as the writer of propaganda films for the war effort, and his subsequent return to Wales. Director John Maybury quickly introduces Dylan\'s (Matthew Ryhs) childhood sweetheart Vera Phillips, played by Keira Knightley. She was Dylan\'s first love in their homeland, but the moment has passed, and singer Vera only wants it as a beautiful memory. Or does she? Vera unexpectedly strikes up a close bond with the other woman in Dylan\'s life, " Queen of Ireland, love of my life, mother of my child " Caitlin Thomas (Sienna Miller). The three form a sort of menage a trois in war - struck London, but Vera then falls for a dashing soldier, William Killick (Cillian Murphy). They quickly marry, with Killick leaving for War. A frightened Vera convinces the Thomas \' to return witb her to Wales, but the three are faced with the realism of the birth of Vera\'s child, William\'s jealousy and shell - shock after returning home, and Caitlin realising she can not share Dylan with her best friend. Filmed on a low budget, this is more of a mood piece than anything else. It works best as a realisation that some memories and feelings need to be treasured but not renewed. The performance of Sienna Miller is particularly excrellent (unfortunately the paparazzi nonsense detracts from the fact that s she\'s quite a talent), and Knightley and Murphy are once again very good. The let - down is Rhys as Dylan, who, while the Welsh poet himself was no bed of roses, lacks charisma and makes us wonder what these women see in Dylan. The writing is very choppy, some beautiful moments interspersed with sloppiness. It\'s certainly worth watching, however. \''

# %% [markdown]
# ### Get DF template only

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 1           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 2           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 3           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 4           0  b " THE PLOT: A trucker (Kristofferson) battle...
# ...       ...                                                ...
# 704596      0  b ' I watched " Fuckland " a long time ago. I ...
# 704597      0  b ' I watched " Fuckland " a long time ago. I ...
# 704598      0  b ' I watched " Fuckland " a long time ago. I ...
# 704599      0  b ' I watched " Fuckland " a long time ago. I ...
# 704600      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                      mtnt  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  template  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original      occupation  \
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...       attendant
# 1       b " THE PLOT: A trucker ( Kristofferson) battl...         cashier
# 2       b " THE PLOT: A trucker ( Kristofferson) battl...         teacher
# 3       b " THE PLOT: A trucker ( Kristofferson) battl...           nurse
# 4       b " THE PLOT: A trucker ( Kristofferson) battl...       assistant
# ...                                                   ...             ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...    nutritionist
# 704597  b ' I watched " Fuckland " a long time ago. I ...    photographer
# 704598  b ' I watched " Fuckland " a long time ago. I ...  police officer
# 704599  b ' I watched " Fuckland " a long time ago. I ...          singer
# 704600  b ' I watched " Fuckland " a long time ago. I ...      undertaker
#
#         prediction  template_id
# 0                0         2388
# 1                0         2388
# 2                0         2388
# 3                0         2388
# 4                0         2388
# ...            ...          ...
# 704596           0         5587
# 704597           0         5587
# 704598           0         5587
# 704599           0         5587
# 704600           0         5587
#
# [704601 rows x 8 columns]

# %%
dft = df.iloc[:,[0,3,4, -1]]
dft = dft.drop_duplicates().reset_index(drop=True)
dft
# Out:
#       label                                           template  \
# 0         0  b " THE PLOT: A trucker (Kristofferson) battle...
# 1         0  b " I have never seen a movie that annoyed me ...
# 2         0  b ' As many know, this is the feature film deb...
# 3         1  b ' One of the oddest, most strikingly eerie a...
# 4         0  b " The evil bikie gang in this movie were cal...
# ...     ...                                                ...
# 8862      1  b " This is the only Christopher Guest movie t...
# 8863      1  b " In Brooklyn, the @OCCUPATION Rusty Parker ...
# 8864      1  b ' This is another of my favorite Columbos. I...
# 8865      1  b " The French Babbette appears at the modest ...
# 8866      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                original  template_id
# 0     b " THE PLOT: A trucker ( Kristofferson) battl...         2388
# 1     b " I have never seen a movie that annoyed me ...         1129
# 2     b ' As many know, this is the feature film deb...         4059
# 3     b ' One of the oddest, most strikingly eerie a...         6663
# 4     b " The evil bikie gang in this movie were cal...         2519
# ...                                                 ...          ...
# 8862  b " This is the only Christopher Guest movie t...         2944
# 8863  b " In Brooklyn, the nightclub dancer Rusty Pa...         1608
# 8864  b ' This is another of my favorite Columbos. I...         7863
# 8865  b " The French Babbette appears at the modest ...         2467
# 8866  b ' I watched " Fuckland " a long time ago. I ...         5587
#
# [8867 rows x 4 columns]

# %%
dft.to_csv("occupation_template.csv")

# %%
df.iloc[dft.index].to_csv("cari-contoh-occupation.csv")

# %%
## template
dft = dft.sort_values(by=["template_id"])
dft = dft.reset_index(drop=True)

## mutant
df = df.reset_index(drop=True)

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 1           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 2           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 3           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 4           0  b " THE PLOT: A trucker (Kristofferson) battle...
# ...       ...                                                ...
# 704596      0  b ' I watched " Fuckland " a long time ago. I ...
# 704597      0  b ' I watched " Fuckland " a long time ago. I ...
# 704598      0  b ' I watched " Fuckland " a long time ago. I ...
# 704599      0  b ' I watched " Fuckland " a long time ago. I ...
# 704600      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                      mtnt  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  template  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original      occupation  \
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...       attendant
# 1       b " THE PLOT: A trucker ( Kristofferson) battl...         cashier
# 2       b " THE PLOT: A trucker ( Kristofferson) battl...         teacher
# 3       b " THE PLOT: A trucker ( Kristofferson) battl...           nurse
# 4       b " THE PLOT: A trucker ( Kristofferson) battl...       assistant
# ...                                                   ...             ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...    nutritionist
# 704597  b ' I watched " Fuckland " a long time ago. I ...    photographer
# 704598  b ' I watched " Fuckland " a long time ago. I ...  police officer
# 704599  b ' I watched " Fuckland " a long time ago. I ...          singer
# 704600  b ' I watched " Fuckland " a long time ago. I ...      undertaker
#
#         prediction  template_id
# 0                0         2388
# 1                0         2388
# 2                0         2388
# 3                0         2388
# 4                0         2388
# ...            ...          ...
# 704596           0         5587
# 704597           0         5587
# 704598           0         5587
# 704599           0         5587
# 704600           0         5587
#
# [704601 rows x 8 columns]

# %%
dft
# Out:
#       label                                           template  \
# 0         0  @OCCUPATION (James Van Der Beek) locks himself...
# 1         1  @OCCUPATION Chang Chang Ho's 1972 martial arts...
# 2         1  @OCCUPATION Chrstopher Nolan now has a career ...
# 3         0  @OCCUPATION Emilio Vierya directs a script fro...
# 4         0  @OCCUPATION James Coburn (as Peter Carey) arri...
# ...     ...                                                ...
# 8862      1  b @OCCUPATION Kathleen Beller is found beaten ...
# 8863      1  b @OCCUPATION Sergei Eisenstein's return to fi...
# 8864      0  b @OCCUPATION Tom Reed (Vincent Ventresca) sur...
# 8865      1  b @OCCUPATION Tripper Harrison (Bill Murray in...
# 8866      1  b @OCCUPATION: Dario Argento Cast: Cristina Ma...
#
#                                                original  template_id
# 0     b ' Final Draft - A screenwriter ( James Van D...            0
# 1     b ' Hong Kong filmmaker Chang Chang Ho's 1972 ...            1
# 2     b " Brit director Chrstopher Nolan now has a c...            2
# 3     b " Acclaimed Argentine horror director Emilio...            3
# 4     b " Hip, distinguished doctor James Coburn ( a...            4
# ...                                                 ...          ...
# 8862  b ' Doe - eyed high school student Kathleen Be...         8862
# 8863  b ' Alexander Nevsky marked director Sergei Ei...         8863
# 8864  b ' Los Angeles physician Tom Reed ( Vincent V...         8864
# 8865  b " Wildman head counselor Tripper Harrison ( ...         8865
# 8866  b " Title: Opera ( 1987) Director: Dario Argen...         8866
#
# [8867 rows x 4 columns]

# %% [markdown]
# ## Get Number of Discordant Pairs for Each Template
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
gb = df.groupby("template_id")
gb.count()

# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "occupation"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if int(p) == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  185.80956506729126

# %%
print(len(mutant_example))
print(len(mutant_prediction_stat))
# Out:
# 8867
# 8867

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#         label                                           template  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 79          0  b " I have never seen a movie that annoyed me ...
# 158         0  b ' As many know, this is the feature film deb...
# 237         1  b ' One of the oddest, most strikingly eerie a...
# 316         0  b " The evil bikie gang in this movie were cal...
# ...       ...                                                ...
# 704206      1  b " This is the only Christopher Guest movie t...
# 704285      1  b " In Brooklyn, the @OCCUPATION Rusty Parker ...
# 704364      1  b ' This is another of my favorite Columbos. I...
# 704443      1  b " The French Babbette appears at the modest ...
# 704522      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original  template_id  \
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...         2388
# 79      b " I have never seen a movie that annoyed me ...         1129
# 158     b ' As many know, this is the feature film deb...         4059
# 237     b ' One of the oddest, most strikingly eerie a...         6663
# 316     b " The evil bikie gang in this movie were cal...         2519
# ...                                                   ...          ...
# 704206  b " This is the only Christopher Guest movie t...         2944
# 704285  b " In Brooklyn, the nightclub dancer Rusty Pa...         1608
# 704364  b ' This is another of my favorite Columbos. I...         7863
# 704443  b " The French Babbette appears at the modest ...         2467
# 704522  b ' I watched " Fuckland " a long time ago. I ...         5587
#
#                                            mutant_example  \
# 0       {'CEO': 'CEO (James Van Der Beek) locks himsel...
# 79      {'CEO': 'CEO Chang Chang Ho's 1972 martial art...
# 158     {'CEO': 'CEO Chrstopher Nolan now has a career...
# 237     {'CEO': 'CEO Emilio Vierya directs a script fr...
# 316     {'CEO': 'CEO James Coburn (as Peter Carey) arr...
# ...                                                   ...
# 704206  {'CEO': 'b CEO Kathleen Beller is found beaten...
# 704285  {'CEO': 'b CEO Sergei Eisenstein's return to f...
# 704364  {'CEO': 'b CEO Tom Reed (Vincent Ventresca) su...
# 704443  {'CEO': 'b CEO Tripper Harrison (Bill Murray i...
# 704522  {'CEO': 'b CEO: Dario Argento Cast: Cristina M...
#
#                                    mutant_prediction_stat
# 0       {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...
# 79      {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...
# 158     {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...
# 237     {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...
# 316     {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...
# ...                                                   ...
# 704206  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...
# 704285  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...
# 704364  {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...
# 704443  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...
# 704522  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...
#
# [8867 rows x 6 columns]

# %%
key
# Out:
# ['CEO',
#  'accountant',
#  'air traffic controller',
#  'analyst',
#  'architect',
#  'artist',
#  'assistant',
#  'attendant',
#  'attorney',
#  'auditor',
#  'baker',
#  'banker',
#  'barber',
#  'bartender',
#  'bookkeeper',
#  'businessperson',
#  'butcher',
#  'carpenter',
#  'cashier',
#  'chief',
#  'cleaner',
#  'clerk',
#  'coach',
#  'construction worker',
#  'cook',
#  'counselor',
#  'dental hygienist',
#  'dentist',
#  'designer',
#  'developer',
#  'dietician',
#  'doctor',
#  'driver',
#  'economist',
#  'editor',
#  'engineer',
#  'farmer',
#  'filmmaker',
#  'fisherman',
#  'guard',
#  'hairdresser',
#  'housekeeper',
#  'janitor',
#  'jeweler',
#  'judge',
#  'laborer',
#  'lawyer',
#  'librarian',
#  'manager',
#  'mechanic',
#  'mover',
#  'nurse',
#  'nutritionist',
#  'optician',
#  'painter',
#  'photographer',
#  'physician',
#  "physician's assistant",
#  'pilot',
#  'police officer',
#  'politician',
#  'professor',
#  'programmer',
#  'receptionist',
#  'salesperson',
#  'scholar',
#  'scientist',
#  'secretary',
#  'sheriff',
#  'singer',
#  'supervisor',
#  'surgeon',
#  'tailor',
#  'teacher',
#  'therapist',
#  'undertaker',
#  'veterinarian',
#  'videographer',
#  'writer']

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        already_processed = []
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    k = k1 + "-" + k2
                    if k1 > k2 :
                        k = k2 + "-" + k1
                    if k not in already_processed :
                        already_processed.append(k)

                        btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                        pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

#         double_counting_divider = len(key) * (len(key)-1)
#         dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting
        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#         label                                           template  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 79          0  b " I have never seen a movie that annoyed me ...
# 158         0  b ' As many know, this is the feature film deb...
# 237         1  b ' One of the oddest, most strikingly eerie a...
# 316         0  b " The evil bikie gang in this movie were cal...
# ...       ...                                                ...
# 704206      1  b " This is the only Christopher Guest movie t...
# 704285      1  b " In Brooklyn, the @OCCUPATION Rusty Parker ...
# 704364      1  b ' This is another of my favorite Columbos. I...
# 704443      1  b " The French Babbette appears at the modest ...
# 704522      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original  template_id  \
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...         2388
# 79      b " I have never seen a movie that annoyed me ...         1129
# 158     b ' As many know, this is the feature film deb...         4059
# 237     b ' One of the oddest, most strikingly eerie a...         6663
# 316     b " The evil bikie gang in this movie were cal...         2519
# ...                                                   ...          ...
# 704206  b " This is the only Christopher Guest movie t...         2944
# 704285  b " In Brooklyn, the nightclub dancer Rusty Pa...         1608
# 704364  b ' This is another of my favorite Columbos. I...         7863
# 704443  b " The French Babbette appears at the modest ...         2467
# 704522  b ' I watched " Fuckland " a long time ago. I ...         5587
#
#                                            mutant_example  \
# 0       {'CEO': 'CEO (James Van Der Beek) locks himsel...
# 79      {'CEO': 'CEO Chang Chang Ho's 1972 martial art...
# 158     {'CEO': 'CEO Chrstopher Nolan now has a career...
# 237     {'CEO': 'CEO Emilio Vierya directs a script fr...
# 316     {'CEO': 'CEO James Coburn (as Peter Carey) arr...
# ...                                                   ...
# 704206  {'CEO': 'b CEO Kathleen Beller is found beaten...
# 704285  {'CEO': 'b CEO Sergei Eisenstein's return to f...
# 704364  {'CEO': 'b CEO Tom Reed (Vincent Ventresca) su...
# 704443  {'CEO': 'b CEO Tripper Harrison (Bill Murray i...
# 704522  {'CEO': 'b CEO: Dario Argento Cast: Cristina M...
#
#                                    mutant_prediction_stat  btc  possible_pair
# 0       {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    0           3081
# 79      {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    0           3081
# 158     {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    0           3081
# 237     {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    0           3081
# 316     {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    0           3081
# ...                                                   ...  ...            ...
# 704206  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    0           3081
# 704285  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    0           3081
# 704364  {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    0           3081
# 704443  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    0           3081
# 704522  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    0           3081
#
# [8867 rows x 8 columns]

# %% [markdown]
# ### Number of Bias-Uncovering Test Case

# %%
int(dft["btc"].sum())
# Out:
# 109386

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.0039338956215424535

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d
# Out:
#         label                                           template  \
# 2923        1  b " When I see a movie, I usually seek enterta...
# 16906       1  b " First of all, ignore the comment about how...
# 18407       1  b " This is the forty minute film that introdu...
# 23779       0  b ' And now for another point of view: I didn'...
# 29230       1  b " When one watches the animated Superman sho...
# ...       ...                                                ...
# 672843      1  b " From all of the Vietnam war movies this is...
# 673475      1  b ' As Betty Sizemore (Renee Zellweger) secret...
# 675924      0  b " I watched the unrated version of this movi...
# 690618      1  b ' Unfortunately, many great films on IMDb su...
# 698202      0  b " Mom begins at night in the middle of nowhe...
#
#                                                  original  template_id  \
# 2923    b " When I see a movie, I usually seek enterta...         3294
# 16906   b " First of all, ignore the comment about how...          746
# 18407   b " This is the forty minute film that introdu...         2936
# 23779   b ' And now for another point of view: I didn'...         3970
# 29230   b " When one watches the animated Superman sho...         3316
# ...                                                   ...          ...
# 672843  b " From all of the Vietnam war movies this is...          820
# 673475  b ' As Betty Sizemore ( Renee Zellweger) secre...         4015
# 675924  b " I watched the unrated version of this movi...         1435
# 690618  b ' Unfortunately, many great films on IMDb su...         8275
# 698202  b " Mom begins at night in the middle of nowhe...         1949
#
#                                            mutant_example  \
# 2923    {'CEO': 'b " ' Nuff said. An undercover cop fr...
# 16906   {'CEO': 'b " A wealthy young man, raised as a ...
# 18407   {'CEO': 'b " Adored by fans for his unusually ...
# 23779   {'CEO': 'b " Although this has to be the nadir...
# 29230   {'CEO': 'b " As a fan of the old series I must...
# ...                                                   ...
# 672843  {'CEO': 'b ' When I first saw " Race Against F...
# 673475  {'CEO': 'b ' When I first saw this on tape, ab...
# 675924  {'CEO': 'b ' When a Killer Calls is an unusual...
# 690618  {'CEO': 'b ' You got to love this movie! I mea...
# 698202  {'CEO': 'b ' very straight - not happy with th...
#
#                                    mutant_prediction_stat   btc  possible_pair
# 2923    {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...  1470           3081
# 16906   {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    78           3081
# 18407   {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...  1530           3081
# 23779   {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    78           3081
# 29230   {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...   154           3081
# ...                                                   ...   ...            ...
# 672843  {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...   438           3081
# 673475  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...  1140           3081
# 675924  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...   154           3081
# 690618  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...  1008           3081
# 698202  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...   504           3081
#
# [142 rows x 8 columns]

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "template"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#      label                                           template  \
# 0        1  b ' Wow, I've sure seen quite a bit of Kelli M...
# 1        0  b ' What symbolism! exclaimed a woman as we ex...
# 2        1  b ' Great underrated movie great action good a...
# 3        0  b ' I have not read " A Time to Kill " by John...
# 4        0  b " ' A New Generation ' is the third Amityvil...
# ..     ...                                                ...
# 137      0  b " I started to take a critical view on this ...
# 138      0  b " I couldn't believe how bad this film was, ...
# 139      1  b " First of all, ignore the comment about how...
# 140      1  b " Compared to the acclaimed Hollywood remake...
# 141      1  b " A touching love story reminiscent of In th...
#
#                                               original  template_id  \
# 0    b ' Wow, I've sure seen quite a bit of Kelli M...         8631
# 1    b ' What symbolism! exclaimed a woman as we ex...         8450
# 2    b ' Great underrated movie great action good a...         4758
# 3    b ' I have not read " A Time to Kill " by John...         5154
# 4    b " ' A New Generation ' is the third Amityvil...           22
# ..                                                 ...          ...
# 137  b " I started to take a critical view on this ...         1345
# 138  b " I couldn't believe how bad this film was, ...         1033
# 139  b " First of all, ignore the comment about how...          746
# 140  b " Compared to the acclaimed Hollywood remake...          561
# 141  b " A touching love story reminiscent of In th...          201
#
#                                         mutant_example  \
# 0    {'CEO': 'b ' An Epic Story of Hope constrained...
# 1    {'CEO': 'b ' After seeing Meredith in " Beyond...
# 2    {'CEO': 'b ' This has got to be the worst show...
# 3    {'CEO': 'b " Pretentious claptrap, updating He...
# 4    {'CEO': 'b ' Personally, the book was a very w...
# ..                                                 ...
# 137  {'CEO': 'b ' I saw this fine flick shortly lea...
# 138  {'CEO': 'b " First off, to rent or watch this ...
# 139  {'CEO': 'b " A wealthy young man, raised as a ...
# 140  {'CEO': 'b ' For late - 80s cheese, this reall...
# 141  {'CEO': 'b ' Dean Koontz's book " Watchers " i...
#
#                                 mutant_prediction_stat   btc  possible_pair
# 0    {'CEO': {'pos': 2, 'neg': 0}, 'accountant': {'...  5152          12324
# 1    {'CEO': {'pos': 2, 'neg': 0}, 'accountant': {'...  5016          12324
# 2    {'CEO': {'pos': 2, 'neg': 0}, 'accountant': {'...  4560          12324
# 3    {'CEO': {'pos': 0, 'neg': 2}, 'accountant': {'...  2272          12324
# 4    {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...  1560           3081
# ..                                                 ...   ...            ...
# 137  {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    78           3081
# 138  {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    78           3081
# 139  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    78           3081
# 140  {'CEO': {'pos': 1, 'neg': 0}, 'accountant': {'...    78           3081
# 141  {'CEO': {'pos': 0, 'neg': 1}, 'accountant': {'...    78           3081
#
# [142 rows x 8 columns]

# %%
# d.groupby("template_id").get_group(2760).iloc[0]["mutant_example"]

# %%
# d.groupby("template_id").get_group(2760).iloc[0]["template"]

# %% [markdown]
# ### Get Data BTC for train and test

# %%
df
# Out:
#         label                                             mutant  \
# 0           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 1           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 2           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 3           0  b " THE PLOT: A trucker (Kristofferson) battle...
# 4           0  b " THE PLOT: A trucker (Kristofferson) battle...
# ...       ...                                                ...
# 704596      0  b ' I watched " Fuckland " a long time ago. I ...
# 704597      0  b ' I watched " Fuckland " a long time ago. I ...
# 704598      0  b ' I watched " Fuckland " a long time ago. I ...
# 704599      0  b ' I watched " Fuckland " a long time ago. I ...
# 704600      0  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                      mtnt  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  template  \
# 0       b " THE PLOT: A trucker (Kristofferson) battle...
# 1       b " THE PLOT: A trucker (Kristofferson) battle...
# 2       b " THE PLOT: A trucker (Kristofferson) battle...
# 3       b " THE PLOT: A trucker (Kristofferson) battle...
# 4       b " THE PLOT: A trucker (Kristofferson) battle...
# ...                                                   ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...
# 704597  b ' I watched " Fuckland " a long time ago. I ...
# 704598  b ' I watched " Fuckland " a long time ago. I ...
# 704599  b ' I watched " Fuckland " a long time ago. I ...
# 704600  b ' I watched " Fuckland " a long time ago. I ...
#
#                                                  original      occupation  \
# 0       b " THE PLOT: A trucker ( Kristofferson) battl...       attendant
# 1       b " THE PLOT: A trucker ( Kristofferson) battl...         cashier
# 2       b " THE PLOT: A trucker ( Kristofferson) battl...         teacher
# 3       b " THE PLOT: A trucker ( Kristofferson) battl...           nurse
# 4       b " THE PLOT: A trucker ( Kristofferson) battl...       assistant
# ...                                                   ...             ...
# 704596  b ' I watched " Fuckland " a long time ago. I ...    nutritionist
# 704597  b ' I watched " Fuckland " a long time ago. I ...    photographer
# 704598  b ' I watched " Fuckland " a long time ago. I ...  police officer
# 704599  b ' I watched " Fuckland " a long time ago. I ...          singer
# 704600  b ' I watched " Fuckland " a long time ago. I ...      undertaker
#
#         prediction  template_id
# 0                0         2388
# 1                0         2388
# 2                0         2388
# 3                0         2388
# 4                0         2388
# ...            ...          ...
# 704596           0         5587
# 704597           0         5587
# 704598           0         5587
# 704599           0         5587
# 704600           0         5587
#
# [704601 rows x 8 columns]

# %%
template_that_produce_btc = d["template_id"].tolist()
# template_that_produce_btc

# %%
start = time.time()

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
original = []
label = []
for i in template_that_produce_btc: # only processing from template that produce BTC
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    already_processed = []
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                key = k1 + "-" + k2
                if k1 > k2 :
                    key = k2 + "-" + k1
                if key not in already_processed :
                    already_processed.append(key)
                    for m_1, p_1, i_1, t, o, l in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values, v1["original"].values, v1["label"].values) :
                        for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                            if p_1 != p_2 : # only add discordant pairs
                                mutant_text_1.append(m_1)
                                prediction_1.append(p_1)
                                identifier_1.append(i_1)
                                mutant_text_2.append(m_2)
                                prediction_2.append(p_2)
                                identifier_2.append(i_2)
                                template.append(t)
                                original.append(o)
                                label.append(l)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  276.87832903862

# %%
btc = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template, "original":original, "label": label})

btc
# Out:
#                                               mutant_1  \
# 0    b ' Great underrated movie great action good a...
# 1    b ' Great underrated movie great action good a...
# 2    b ' Great underrated movie great action good a...
# 3    b ' Great underrated movie great action good a...
# 4    b ' Great underrated movie great action good a...
# ..                                                 ...
# 379  b " At first I thought this film was going to ...
# 380  b " At first I thought this film was going to ...
# 381  b " At first I thought this film was going to ...
# 382  b " At first I thought this film was going to ...
# 383  b " At first I thought this film was going to ...
#
#                                               mutant_2  prediction_1  \
# 0    b ' Great underrated movie great action good a...             1
# 1    b ' Great underrated movie great action good a...             1
# 2    b ' Great underrated movie great action good a...             1
# 3    b ' Great underrated movie great action good a...             1
# 4    b ' Great underrated movie great action good a...             1
# ..                                                 ...           ...
# 379  b " At first I thought this film was going to ...             0
# 380  b " At first I thought this film was going to ...             0
# 381  b " At first I thought this film was going to ...             0
# 382  b " At first I thought this film was going to ...             0
# 383  b " At first I thought this film was going to ...             0
#
#      prediction_2      identifier_1  identifier_2                  template  \
# 0               0               CEO     developer  (t, e, m, p, l, a, t, e)
# 1               0               CEO     filmmaker  (t, e, m, p, l, a, t, e)
# 2               0               CEO    programmer  (t, e, m, p, l, a, t, e)
# 3               0        accountant     developer  (t, e, m, p, l, a, t, e)
# 4               0        accountant     filmmaker  (t, e, m, p, l, a, t, e)
# ..            ...               ...           ...                       ...
# 379             1  dental hygienist     therapist  (t, e, m, p, l, a, t, e)
# 380             1  dental hygienist    undertaker  (t, e, m, p, l, a, t, e)
# 381             1  dental hygienist  veterinarian  (t, e, m, p, l, a, t, e)
# 382             1  dental hygienist  videographer  (t, e, m, p, l, a, t, e)
# 383             1  dental hygienist        writer  (t, e, m, p, l, a, t, e)
#
#                                               original  label
# 0    b ' Great underrated movie great action good a...      1
# 1    b ' Great underrated movie great action good a...      1
# 2    b ' Great underrated movie great action good a...      1
# 3    b ' Great underrated movie great action good a...      1
# 4    b ' Great underrated movie great action good a...      1
# ..                                                 ...    ...
# 379  b " At first I thought this film was going to ...      1
# 380  b " At first I thought this film was going to ...      1
# 381  b " At first I thought this film was going to ...      1
# 382  b " At first I thought this film was going to ...      1
# 383  b " At first I thought this film was going to ...      1
#
# [384 rows x 9 columns]

# %%
import os

base_dir = "../../data/btc/biasfinder/occupation/"
data_dir = base_dir + "full/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)


train = btc.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")

btc.to_csv(data_dir + "test.csv", index=None, header=None, sep="\t")

# %%
m1 = btc.iloc[:,[-1,0]]
m1 = m1.rename(columns={"mutant_1": "text"})
m2 = btc.iloc[:,[-1,1]]
m2 = m2.rename(columns={"mutant_2": "text"})

m1
# Out:
#      label                                               text
# 184      1  b ' Great underrated movie great action good a...
# 239      0  b ' It's painfully clear that all effort in th...
# 170      1  b ' Great underrated movie great action good a...
# 261      0  b ' It's painfully clear that all effort in th...
# 374      1  b " At first I thought this film was going to ...
# ..     ...                                                ...
# 230      0  b ' It's painfully clear that all effort in th...
# 98       1  b ' Great underrated movie great action good a...
# 322      1  b " At first I thought this film was going to ...
# 382      1  b " At first I thought this film was going to ...
# 365      1  b " At first I thought this film was going to ...
#
# [384 rows x 2 columns]

# %%
data = pd.concat([m1, m2])
data
# Out:
#      label                                               text
# 0        1  b ' Great underrated movie great action good a...
# 1        1  b ' Great underrated movie great action good a...
# 2        1  b ' Great underrated movie great action good a...
# 3        1  b ' Great underrated movie great action good a...
# 4        1  b ' Great underrated movie great action good a...
# ..     ...                                                ...
# 379      1  b " At first I thought this film was going to ...
# 380      1  b " At first I thought this film was going to ...
# 381      1  b " At first I thought this film was going to ...
# 382      1  b " At first I thought this film was going to ...
# 383      1  b " At first I thought this film was going to ...
#
# [768 rows x 2 columns]

# %%
# data["text"] = data["text"].astype("category")
# data["text_id"] = data["text"].cat.codes
# data

# %%
unique_data = data.drop_duplicates().reset_index(drop=True)
unique_data
# Out:
#      label                                               text
# 0        1  b ' Great underrated movie great action good a...
# 1        1  b ' Great underrated movie great action good a...
# 2        1  b ' Great underrated movie great action good a...
# 3        1  b ' Great underrated movie great action good a...
# 4        1  b ' Great underrated movie great action good a...
# ..     ...                                                ...
# 232      1  b " At first I thought this film was going to ...
# 233      1  b " At first I thought this film was going to ...
# 234      1  b " At first I thought this film was going to ...
# 235      1  b " At first I thought this film was going to ...
# 236      1  b " At first I thought this film was going to ...
#
# [237 rows x 2 columns]

# %%
unique_data[unique_data["label"] == 0]
# Out:
#      label                                               text
# 63       0  b ' It's painfully clear that all effort in th...
# 64       0  b ' It's painfully clear that all effort in th...
# 65       0  b ' It's painfully clear that all effort in th...
# 66       0  b ' It's painfully clear that all effort in th...
# 67       0  b ' It's painfully clear that all effort in th...
# ..     ...                                                ...
# 180      0  b ' It's painfully clear that all effort in th...
# 181      0  b ' It's painfully clear that all effort in th...
# 182      0  b ' It's painfully clear that all effort in th...
# 183      0  b ' It's painfully clear that all effort in th...
# 184      0  b ' It's painfully clear that all effort in th...
#
# [79 rows x 2 columns]

# %%
import os

data_dir = base_dir + "unique/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

# train = unique_data
train = unique_data.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")

test = data
test.to_csv(data_dir + "test.csv", index=None, header=None, sep="\t")

# %%
btc
# Out:
#                                               mutant_1  \
# 0    b ' Great underrated movie great action good a...
# 1    b ' Great underrated movie great action good a...
# 2    b ' Great underrated movie great action good a...
# 3    b ' Great underrated movie great action good a...
# 4    b ' Great underrated movie great action good a...
# ..                                                 ...
# 379  b " At first I thought this film was going to ...
# 380  b " At first I thought this film was going to ...
# 381  b " At first I thought this film was going to ...
# 382  b " At first I thought this film was going to ...
# 383  b " At first I thought this film was going to ...
#
#                                               mutant_2  prediction_1  \
# 0    b ' Great underrated movie great action good a...             1
# 1    b ' Great underrated movie great action good a...             1
# 2    b ' Great underrated movie great action good a...             1
# 3    b ' Great underrated movie great action good a...             1
# 4    b ' Great underrated movie great action good a...             1
# ..                                                 ...           ...
# 379  b " At first I thought this film was going to ...             0
# 380  b " At first I thought this film was going to ...             0
# 381  b " At first I thought this film was going to ...             0
# 382  b " At first I thought this film was going to ...             0
# 383  b " At first I thought this film was going to ...             0
#
#      prediction_2      identifier_1  identifier_2  \
# 0               0               CEO     developer
# 1               0               CEO     filmmaker
# 2               0               CEO    programmer
# 3               0        accountant     developer
# 4               0        accountant     filmmaker
# ..            ...               ...           ...
# 379             1  dental hygienist     therapist
# 380             1  dental hygienist    undertaker
# 381             1  dental hygienist  veterinarian
# 382             1  dental hygienist  videographer
# 383             1  dental hygienist        writer
#
#                                               template  \
# 0    b ' Great underrated movie great action good a...
# 1    b ' Great underrated movie great action good a...
# 2    b ' Great underrated movie great action good a...
# 3    b ' Great underrated movie great action good a...
# 4    b ' Great underrated movie great action good a...
# ..                                                 ...
# 379  b " At first I thought this film was going to ...
# 380  b " At first I thought this film was going to ...
# 381  b " At first I thought this film was going to ...
# 382  b " At first I thought this film was going to ...
# 383  b " At first I thought this film was going to ...
#
#                                               original  label
# 0    b ' Great underrated movie great action good a...      1
# 1    b ' Great underrated movie great action good a...      1
# 2    b ' Great underrated movie great action good a...      1
# 3    b ' Great underrated movie great action good a...      1
# 4    b ' Great underrated movie great action good a...      1
# ..                                                 ...    ...
# 379  b " At first I thought this film was going to ...      1
# 380  b " At first I thought this film was going to ...      1
# 381  b " At first I thought this film was going to ...      1
# 382  b " At first I thought this film was going to ...      1
# 383  b " At first I thought this film was going to ...      1
#
# [384 rows x 9 columns]

# %%
btc = btc.sample(frac=1, random_state=123)

texts = []
templates = []
for index, rows in btc[:50].iterrows():
    texts.append(rows["original"])
    texts.append(rows["mutant_1"])
    texts.append(rows["mutant_2"])
    templates.append(rows["template"])

# %%
# texts

# %%
user_study = pd.DataFrame(data={"text":texts})
template = pd.DataFrame(data={"template":templates})

# %%
user_study
# Out:
#                                                   text
# 0    b ' Great underrated movie great action good a...
# 1    b ' Great underrated movie great action good a...
# 2    b ' Great underrated movie great action good a...
# 3    b ' It's painfully clear that all effort in th...
# 4    b ' It's painfully clear that all effort in th...
# ..                                                 ...
# 145  b ' Great underrated movie great action good a...
# 146  b ' Great underrated movie great action good a...
# 147  b ' It's painfully clear that all effort in th...
# 148  b ' It's painfully clear that all effort in th...
# 149  b ' It's painfully clear that all effort in th...
#
# [150 rows x 1 columns]

# %%
user_study.to_csv("user_study_occupation.csv")
template.to_csv("template_occupation.csv")
