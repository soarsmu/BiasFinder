# %% [markdown]
# ## FNED and FPED Implementation

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# #### Read Original Data

# %%
data_dir = "gc_imdb"
df = pd.read_csv("../data/" + data_dir + "/test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "identifier", "type", "gender", "country"])
df
# Out:
#          label                                             mutant  \
# 0            1  I have only see three episodes of Hack, starri...
# 1            1  I have only see three episodes of Hack, starri...
# 2            1  I have only see three episodes of Hack, starri...
# 3            1  I have only see three episodes of Hack, starri...
# 4            1  I have only see three episodes of Hack, starri...
# ...        ...                                                ...
# 1080749      1  Well, the movie did turn out a lot better than...
# 1080750      1  Well, the movie did turn out a lot better than...
# 1080751      1  Well, the movie did turn out a lot better than...
# 1080752      1  Well, the movie did turn out a lot better than...
# 1080753      1  Well, the movie did turn out a lot better than...
#
#                                                   template  \
# 0        I have only see three episodes of Hack, starri...
# 1        I have only see three episodes of Hack, starri...
# 2        I have only see three episodes of Hack, starri...
# 3        I have only see three episodes of Hack, starri...
# 4        I have only see three episodes of Hack, starri...
# ...                                                    ...
# 1080749  Well, the movie did turn out a lot better than...
# 1080750  Well, the movie did turn out a lot better than...
# 1080751  Well, the movie did turn out a lot better than...
# 1080752  Well, the movie did turn out a lot better than...
# 1080753  Well, the movie did turn out a lot better than...
#
#                                                   original identifier  \
# 0        I have only see three episodes of Hack, starri...   template
# 1        I have only see three episodes of Hack, starri...       Roen
# 2        I have only see three episodes of Hack, starri...       Jeet
# 3        I have only see three episodes of Hack, starri...      Hagen
# 4        I have only see three episodes of Hack, starri...     Willow
# ...                                                    ...        ...
# 1080749  Well, the movie did turn out a lot better than...       Dódi
# 1080750  Well, the movie did turn out a lot better than...     Iboyka
# 1080751  Well, the movie did turn out a lot better than...     Zsófia
# 1080752  Well, the movie did turn out a lot better than...      Ágota
# 1080753  Well, the movie did turn out a lot better than...      Alexa
#
#              type    gender   country
# 0        template  template  template
# 1            name      male        UK
# 2            name      male        UK
# 3            name      male        UK
# 4            name      male        UK
# ...           ...       ...       ...
# 1080749      name    female   Hungary
# 1080750      name    female   Hungary
# 1080751      name    female   Hungary
# 1080752      name    female   Hungary
# 1080753      name    female   Hungary
#
# [1080754 rows x 8 columns]

# %% [markdown]
# #### Read Prediction Result from the Model
#
# Make sure you set variable `ouput_dir` with the same `output_dir` in the fine-tuning parameter

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "gc_imdb"

result_dir = "../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 1080754

# %%
df["prediction"] = pred
# df["label"] = df[0]

# %%
df = df[df["gender"] != "template"]

# %%
df.head()
# Out:
#    label                                             mutant  \
# 1      1  I have only see three episodes of Hack, starri...
# 2      1  I have only see three episodes of Hack, starri...
# 3      1  I have only see three episodes of Hack, starri...
# 4      1  I have only see three episodes of Hack, starri...
# 5      1  I have only see three episodes of Hack, starri...
#
#                                             template  \
# 1  I have only see three episodes of Hack, starri...
# 2  I have only see three episodes of Hack, starri...
# 3  I have only see three episodes of Hack, starri...
# 4  I have only see three episodes of Hack, starri...
# 5  I have only see three episodes of Hack, starri...
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90    503830
#            1       0.91      0.91      0.91    572922
#
#     accuracy                           0.91   1076752
#    macro avg       0.91      0.91      0.91   1076752
# weighted avg       0.91      0.91      0.91   1076752
#
# [[452159  51671]
#  [ 49172 523750]]

# %% [markdown]
# #### Calculate Performance for each Group

# %%
for k, v in dict(iter(dc)).items() :
    y_test = v["label"]
    y_pred = v["prediction"]
#     print(classification_report(y_test, y_pred))
#     cm = confusion_matrix(y_test, y_pred)
#     print(cm)

# %% [markdown]
# #### Implementation
#
# Fundamental Thery about FPR and FNR:
# https://medium.com/datadriveninvestor/confusion-matric-tpr-fpr-fnr-tnr-precision-recall-f1-score-73efa162a25f
#
#
# Theory on FPED and FNED:
# https://research.google/pubs/pub46743/

# %%
# calculate false positive rate from given consufsion matrix
def calculate_fpr(cm) :
    negative = np.sum(cm[0])
    fp = cm[0][1]
    fpr = fp / negative
    return fpr

# calculate false positive rate from given consufsion matrix
def calculate_fnr(cm) :
    negative = np.sum(cm[0])
    fn = cm[1][0]
    fnr = fn / negative
    return fnr

print(calculate_fpr(cm))
print(calculate_fnr(cm))
# Out:
# 0.10255641783935057
# 0.09759641148800191

# %% [markdown]
# #### Calculate Global FPR and FNR

# %%
y_test = df["label"]
y_pred = df["prediction"]
cm = confusion_matrix(y_test, y_pred)
global_fpr = calculate_fpr(cm)
global_fnr = calculate_fnr(cm)
print("global fpr: ", global_fpr)
print("global fnr: ", global_fnr)
# Out:
# global fpr:  0.10255641783935057
# global fnr:  0.09759641148800191

# %% [markdown]
# #### Calculate FPR and FNR for each Country

# %%
fprs = []
fnrs = []

for k, v in dict(iter(dc)).items() :
    y_test = v["label"]
    y_pred = v["prediction"]
    cm = confusion_matrix(y_test, y_pred)
    fpr = calculate_fpr(cm)
    fnr = calculate_fnr(cm)
    fprs.append(round(fpr, 5))
    fnrs.append(round(fnr, 5))

# %%
# !pip install certifi
# Out:
# Requirement already satisfied: certifi in /opt/conda/lib/python3.6/site-packages (2020.6.20)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


dfprs = pd.DataFrame(data={"identifier": identifiers, "FPR":fprs})
dfprs = dfprs.groupby("identifier").sum().sort_values(by=["FPR"],ascending=False)

dfprs.head()
# Out:
#                 FPR
# identifier
# Spain       0.10313
# Australia   0.10294
# Belgium     0.10294
# Vietnam     0.10294
# Ukraine     0.10294

# %%
my_plot = dfprs.plot(kind='bar', legend=None, title="FPR per " + identifier)
my_plot.set_xlabel(identifier)
my_plot.set_ylabel("FPR")
# Out:
# Text(0, 0.5, 'FPR')

# %%
dfnrs = pd.DataFrame(data={"identifier": identifiers, "FNR":fnrs})
dfnrs = dfnrs.groupby("identifier").sum().sort_values(by=["FNR"],ascending=False)

dfnrs.head()
# Out:
#                 FNR
# identifier
# Ireland     0.09750
# Iran        0.09737
# UK          0.09725
# Turkey      0.09725
# Flanders    0.09725

# %%
my_plot = dfnrs.plot(kind='bar', legend=None, title="FNR per " + identifier)
my_plot.set_xlabel(identifier)
my_plot.set_ylabel("FNR")
# Out:
# Text(0, 0.5, 'FNR')

# %% [markdown]
# #### Calculate FNED and FPED

# %%
fped = 0
fned = 0

for _fpr, _fnr in zip(fprs, fnrs) :
    fped += abs(global_fpr - fpr)
    fned += abs(global_fnr - fnr)

print()
print("FPED: ", fped)
print("FNED: ", fned)
# Out:
# FPED:  0.011927517568367407
# FNED:  0.018605151622427027
