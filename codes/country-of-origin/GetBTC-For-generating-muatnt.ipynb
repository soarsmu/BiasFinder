# %%
import pandas as pd
import os

# %%
base_dir = "../../data/btc/biasfinder/country/"

if not os.path.exists(base_dir) :
    os.makedirs(base_dir)

btc = pd.read_csv(base_dir + "original.csv")
btc
# Out:
#                                                 mutant_1  \
# 0      ' ' Queen of the Damned '' is one of the worst...
# 1      ' ' Queen of the Damned '' is one of the worst...
# 2      ' ' Queen of the Damned '' is one of the worst...
# 3      ' ' Queen of the Damned '' is one of the worst...
# 4      ' ' Queen of the Damned '' is one of the worst...
# ...                                                  ...
# 18177  yes barney is nonsense now but when i was a ki...
# 18178  yes barney is nonsense now but when i was a ki...
# 18179  yes barney is nonsense now but when i was a ki...
# 18180  yes barney is nonsense now but when i was a ki...
# 18181  yes barney is nonsense now but when i was a ki...
#
#                                                 mutant_2  prediction_1  \
# 0      ' ' Queen of the Damned '' is one of the worst...             1
# 1      ' ' Queen of the Damned '' is one of the worst...             1
# ...
