# %% [markdown]
# # Number of BTC
#
# BTC is a pair contain of male-female and its prediction, such that the Sentiment Analysis produce a different prediction.
# Example of discordant pair from country:
#
# `<(name from Indonesia, prediction), (name from USA, prediction)>`
#
# `<(“Paijo is angry”, 1), (“John is angry”, 0)>`

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
eval_dir = "imdb_using_eec_name"
# df = pd.read_csv("../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=[0, 1, "mutant", "template", "gender", "label", "country"])
df = pd.read_csv("../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "identifier", "type", "gender", "country"])
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 140837      1  Well, the movie did turn out a lot better than...
# 140838      1  Well, the movie did turn out a lot better than...
# 140839      1  Well, the movie did turn out a lot better than...
# 140840      1  Well, the movie did turn out a lot better than...
# 140841      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 140837  Well, the movie did turn out a lot better than...
# 140838  Well, the movie did turn out a lot better than...
# 140839  Well, the movie did turn out a lot better than...
# 140840  Well, the movie did turn out a lot better than...
# 140841  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...     Alonzo  name
# 1       I have only see three episodes of Hack, starri...       Adam  name
# 2       I have only see three episodes of Hack, starri...   Alphonse  name
# 3       I have only see three episodes of Hack, starri...       Alan  name
# 4       I have only see three episodes of Hack, starri...    Darnell  name
# ...                                                   ...        ...   ...
# 140837  Well, the movie did turn out a lot better than...    Melanie  name
# 140838  Well, the movie did turn out a lot better than...    Tanisha  name
# 140839  Well, the movie did turn out a lot better than...      Nancy  name
# 140840  Well, the movie did turn out a lot better than...        Tia  name
# 140841  Well, the movie did turn out a lot better than...  Stephanie  name
#
#         gender            country
# 0         male   African American
# 1         male   African American
# 2         male   African American
# 3         male   African American
# 4         male   African American
# ...        ...                ...
# 140837  female  European American
# 140838  female  European American
# 140839  female  European American
# 140840  female  European American
# 140841  female  European American
#
# [140842 rows x 8 columns]

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "eec_biasfinder"

result_dir = "../result/" + output_dir + "/"

path = result_dir + "results_before_data_1_ep1.txt"

pred_before = read_txt(path)

print(len(pred_before))

path = result_dir + "results_after_data_1_ep1.txt"

pred_after = read_txt(path)

print(len(pred_after))
# Out:
# 140842
# 140842

# %%
df["prediction_before"] = pred_before #fine tune
df["prediction_after"] = pred_after #fine tune
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 140837      1  Well, the movie did turn out a lot better than...
# 140838      1  Well, the movie did turn out a lot better than...
# 140839      1  Well, the movie did turn out a lot better than...
# 140840      1  Well, the movie did turn out a lot better than...
# 140841      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 140837  Well, the movie did turn out a lot better than...
# 140838  Well, the movie did turn out a lot better than...
# 140839  Well, the movie did turn out a lot better than...
# 140840  Well, the movie did turn out a lot better than...
# 140841  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...     Alonzo  name
# 1       I have only see three episodes of Hack, starri...       Adam  name
# 2       I have only see three episodes of Hack, starri...   Alphonse  name
# 3       I have only see three episodes of Hack, starri...       Alan  name
# 4       I have only see three episodes of Hack, starri...    Darnell  name
# ...                                                   ...        ...   ...
# 140837  Well, the movie did turn out a lot better than...    Melanie  name
# 140838  Well, the movie did turn out a lot better than...    Tanisha  name
# 140839  Well, the movie did turn out a lot better than...      Nancy  name
# 140840  Well, the movie did turn out a lot better than...        Tia  name
# 140841  Well, the movie did turn out a lot better than...  Stephanie  name
#
#         gender            country  prediction_before  prediction_after
# 0         male   African American                  1                 1
# 1         male   African American                  1                 1
# 2         male   African American                  1                 1
# 3         male   African American                  1                 1
# 4         male   African American                  1                 1
# ...        ...                ...                ...               ...
# 140837  female  European American                  1                 1
# 140838  female  European American                  1                 1
# 140839  female  European American                  1                 1
# 140840  female  European American                  1                 1
# 140841  female  European American                  1                 1
#
# [140842 rows x 10 columns]

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
df["original"] = df["original"].astype("category")
df["template_id"] = df["original"].cat.codes

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template  original  identifier  type  gender  \
# template_id
# 0               40      40        40        40          40    40      40
# 1               26      26        26        26          26    26      26
# 2               40      40        40        40          40    40      40
# 3               40      40        40        40          40    40      40
# 4               40      40        40        40          40    40      40
# ...            ...     ...       ...       ...         ...   ...     ...
# 3725            40      40        40        40          40    40      40
# 3726            40      40        40        40          40    40      40
# 3727            40      40        40        40          40    40      40
# 3728            26      26        26        26          26    26      26
# 3729            40      40        40        40          40    40      40
#
#              country  prediction_before  prediction_after
# template_id
# 0                 40                 40                40
# 1                  0                 26                26
# 2                 40                 40                40
# 3                 40                 40                40
# 4                 40                 40                40
# ...              ...                ...               ...
# 3725              40                 40                40
# 3726              40                 40                40
# 3727              40                 40                40
# 3728               0                 26                26
# 3729              40                 40                40
#
# [3730 rows x 10 columns]

# %%
x = gb.count()["mutant"] != 60
gb.count()[x]
# Out:
#              label  mutant  template  original  identifier  type  gender  \
# template_id
# 0               40      40        40        40          40    40      40
# 1               26      26        26        26          26    26      26
# 2               40      40        40        40          40    40      40
# 3               40      40        40        40          40    40      40
# 4               40      40        40        40          40    40      40
# ...            ...     ...       ...       ...         ...   ...     ...
# 3725            40      40        40        40          40    40      40
# 3726            40      40        40        40          40    40      40
# 3727            40      40        40        40          40    40      40
# 3728            26      26        26        26          26    26      26
# 3729            40      40        40        40          40    40      40
#
#              country  prediction_before  prediction_after
# template_id
# 0                 40                 40                40
# 1                  0                 26                26
# 2                 40                 40                40
# 3                 40                 40                40
# 4                 40                 40                40
# ...              ...                ...               ...
# 3725              40                 40                40
# 3726              40                 40                40
# 3727              40                 40                40
# 3728               0                 26                26
# 3729              40                 40                40
#
# [3730 rows x 10 columns]

# %%
# gb.get_group(0)["template"]

# %%
len(gb.size())
# Out:
# 3730

# %% [markdown]
# # Create Discordant Pairs BEFORE
#
# You can create another discordant pairs from another column by changing the `identifier`.
#
# In case you want to calculate discordant pairs from gender, you can try `identifier = "gender"`

# %%
df["prediction"] = df["prediction_before"]
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 140837      1  Well, the movie did turn out a lot better than...
# 140838      1  Well, the movie did turn out a lot better than...
# 140839      1  Well, the movie did turn out a lot better than...
# 140840      1  Well, the movie did turn out a lot better than...
# 140841      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 140837  Well, the movie did turn out a lot better than...
# 140838  Well, the movie did turn out a lot better than...
# 140839  Well, the movie did turn out a lot better than...
# 140840  Well, the movie did turn out a lot better than...
# 140841  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...     Alonzo  name
# 1       I have only see three episodes of Hack, starri...       Adam  name
# 2       I have only see three episodes of Hack, starri...   Alphonse  name
# 3       I have only see three episodes of Hack, starri...       Alan  name
# 4       I have only see three episodes of Hack, starri...    Darnell  name
# ...                                                   ...        ...   ...
# 140837  Well, the movie did turn out a lot better than...    Melanie  name
# 140838  Well, the movie did turn out a lot better than...    Tanisha  name
# 140839  Well, the movie did turn out a lot better than...      Nancy  name
# 140840  Well, the movie did turn out a lot better than...        Tia  name
# 140841  Well, the movie did turn out a lot better than...  Stephanie  name
#
#         gender            country  prediction_before  prediction_after  \
# 0         male   African American                  1                 1
# 1         male   African American                  1                 1
# 2         male   African American                  1                 1
# 3         male   African American                  1                 1
# 4         male   African American                  1                 1
# ...        ...                ...                ...               ...
# 140837  female  European American                  1                 1
# 140838  female  European American                  1                 1
# 140839  female  European American                  1                 1
# 140840  female  European American                  1                 1
# 140841  female  European American                  1                 1
#
#         template_id  prediction
# 0              1092           1
# 1              1092           1
# 2              1092           1
# 3              1092           1
# 4              1092           1
# ...             ...         ...
# 140837         3412           1
# 140838         3412           1
# 140839         3412           1
# 140840         3412           1
# 140841         3412           1
#
# [140842 rows x 12 columns]

# %%
start = time.time()

identifier = "gender"

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
for i in range(len(gb.size())) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                for m_1, p_1, i_1, t in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values) :
                    for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                        mutant_text_1.append(m_1)
                        prediction_1.append(p_1)
                        identifier_1.append(i_1)
                        mutant_text_2.append(m_2)
                        prediction_2.append(p_2)
                        identifier_2.append(i_2)
                        template.append(t)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  15.888363361358643

# %%
dfcross = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template})

dfcross
# Out:
#                                                   mutant_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...
# 1        !!! Spoiler alert!!! The point is, though, tha...
# 2        !!! Spoiler alert!!! The point is, though, tha...
# 3        !!! Spoiler alert!!! The point is, though, tha...
# 4        !!! Spoiler alert!!! The point is, though, tha...
# ...                                                    ...
# 2708181  you know I've seen a lot of crappy hong kong m...
# 2708182  you know I've seen a lot of crappy hong kong m...
# 2708183  you know I've seen a lot of crappy hong kong m...
# 2708184  you know I've seen a lot of crappy hong kong m...
# 2708185  you know I've seen a lot of crappy hong kong m...
#
#                                                   mutant_2  prediction_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...             1
# 1        !!! Spoiler alert!!! The point is, though, tha...             1
# 2        !!! Spoiler alert!!! The point is, though, tha...             1
# 3        !!! Spoiler alert!!! The point is, though, tha...             1
# 4        !!! Spoiler alert!!! The point is, though, tha...             1
# ...                                                    ...           ...
# 2708181  you know I've seen a lot of crappy hong kong m...             1
# 2708182  you know I've seen a lot of crappy hong kong m...             1
# 2708183  you know I've seen a lot of crappy hong kong m...             1
# 2708184  you know I've seen a lot of crappy hong kong m...             1
# 2708185  you know I've seen a lot of crappy hong kong m...             1
#
#          prediction_2 identifier_1 identifier_2  \
# 0                   1       female         male
# 1                   1       female         male
# 2                   1       female         male
# 3                   1       female         male
# 4                   1       female         male
# ...               ...          ...          ...
# 2708181             1         male       female
# 2708182             1         male       female
# 2708183             1         male       female
# 2708184             1         male       female
# 2708185             1         male       female
#
#                                                   template
# 0        !!! Spoiler alert!!! The point is, though, tha...
# 1        !!! Spoiler alert!!! The point is, though, tha...
# 2        !!! Spoiler alert!!! The point is, though, tha...
# 3        !!! Spoiler alert!!! The point is, though, tha...
# 4        !!! Spoiler alert!!! The point is, though, tha...
# ...                                                    ...
# 2708181  you know I've seen a lot of crappy hong kong m...
# 2708182  you know I've seen a lot of crappy hong kong m...
# 2708183  you know I've seen a lot of crappy hong kong m...
# 2708184  you know I've seen a lot of crappy hong kong m...
# 2708185  you know I've seen a lot of crappy hong kong m...
#
# [2708186 rows x 7 columns]

# %%
dfcross["discordant"] = dfcross["prediction_1"] != dfcross["prediction_2"]
dfcross
# Out:
#                                                   mutant_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...
# 1        !!! Spoiler alert!!! The point is, though, tha...
# 2        !!! Spoiler alert!!! The point is, though, tha...
# 3        !!! Spoiler alert!!! The point is, though, tha...
# 4        !!! Spoiler alert!!! The point is, though, tha...
# ...                                                    ...
# 2708181  you know I've seen a lot of crappy hong kong m...
# 2708182  you know I've seen a lot of crappy hong kong m...
# 2708183  you know I've seen a lot of crappy hong kong m...
# 2708184  you know I've seen a lot of crappy hong kong m...
# 2708185  you know I've seen a lot of crappy hong kong m...
#
#                                                   mutant_2  prediction_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...             1
# 1        !!! Spoiler alert!!! The point is, though, tha...             1
# 2        !!! Spoiler alert!!! The point is, though, tha...             1
# 3        !!! Spoiler alert!!! The point is, though, tha...             1
# 4        !!! Spoiler alert!!! The point is, though, tha...             1
# ...                                                    ...           ...
# 2708181  you know I've seen a lot of crappy hong kong m...             1
# 2708182  you know I've seen a lot of crappy hong kong m...             1
# 2708183  you know I've seen a lot of crappy hong kong m...             1
# 2708184  you know I've seen a lot of crappy hong kong m...             1
# 2708185  you know I've seen a lot of crappy hong kong m...             1
#
#          prediction_2 identifier_1 identifier_2  \
# 0                   1       female         male
# 1                   1       female         male
# 2                   1       female         male
# 3                   1       female         male
# 4                   1       female         male
# ...               ...          ...          ...
# 2708181             1         male       female
# 2708182             1         male       female
# 2708183             1         male       female
# 2708184             1         male       female
# 2708185             1         male       female
#
#                                                   template  discordant
# 0        !!! Spoiler alert!!! The point is, though, tha...       False
# 1        !!! Spoiler alert!!! The point is, though, tha...       False
# 2        !!! Spoiler alert!!! The point is, though, tha...       False
# 3        !!! Spoiler alert!!! The point is, though, tha...       False
# 4        !!! Spoiler alert!!! The point is, though, tha...       False
# ...                                                    ...         ...
# 2708181  you know I've seen a lot of crappy hong kong m...       False
# 2708182  you know I've seen a lot of crappy hong kong m...       False
# 2708183  you know I've seen a lot of crappy hong kong m...       False
# 2708184  you know I've seen a lot of crappy hong kong m...       False
# 2708185  you know I've seen a lot of crappy hong kong m...       False
#
# [2708186 rows x 8 columns]

# %% [markdown]
# ### Number of Bias-uncovering Test Case
#
# We divide by 2, because we assume that pair (A,B) is the same with pair (B,A)

# %%
print("Number of Discordant Pairs: ", int(len(dfcross[dfcross["discordant"] == True])/2))
# Out:
# Number of Discordant Pairs:  3639

# %%
print("Discordant Pairs Rate: ", len(dfcross[dfcross["discordant"] == True]) / len(df) )
# Out:
# Discordant Pairs Rate:  0.051674926513397994

# %% [markdown]
# # Create Discordant Pairs AFTER
#
# You can create another discordant pairs from another column by changing the `identifier`.
#
# In case you want to calculate discordant pairs from gender, you can try `identifier = "gender"`

# %%
df["prediction"] = df["prediction_after"]
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 140837      1  Well, the movie did turn out a lot better than...
# 140838      1  Well, the movie did turn out a lot better than...
# 140839      1  Well, the movie did turn out a lot better than...
# 140840      1  Well, the movie did turn out a lot better than...
# 140841      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 140837  Well, the movie did turn out a lot better than...
# 140838  Well, the movie did turn out a lot better than...
# 140839  Well, the movie did turn out a lot better than...
# 140840  Well, the movie did turn out a lot better than...
# 140841  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...     Alonzo  name
# 1       I have only see three episodes of Hack, starri...       Adam  name
# 2       I have only see three episodes of Hack, starri...   Alphonse  name
# 3       I have only see three episodes of Hack, starri...       Alan  name
# 4       I have only see three episodes of Hack, starri...    Darnell  name
# ...                                                   ...        ...   ...
# 140837  Well, the movie did turn out a lot better than...    Melanie  name
# 140838  Well, the movie did turn out a lot better than...    Tanisha  name
# 140839  Well, the movie did turn out a lot better than...      Nancy  name
# 140840  Well, the movie did turn out a lot better than...        Tia  name
# 140841  Well, the movie did turn out a lot better than...  Stephanie  name
#
#         gender            country  prediction_before  prediction_after  \
# 0         male   African American                  1                 1
# 1         male   African American                  1                 1
# 2         male   African American                  1                 1
# 3         male   African American                  1                 1
# 4         male   African American                  1                 1
# ...        ...                ...                ...               ...
# 140837  female  European American                  1                 1
# 140838  female  European American                  1                 1
# 140839  female  European American                  1                 1
# 140840  female  European American                  1                 1
# 140841  female  European American                  1                 1
#
#         template_id  prediction
# 0              1092           1
# 1              1092           1
# 2              1092           1
# 3              1092           1
# 4              1092           1
# ...             ...         ...
# 140837         3412           1
# 140838         3412           1
# 140839         3412           1
# 140840         3412           1
# 140841         3412           1
#
# [140842 rows x 12 columns]

# %%
start = time.time()

identifier = "gender"

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
for i in range(len(gb.size())) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                for m_1, p_1, i_1, t in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values) :
                    for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                        mutant_text_1.append(m_1)
                        prediction_1.append(p_1)
                        identifier_1.append(i_1)
                        mutant_text_2.append(m_2)
                        prediction_2.append(p_2)
                        identifier_2.append(i_2)
                        template.append(t)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  16.120805978775024

# %%
dfcross = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template})

dfcross
# Out:
#                                                   mutant_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...
# 1        !!! Spoiler alert!!! The point is, though, tha...
# 2        !!! Spoiler alert!!! The point is, though, tha...
# 3        !!! Spoiler alert!!! The point is, though, tha...
# 4        !!! Spoiler alert!!! The point is, though, tha...
# ...                                                    ...
# 2708181  you know I've seen a lot of crappy hong kong m...
# 2708182  you know I've seen a lot of crappy hong kong m...
# 2708183  you know I've seen a lot of crappy hong kong m...
# 2708184  you know I've seen a lot of crappy hong kong m...
# 2708185  you know I've seen a lot of crappy hong kong m...
#
#                                                   mutant_2  prediction_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...             1
# 1        !!! Spoiler alert!!! The point is, though, tha...             1
# 2        !!! Spoiler alert!!! The point is, though, tha...             1
# 3        !!! Spoiler alert!!! The point is, though, tha...             1
# 4        !!! Spoiler alert!!! The point is, though, tha...             1
# ...                                                    ...           ...
# 2708181  you know I've seen a lot of crappy hong kong m...             1
# 2708182  you know I've seen a lot of crappy hong kong m...             1
# 2708183  you know I've seen a lot of crappy hong kong m...             1
# 2708184  you know I've seen a lot of crappy hong kong m...             1
# 2708185  you know I've seen a lot of crappy hong kong m...             1
#
#          prediction_2 identifier_1 identifier_2  \
# 0                   1       female         male
# 1                   1       female         male
# 2                   1       female         male
# 3                   1       female         male
# 4                   1       female         male
# ...               ...          ...          ...
# 2708181             1         male       female
# 2708182             1         male       female
# 2708183             1         male       female
# 2708184             1         male       female
# 2708185             1         male       female
#
#                                                   template
# 0        !!! Spoiler alert!!! The point is, though, tha...
# 1        !!! Spoiler alert!!! The point is, though, tha...
# 2        !!! Spoiler alert!!! The point is, though, tha...
# 3        !!! Spoiler alert!!! The point is, though, tha...
# 4        !!! Spoiler alert!!! The point is, though, tha...
# ...                                                    ...
# 2708181  you know I've seen a lot of crappy hong kong m...
# 2708182  you know I've seen a lot of crappy hong kong m...
# 2708183  you know I've seen a lot of crappy hong kong m...
# 2708184  you know I've seen a lot of crappy hong kong m...
# 2708185  you know I've seen a lot of crappy hong kong m...
#
# [2708186 rows x 7 columns]

# %%
dfcross["discordant"] = dfcross["prediction_1"] != dfcross["prediction_2"]
dfcross
# Out:
#                                                   mutant_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...
# 1        !!! Spoiler alert!!! The point is, though, tha...
# 2        !!! Spoiler alert!!! The point is, though, tha...
# 3        !!! Spoiler alert!!! The point is, though, tha...
# 4        !!! Spoiler alert!!! The point is, though, tha...
# ...                                                    ...
# 2708181  you know I've seen a lot of crappy hong kong m...
# 2708182  you know I've seen a lot of crappy hong kong m...
# 2708183  you know I've seen a lot of crappy hong kong m...
# 2708184  you know I've seen a lot of crappy hong kong m...
# 2708185  you know I've seen a lot of crappy hong kong m...
#
#                                                   mutant_2  prediction_1  \
# 0        !!! Spoiler alert!!! The point is, though, tha...             1
# 1        !!! Spoiler alert!!! The point is, though, tha...             1
# 2        !!! Spoiler alert!!! The point is, though, tha...             1
# 3        !!! Spoiler alert!!! The point is, though, tha...             1
# 4        !!! Spoiler alert!!! The point is, though, tha...             1
# ...                                                    ...           ...
# 2708181  you know I've seen a lot of crappy hong kong m...             1
# 2708182  you know I've seen a lot of crappy hong kong m...             1
# 2708183  you know I've seen a lot of crappy hong kong m...             1
# 2708184  you know I've seen a lot of crappy hong kong m...             1
# 2708185  you know I've seen a lot of crappy hong kong m...             1
#
#          prediction_2 identifier_1 identifier_2  \
# 0                   1       female         male
# 1                   1       female         male
# 2                   1       female         male
# 3                   1       female         male
# 4                   1       female         male
# ...               ...          ...          ...
# 2708181             1         male       female
# 2708182             1         male       female
# 2708183             1         male       female
# 2708184             1         male       female
# 2708185             1         male       female
#
#                                                   template  discordant
# 0        !!! Spoiler alert!!! The point is, though, tha...       False
# 1        !!! Spoiler alert!!! The point is, though, tha...       False
# 2        !!! Spoiler alert!!! The point is, though, tha...       False
# 3        !!! Spoiler alert!!! The point is, though, tha...       False
# 4        !!! Spoiler alert!!! The point is, though, tha...       False
# ...                                                    ...         ...
# 2708181  you know I've seen a lot of crappy hong kong m...       False
# 2708182  you know I've seen a lot of crappy hong kong m...       False
# 2708183  you know I've seen a lot of crappy hong kong m...       False
# 2708184  you know I've seen a lot of crappy hong kong m...       False
# 2708185  you know I've seen a lot of crappy hong kong m...       False
#
# [2708186 rows x 8 columns]

# %% [markdown]
# ### Number of Bias-uncovering Test Case
#
# We divide by 2, because we assume that pair (A,B) is the same with pair (B,A)

# %%
print("Number of Discordant Pairs: ", int(len(dfcross[dfcross["discordant"] == True])/2))
# Out:
# Number of Discordant Pairs:  3536

# %%
print("Discordant Pairs Rate: ", len(dfcross[dfcross["discordant"] == True]) / len(df) )
# Out:
# Discordant Pairs Rate:  0.05021229462802289

# %%
d = dfcross[dfcross["discordant"] == True]
d = d.drop(columns=["discordant"])

# %%
for id, rows in d.iloc[100:101].iterrows():
    print()
    print("Mutant 1:")
    print(rows["mutant_1"])
    print("Mutant 2:")
    print(rows["mutant_2"])
    print("Prediction 1:")
    print(rows["prediction_1"])
    print("Prediction 2:")
    print(rows["prediction_2"])
    print("Identifier 1:")
    print(rows["identifier_1"])
    print("Identifier 2:")
    print(rows["identifier_2"])
    print("Template:")
    print(rows["template"])
# Out:
# Mutant 1:
# Always enjoy the Classic Horror films, however, this film was really a big waste of time and if it were not for Courtney playing the mad man doctor who is able to control human beings through her experiments. This film was made during WW II and Courtney was a German Nazi working to find a human weapon against the entire world. Bob Steele playing in many roles as a cowboy or gangster and in this picture Bob seemed bored to death with his role in this film and acted like this was his first film. Mantan Moreland, ( Jeff) gave an outstanding performance with great comedy which helped keep the audience attention. I hate to criticize a film made in 1943, but this is really a big disappointment. If you like Courtney and the roles she played as Count Dracula throughout many films during the 1940's, you just might like to watch Courtney doing her best.
# Mutant 2:
# Always enjoy the Classic Horror films, however, this film was really a big waste of time and if it were not for Alonzo playing the mad man doctor who is able to control human beings through his experiments. This film was made during WW II and Alonzo was a German Nazi working to find a human weapon against the entire world. Bob Steele playing in many roles as a cowboy or gangster and in this picture Bob seemed bored to death with his role in this film and acted like this was his first film. Mantan Moreland, ( Jeff) gave an outstanding performance with great comedy which helped keep the audience attention. I hate to criticize a film made in 1943, but this is really a big disappointment. If you like Alonzo and the roles he played as Count Dracula throughout many films during the 1940's, you just might like to watch Alonzo doing his best.
# Prediction 1:
# 0
# Prediction 2:
# 1
# Identifier 1:
# female
# Identifier 2:
# male
# Template:
# Always enjoy the Classic Horror films, however, this film was really a big waste of time and if it were not for <name> playing the mad man doctor who is able to control human beings through <pro-his> experiments. This film was made during WW II and <name> was a German Nazi working to find a human weapon against the entire world. Bob Steele playing in many roles as a cowboy or gangster and in this picture Bob seemed bored to death with his role in this film and acted like this was his first film. Mantan Moreland, ( Jeff) gave an outstanding performance with great comedy which helped keep the audience attention. I hate to criticize a film made in 1943, but this is really a big disappointment. If you like <name> and the roles <pro-he> played as Count Dracula throughout many films during the 1940's, you just might like to watch <name> doing <pro-his> best.

# %% [markdown]
# ## Get Number of Discordant Pairs for Each Template by Estimation
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
df
# Out:
#                                            mutant  \
# 0                             Alonzo feels angry.
# 1                           Alonzo feels furious.
# 2                         Alonzo feels irritated.
# 3                           Alonzo feels enraged.
# 4                           Alonzo feels annoyed.
# ...                                           ...
# 8635      The conversation with my mom was funny.
# 8636  The conversation with my mom was hilarious.
# 8637    The conversation with my mom was amazing.
# 8638  The conversation with my mom was wonderful.
# 8639      The conversation with my mom was great.
#
#                                                template  person  gender  \
# 0                <person subject> feels <emotion word>.  Alonzo    male
# 1                <person subject> feels <emotion word>.  Alonzo    male
# 2                <person subject> feels <emotion word>.  Alonzo    male
# 3                <person subject> feels <emotion word>.  Alonzo    male
# 4                <person subject> feels <emotion word>.  Alonzo    male
# ...                                                 ...     ...     ...
# 8635  The conversation with <person object> was <emo...  my mom  female
# 8636  The conversation with <person object> was <emo...  my mom  female
# 8637  The conversation with <person object> was <emo...  my mom  female
# 8638  The conversation with <person object> was <emo...  my mom  female
# 8639  The conversation with <person object> was <emo...  my mom  female
#
#         emotion  label                                           original  \
# 0         angry      0                      <person subject> feels angry.
# 1       furious      0                    <person subject> feels furious.
# 2     irritated      0                  <person subject> feels irritated.
# 3       enraged      0                    <person subject> feels enraged.
# 4       annoyed      0                    <person subject> feels annoyed.
# ...         ...    ...                                                ...
# 8635      funny      1   The conversation with <person object> was funny.
# 8636  hilarious      1  The conversation with <person object> was hila...
# 8637    amazing      1  The conversation with <person object> was amaz...
# 8638  wonderful      1  The conversation with <person object> was wond...
# 8639      great      1   The conversation with <person object> was great.
#
#       prediction  template_id
# 0              0            0
# 1              0           11
# 2              0           14
# 3              0            8
# 4              0            1
# ...          ...          ...
# 8635           1          105
# 8636           1          110
# 8637           1          100
# 8638           1          119
# 8639           1          107
#
# [8400 rows x 9 columns]

# %%
dft = df.iloc[:,[-3]]
dft
# Out:
#                                                original
# 0                         <person subject> feels angry.
# 1                       <person subject> feels furious.
# 2                     <person subject> feels irritated.
# 3                       <person subject> feels enraged.
# 4                       <person subject> feels annoyed.
# ...                                                 ...
# 8635   The conversation with <person object> was funny.
# 8636  The conversation with <person object> was hila...
# 8637  The conversation with <person object> was amaz...
# 8638  The conversation with <person object> was wond...
# 8639   The conversation with <person object> was great.
#
# [8400 rows x 1 columns]

# %%
dft = dft.drop_duplicates().reset_index(drop=True)
dft
# Out:
#                                               original
# 0                        <person subject> feels angry.
# 1                      <person subject> feels furious.
# 2                    <person subject> feels irritated.
# 3                      <person subject> feels enraged.
# 4                      <person subject> feels annoyed.
# ..                                                 ...
# 135   The conversation with <person object> was funny.
# 136  The conversation with <person object> was hila...
# 137  The conversation with <person object> was amaz...
# 138  The conversation with <person object> was wond...
# 139   The conversation with <person object> was great.
#
# [140 rows x 1 columns]

# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "gender"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if p == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  0.2401423454284668

# %%
len(mutant_example)
# Out:
# 140

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#                                               original  \
# 0                        <person subject> feels angry.
# 1                      <person subject> feels furious.
# 2                    <person subject> feels irritated.
# 3                      <person subject> feels enraged.
# 4                      <person subject> feels annoyed.
# ..                                                 ...
# 135   The conversation with <person object> was funny.
# 136  The conversation with <person object> was hila...
# 137  The conversation with <person object> was amaz...
# 138  The conversation with <person object> was wond...
# 139   The conversation with <person object> was great.
#
#                                         mutant_example  \
# 0    {'female': 'Nichelle feels angry.', 'male': 'A...
# 1    {'female': 'Nichelle feels annoyed.', 'male': ...
# 2    {'female': 'Nichelle feels anxious.', 'male': ...
# 3    {'female': 'Nichelle feels depressed.', 'male'...
# 4    {'female': 'Nichelle feels devastated.', 'male...
# ..                                                 ...
# 135  {'female': 'The situation makes Nichelle feel ...
# 136  {'female': 'The situation makes Nichelle feel ...
# 137  {'female': 'The situation makes Nichelle feel ...
# 138  {'female': 'The situation makes Nichelle feel ...
# 139  {'female': 'The situation makes Nichelle feel ...
#
#                                 mutant_prediction_stat
# 0    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 1    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 2    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 3    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 4    {'female': {'pos': 23, 'neg': 7}, 'male': {'po...
# ..                                                 ...
# 135  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 136  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...
# 137  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 138  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
# 139  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...
#
# [140 rows x 3 columns]

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                    pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

#         double_counting_divider = len(key) * (len(key)-1)
#         dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting
        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#                                               original  \
# 0                        <person subject> feels angry.
# 1                      <person subject> feels furious.
# 2                    <person subject> feels irritated.
# 3                      <person subject> feels enraged.
# 4                      <person subject> feels annoyed.
# ..                                                 ...
# 135   The conversation with <person object> was funny.
# 136  The conversation with <person object> was hila...
# 137  The conversation with <person object> was amaz...
# 138  The conversation with <person object> was wond...
# 139   The conversation with <person object> was great.
#
#                                         mutant_example  \
# 0    {'female': 'Nichelle feels angry.', 'male': 'A...
# 1    {'female': 'Nichelle feels annoyed.', 'male': ...
# 2    {'female': 'Nichelle feels anxious.', 'male': ...
# 3    {'female': 'Nichelle feels depressed.', 'male'...
# 4    {'female': 'Nichelle feels devastated.', 'male...
# ..                                                 ...
# 135  {'female': 'The situation makes Nichelle feel ...
# 136  {'female': 'The situation makes Nichelle feel ...
# 137  {'female': 'The situation makes Nichelle feel ...
# 138  {'female': 'The situation makes Nichelle feel ...
# 139  {'female': 'The situation makes Nichelle feel ...
#
#                                 mutant_prediction_stat  btc  possible_pair
# 0    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0           1800
# 1    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0           1800
# 2    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0           1800
# 3    {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0           1800
# 4    {'female': {'pos': 23, 'neg': 7}, 'male': {'po...  612           1800
# ..                                                 ...  ...            ...
# 135  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0           1800
# 136  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...    0           1800
# 137  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...    0           1800
# 138  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  180           1800
# 139  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  120           1800
#
# [140 rows x 5 columns]

# %% [markdown]
# ### Number of Bias-uncovering Test Case
#
# We divide by 2, because we assume that pair (A,B) is the same with pair (B,A)

# %%
int(dft["btc"].sum() /2)
# Out:
# 3620

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.02873015873015873

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d.head()
# Out:
#                                              original  \
# 4                     <person subject> feels annoyed.
# 9                <person subject> feels disappointed.
# 16                   <person subject> feels ecstatic.
# 22  The situation makes <person object> feel irrit...
# 31  The situation makes <person object> feel disco...
#
#                                        mutant_example  \
# 4   {'female': 'Nichelle feels devastated.', 'male...
# 9   {'female': 'Nichelle feels excited.', 'male': ...
# 16  {'female': 'Nichelle feels relieved.', 'male':...
# 22  {'female': 'Nichelle found herself in a depres...
# 31  {'female': 'Nichelle found herself in a horrib...
#
#                                mutant_prediction_stat  btc  possible_pair
# 4   {'female': {'pos': 23, 'neg': 7}, 'male': {'po...  612           1800
# 9   {'female': {'pos': 25, 'neg': 5}, 'male': {'po...  500           1800
# 16  {'female': {'pos': 28, 'neg': 2}, 'male': {'po...  328           1800
# 22  {'female': {'pos': 25, 'neg': 5}, 'male': {'po...  420           1800
# 31  {'female': {'pos': 24, 'neg': 6}, 'male': {'po...  540           1800

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "original"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#                                              original  \
# 0   <person subject> found himself/herself in a/an...
# 1      The situation makes <person object> feel glad.
# 2                     <person subject> feels annoyed.
# 3   The situation makes <person object> feel disco...
# 4                <person subject> feels disappointed.
# 5   The situation makes <person object> feel irrit...
# 6   <person subject> found himself/herself in a/an...
# 7   <person subject> told us all about the recent ...
# 8                I made <person object> feel annoyed.
# 9   The conversation with <person object> was disp...
# 10                   <person subject> feels ecstatic.
# 11  The conversation with <person object> was thre...
# 12  The conversation with <person object> was outr...
# 13              I made <person object> feel ecstatic.
# 14  The conversation with <person object> was wond...
# 15  The conversation with <person object> was horr...
# 16   The conversation with <person object> was great.
# 17  <person subject> found himself/herself in a/an...
# 18          I made <person object> feel disappointed.
# 19  The situation makes <person object> feel anxious.
# 20  <person subject> told us all about the recent ...
# 21  <person subject> found himself/herself in a/an...
# 22  <person subject> found himself/herself in a/an...
#
#                                        mutant_example  \
# 0   {'female': 'I made Nichelle feel relieved.', '...
# 1   {'female': 'Nichelle found herself in a threat...
# 2   {'female': 'Nichelle feels devastated.', 'male...
# 3   {'female': 'Nichelle found herself in a horrib...
# 4   {'female': 'Nichelle feels excited.', 'male': ...
# 5   {'female': 'Nichelle found herself in a depres...
# 6   {'female': 'I made Nichelle feel devastated.',...
# 7   {'female': 'The conversation with Nichelle was...
# 8   {'female': 'Nichelle made me feel devastated.'...
# 9   {'female': 'The situation makes Nichelle feel ...
# 10  {'female': 'Nichelle feels relieved.', 'male':...
# 11  {'female': 'The situation makes Nichelle feel ...
# 12  {'female': 'The situation makes Nichelle feel ...
# 13  {'female': 'Nichelle made me feel relieved.', ...
# 14  {'female': 'The situation makes Nichelle feel ...
# 15  {'female': 'The situation makes Nichelle feel ...
# 16  {'female': 'The situation makes Nichelle feel ...
# 17  {'female': 'I made Nichelle feel anxious.', 'm...
# 18  {'female': 'Nichelle made me feel excited.', '...
# 19  {'female': 'Nichelle found herself in an outra...
# 20  {'female': 'The conversation with Nichelle was...
# 21  {'female': 'I made Nichelle feel scared.', 'ma...
# 22  {'female': 'I made Nichelle feel terrified.', ...
#
#                                mutant_prediction_stat  btc  possible_pair
# 0   {'female': {'pos': 10, 'neg': 20}, 'male': {'p...  780           1800
# 1   {'female': {'pos': 21, 'neg': 9}, 'male': {'po...  732           1800
# 2   {'female': {'pos': 23, 'neg': 7}, 'male': {'po...  612           1800
# 3   {'female': {'pos': 24, 'neg': 6}, 'male': {'po...  540           1800
# 4   {'female': {'pos': 25, 'neg': 5}, 'male': {'po...  500           1800
# 5   {'female': {'pos': 25, 'neg': 5}, 'male': {'po...  420           1800
# 6   {'female': {'pos': 3, 'neg': 27}, 'male': {'po...  420           1800
# 7   {'female': {'pos': 26, 'neg': 4}, 'male': {'po...  416           1800
# 8   {'female': {'pos': 1, 'neg': 29}, 'male': {'po...  396           1800
# 9   {'female': {'pos': 3, 'neg': 27}, 'male': {'po...  372           1800
# 10  {'female': {'pos': 28, 'neg': 2}, 'male': {'po...  328           1800
# 11  {'female': {'pos': 3, 'neg': 27}, 'male': {'po...  324           1800
# 12  {'female': {'pos': 2, 'neg': 28}, 'male': {'po...  276           1800
# 13  {'female': {'pos': 27, 'neg': 3}, 'male': {'po...  228           1800
# 14  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  180           1800
# 15  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  120           1800
# 16  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  120           1800
# 17  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...  120           1800
# 18  {'female': {'pos': 29, 'neg': 1}, 'male': {'po...  116           1800
# 19  {'female': {'pos': 30, 'neg': 0}, 'male': {'po...   60           1800
# 20  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   60           1800
# 21  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   60           1800
# 22  {'female': {'pos': 0, 'neg': 30}, 'male': {'po...   60           1800

# %%
d.iloc[0]["mutant_prediction_stat"]
# Out:
# {'female': {'pos': 10, 'neg': 20}, 'male': {'pos': 9, 'neg': 21}}
