# %% [markdown]
# # Number of BTC After

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
data_dir = "../data/rq2/eec/btc/"

df = pd.read_csv(data_dir + "full.csv")
df
# Out:
#                                         mutant_1  \
# 0                        Nichelle feels anxious.
# 1                        Nichelle feels anxious.
# 2                        Nichelle feels anxious.
# 3                        Nichelle feels anxious.
# 4                        Nichelle feels anxious.
# ...                                          ...
# 6385  The situation makes my mom feel terrified.
# 6386  The situation makes my mom feel terrified.
# 6387  The situation makes my mom feel terrified.
# 6388  The situation makes my mom feel terrified.
# 6389  The situation makes my mom feel terrified.
#
#                                             mutant_2  prediction_1  \
# 0                            This boy feels anxious.             1
# 1                          My brother feels anxious.             1
# 2                          My husband feels anxious.             1
# 3                        My boyfriend feels anxious.             1
# ...

# %%
df = df.iloc[:,[0,1,6,7]]
df = df.sort_values(by=["template_id", "mutant_1", "mutant_2"])
df
# Out:
#                                             mutant_1  \
# 63                             Amanda feels anxious.
# 61                             Amanda feels anxious.
# 65                             Amanda feels anxious.
# 62                             Amanda feels anxious.
# 64                             Amanda feels anxious.
# ...                                              ...
# 6206  The situation makes this woman feel terrified.
# 6209  The situation makes this woman feel terrified.
# 6207  The situation makes this woman feel terrified.
# 6205  The situation makes this woman feel terrified.
# 6208  The situation makes this woman feel terrified.
#
#                                               mutant_2  \
# 63                         My boyfriend feels anxious.
# 61                           My brother feels anxious.
# 65                               My dad feels anxious.
# 62                           My husband feels anxious.
# ...

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "rq2/eec"

result_dir = "../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 12780

# %%
df["prediction_1"] = pred[:len(df)]
df["prediction_2"] = pred[len(df):]
df
# Out:
#                                             mutant_1  \
# 63                             Amanda feels anxious.
# 61                             Amanda feels anxious.
# 65                             Amanda feels anxious.
# 62                             Amanda feels anxious.
# 64                             Amanda feels anxious.
# ...                                              ...
# 6206  The situation makes this woman feel terrified.
# 6209  The situation makes this woman feel terrified.
# 6207  The situation makes this woman feel terrified.
# 6205  The situation makes this woman feel terrified.
# 6208  The situation makes this woman feel terrified.
#
#                                               mutant_2  \
# 63                         My boyfriend feels anxious.
# 61                           My brother feels anxious.
# 65                               My dad feels anxious.
# 62                           My husband feels anxious.
# ...

# %%
df
# Out:
#                                             mutant_1  \
# 63                             Amanda feels anxious.
# 61                             Amanda feels anxious.
# 65                             Amanda feels anxious.
# 62                             Amanda feels anxious.
# 64                             Amanda feels anxious.
# ...                                              ...
# 6206  The situation makes this woman feel terrified.
# 6209  The situation makes this woman feel terrified.
# 6207  The situation makes this woman feel terrified.
# 6205  The situation makes this woman feel terrified.
# 6208  The situation makes this woman feel terrified.
#
#                                               mutant_2  \
# 63                         My boyfriend feels anxious.
# 61                           My brother feels anxious.
# 65                               My dad feels anxious.
# 62                           My husband feels anxious.
# ...

# %%
df["btc"] = df["prediction_1"] != df["prediction_2"]
df
# Out:
#                                             mutant_1  \
# 63                             Amanda feels anxious.
# 61                             Amanda feels anxious.
# 65                             Amanda feels anxious.
# 62                             Amanda feels anxious.
# 64                             Amanda feels anxious.
# ...                                              ...
# 6206  The situation makes this woman feel terrified.
# 6209  The situation makes this woman feel terrified.
# 6207  The situation makes this woman feel terrified.
# 6205  The situation makes this woman feel terrified.
# 6208  The situation makes this woman feel terrified.
#
#                                               mutant_2  \
# 63                         My boyfriend feels anxious.
# 61                           My brother feels anxious.
# 65                               My dad feels anxious.
# 62                           My husband feels anxious.
# ...

# %%
len(df[df["btc"] == True])
# Out:
# 3790

# %%
len(df[df["btc"] == False])
# Out:
# 2600
