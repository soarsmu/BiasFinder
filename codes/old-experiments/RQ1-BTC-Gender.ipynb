# %% [markdown]
# # User Study

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
eval_dir = "gc_imdb"
# df = pd.read_csv("../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=[0, 1, "mutant", "template", "gender", "label", "country"])
df = pd.read_csv("../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "identifier", "type", "gender", "country"])
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 986747      1  Well, the movie did turn out a lot better than...
# 986748      1  Well, the movie did turn out a lot better than...
# 986749      1  Well, the movie did turn out a lot better than...
# 986750      1  Well, the movie did turn out a lot better than...
# 986751      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 986747  Well, the movie did turn out a lot better than...
# 986748  Well, the movie did turn out a lot better than...
# 986749  Well, the movie did turn out a lot better than...
# 986750  Well, the movie did turn out a lot better than...
# 986751  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...       Roen  name
# 1       I have only see three episodes of Hack, starri...       Jeet  name
# 2       I have only see three episodes of Hack, starri...      Hagen  name
# 3       I have only see three episodes of Hack, starri...     Willow  name
# 4       I have only see three episodes of Hack, starri...      Belal  name
# ...                                                   ...        ...   ...
# 986747  Well, the movie did turn out a lot better than...       Dódi  name
# 986748  Well, the movie did turn out a lot better than...     Iboyka  name
# 986749  Well, the movie did turn out a lot better than...     Zsófia  name
# 986750  Well, the movie did turn out a lot better than...      Ágota  name
# 986751  Well, the movie did turn out a lot better than...      Alexa  name
#
#         gender  country
# 0         male       UK
# 1         male       UK
# 2         male       UK
# 3         male       UK
# 4         male       UK
# ...        ...      ...
# 986747  female  Hungary
# 986748  female  Hungary
# 986749  female  Hungary
# 986750  female  Hungary
# 986751  female  Hungary
#
# [986752 rows x 8 columns]

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "gc_imdb"

result_dir = "../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 986752

# %%
df["prediction"] = pred

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 986747      1  Well, the movie did turn out a lot better than...
# 986748      1  Well, the movie did turn out a lot better than...
# 986749      1  Well, the movie did turn out a lot better than...
# 986750      1  Well, the movie did turn out a lot better than...
# 986751      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 986747  Well, the movie did turn out a lot better than...
# 986748  Well, the movie did turn out a lot better than...
# 986749  Well, the movie did turn out a lot better than...
# 986750  Well, the movie did turn out a lot better than...
# 986751  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...       Roen  name
# 1       I have only see three episodes of Hack, starri...       Jeet  name
# 2       I have only see three episodes of Hack, starri...      Hagen  name
# 3       I have only see three episodes of Hack, starri...     Willow  name
# 4       I have only see three episodes of Hack, starri...      Belal  name
# ...                                                   ...        ...   ...
# 986747  Well, the movie did turn out a lot better than...       Dódi  name
# 986748  Well, the movie did turn out a lot better than...     Iboyka  name
# 986749  Well, the movie did turn out a lot better than...     Zsófia  name
# 986750  Well, the movie did turn out a lot better than...      Ágota  name
# 986751  Well, the movie did turn out a lot better than...      Alexa  name
#
#         gender  country  prediction
# 0         male       UK           1
# 1         male       UK           1
# 2         male       UK           1
# 3         male       UK           1
# 4         male       UK           1
# ...        ...      ...         ...
# 986747  female  Hungary           1
# 986748  female  Hungary           1
# 986749  female  Hungary           1
# 986750  female  Hungary           1
# 986751  female  Hungary           1
#
# [986752 rows x 9 columns]

# %%
df[df["label"] == 0].reset_index(drop=True)["original"][0]
# Out:
# 'Does anyone else think that " Reba " is basically a ripoff of " Roseanne "? Just look at the characters from the two families, Connors ( Roseanne) and Harts ( Reba); the blonde bombshell elder daughter ( Becky Connor and Cheyenne Hart) who\'s married to a moron ( Mark Healy and Van Montgomery), the sarcastic brunette younger daughter ( Darlene Connor and Kyra Hart), the little brother ( DJ Connor and Jake Hart), and the quirky relative ( Jackie Connor and BarbaraJean Booker Hart).   And then, of course, there is the biggest similarity, Reba Hart and Roseanne Connor. " Reba " tried to copy the sarcastic and toughlove style mom without giving her the same lovable qualities as Roseanne had. Or, perhaps, they made her* too* lovable, for Reba Hart seems to waver between being mean and scary ( hence Van\'s line to his wife Cheyenne " I\'m not afraid of you, I\'m afraid of your mother! ") and being sweet and caring with little transition in between. Roseanne at least managed to get it across that she was being cruel to be kind, since she was always mean and sarcastic and, whenever she tried to open up, it was hard for her. As inconsistent as Reba\'s character is, it\'s hard for her to be believable.   But even if the characters weren\'t completely ripped off of " Roseanne ", nothing could\'ve saved the show from being subpar in the plot area. The writers try to give the show substance but they really can\'t lay off the corny jokes long enough to give any impact. And you\'d better believe the jokes are corny; it\'s as if they were written by a twelveyearold who thinks that any joke is hilarious. While occasionally they come out with something that\'s funny ( I don\'t pretend that I didn\'t laugh at a few episodes) these gems are too few and far between to make " Reba " witty.   Overall, " Reba " is a very mediocre show with obvious ripoffs of " Roseanne ", subpar plots and subsubpar humor, and ( let\'s face it) terrible acting. The show might be a bit better, actually, if they replaced all the actors, especially Reba herself, who is more community- theater quality than primetime sitcom quality.   I give it a 3 out of 10 just to be fair to the good jokes that make it in.'

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
df["template"] = df["template"].astype("category")
df["template_id"] = df["template"].cat.codes

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template  original  identifier  type  gender  \
# template_id
# 0              310     310       310       310         310   310     310
# 1               26      26        26        26          26    26      26
# 2              310     310       310       310         310   310     310
# 3              310     310       310       310         310   310     310
# 4              310     310       310       310         310   310     310
# ...            ...     ...       ...       ...         ...   ...     ...
# 3725           310     310       310       310         310   310     310
# 3726           310     310       310       310         310   310     310
# 3727           310     310       310       310         310   310     310
# 3728            26      26        26        26          26    26      26
# 3729           310     310       310       310         310   310     310
#
#              country  prediction
# template_id
# 0                310         310
# 1                  0          26
# 2                310         310
# 3                310         310
# 4                310         310
# ...              ...         ...
# 3725             310         310
# 3726             310         310
# 3727             310         310
# 3728               0          26
# 3729             310         310
#
# [3730 rows x 9 columns]

# %%
len(gb.size())
# Out:
# 3692

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 986747      1  Well, the movie did turn out a lot better than...
# 986748      1  Well, the movie did turn out a lot better than...
# 986749      1  Well, the movie did turn out a lot better than...
# 986750      1  Well, the movie did turn out a lot better than...
# 986751      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 986747  Well, the movie did turn out a lot better than...
# 986748  Well, the movie did turn out a lot better than...
# 986749  Well, the movie did turn out a lot better than...
# 986750  Well, the movie did turn out a lot better than...
# 986751  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...       Roen  name
# 1       I have only see three episodes of Hack, starri...       Jeet  name
# 2       I have only see three episodes of Hack, starri...      Hagen  name
# 3       I have only see three episodes of Hack, starri...     Willow  name
# 4       I have only see three episodes of Hack, starri...      Belal  name
# ...                                                   ...        ...   ...
# 986747  Well, the movie did turn out a lot better than...       Dódi  name
# 986748  Well, the movie did turn out a lot better than...     Iboyka  name
# 986749  Well, the movie did turn out a lot better than...     Zsófia  name
# 986750  Well, the movie did turn out a lot better than...      Ágota  name
# 986751  Well, the movie did turn out a lot better than...      Alexa  name
#
#         gender  country  prediction  template_id
# 0         male       UK           1         1218
# 1         male       UK           1         1218
# 2         male       UK           1         1218
# 3         male       UK           1         1218
# 4         male       UK           1         1218
# ...        ...      ...         ...          ...
# 986747  female  Hungary           1         3417
# 986748  female  Hungary           1         3417
# 986749  female  Hungary           1         3417
# 986750  female  Hungary           1         3417
# 986751  female  Hungary           1         3417
#
# [986752 rows x 10 columns]

# %% [markdown]
# ### Get DF template only

# %%
dft = df.iloc[:,[2,3,9]]
dft = dft.drop_duplicates()
dft
# Out:
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 310     In the groovy mid 70's a scruffy bunch of bras...
# 620     This must have been one of <name> 's most ambi...
# 930     The debut that plucked from obscurity one of t...
# 1240    There is really no way to compare this motion ...
# ...                                                   ...
# 985202  I caught this a few times on TV in the late 19...
# 985512  This film is hilarious. Brilliant comedy, but ...
# 985822  One of my favorite movies. I like horses, I li...
# 986132  My Take: Yet another lame PG-13 horror movie w...
# 986442  Well, the movie did turn out a lot better than...
#
#                                                  original  template_id
# 0       I have only see three episodes of Hack, starri...         1218
# 310     In the groovy mid 70's a scruffy bunch of bras...         1830
# 620     This must have been one of Chaplin's most ambi...         3218
# 930     The debut that plucked from obscurity one of t...         2615
# 1240    There is really no way to compare this motion ...         2771
# ...                                                   ...          ...
# 985202  I caught this a few times on TV in the late 19...         1061
# 985512  This film is hilarious. Brilliant comedy, but ...         2855
# 985822  One of my favorite movies. I like horses, I li...         2272
# 986132  My Take: Yet another lame PG-13 horror movie w...         2091
# 986442  Well, the movie did turn out a lot better than...         3417
#
# [3730 rows x 3 columns]

# %%
## template
dft = dft.sort_values(by=["template_id"])
dft = dft.reset_index(drop=True)

## mutant
df = df.reset_index(drop=True)

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 986747      1  Well, the movie did turn out a lot better than...
# 986748      1  Well, the movie did turn out a lot better than...
# 986749      1  Well, the movie did turn out a lot better than...
# 986750      1  Well, the movie did turn out a lot better than...
# 986751      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 986747  Well, the movie did turn out a lot better than...
# 986748  Well, the movie did turn out a lot better than...
# 986749  Well, the movie did turn out a lot better than...
# 986750  Well, the movie did turn out a lot better than...
# 986751  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...       Roen  name
# 1       I have only see three episodes of Hack, starri...       Jeet  name
# 2       I have only see three episodes of Hack, starri...      Hagen  name
# 3       I have only see three episodes of Hack, starri...     Willow  name
# 4       I have only see three episodes of Hack, starri...      Belal  name
# ...                                                   ...        ...   ...
# 986747  Well, the movie did turn out a lot better than...       Dódi  name
# 986748  Well, the movie did turn out a lot better than...     Iboyka  name
# 986749  Well, the movie did turn out a lot better than...     Zsófia  name
# 986750  Well, the movie did turn out a lot better than...      Ágota  name
# 986751  Well, the movie did turn out a lot better than...      Alexa  name
#
#         gender  country  prediction  template_id
# 0         male       UK           1         1218
# 1         male       UK           1         1218
# 2         male       UK           1         1218
# 3         male       UK           1         1218
# 4         male       UK           1         1218
# ...        ...      ...         ...          ...
# 986747  female  Hungary           1         3417
# 986748  female  Hungary           1         3417
# 986749  female  Hungary           1         3417
# 986750  female  Hungary           1         3417
# 986751  female  Hungary           1         3417
#
# [986752 rows x 10 columns]

# %%
dft
# Out:
#                                                template  \
# 0     !!! Spoiler alert!!! The point is, though, tha...
# 1     !!!! MILD SPOILERS!!!! The premise goes like t...
# 2     ' <name> Saves Christmas ' is comedian Ernest'...
# 3     ' Be With Me ' is almost the ultimate wallpape...
# 4     ' Illuminata ' has expanded the limits of John...
# ...                                                 ...
# 3725  without a doubt, one of the most racially prej...
# 3726  wow is all i could say i really loved the movi...
# 3727  wow! it's even better than I expected! the bes...
# 3728  www.petitiononline.com/19784444/petition.html ...
# 3729  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2     ' Ernest Saves Christmas ' is comedian Ernest'...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Illuminata ' has expanded the limits of John...            4
# ...                                                 ...          ...
# 3725  without a doubt, one of the most racially prej...         3725
# 3726  wow is all i could say i really loved the movi...         3726
# 3727  wow! it's even better than I expected! the bes...         3727
# 3728  www.petitiononline.com/19784444/petition.html ...         3728
# 3729  you know I've seen a lot of crappy hong kong m...         3729
#
# [3730 rows x 3 columns]

# %%
dft.to_csv("gender-template.csv")

# %% [markdown]
# ## Get Number of Discordant Pairs for Each Template
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
gb = df.groupby("template_id")
gb.count()
# Out:
#              label  mutant  template  original  identifier  type  gender  \
# template_id
# 0              310     310       310       310         310   310     310
# 1               26      26        26        26          26    26      26
# 2              310     310       310       310         310   310     310
# 3              310     310       310       310         310   310     310
# 4              310     310       310       310         310   310     310
# ...            ...     ...       ...       ...         ...   ...     ...
# 3725           310     310       310       310         310   310     310
# 3726           310     310       310       310         310   310     310
# 3727           310     310       310       310         310   310     310
# 3728            26      26        26        26          26    26      26
# 3729           310     310       310       310         310   310     310
#
#              country  prediction
# template_id
# 0                310         310
# 1                  0          26
# 2                310         310
# 3                310         310
# 4                310         310
# ...              ...         ...
# 3725             310         310
# 3726             310         310
# 3727             310         310
# 3728               0          26
# 3729             310         310
#
# [3730 rows x 9 columns]

# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "gender"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if p == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  6.637021064758301

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#                                                template  \
# 0     !!! Spoiler alert!!! The point is, though, tha...
# 1     !!!! MILD SPOILERS!!!! The premise goes like t...
# 2     ' <name> Saves Christmas ' is comedian Ernest'...
# 3     ' Be With Me ' is almost the ultimate wallpape...
# 4     ' Illuminata ' has expanded the limits of John...
# ...                                                 ...
# 3725  without a doubt, one of the most racially prej...
# 3726  wow is all i could say i really loved the movi...
# 3727  wow! it's even better than I expected! the bes...
# 3728  www.petitiononline.com/19784444/petition.html ...
# 3729  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id  \
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2     ' Ernest Saves Christmas ' is comedian Ernest'...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Illuminata ' has expanded the limits of John...            4
# ...                                                 ...          ...
# 3725  without a doubt, one of the most racially prej...         3725
# 3726  wow is all i could say i really loved the movi...         3726
# 3727  wow! it's even better than I expected! the bes...         3727
# 3728  www.petitiononline.com/19784444/petition.html ...         3728
# 3729  you know I've seen a lot of crappy hong kong m...         3729
#
#                                          mutant_example  \
# 0     {'female': '!!! Spoiler alert!!! The point is,...
# 1     {'female': '!!!! MILD SPOILERS!!!! The premise...
# 2     {'female': '' Sárinka Saves Christmas ' is com...
# 3     {'female': '' Be With Me ' is almost the ultim...
# 4     {'female': '' Illuminata ' has expanded the li...
# ...                                                 ...
# 3725  {'female': 'without a doubt, one of the most r...
# 3726  {'female': 'wow is all i could say i really lo...
# 3727  {'female': 'wow! it's even better than I expec...
# 3728  {'female': 'www.petitiononline.com/19784444/pe...
# 3729  {'female': 'you know I've seen a lot of crappy...
#
#                                  mutant_prediction_stat
# 0     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 1     {'female': {'pos': 0, 'neg': 13}, 'male': {'po...
# 2     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 3     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 4     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# ...                                                 ...
# 3725  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...
# 3726  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 3727  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
# 3728  {'female': {'pos': 13, 'neg': 0}, 'male': {'po...
# 3729  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...
#
# [3730 rows x 5 columns]

# %%
key
# Out:
# ['female', 'male']

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        already_processed = []
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    k = k1 + "-" + k2
                    if k1 > k2 :
                        k = k2 + "-" + k1
                    if k not in already_processed :
                        already_processed.append(k)

                        btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                        pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

#         double_counting_divider = len(key) * (len(key)-1)
#         dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting
        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#                                                template  \
# 0     !!! Spoiler alert!!! The point is, though, tha...
# 1     !!!! MILD SPOILERS!!!! The premise goes like t...
# 2     ' <name> Saves Christmas ' is comedian Ernest'...
# 3     ' Be With Me ' is almost the ultimate wallpape...
# 4     ' Illuminata ' has expanded the limits of John...
# ...                                                 ...
# 3725  without a doubt, one of the most racially prej...
# 3726  wow is all i could say i really loved the movi...
# 3727  wow! it's even better than I expected! the bes...
# 3728  www.petitiononline.com/19784444/petition.html ...
# 3729  you know I've seen a lot of crappy hong kong m...
#
#                                                original  template_id  \
# 0     !!! Spoiler alert!!! The point is, though, tha...            0
# 1     !!!! MILD SPOILERS!!!! The premise goes like t...            1
# 2     ' Ernest Saves Christmas ' is comedian Ernest'...            2
# 3     ' Be With Me ' is almost the ultimate wallpape...            3
# 4     ' Illuminata ' has expanded the limits of John...            4
# ...                                                 ...          ...
# 3725  without a doubt, one of the most racially prej...         3725
# 3726  wow is all i could say i really loved the movi...         3726
# 3727  wow! it's even better than I expected! the bes...         3727
# 3728  www.petitiononline.com/19784444/petition.html ...         3728
# 3729  you know I've seen a lot of crappy hong kong m...         3729
#
#                                          mutant_example  \
# 0     {'female': '!!! Spoiler alert!!! The point is,...
# 1     {'female': '!!!! MILD SPOILERS!!!! The premise...
# 2     {'female': '' Sárinka Saves Christmas ' is com...
# 3     {'female': '' Be With Me ' is almost the ultim...
# 4     {'female': '' Illuminata ' has expanded the li...
# ...                                                 ...
# 3725  {'female': 'without a doubt, one of the most r...
# 3726  {'female': 'wow is all i could say i really lo...
# 3727  {'female': 'wow! it's even better than I expec...
# 3728  {'female': 'www.petitiononline.com/19784444/pe...
# 3729  {'female': 'you know I've seen a lot of crappy...
#
#                                  mutant_prediction_stat  btc  possible_pair
# 0     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...    0          24025
# 1     {'female': {'pos': 0, 'neg': 13}, 'male': {'po...    0            169
# 2     {'female': {'pos': 155, 'neg': 0}, 'male': {'p...    0          24025
# 3     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    0          24025
# 4     {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    0          24025
# ...                                                 ...  ...            ...
# 3725  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    0          24025
# 3726  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...    0          24025
# 3727  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...    0          24025
# 3728  {'female': {'pos': 13, 'neg': 0}, 'male': {'po...    0            169
# 3729  {'female': {'pos': 155, 'neg': 0}, 'male': {'p...    0          24025
#
# [3730 rows x 7 columns]

# %% [markdown]
# ### Number of Bias-uncvering Test Case

# %%
int(dft["btc"].sum())
# Out:
# 229096

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.003039568764830097

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d.head()
# Out:
#                                               template  \
# 139  <name> has made 3 great movies: Boys Meet Girl...
# 191  <name> is perhaps not the most original comic,...
# 376  According to the article at http://blog.ifeng....
# 395  After seeing <name> in " Beyond the Prairie " ...
# 512  As an earlier reviewer said, <name> stole ever...
#
#                                               original  template_id  \
# 139  Leos Carax has made 3 great movies: Boys Meet ...          139
# 191  Carlos is perhaps not the most original comic,...          191
# 376  According to the article at http://blog.ifeng....          376
# 395  After seeing Meredith in " Beyond the Prairie ...          395
# 512  As an earlier reviewer said, Travolta stole ev...          512
#
#                                         mutant_example  \
# 139  {'female': 'Sárinka has made 3 great movies: B...
# 191  {'female': 'Sárinka is perhaps not the most or...
# 376  {'female': 'According to the article at http:/...
# 395  {'female': 'After seeing Sárinka in " Beyond t...
# 512  {'female': 'As an earlier reviewer said, Sárin...
#
#                                 mutant_prediction_stat    btc  possible_pair
# 139  {'female': {'pos': 149, 'neg': 6}, 'male': {'p...   1359          24025
# 191  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  23560          24025
# 376  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    155          24025
# 395  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  23560          24025
# 512  {'female': {'pos': 149, 'neg': 6}, 'male': {'p...   1359          24025

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "template"], ascending=False)
d = d.reset_index(drop=True)
d
# Out:
#                                              template  \
# 0   i think that it was just like <name> except th...
# 1   There are two things that I noticed in this fi...
# 2   OK, so I admit that it often seems like most o...
# 3   I am a huge <name> fan, so I was surprised and...
# 4   The best bit in the film was when <name> pulle...
# 5   After seeing <name> in " Beyond the Prairie " ...
# 6   <name> is perhaps not the most original comic,...
# 7   I enjoyed THE MUPPET MOVIE very much. It was t...
# 8   Back in 2002 when <name> did The Hot Chick, I ...
# 9   As an earlier reviewer said, <name> stole ever...
# 10  <name> has made 3 great movies: Boys Meet Girl...
# 11  I am a huge Shirley Temple fan. When I saw thi...
# 12  Curse of Michael Myers is a very frustrating p...
# 13  This movie should have been billed as three mo...
# 14  Since others have complained about putting <na...
# 15  Reading through most of the other reviews, I t...
# 16  In The Book of Life, Martin Donovan plays Jesu...
# 17  I was quite impressed with this movie as a chi...
# 18  I learned a thing: you have to take this film ...
# 19  I just rewatched a few episodes of this series...
# 20  Hilary was great as julie, and Pat was once ag...
# 21  From Kreestos: The dialog is terrible, awful, ...
# 22  I received this movie as a birthday gift becau...
# 23  I did not think Haggard was the funniest movie...
# 24  I saw this movie for the first time on NBC Fri...
# 25  If you can stomach the campiness, this movie s...
# 26  Tyra Banks needs to teach these girls that it'...
# 27  Not good. Mostly because you don't give a damn...
# 28  I like all of the main actors involved in this...
# 29  According to the article at http://blog.ifeng....
# 30  Try as I might, I just simply couldn't get int...
#
#                                              original  template_id  \
# 0   i think that it was just like Lizzie McGuire e...         3667
# 1   There are two things that I noticed in this fi...         2760
# 2   OK, so I admit that it often seems like most o...         2198
# 3   I am a huge Randolph Scott fan, so I was surpr...         1010
# 4   The best bit in the film was when Alan pulled ...         2601
# 5   After seeing Meredith in " Beyond the Prairie ...          395
# 6   Carlos is perhaps not the most original comic,...          191
# 7   I enjoyed THE MUPPET MOVIE very much. It was t...         1107
# 8   Back in 2002 when Matthew Lawrence did The Hot...          557
# 9   As an earlier reviewer said, Travolta stole ev...          512
# 10  Leos Carax has made 3 great movies: Boys Meet ...          139
# 11  I am a huge Shirley Temple fan. When I saw thi...         1012
# 12  Curse of Michael Myers is a very frustrating p...          662
# 13  This movie should have been billed as three mo...         3156
# 14  Since others have complained about putting She...         2422
# 15  Reading through most of the other reviews, I t...         2351
# 16  In The Book of Life, Martin Donovan plays Jesu...         1812
# 17  I was quite impressed with this movie as a chi...         1589
# 18  I learned a thing: you have to take this film ...         1303
# 19  I just rewatched a few episodes of this series...         1276
# 20  Hilary was great as julie, and Pat was once ag...          952
# 21  From Kreestos:   The dialog is terrible, awful...          865
# 22  I received this movie as a birthday gift becau...         1404
# 23  I did not think Haggard was the funniest movie...         1079
# 24  I saw this movie for the first time on NBC Fri...         1465
# 25  If you can stomach the campiness, this movie s...         1771
# 26  Tyra Banks needs to teach these girls that it'...         3343
# 27  Not good. Mostly because you don't give a damn...         2159
# 28  I like all of the main actors involved in this...         1310
# 29  According to the article at http://blog.ifeng....          376
# 30  Try as I might, I just simply couldn't get int...         3335
#
#                                        mutant_example  \
# 0   {'female': 'i think that it was just like Sári...
# 1   {'female': 'There are two things that I notice...
# 2   {'female': 'OK, so I admit that it often seems...
# 3   {'female': 'I am a huge Sárinka fan, so I was ...
# 4   {'female': 'The best bit in the film was when ...
# 5   {'female': 'After seeing Sárinka in " Beyond t...
# 6   {'female': 'Sárinka is perhaps not the most or...
# 7   {'female': 'I enjoyed THE MUPPET MOVIE very mu...
# 8   {'female': 'Back in 2002 when Sárinka did The ...
# 9   {'female': 'As an earlier reviewer said, Sárin...
# 10  {'female': 'Sárinka has made 3 great movies: B...
# 11  {'female': 'I am a huge Shirley Temple fan. Wh...
# 12  {'female': 'Curse of Michael Myers is a very f...
# 13  {'female': 'This movie should have been billed...
# 14  {'female': 'Since others have complained about...
# 15  {'female': 'Reading through most of the other ...
# 16  {'female': 'In The Book of Life, Martin Donova...
# 17  {'female': 'I was quite impressed with this mo...
# 18  {'female': 'I learned a thing: you have to tak...
# 19  {'female': 'I just rewatched a few episodes of...
# 20  {'female': 'Hilary was great as julie, and Pat...
# 21  {'female': 'From Kreestos: The dialog is terri...
# 22  {'female': 'I received this movie as a birthda...
# 23  {'female': 'I did not think Haggard was the fu...
# 24  {'female': 'I saw this movie for the first tim...
# 25  {'female': 'If you can stomach the campiness, ...
# 26  {'female': 'Tyra Banks needs to teach these gi...
# 27  {'female': 'Not good. Mostly because you don't...
# 28  {'female': 'I like all of the main actors invo...
# 29  {'female': 'According to the article at http:/...
# 30  {'female': 'Try as I might, I just simply coul...
#
#                                mutant_prediction_stat    btc  possible_pair
# 0   {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  24025          24025
# 1   {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  24025          24025
# 2   {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  24025          24025
# 3   {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  23870          24025
# 4   {'female': {'pos': 1, 'neg': 154}, 'male': {'p...  23717          24025
# 5   {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  23560          24025
# 6   {'female': {'pos': 0, 'neg': 155}, 'male': {'p...  23560          24025
# 7   {'female': {'pos': 6, 'neg': 149}, 'male': {'p...  23095          24025
# 8   {'female': {'pos': 6, 'neg': 149}, 'male': {'p...  23095          24025
# 9   {'female': {'pos': 149, 'neg': 6}, 'male': {'p...   1359          24025
# 10  {'female': {'pos': 149, 'neg': 6}, 'male': {'p...   1359          24025
# 11  {'female': {'pos': 149, 'neg': 6}, 'male': {'p...   1073          24025
# 12  {'female': {'pos': 149, 'neg': 6}, 'male': {'p...   1073          24025
# 13  {'female': {'pos': 150, 'neg': 5}, 'male': {'p...    920          24025
# 14  {'female': {'pos': 150, 'neg': 5}, 'male': {'p...    920          24025
# 15  {'female': {'pos': 5, 'neg': 150}, 'male': {'p...    920          24025
# 16  {'female': {'pos': 150, 'neg': 5}, 'male': {'p...    920          24025
# 17  {'female': {'pos': 5, 'neg': 150}, 'male': {'p...    920          24025
# 18  {'female': {'pos': 5, 'neg': 150}, 'male': {'p...    920          24025
# 19  {'female': {'pos': 150, 'neg': 5}, 'male': {'p...    920          24025
# 20  {'female': {'pos': 150, 'neg': 5}, 'male': {'p...    920          24025
# 21  {'female': {'pos': 5, 'neg': 150}, 'male': {'p...    920          24025
# 22  {'female': {'pos': 150, 'neg': 5}, 'male': {'p...    775          24025
# 23  {'female': {'pos': 150, 'neg': 5}, 'male': {'p...    775          24025
# 24  {'female': {'pos': 1, 'neg': 154}, 'male': {'p...    461          24025
# 25  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    310          24025
# 26  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    155          24025
# 27  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    155          24025
# 28  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    155          24025
# 29  {'female': {'pos': 0, 'neg': 155}, 'male': {'p...    155          24025
# 30  {'female': {'pos': 0, 'neg': 13}, 'male': {'po...     39            169

# %%
d.to_csv("occ-age/gender-btc.csv")

# %%
d.iloc[0]["mutant_prediction_stat"]
# Out:
# {'female': {'pos': 0, 'neg': 155}, 'male': {'pos': 155, 'neg': 0}}

# %%
d.groupby("template_id").get_group(2760).iloc[0]["mutant_prediction_stat"]
# Out:
# {'female': {'pos': 0, 'neg': 155}, 'male': {'pos': 155, 'neg': 0}}

# %%
# d.groupby("template_id").get_group(2760).iloc[0]["mutant_example"]
# Out:
# {'female': 'There are two things that I noticed in this film. ( This is not a spoiler, just a mistake in storytelling.) When Cole takes Sárinka to her first B&E, she finds the " box ". As soon as Cole finds it she says, " The box. Everyone\'s got a box ". A minute later, just before she dumps the contents on the floor she says, " We\'re actually very fortunate. You don\'t see these often ". Observation# 2 ( Spoiler Alert!) I had to watch the thing three times, I couldn\'t figure a couple of things out. Then I watched the Chronological version and saw that they were having flash backs from the latter to the previous during the time changes. So at some points we were actually watching three different times in about 1 min of wall time. That was a good thing because I don\'t know how many more times I could watch it before returning it to Netflix. Color me obsessive.',
#  'male': 'There are two things that I noticed in this film. ( This is not a spoiler, just a mistake in storytelling.) When Cole takes Roen to his first B&E, he finds the " box ". As soon as Cole finds it he says, " The box. Everyone\'s got a box ". A minute later, just before he dumps the contents on the floor he says, " We\'re actually very fortunate. You don\'t see these often ". Observation# 2 ( Spoiler Alert!) I had to watch the thing three times, I couldn\'t figure a couple of things out. Then I watched the Chronological version and saw that they were having flash backs from the latter to the previous during the time changes. So at some points we were actually watching three different times in about 1 min of wall time. That was a good thing because I don\'t know how many more times I could watch it before returning it to Netflix. Color me obsessive.'}

# %%
# d.groupby("template_id").get_group(2760).iloc[0]["template"]
# Out:
# 'There are two things that I noticed in this film. ( This is not a spoiler, just a mistake in storytelling.) When Cole takes <name> to <pro-his> first B&E, <pro-he> finds the " box ". As soon as Cole finds it <pro-he> says, " The box. Everyone\'s got a box ". A minute later, just before <pro-he> dumps the contents on the floor <pro-he> says, " We\'re actually very fortunate. You don\'t see these often ". Observation# 2 ( Spoiler Alert!) I had to watch the thing three times, I couldn\'t figure a couple of things out. Then I watched the Chronological version and saw that they were having flash backs from the latter to the previous during the time changes. So at some points we were actually watching three different times in about 1 min of wall time. That was a good thing because I don\'t know how many more times I could watch it before returning it to Netflix. Color me obsessive.'

# %% [markdown]
# ### Get Data BTC for train and test

# %%
df
# Out:
#         label                                             mutant  \
# 0           1  I have only see three episodes of Hack, starri...
# 1           1  I have only see three episodes of Hack, starri...
# 2           1  I have only see three episodes of Hack, starri...
# 3           1  I have only see three episodes of Hack, starri...
# 4           1  I have only see three episodes of Hack, starri...
# ...       ...                                                ...
# 986747      1  Well, the movie did turn out a lot better than...
# 986748      1  Well, the movie did turn out a lot better than...
# 986749      1  Well, the movie did turn out a lot better than...
# 986750      1  Well, the movie did turn out a lot better than...
# 986751      1  Well, the movie did turn out a lot better than...
#
#                                                  template  \
# 0       I have only see three episodes of Hack, starri...
# 1       I have only see three episodes of Hack, starri...
# 2       I have only see three episodes of Hack, starri...
# 3       I have only see three episodes of Hack, starri...
# 4       I have only see three episodes of Hack, starri...
# ...                                                   ...
# 986747  Well, the movie did turn out a lot better than...
# 986748  Well, the movie did turn out a lot better than...
# 986749  Well, the movie did turn out a lot better than...
# 986750  Well, the movie did turn out a lot better than...
# 986751  Well, the movie did turn out a lot better than...
#
#                                                  original identifier  type  \
# 0       I have only see three episodes of Hack, starri...       Roen  name
# 1       I have only see three episodes of Hack, starri...       Jeet  name
# 2       I have only see three episodes of Hack, starri...      Hagen  name
# 3       I have only see three episodes of Hack, starri...     Willow  name
# 4       I have only see three episodes of Hack, starri...      Belal  name
# ...                                                   ...        ...   ...
# 986747  Well, the movie did turn out a lot better than...       Dódi  name
# 986748  Well, the movie did turn out a lot better than...     Iboyka  name
# 986749  Well, the movie did turn out a lot better than...     Zsófia  name
# 986750  Well, the movie did turn out a lot better than...      Ágota  name
# 986751  Well, the movie did turn out a lot better than...      Alexa  name
#
#         gender  country  prediction  template_id
# 0         male       UK           1         1218
# 1         male       UK           1         1218
# 2         male       UK           1         1218
# 3         male       UK           1         1218
# 4         male       UK           1         1218
# ...        ...      ...         ...          ...
# 986747  female  Hungary           1         3417
# 986748  female  Hungary           1         3417
# 986749  female  Hungary           1         3417
# 986750  female  Hungary           1         3417
# 986751  female  Hungary           1         3417
#
# [986752 rows x 10 columns]

# %%
template_that_produce_btc = d["template_id"].tolist()
# template_that_produce_btc

# %%
start = time.time()

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
label = []
for i in template_that_produce_btc: # only processing from template that produce BTC
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    already_processed = []
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                key = k1 + "-" + k2
                if k1 > k2 :
                    key = k2 + "-" + k1
                if key not in already_processed :
                    already_processed.append(key)
                    for m_1, p_1, i_1, t, l in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values,  v1["label"].values) :
                        for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                            if p_1 != p_2 : # only add discordant pairs
                                mutant_text_1.append(m_1)
                                prediction_1.append(p_1)
                                identifier_1.append(i_1)
                                mutant_text_2.append(m_2)
                                prediction_2.append(p_2)
                                identifier_2.append(i_2)
                                template.append(t)
                                label.append(l)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  0.4049961566925049

# %%
btc = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template, "label": label})

btc
# Out:
#                                                  mutant_1  \
# 0       i think that it was just like Sárinka except t...
# 1       i think that it was just like Sárinka except t...
# 2       i think that it was just like Sárinka except t...
# 3       i think that it was just like Sárinka except t...
# 4       i think that it was just like Sárinka except t...
# ...                                                   ...
# 229091  Try as I might, I just simply couldn't get int...
# 229092  Try as I might, I just simply couldn't get int...
# 229093  Try as I might, I just simply couldn't get int...
# 229094  Try as I might, I just simply couldn't get int...
# 229095  Try as I might, I just simply couldn't get int...
#
#                                                  mutant_2  prediction_1  \
# 0       i think that it was just like Roen except that...             0
# 1       i think that it was just like Jeet except that...             0
# 2       i think that it was just like Hagen except tha...             0
# 3       i think that it was just like Willow except th...             0
# 4       i think that it was just like Belal except tha...             0
# ...                                                   ...           ...
# 229091  Try as I might, I just simply couldn't get int...             0
# 229092  Try as I might, I just simply couldn't get int...             0
# 229093  Try as I might, I just simply couldn't get int...             0
# 229094  Try as I might, I just simply couldn't get int...             0
# 229095  Try as I might, I just simply couldn't get int...             0
#
#         prediction_2 identifier_1 identifier_2  \
# 0                  1       female         male
# 1                  1       female         male
# 2                  1       female         male
# 3                  1       female         male
# 4                  1       female         male
# ...              ...          ...          ...
# 229091             1       female         male
# 229092             1       female         male
# 229093             1       female         male
# 229094             1       female         male
# 229095             1       female         male
#
#                                                  template  label
# 0       i think that it was just like <name> except th...      0
# 1       i think that it was just like <name> except th...      0
# 2       i think that it was just like <name> except th...      0
# 3       i think that it was just like <name> except th...      0
# 4       i think that it was just like <name> except th...      0
# ...                                                   ...    ...
# 229091  Try as I might, I just simply couldn't get int...      0
# 229092  Try as I might, I just simply couldn't get int...      0
# 229093  Try as I might, I just simply couldn't get int...      0
# 229094  Try as I might, I just simply couldn't get int...      0
# 229095  Try as I might, I just simply couldn't get int...      0
#
# [229096 rows x 8 columns]

# %%
import os
data_dir = "../data/rq2/biasfinder_btc/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)


train = btc.sample(frac=1, random_state=123)
train.to_csv(data_dir + "train.csv", index=None, header=None, sep="\t")

# %%
data_dir = "../data/rq2/biasfinder_btc/"

if not os.path.exists(data_dir) :
    os.makedirs(data_dir)

train.to_csv(data_dir + "test.csv", index=None, header=None, sep="\t")
