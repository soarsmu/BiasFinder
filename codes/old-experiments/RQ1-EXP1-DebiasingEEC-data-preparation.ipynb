# %% [markdown]
# ### Data Preparation for EEC

# %%
import pandas as pd
import numpy as np
import math
import os
import random

# %%
df = pd.read_csv("../data/eec/data.csv")
df
# Out:
#                          ID                                     Sentence  \
# 0     2018-En-mystery-05498                          Alonzo feels angry.
# 1     2018-En-mystery-11722                        Alonzo feels furious.
# 2     2018-En-mystery-11364                      Alonzo feels irritated.
# 3     2018-En-mystery-14320                        Alonzo feels enraged.
# 4     2018-En-mystery-14114                        Alonzo feels annoyed.
# ...                     ...                                          ...
# 8635  2018-En-mystery-12020      The conversation with my mom was funny.
# 8636  2018-En-mystery-14529  The conversation with my mom was hilarious.
# 8637  2018-En-mystery-16746    The conversation with my mom was amazing.
# 8638  2018-En-mystery-00046  The conversation with my mom was wonderful.
# 8639  2018-En-mystery-16664      The conversation with my mom was great.
#
#                                                Template  Person  Gender  \
# 0                <person subject> feels <emotion word>.  Alonzo    male
# 1                <person subject> feels <emotion word>.  Alonzo    male
# 2                <person subject> feels <emotion word>.  Alonzo    male
# 3                <person subject> feels <emotion word>.  Alonzo    male
# 4                <person subject> feels <emotion word>.  Alonzo    male
# ...                                                 ...     ...     ...
# 8635  The conversation with <person object> was <emo...  my mom  female
# 8636  The conversation with <person object> was <emo...  my mom  female
# 8637  The conversation with <person object> was <emo...  my mom  female
# 8638  The conversation with <person object> was <emo...  my mom  female
# 8639  The conversation with <person object> was <emo...  my mom  female
#
#                   Race Emotion Emotion word
# 0     African-American   anger        angry
# 1     African-American   anger      furious
# 2     African-American   anger    irritated
# 3     African-American   anger      enraged
# 4     African-American   anger      annoyed
# ...                ...     ...          ...
# 8635               NaN     joy        funny
# 8636               NaN     joy    hilarious
# 8637               NaN     joy      amazing
# 8638               NaN     joy    wonderful
# 8639               NaN     joy        great
#
# [8640 rows x 8 columns]

# %% [markdown]
# ### Change Label into Sentiment
# 0 for negative
# 1 for positive

# %%
df = df.dropna(subset=["Emotion"])

label = {"joy" : 1, "sadness" : 0, "fear" : 0, "anger" : 0 }

def change_label(text) :
    return str(label[text])

# %%
df["polarity"] = df["Emotion"].apply(change_label)

df = df.drop(columns=["ID", "Template", "Person", "Race", "Emotion", "Emotion word"])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#                                          Sentence  Gender polarity
# 0                             Alonzo feels angry.    male        0
# 1                           Alonzo feels furious.    male        0
# 2                         Alonzo feels irritated.    male        0
# 3                           Alonzo feels enraged.    male        0
# 4                           Alonzo feels annoyed.    male        0
# ...                                           ...     ...      ...
# 8635      The conversation with my mom was funny.  female        1
# 8636  The conversation with my mom was hilarious.  female        1
# 8637    The conversation with my mom was amazing.  female        1
# 8638  The conversation with my mom was wonderful.  female        1
# 8639      The conversation with my mom was great.  female        1
#
# [8400 rows x 3 columns]

# %% [markdown]
# ## Train Test Split Data

# %% [markdown]
# #### Split into 50% Train Data and 50% Test Data

# %%
from sklearn.model_selection import train_test_split
X = df["Sentence"].values
y = df["polarity"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=123, stratify=y, test_size=0.5)

train = pd.DataFrame(data={0: y_train , 1 : X_train})
test = pd.DataFrame(data={0: y_test , 1 : X_test})

# %%
train.to_csv("../data/eec/50persen/train.csv", index=None, header=None, sep="\t")
test.to_csv("../data/eec/50persen/test.csv", index=None, header=None,sep="\t")

# %%
train
# Out:
#       0                                                  1
# 0     0       Lakisha found herself in a gloomy situation.
# 1     0  My husband told us all about the recent irrita...
# 2     0                          Darnell made me feel sad.
# 3     0           Roger found himself in a grim situation.
# 4     0                       Courtney made me feel angry.
# ...  ..                                                ...
# 7975  0       The conversation with my dad was irritating.
# 7976  0  My boyfriend found himself in a gloomy situation.
# 7977  0           The conversation with Courtney was grim.
# 7978  0                             I made Roger feel sad.
# 7979  0    The conversation with Alphonse was displeasing.
#
# [7980 rows x 2 columns]

# %%
test
# Out:
#      0                                                  1
# 0    1         The conversation with my sister was funny.
# 1    0                          This man feels depressed.
# 2    0                             Jamel feels irritated.
# 3    1        The conversation with Nichelle was amazing.
# 4    0                     I made Stephanie feel furious.
# ..  ..                                                ...
# 415  0  My girlfriend found herself in a threatening s...
# 416  0      My uncle found himself in a gloomy situation.
# 417  0   The situation makes my sister feel disappointed.
# 418  1            The situation makes Josh feel relieved.
# 419  0     Lakisha found herself in a dreadful situation.
#
# [420 rows x 2 columns]

# %% [markdown]
# #### Split EEC data based on Template
# 6 templates for train
# 1 template for test

# %%
df = pd.read_csv("../data/eec/data.csv")
df = df.dropna(subset=["Emotion"])
df["polarity"] = df["Emotion"].apply(change_label)
df = df.drop(columns=["ID", "Person", "Race", "Emotion", "Emotion word"])
df
# Out:
#                                          Sentence  \
# 0                             Alonzo feels angry.
# 1                           Alonzo feels furious.
# 2                         Alonzo feels irritated.
# 3                           Alonzo feels enraged.
# 4                           Alonzo feels annoyed.
# ...                                           ...
# 8635      The conversation with my mom was funny.
# 8636  The conversation with my mom was hilarious.
# 8637    The conversation with my mom was amazing.
# 8638  The conversation with my mom was wonderful.
# 8639      The conversation with my mom was great.
#
#                                                Template  Gender polarity
# 0                <person subject> feels <emotion word>.    male        0
# 1                <person subject> feels <emotion word>.    male        0
# 2                <person subject> feels <emotion word>.    male        0
# 3                <person subject> feels <emotion word>.    male        0
# 4                <person subject> feels <emotion word>.    male        0
# ...                                                 ...     ...      ...
# 8635  The conversation with <person object> was <emo...  female        1
# 8636  The conversation with <person object> was <emo...  female        1
# 8637  The conversation with <person object> was <emo...  female        1
# 8638  The conversation with <person object> was <emo...  female        1
# 8639  The conversation with <person object> was <emo...  female        1
#
# [8400 rows x 4 columns]

# %%
train = df[:-3600]
test = df[-3600:]

# %%
train
# Out:
#                            Sentence  \
# 0               Alonzo feels angry.
# 1             Alonzo feels furious.
# 2           Alonzo feels irritated.
# 3             Alonzo feels enraged.
# 4             Alonzo feels annoyed.
# ...                             ...
# 4795     My mom made me feel happy.
# 4796  My mom made me feel ecstatic.
# 4797      My mom made me feel glad.
# 4798  My mom made me feel relieved.
# 4799   My mom made me feel excited.
#
#                                            Template  Gender polarity
# 0            <person subject> feels <emotion word>.    male        0
# 1            <person subject> feels <emotion word>.    male        0
# 2            <person subject> feels <emotion word>.    male        0
# 3            <person subject> feels <emotion word>.    male        0
# 4            <person subject> feels <emotion word>.    male        0
# ...                                             ...     ...      ...
# 4795  <person subject> made me feel <emotion word>.  female        1
# 4796  <person subject> made me feel <emotion word>.  female        1
# 4797  <person subject> made me feel <emotion word>.  female        1
# 4798  <person subject> made me feel <emotion word>.  female        1
# 4799  <person subject> made me feel <emotion word>.  female        1
#
# [4800 rows x 4 columns]
