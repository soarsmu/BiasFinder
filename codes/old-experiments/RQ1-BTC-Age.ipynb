# %% [markdown]
# # Number of Discordant Pairs Country
#
# Discordant pair is a pair contain of male-female and its prediction, such that the Sentiment Analysis produce a different prediction.
# Example of discordant pair from country:
#
# `<(name from Indonesia, prediction), (name from USA, prediction)>`
#
# `<(“Paijo is angry”, 1), (“John is angry”, 0)>`

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
file_name = "age"
df = pd.read_csv("occ-age/prepared/" + file_name + ".csv")
df["label"] = df["0"]
df = df.iloc[:,2:]
df
# Out:
#                                                   mutant  \
# 0      b " The Mascot is Starewicz's masterpiece. It ...
# 1      b " The Mascot is Starewicz's masterpiece. It ...
# 2      b " I have only see three episodes of Hack, st...
# 3      b " I have only see three episodes of Hack, st...
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...
# ...                                                  ...
# 36909  b " How do you describe perfection? In - the -...
# 36910  b " The French Babbette appears at the modest ...
# 36911  b " The French Babbette appears at the modest ...
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...
#
#                                                 template  \
# 0      b " The Mascot is Starewicz's masterpiece. It ...
# 1      b " The Mascot is Starewicz's masterpiece. It ...
# 2      b " I have only see three episodes of Hack, st...
# 3      b " I have only see three episodes of Hack, st...
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...
# ...                                                  ...
# 36909  b " How do you describe perfection? In - the -...
# 36910  b " The French Babbette appears at the modest ...
# 36911  b " The French Babbette appears at the modest ...
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...
#
#                                                 original    age  \
# 0      b " The Mascot is Ladislaw Starewicz's masterp...  young
# 1      b " The Mascot is Ladislaw Starewicz's masterp...    old
# 2      b " I have only see three episodes of Hack, st...  young
# 3      b " I have only see three episodes of Hack, st...    old
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...  young
# ...                                                  ...    ...
# 36909  b " How do you describe perfection? In - the -...    old
# 36910  b " The French Babbette appears at the modest ...  young
# 36911  b " The French Babbette appears at the modest ...    old
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...  young
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...    old
#
#                 name  label
# 0          Starewicz      1
# 1          Starewicz      1
# 2        David Morse      1
# 3        David Morse      1
# 4       Shabana Azmi      1
# ...              ...    ...
# 36909  Maggie Cheung      1
# 36910        Babette      1
# 36911        Babette      1
# 36912     Gary Busey      1
# 36913     Gary Busey      1
#
# [36914 rows x 6 columns]

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "age"

result_dir = "../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 36914

# %%
df["prediction"] = pred
df
# Out:
#                                                   mutant  \
# 0      b " The Mascot is Starewicz's masterpiece. It ...
# 1      b " The Mascot is Starewicz's masterpiece. It ...
# 2      b " I have only see three episodes of Hack, st...
# 3      b " I have only see three episodes of Hack, st...
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...
# ...                                                  ...
# 36909  b " How do you describe perfection? In - the -...
# 36910  b " The French Babbette appears at the modest ...
# 36911  b " The French Babbette appears at the modest ...
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...
#
#                                                 template  \
# 0      b " The Mascot is Starewicz's masterpiece. It ...
# 1      b " The Mascot is Starewicz's masterpiece. It ...
# 2      b " I have only see three episodes of Hack, st...
# 3      b " I have only see three episodes of Hack, st...
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...
# ...                                                  ...
# 36909  b " How do you describe perfection? In - the -...
# 36910  b " The French Babbette appears at the modest ...
# 36911  b " The French Babbette appears at the modest ...
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...
#
#                                                 original    age  \
# 0      b " The Mascot is Ladislaw Starewicz's masterp...  young
# 1      b " The Mascot is Ladislaw Starewicz's masterp...    old
# 2      b " I have only see three episodes of Hack, st...  young
# 3      b " I have only see three episodes of Hack, st...    old
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...  young
# ...                                                  ...    ...
# 36909  b " How do you describe perfection? In - the -...    old
# 36910  b " The French Babbette appears at the modest ...  young
# 36911  b " The French Babbette appears at the modest ...    old
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...  young
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...    old
#
#                 name  label  prediction
# 0          Starewicz      1           1
# 1          Starewicz      1           1
# 2        David Morse      1           1
# 3        David Morse      1           1
# 4       Shabana Azmi      1           1
# ...              ...    ...         ...
# 36909  Maggie Cheung      1           1
# 36910        Babette      1           1
# 36911        Babette      1           1
# 36912     Gary Busey      1           1
# 36913     Gary Busey      1           1
#
# [36914 rows x 7 columns]

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
df["original"] = df["original"].astype("category")
df["template_id"] = df["original"].cat.codes

# %%
df = df.sort_values(by="template_id").reset_index(drop=True)

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              mutant  template  original  age  name  label  prediction
# template_id
# 0                 2         2         2    2     2      2           2
# 1                 2         2         2    2     2      2           2
# 2                 2         2         2    2     2      2           2
# 3                 2         2         2    2     2      2           2
# 4                 2         2         2    2     2      2           2
# ...             ...       ...       ...  ...   ...    ...         ...
# 18313             2         2         2    2     2      2           2
# 18314             2         2         2    2     2      2           2
# 18315             2         2         2    2     2      2           2
# 18316             2         2         2    2     2      2           2
# 18317             2         2         2    2     2      2           2
#
# [18318 rows x 7 columns]

# %%
len(gb.size())
# Out:
# 18318

# %% [markdown]
# #### Create Discordant Pairs based on Country
#
# You can create another discordant pairs from another column by changing the `identifier`.
#
# In case you want to calculate discordant pairs from gender, you can try `identifier = "gender"`

# %%
start = time.time()

identifier = "age"

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    already_processed = []
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                key = k1 + "-" + k2
                if k1 > k2 :
                    key = k2 + "-" + k1
                if key not in already_processed :
                    already_processed.append(key)
                    for m_1, p_1, i_1, t in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values) :
                        for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                            if p_1 != p_2 : # only add discordant pairs
                                mutant_text_1.append(m_1)
                                prediction_1.append(p_1)
                                identifier_1.append(i_1)
                                mutant_text_2.append(m_2)
                                prediction_2.append(p_2)
                                identifier_2.append(i_2)
                                template.append(t)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  56.55478858947754

# %%
dfcross = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template})

dfcross
# Out:
#                                              mutant_1  \
# 0   b " Even the trailer for this movie makes me c...
# 1   b " old Gary Cooper is a cool headed guy. Alwa...
# 2   b " Half Past Dead was unlike any old Steven S...
# 3   b " old Hedy Lamarr who may have been kept by ...
# 4   b " I actually liked this movie. Sure, the act...
# 5   b " I rented this film because I enjoy watchin...
# 6   b " I went to see this thinking it would be a ...
# 7   b " I've Seen The Beginning Of The Muppet Movi...
# 8   b " If you like silly comedies like Airplane y...
# 9   b " old Leno talks through his punch lines. Th...
# 10  b " old Leos Carax has made 3 great movies: Bo...
# 11  b " old Leos Carax has made 3 great movies: Bo...
# 12  b " old Leos Carax has made 3 great movies: Bo...
# 13  b " old Leos Carax has made 3 great movies: Bo...
# 14  b " That pretty much sums it up ... corny. Mac...
# 15  b " This movie is a must see for any war movie...
# 16  b " Very intelligent language usage of old Ali...
# 17  b " Where the hell did VH1 find the scriptwrit...
# 18  b " old Michael Dudikoff like young Lord Greys...
# 19  b ' As a physicist, talk about blackholes and ...
# 20  b ' Childish storyline ripped off of a lame Ho...
# 21  b ' I have long tried to understand why people...
# 22  b ' Ice the Limerick: A virus pulled out of th...
# 23  b ' It might be a stretch saying this as a die...
# 24  b ' My yardstick for measuring a movie's watch...
# 25  b ' Often considered old Argento's last " grea...
# 26  b ' The tagline for this show is, " He's speak...
# 27  b ' They missed up the film when the tried to ...
# 28  b ' What we know of Caravaggio suggests a stru...
# 29  b ' Wow, was this version of THE RACKETEER tou...
# 30  b ' You can not be seeing the same movie if yo...
#
#                                              mutant_2  prediction_1  \
# 0   b " Even the trailer for this movie makes me c...             0
# 1   b " young Gary Cooper is a cool headed guy. Al...             0
# 2   b " Half Past Dead was unlike any young Steven...             1
# 3   b " young Hedy Lamarr who may have been kept b...             0
# 4   b " I actually liked this movie. Sure, the act...             0
# 5   b " I rented this film because I enjoy watchin...             0
# 6   b " I went to see this thinking it would be a ...             1
# 7   b " I've Seen The Beginning Of The Muppet Movi...             0
# 8   b " If you like silly comedies like Airplane y...             0
# 9   b " young Leno talks through his punch lines. ...             0
# 10  b " young Leos Carax has made 3 great movies: ...             0
# 11  b " young Leos Carax has made 3 great movies: ...             0
# 12  b " young Leos Carax has made 3 great movies: ...             0
# 13  b " young Leos Carax has made 3 great movies: ...             0
# 14  b " That pretty much sums it up ... corny. Mac...             0
# 15  b " This movie is a must see for any war movie...             0
# 16  b " Very intelligent language usage of young A...             1
# 17  b " Where the hell did VH1 find the scriptwrit...             1
# 18  b " young Michael Dudikoff like young Lord Gre...             0
# 19  b ' As a physicist, talk about blackholes and ...             1
# 20  b ' Childish storyline ripped off of a lame Ho...             0
# 21  b ' I have long tried to understand why people...             0
# 22  b ' Ice the Limerick: A virus pulled out of th...             0
# 23  b ' It might be a stretch saying this as a die...             0
# 24  b ' My yardstick for measuring a movie's watch...             0
# 25  b ' Often considered young Argento's last " gr...             1
# 26  b ' The tagline for this show is, " He's speak...             1
# 27  b ' They missed up the film when the tried to ...             1
# 28  b ' What we know of Caravaggio suggests a stru...             0
# 29  b ' Wow, was this version of THE RACKETEER tou...             0
# 30  b ' You can not be seeing the same movie if yo...             0
#
#     prediction_2 identifier_1 identifier_2  \
# 0              1          old        young
# 1              1          old        young
# 2              0          old        young
# 3              1          old        young
# 4              1          old        young
# 5              1          old        young
# 6              0          old        young
# 7              1          old        young
# 8              1          old        young
# 9              1          old        young
# 10             1          old        young
# 11             1          old        young
# 12             1          old        young
# 13             1          old        young
# 14             1          old        young
# 15             1          old        young
# 16             0          old        young
# 17             0          old        young
# 18             1          old        young
# 19             0          old        young
# 20             1          old        young
# 21             1          old        young
# 22             1          old        young
# 23             1          old        young
# 24             1          old        young
# 25             0          old        young
# 26             0          old        young
# 27             0          old        young
# 28             1          old        young
# 29             1          old        young
# 30             1          old        young
#
#                                              template
# 0   b " Even the trailer for this movie makes me c...
# 1   b " @ADJ Gary Cooper is a cool headed guy. Alw...
# 2   b " Half Past Dead was unlike any @ADJ Steven ...
# 3   b " @ADJ Hedy Lamarr who may have been kept by...
# 4   b " I actually liked this movie. Sure, the act...
# 5   b " I rented this film because I enjoy watchin...
# 6   b " I went to see this thinking it would be a ...
# 7   b " I've Seen The Beginning Of The Muppet Movi...
# 8   b " If you like silly comedies like Airplane y...
# 9   b " @ADJ Leno talks through his punch lines. T...
# 10  b " @ADJ Leos Carax has made 3 great movies: B...
# 11  b " @ADJ Leos Carax has made 3 great movies: B...
# 12  b " @ADJ Leos Carax has made 3 great movies: B...
# 13  b " @ADJ Leos Carax has made 3 great movies: B...
# 14  b " That pretty much sums it up ... corny. Mac...
# 15  b " This movie is a must see for any war movie...
# 16  b " Very intelligent language usage of @ADJ Al...
# 17  b " Where the hell did VH1 find the scriptwrit...
# 18  b " @ADJ Michael Dudikoff like young Lord Grey...
# 19  b ' As a physicist, talk about blackholes and ...
# 20  b ' Childish storyline ripped off of a lame Ho...
# 21  b ' I have long tried to understand why people...
# 22  b ' Ice the Limerick: A virus pulled out of th...
# 23  b ' It might be a stretch saying this as a die...
# 24  b ' My yardstick for measuring a movie's watch...
# 25  b ' Often considered @ADJ Argento's last " gre...
# 26  b ' The tagline for this show is, " He's speak...
# 27  b ' They missed up the film when the tried to ...
# 28  b ' What we know of Caravaggio suggests a stru...
# 29  b ' Wow, was this version of THE RACKETEER tou...
# 30  b ' You can not be seeing the same movie if yo...

# %%
dfcross["btc"] = dfcross["prediction_1"] != dfcross["prediction_2"]
dfcross
# Out:
#                                              mutant_1  \
# 0   b " Even the trailer for this movie makes me c...
# 1   b " old Gary Cooper is a cool headed guy. Alwa...
# 2   b " Half Past Dead was unlike any old Steven S...
# 3   b " old Hedy Lamarr who may have been kept by ...
# 4   b " I actually liked this movie. Sure, the act...
# 5   b " I rented this film because I enjoy watchin...
# 6   b " I went to see this thinking it would be a ...
# 7   b " I've Seen The Beginning Of The Muppet Movi...
# 8   b " If you like silly comedies like Airplane y...
# 9   b " old Leno talks through his punch lines. Th...
# 10  b " old Leos Carax has made 3 great movies: Bo...
# 11  b " old Leos Carax has made 3 great movies: Bo...
# 12  b " old Leos Carax has made 3 great movies: Bo...
# 13  b " old Leos Carax has made 3 great movies: Bo...
# 14  b " That pretty much sums it up ... corny. Mac...
# 15  b " This movie is a must see for any war movie...
# 16  b " Very intelligent language usage of old Ali...
# 17  b " Where the hell did VH1 find the scriptwrit...
# 18  b " old Michael Dudikoff like young Lord Greys...
# 19  b ' As a physicist, talk about blackholes and ...
# 20  b ' Childish storyline ripped off of a lame Ho...
# 21  b ' I have long tried to understand why people...
# 22  b ' Ice the Limerick: A virus pulled out of th...
# 23  b ' It might be a stretch saying this as a die...
# 24  b ' My yardstick for measuring a movie's watch...
# 25  b ' Often considered old Argento's last " grea...
# 26  b ' The tagline for this show is, " He's speak...
# 27  b ' They missed up the film when the tried to ...
# 28  b ' What we know of Caravaggio suggests a stru...
# 29  b ' Wow, was this version of THE RACKETEER tou...
# 30  b ' You can not be seeing the same movie if yo...
#
#                                              mutant_2  prediction_1  \
# 0   b " Even the trailer for this movie makes me c...             0
# 1   b " young Gary Cooper is a cool headed guy. Al...             0
# 2   b " Half Past Dead was unlike any young Steven...             1
# 3   b " young Hedy Lamarr who may have been kept b...             0
# 4   b " I actually liked this movie. Sure, the act...             0
# 5   b " I rented this film because I enjoy watchin...             0
# 6   b " I went to see this thinking it would be a ...             1
# 7   b " I've Seen The Beginning Of The Muppet Movi...             0
# 8   b " If you like silly comedies like Airplane y...             0
# 9   b " young Leno talks through his punch lines. ...             0
# 10  b " young Leos Carax has made 3 great movies: ...             0
# 11  b " young Leos Carax has made 3 great movies: ...             0
# 12  b " young Leos Carax has made 3 great movies: ...             0
# 13  b " young Leos Carax has made 3 great movies: ...             0
# 14  b " That pretty much sums it up ... corny. Mac...             0
# 15  b " This movie is a must see for any war movie...             0
# 16  b " Very intelligent language usage of young A...             1
# 17  b " Where the hell did VH1 find the scriptwrit...             1
# 18  b " young Michael Dudikoff like young Lord Gre...             0
# 19  b ' As a physicist, talk about blackholes and ...             1
# 20  b ' Childish storyline ripped off of a lame Ho...             0
# 21  b ' I have long tried to understand why people...             0
# 22  b ' Ice the Limerick: A virus pulled out of th...             0
# 23  b ' It might be a stretch saying this as a die...             0
# 24  b ' My yardstick for measuring a movie's watch...             0
# 25  b ' Often considered young Argento's last " gr...             1
# 26  b ' The tagline for this show is, " He's speak...             1
# 27  b ' They missed up the film when the tried to ...             1
# 28  b ' What we know of Caravaggio suggests a stru...             0
# 29  b ' Wow, was this version of THE RACKETEER tou...             0
# 30  b ' You can not be seeing the same movie if yo...             0
#
#     prediction_2 identifier_1 identifier_2  \
# 0              1          old        young
# 1              1          old        young
# 2              0          old        young
# 3              1          old        young
# 4              1          old        young
# 5              1          old        young
# 6              0          old        young
# 7              1          old        young
# 8              1          old        young
# 9              1          old        young
# 10             1          old        young
# 11             1          old        young
# 12             1          old        young
# 13             1          old        young
# 14             1          old        young
# 15             1          old        young
# 16             0          old        young
# 17             0          old        young
# 18             1          old        young
# 19             0          old        young
# 20             1          old        young
# 21             1          old        young
# 22             1          old        young
# 23             1          old        young
# 24             1          old        young
# 25             0          old        young
# 26             0          old        young
# 27             0          old        young
# 28             1          old        young
# 29             1          old        young
# 30             1          old        young
#
#                                              template   btc
# 0   b " Even the trailer for this movie makes me c...  True
# 1   b " @ADJ Gary Cooper is a cool headed guy. Alw...  True
# 2   b " Half Past Dead was unlike any @ADJ Steven ...  True
# 3   b " @ADJ Hedy Lamarr who may have been kept by...  True
# 4   b " I actually liked this movie. Sure, the act...  True
# 5   b " I rented this film because I enjoy watchin...  True
# 6   b " I went to see this thinking it would be a ...  True
# 7   b " I've Seen The Beginning Of The Muppet Movi...  True
# 8   b " If you like silly comedies like Airplane y...  True
# 9   b " @ADJ Leno talks through his punch lines. T...  True
# 10  b " @ADJ Leos Carax has made 3 great movies: B...  True
# 11  b " @ADJ Leos Carax has made 3 great movies: B...  True
# 12  b " @ADJ Leos Carax has made 3 great movies: B...  True
# 13  b " @ADJ Leos Carax has made 3 great movies: B...  True
# 14  b " That pretty much sums it up ... corny. Mac...  True
# 15  b " This movie is a must see for any war movie...  True
# 16  b " Very intelligent language usage of @ADJ Al...  True
# 17  b " Where the hell did VH1 find the scriptwrit...  True
# 18  b " @ADJ Michael Dudikoff like young Lord Grey...  True
# 19  b ' As a physicist, talk about blackholes and ...  True
# 20  b ' Childish storyline ripped off of a lame Ho...  True
# 21  b ' I have long tried to understand why people...  True
# 22  b ' Ice the Limerick: A virus pulled out of th...  True
# 23  b ' It might be a stretch saying this as a die...  True
# 24  b ' My yardstick for measuring a movie's watch...  True
# 25  b ' Often considered @ADJ Argento's last " gre...  True
# 26  b ' The tagline for this show is, " He's speak...  True
# 27  b ' They missed up the film when the tried to ...  True
# 28  b ' What we know of Caravaggio suggests a stru...  True
# 29  b ' Wow, was this version of THE RACKETEER tou...  True
# 30  b ' You can not be seeing the same movie if yo...  True

# %%
d = dfcross[dfcross["btc"] == True].reset_index(drop=True)

# %%
d.to_csv("occ-age/age-btc.csv")

# %% [markdown]
# ### Number of Bias-uncovering Test Case

# %%
print("Number of Discordant Pairs: ", int(len(dfcross[dfcross["btc"] == True])))
# Out:
# Number of Discordant Pairs:  31

# %%
print("Discordant Pairs Rate: ", len(dfcross[dfcross["btc"] == True]) / len(df) )
# Out:
# Discordant Pairs Rate:  0.0008397897816546568

# %%
d = dfcross[dfcross["discordant"] == True]
d = d.drop(columns=["discordant"])

# %%
for id, rows in d.iloc[100:101].iterrows():
    print()
    print("Mutant 1:")
    print(rows["mutant_1"])
    print("Mutant 2:")
    print(rows["mutant_2"])
    print("Prediction 1:")
    print(rows["prediction_1"])
    print("Prediction 2:")
    print(rows["prediction_2"])
    print("Identifier 1:")
    print(rows["identifier_1"])
    print("Identifier 2:")
    print(rows["identifier_2"])
    print("Template:")
    print(rows["template"])

# %% [markdown]
# ## Get Number of Discordant Pairs for Each Template by Estimation
#
# There is a memory limitation that make us can't directly produce +- 240M pairs. Fortunately, the number of discordant pairs for each template can be calculate theoritically without crossing th data to get +- 240M pairs. This will solve the memory issue.
#
# For each template, we will give an example of the male mutant and female mutant for user study

# %%
df
# Out:
#                                                   mutant  \
# 0      b " The Mascot is Starewicz's masterpiece. It ...
# 1      b " The Mascot is Starewicz's masterpiece. It ...
# 2      b " I have only see three episodes of Hack, st...
# 3      b " I have only see three episodes of Hack, st...
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...
# ...                                                  ...
# 36909  b " How do you describe perfection? In - the -...
# 36910  b " The French Babbette appears at the modest ...
# 36911  b " The French Babbette appears at the modest ...
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...
#
#                                                 template  \
# 0      b " The Mascot is Starewicz's masterpiece. It ...
# 1      b " The Mascot is Starewicz's masterpiece. It ...
# 2      b " I have only see three episodes of Hack, st...
# 3      b " I have only see three episodes of Hack, st...
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...
# ...                                                  ...
# 36909  b " How do you describe perfection? In - the -...
# 36910  b " The French Babbette appears at the modest ...
# 36911  b " The French Babbette appears at the modest ...
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...
#
#                                                 original    age  \
# 0      b " The Mascot is Ladislaw Starewicz's masterp...  young
# 1      b " The Mascot is Ladislaw Starewicz's masterp...    old
# 2      b " I have only see three episodes of Hack, st...  young
# 3      b " I have only see three episodes of Hack, st...    old
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...  young
# ...                                                  ...    ...
# 36909  b " How do you describe perfection? In - the -...    old
# 36910  b " The French Babbette appears at the modest ...  young
# 36911  b " The French Babbette appears at the modest ...    old
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...  young
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...    old
#
#                 name  label  prediction  template_id
# 0          Starewicz      1           1         5573
# 1          Starewicz      1           1         5573
# 2        David Morse      1           1         2440
# 3        David Morse      1           1         2440
# 4       Shabana Azmi      1           1         9548
# ...              ...    ...         ...          ...
# 36909  Maggie Cheung      1           1         1905
# 36910        Babette      1           1         5542
# 36911        Babette      1           1         5542
# 36912     Gary Busey      1           1         1510
# 36913     Gary Busey      1           1         1510
#
# [36914 rows x 8 columns]

# %%
dft = df.iloc[:,[1,2,7]]
dft
# Out:
#                                                 template  \
# 0      b " The Mascot is Starewicz's masterpiece. It ...
# 1      b " The Mascot is Starewicz's masterpiece. It ...
# 2      b " I have only see three episodes of Hack, st...
# 3      b " I have only see three episodes of Hack, st...
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...
# ...                                                  ...
# 36909  b " How do you describe perfection? In - the -...
# 36910  b " The French Babbette appears at the modest ...
# 36911  b " The French Babbette appears at the modest ...
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...
#
#                                                 original  template_id
# 0      b " The Mascot is Ladislaw Starewicz's masterp...         5573
# 1      b " The Mascot is Ladislaw Starewicz's masterp...         5573
# 2      b " I have only see three episodes of Hack, st...         2440
# 3      b " I have only see three episodes of Hack, st...         2440
# 4      b ' Deepa Mehta's " Fire " is groundbreaking, ...         9548
# ...                                                  ...          ...
# 36909  b " How do you describe perfection? In - the -...         1905
# 36910  b " The French Babbette appears at the modest ...         5542
# 36911  b " The French Babbette appears at the modest ...         5542
# 36912  b " First, I'm a huge Buddy Holly fan. I grew ...         1510
# 36913  b " First, I'm a huge Buddy Holly fan. I grew ...         1510
#
# [36914 rows x 3 columns]

# %%
dft = dft.drop_duplicates().reset_index(drop=True)
dft = dft.sort_values(by=["template_id"]).reset_index(drop=True)
dft
# Out:
#                                                 template  \
# 0      b " ' A New Generation ' is the third Amityvil...
# 1      b " ' A Tale of Two Sisters ', or ' Janghwa, @...
# 2      b " ' A comedy of biblical proportions! ' Thos...
# 3      b " ' Airport 4 ' is basically a slopped toget...
# 4      b " ' @ADJ Anne Christie ' was Garbo's 14th fi...
# ...                                                  ...
# 18313  b '****************** SPOILER*****************...
# 18314  b '. but unfortunately no one thought about ha...
# 18315  b '. this movie has been done when @ADJ Hitler...
# 18316  b '/* may contain SPOILERS, but of course it d...
# 18317  b '_ The Wild Life_ has an obvious resemblance...
#
#                                                 original  template_id
# 0      b " ' A New Generation ' is the third Amityvil...            0
# 1      b " ' A Tale of Two Sisters ', or ' Janghwa, H...            1
# 2      b " ' A comedy of biblical proportions! ' Thos...            2
# 3      b " ' Airport 4 ' is basically a slopped toget...            3
# 4      b " ' Anne Christie ' was Garbo's 14th film an...            4
# ...                                                  ...          ...
# 18313  b '****************** SPOILER*****************...        18313
# 18314  b '. but unfortunately no one thought about ha...        18314
# 18315  b '. this movie has been done when Hitler ( an...        18315
# 18316  b '/* may contain SPOILERS, but of course it d...        18316
# 18317  b '_ The Wild Life_ has an obvious resemblance...        18317
#
# [18318 rows x 3 columns]

# %% [markdown]
# ### Data crossing

# %%
import time

start = time.time()

identifier = "age"

mutant_example = []
mutant_prediction_stat = []
key = []
for i in range(len(gb.size())) :
# for i in range(10) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    me = {} # mutant example
    mp = {} # mutant prediction
    key = []
    for k, v in dict(iter(dc)).items() :
        key.append(k)
        is_first_instance = True
        pos_counter = 0 # positive counter
        neg_counter = 0 # negative counter
        for m, p in zip(v["mutant"].values, v["prediction"].values) :
            if is_first_instance :
                me[k] = m
                is_first_instance = False
            if p == 1 :
                pos_counter += 1
            else :
                neg_counter += 1
        mp[k] = {"pos": pos_counter, "neg" : neg_counter}
        
    mutant_example.append(me)
    mutant_prediction_stat.append(mp)
                            
end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  29.834168910980225

# %%
len(mutant_example)
# Out:
# 18318

# %%
dft["mutant_example"] = mutant_example
dft["mutant_prediction_stat"] = mutant_prediction_stat
dft
# Out:
#                                                 template  \
# 0      b " ' A New Generation ' is the third Amityvil...
# 1      b " ' A Tale of Two Sisters ', or ' Janghwa, @...
# 2      b " ' A comedy of biblical proportions! ' Thos...
# 3      b " ' Airport 4 ' is basically a slopped toget...
# 4      b " ' @ADJ Anne Christie ' was Garbo's 14th fi...
# ...                                                  ...
# 18313  b '****************** SPOILER*****************...
# 18314  b '. but unfortunately no one thought about ha...
# 18315  b '. this movie has been done when @ADJ Hitler...
# 18316  b '/* may contain SPOILERS, but of course it d...
# 18317  b '_ The Wild Life_ has an obvious resemblance...
#
#                                                 original  template_id  \
# 0      b " ' A New Generation ' is the third Amityvil...            0
# 1      b " ' A Tale of Two Sisters ', or ' Janghwa, H...            1
# 2      b " ' A comedy of biblical proportions! ' Thos...            2
# 3      b " ' Airport 4 ' is basically a slopped toget...            3
# 4      b " ' Anne Christie ' was Garbo's 14th film an...            4
# ...                                                  ...          ...
# 18313  b '****************** SPOILER*****************...        18313
# 18314  b '. but unfortunately no one thought about ha...        18314
# 18315  b '. this movie has been done when Hitler ( an...        18315
# 18316  b '/* may contain SPOILERS, but of course it d...        18316
# 18317  b '_ The Wild Life_ has an obvious resemblance...        18317
#
#                                           mutant_example  \
# 0      {'old': 'b " ' A New Generation ' is the third...
# 1      {'old': 'b " ' A Tale of Two Sisters ', or ' J...
# 2      {'old': 'b " ' A comedy of biblical proportion...
# 3      {'old': 'b " ' Airport 4 ' is basically a slop...
# 4      {'old': 'b " ' old Anne Christie ' was Garbo's...
# ...                                                  ...
# 18313  {'old': 'b '****************** SPOILER********...
# 18314  {'old': 'b '. but unfortunately no one thought...
# 18315  {'old': 'b '. this movie has been done when ol...
# 18316  {'old': 'b '/* may contain SPOILERS, but of co...
# 18317  {'old': 'b '_ The Wild Life_ has an obvious re...
#
#                                   mutant_prediction_stat
# 0      {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...
# 1      {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...
# 2      {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...
# 3      {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...
# 4      {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...
# ...                                                  ...
# 18313  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...
# 18314  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...
# 18315  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...
# 18316  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...
# 18317  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...
#
# [18318 rows x 5 columns]

# %%
btcs = []
pairs = []
for mp in dft["mutant_prediction_stat"].values :
    if len(mp) > 0 :
        btc = 0
        pair = 0
        for k1 in key :
            for k2 in key :
                if k1 != k2 :
                    btc += ((mp[k1]["pos"] * mp[k2]["neg"]) + (mp[k1]["neg"] * mp[k2]["pos"]))
                    pair += (mp[k1]["pos"] + mp[k1]["neg"]) * (mp[k2]["pos"] + mp[k2]["neg"])

#         double_counting_divider = len(key) * (len(key)-1)
#         dp.append(int(_dp/double_counting_divider)) # we must divide the number with the number of key to reduce the double counting
        btcs.append(btc)
        pairs.append(pair)
    else :
        btcs.append(0)
        pairs.append(0)

# %%
dft["btc"] = btcs
dft["possible_pair"] = pairs
dft
# Out:
#                                                 template  \
# 0      b " ' A New Generation ' is the third Amityvil...
# 1      b " ' A Tale of Two Sisters ', or ' Janghwa, @...
# 2      b " ' A comedy of biblical proportions! ' Thos...
# 3      b " ' Airport 4 ' is basically a slopped toget...
# 4      b " ' @ADJ Anne Christie ' was Garbo's 14th fi...
# ...                                                  ...
# 18313  b '****************** SPOILER*****************...
# 18314  b '. but unfortunately no one thought about ha...
# 18315  b '. this movie has been done when @ADJ Hitler...
# 18316  b '/* may contain SPOILERS, but of course it d...
# 18317  b '_ The Wild Life_ has an obvious resemblance...
#
#                                                 original  template_id  \
# 0      b " ' A New Generation ' is the third Amityvil...            0
# 1      b " ' A Tale of Two Sisters ', or ' Janghwa, H...            1
# 2      b " ' A comedy of biblical proportions! ' Thos...            2
# 3      b " ' Airport 4 ' is basically a slopped toget...            3
# 4      b " ' Anne Christie ' was Garbo's 14th film an...            4
# ...                                                  ...          ...
# 18313  b '****************** SPOILER*****************...        18313
# 18314  b '. but unfortunately no one thought about ha...        18314
# 18315  b '. this movie has been done when Hitler ( an...        18315
# 18316  b '/* may contain SPOILERS, but of course it d...        18316
# 18317  b '_ The Wild Life_ has an obvious resemblance...        18317
#
#                                           mutant_example  \
# 0      {'old': 'b " ' A New Generation ' is the third...
# 1      {'old': 'b " ' A Tale of Two Sisters ', or ' J...
# 2      {'old': 'b " ' A comedy of biblical proportion...
# 3      {'old': 'b " ' Airport 4 ' is basically a slop...
# 4      {'old': 'b " ' old Anne Christie ' was Garbo's...
# ...                                                  ...
# 18313  {'old': 'b '****************** SPOILER********...
# 18314  {'old': 'b '. but unfortunately no one thought...
# 18315  {'old': 'b '. this movie has been done when ol...
# 18316  {'old': 'b '/* may contain SPOILERS, but of co...
# 18317  {'old': 'b '_ The Wild Life_ has an obvious re...
#
#                                   mutant_prediction_stat  btc  possible_pair
# 0      {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    0              2
# 1      {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    0              2
# 2      {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    0              2
# 3      {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    0              2
# 4      {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    0              2
# ...                                                  ...  ...            ...
# 18313  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    0              2
# 18314  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    0              2
# 18315  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    0              2
# 18316  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    0              2
# 18317  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    0              2
#
# [18318 rows x 7 columns]

# %% [markdown]
# ### Number of Bias-uncovering Test Case
#
# We divide by 2, because we assume that pair (A,B) is the same with pair (B,A)

# %%
int(dft["btc"].sum() /2)
# Out:
# 31

# %% [markdown]
# ### BTC Rate

# %%
dft["btc"].sum() / dft["possible_pair"].sum()
# Out:
# 0.001653774339823953

# %% [markdown]
# ### Get Data that Have number of BTC more than one

# %%
d = dft[dft["btc"] > 0]
d.head()
# Out:
#                                                template  \
# 1356  b " Even the trailer for this movie makes me c...
# 1664  b " @ADJ Gary Cooper is a cool headed guy. Alw...
# 1763  b " Half Past Dead was unlike any @ADJ Steven ...
# 1821  b " @ADJ Hedy Lamarr who may have been kept by...
# 1958  b " I actually liked this movie. Sure, the act...
#
#                                                original  template_id  \
# 1356  b " Even the trailer for this movie makes me c...         1356
# 1664  b " Gary Cooper is a cool headed guy. Always l...         1664
# 1763  b " Half Past Dead was unlike any Steven Segal...         1763
# 1821  b " Hedy Lamarr who may have been kept by more...         1821
# 1958  b " I actually liked this movie. Sure, the act...         1958
#
#                                          mutant_example  \
# 1356  {'old': 'b " Even the trailer for this movie m...
# 1664  {'old': 'b " old Gary Cooper is a cool headed ...
# 1763  {'old': 'b " Half Past Dead was unlike any old...
# 1821  {'old': 'b " old Hedy Lamarr who may have been...
# 1958  {'old': 'b " I actually liked this movie. Sure...
#
#                                  mutant_prediction_stat  btc  possible_pair
# 1356  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 1664  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 1763  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 1821  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 1958  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2

# %% [markdown]
# ### Sort Data based on the number of BTC

# %%
d = d.sort_values(["btc", "template"], ascending=False)
d = d.reset_index(drop=True)
d.to_csv("occ-age/age-btc.csv")
d
# Out:
#                                              template  \
# 0   b " @ADJ Leos Carax has made 3 great movies: B...
# 1   b ' You can not be seeing the same movie if yo...
# 2   b ' Wow, was this version of THE RACKETEER tou...
# 3   b ' What we know of Caravaggio suggests a stru...
# 4   b ' They missed up the film when the tried to ...
# 5   b ' The tagline for this show is, " He's speak...
# 6   b ' Often considered @ADJ Argento's last " gre...
# 7   b ' My yardstick for measuring a movie's watch...
# 8   b ' It might be a stretch saying this as a die...
# 9   b ' Ice the Limerick: A virus pulled out of th...
# 10  b ' I have long tried to understand why people...
# 11  b ' Childish storyline ripped off of a lame Ho...
# 12  b ' As a physicist, talk about blackholes and ...
# 13  b " Where the hell did VH1 find the scriptwrit...
# 14  b " Very intelligent language usage of @ADJ Al...
# 15  b " This movie is a must see for any war movie...
# 16  b " That pretty much sums it up ... corny. Mac...
# 17  b " If you like silly comedies like Airplane y...
# 18  b " I've Seen The Beginning Of The Muppet Movi...
# 19  b " I went to see this thinking it would be a ...
# 20  b " I rented this film because I enjoy watchin...
# 21  b " I actually liked this movie. Sure, the act...
# 22  b " Half Past Dead was unlike any @ADJ Steven ...
# 23  b " Even the trailer for this movie makes me c...
# 24  b " @ADJ Michael Dudikoff like young Lord Grey...
# 25  b " @ADJ Leno talks through his punch lines. T...
# 26  b " @ADJ Hedy Lamarr who may have been kept by...
# 27  b " @ADJ Gary Cooper is a cool headed guy. Alw...
#
#                                              original  template_id  \
# 0   b " Leos Carax has made 3 great movies: Boys M...         4214
# 1   b ' You can not be seeing the same movie if yo...        18030
# 2   b ' Wow, was this version of THE RACKETEER tou...        17945
# 3   b ' What we know of Caravaggio suggests a stru...        17591
# 4   b ' They missed up the film when the tried to ...        15782
# 5   b ' The tagline for this show is, " He's speak...        15601
# 6   b ' Often considered Argento's last " great " ...        13914
# 7   b ' My yardstick for measuring a movie's watch...        13682
# 8   b ' It might be a stretch saying this as a die...        12851
# 9   b ' Ice the Limerick: A virus pulled out of th...        12421
# 10  b ' I have long tried to understand why people...        11113
# 11  b ' Childish storyline ripped off of a lame Ho...         9359
# 12  b ' As a physicist, talk about blackholes and ...         8939
# 13  b " Where the hell did VH1 find the scriptwrit...         7616
# 14  b " Very intelligent language usage of Ali, wh...         7282
# 15  b " This movie is a must see for any war movie...         6752
# 16  b " That pretty much sums it up ... corny. Mac...         5462
# 17  b " If you like silly comedies like Airplane y...         3670
# 18  b " I've Seen The Beginning Of The Muppet Movi...         3494
# 19  b " I went to see this thinking it would be a ...         3348
# 20  b " I rented this film because I enjoy watchin...         2875
# 21  b " I actually liked this movie. Sure, the act...         1958
# 22  b " Half Past Dead was unlike any Steven Segal...         1763
# 23  b " Even the trailer for this movie makes me c...         1356
# 24  b " Young Michael Dudikoff like young Lord Gre...         7829
# 25  b " Leno talks through his punch lines. This s...         4209
# 26  b " Hedy Lamarr who may have been kept by more...         1821
# 27  b " Gary Cooper is a cool headed guy. Always l...         1664
#
#                                        mutant_example  \
# 0   {'old': 'b " old Leos Carax has made 3 great m...
# 1   {'old': 'b ' You can not be seeing the same mo...
# 2   {'old': 'b ' Wow, was this version of THE RACK...
# 3   {'old': 'b ' What we know of Caravaggio sugges...
# 4   {'old': 'b ' They missed up the film when the ...
# 5   {'old': 'b ' The tagline for this show is, " H...
# 6   {'old': 'b ' Often considered old Argento's la...
# 7   {'old': 'b ' My yardstick for measuring a movi...
# 8   {'old': 'b ' It might be a stretch saying this...
# 9   {'old': 'b ' Ice the Limerick: A virus pulled ...
# 10  {'old': 'b ' I have long tried to understand w...
# 11  {'old': 'b ' Childish storyline ripped off of ...
# 12  {'old': 'b ' As a physicist, talk about blackh...
# 13  {'old': 'b " Where the hell did VH1 find the s...
# 14  {'old': 'b " Very intelligent language usage o...
# 15  {'old': 'b " This movie is a must see for any ...
# 16  {'old': 'b " That pretty much sums it up ... c...
# 17  {'old': 'b " If you like silly comedies like A...
# 18  {'old': 'b " I've Seen The Beginning Of The Mu...
# 19  {'old': 'b " I went to see this thinking it wo...
# 20  {'old': 'b " I rented this film because I enjo...
# 21  {'old': 'b " I actually liked this movie. Sure...
# 22  {'old': 'b " Half Past Dead was unlike any old...
# 23  {'old': 'b " Even the trailer for this movie m...
# 24  {'old': 'b " old Michael Dudikoff like young L...
# 25  {'old': 'b " old Leno talks through his punch ...
# 26  {'old': 'b " old Hedy Lamarr who may have been...
# 27  {'old': 'b " old Gary Cooper is a cool headed ...
#
#                                mutant_prediction_stat  btc  possible_pair
# 0   {'old': {'pos': 0, 'neg': 2}, 'young': {'pos':...    8              8
# 1   {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 2   {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 3   {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 4   {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 5   {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 6   {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 7   {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 8   {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 9   {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 10  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 11  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 12  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 13  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 14  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 15  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 16  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 17  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 18  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 19  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 20  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 21  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 22  {'old': {'pos': 1, 'neg': 0}, 'young': {'pos':...    2              2
# 23  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 24  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 25  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 26  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2
# 27  {'old': {'pos': 0, 'neg': 1}, 'young': {'pos':...    2              2

# %%
d.iloc[0]["mutant_prediction_stat"]
# Out:
# {'old': {'pos': 0, 'neg': 2}, 'young': {'pos': 2, 'neg': 0}}
