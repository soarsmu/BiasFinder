# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv("../data/occupation/test-uncleaned-39k.csv")
df.head()
# Out:
#    Unnamed: 0         0                                                  1  \
# 0           0  negative  Why do movie makers always go against the atte...
# 1           1  negative  Why do movie makers always go against the cash...
# 2           2  negative  Why do movie makers always go against the teac...
# 3           3  negative  Why do movie makers always go against the nurs...
# 4           4  negative  Why do movie makers always go against the assi...
#
#                                               mutant  \
# 0  Why do movie makers always go against the atte...
# 1  Why do movie makers always go against the cash...
# 2  Why do movie makers always go against the teac...
# 3  Why do movie makers always go against the nurs...
# 4  Why do movie makers always go against the assi...
#
#                                             template occupation
# 0  Why do movie makers always go against @DetOTHE...  attendant
# 1  Why do movie makers always go against @DetOTHE...    cashier
# ...

# %%
df = df.drop(columns=["Unnamed: 0"])
df
# Out:
#               0                                                  1  \
# 0      negative  Why do movie makers always go against the atte...
# 1      negative  Why do movie makers always go against the cash...
# 2      negative  Why do movie makers always go against the teac...
# 3      negative  Why do movie makers always go against the nurs...
# 4      negative  Why do movie makers always go against the assi...
# ...         ...                                                ...
# 39495  positive  This 1953 Sam Fuller movie contains some of hi...
# 39496  positive  This 1953 Sam Fuller movie contains some of hi...
# 39497  positive  This 1953 Sam Fuller movie contains some of hi...
# 39498  positive  This 1953 Sam Fuller movie contains some of hi...
# 39499  positive  This 1953 Sam Fuller movie contains some of hi...
#
#                                                   mutant  \
# 0      Why do movie makers always go against the atte...
# ...

# %%
df["0"]
# Out:
# 0        negative
# 1        negative
# 2        negative
# 3        negative
# 4        negative
#            ...
# 39495    positive
# 39496    positive
# 39497    positive
# 39498    positive
# 39499    positive
# Name: 0, Length: 39500, dtype: object

# %%
def label_encoder(text):
    if text == "positive" :
        return 1
    return 0

df["0"] = df["0"].apply(label_encoder)

# %%
df.to_csv("../data/occupation/test.csv", index=None, header=None, sep="\t")
