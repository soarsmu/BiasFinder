# %% [markdown]
# # Number of Discordant Pairs Country
#
# Discordant pair is a pair contain of male-female and its prediction, such that the Sentiment Analysis produce a different prediction.
# Example of discordant pair from country:
#
# `<(name from Indonesia, prediction), (name from USA, prediction)>`
#
# `<(“Paijo is angry”, 1), (“John is angry”, 0)>`

# %%
import pandas as pd
import numpy as np
import math
import time

# %%
eval_dir = "gc_imdb"
# df = pd.read_csv("../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=[0, 1, "mutant", "template", "gender", "label", "country"])
df = pd.read_csv("../data/" + eval_dir + "/test.csv", header=None, sep="\t", names=["label", "mutant", "template", "original", "identifier", "type", "gender", "country"])
df
# Out:
#          label                                             mutant  \
# 0            1  I have only see three episodes of Hack, starri...
# 1            1  I have only see three episodes of Hack, starri...
# 2            1  I have only see three episodes of Hack, starri...
# 3            1  I have only see three episodes of Hack, starri...
# 4            1  I have only see three episodes of Hack, starri...
# ...        ...                                                ...
# 1080749      1  Well, the movie did turn out a lot better than...
# 1080750      1  Well, the movie did turn out a lot better than...
# 1080751      1  Well, the movie did turn out a lot better than...
# 1080752      1  Well, the movie did turn out a lot better than...
# 1080753      1  Well, the movie did turn out a lot better than...
#
#                                                   template  \
# 0        I have only see three episodes of Hack, starri...
# 1        I have only see three episodes of Hack, starri...
# 2        I have only see three episodes of Hack, starri...
# 3        I have only see three episodes of Hack, starri...
# 4        I have only see three episodes of Hack, starri...
# ...                                                    ...
# 1080749  Well, the movie did turn out a lot better than...
# 1080750  Well, the movie did turn out a lot better than...
# 1080751  Well, the movie did turn out a lot better than...
# 1080752  Well, the movie did turn out a lot better than...
# 1080753  Well, the movie did turn out a lot better than...
#
#                                                   original identifier  \
# 0        I have only see three episodes of Hack, starri...   template
# 1        I have only see three episodes of Hack, starri...       Roen
# 2        I have only see three episodes of Hack, starri...       Jeet
# 3        I have only see three episodes of Hack, starri...      Hagen
# 4        I have only see three episodes of Hack, starri...     Willow
# ...                                                    ...        ...
# 1080749  Well, the movie did turn out a lot better than...       Dódi
# 1080750  Well, the movie did turn out a lot better than...     Iboyka
# 1080751  Well, the movie did turn out a lot better than...     Zsófia
# 1080752  Well, the movie did turn out a lot better than...      Ágota
# 1080753  Well, the movie did turn out a lot better than...      Alexa
#
#              type    gender   country
# 0        template  template  template
# 1            name      male        UK
# 2            name      male        UK
# 3            name      male        UK
# 4            name      male        UK
# ...           ...       ...       ...
# 1080749      name    female   Hungary
# 1080750      name    female   Hungary
# 1080751      name    female   Hungary
# 1080752      name    female   Hungary
# 1080753      name    female   Hungary
#
# [1080754 rows x 8 columns]

# %%
def read_txt(fpath):
    pred = []
    file = open(fpath)
    lines = file.readlines()
    for l in lines :
        pred.append(int(l))
    file.close()
    
    return pred

# %%
output_dir = "trial_on_gc_imdb"

result_dir = "../result/" + output_dir + "/"

path = result_dir + "results_data.txt"

pred = read_txt(path)

print(len(pred))
# Out:
# 1080754

# %%
df["prediction"] = pred

# %%
# df = df.drop(columns=[0,1])
df = df[df["gender"] != "template"]
df.head()
# Out:
#    label                                             mutant  \
# 1      1  I have only see three episodes of Hack, starri...
# 2      1  I have only see three episodes of Hack, starri...
# 3      1  I have only see three episodes of Hack, starri...
# 4      1  I have only see three episodes of Hack, starri...
# 5      1  I have only see three episodes of Hack, starri...
#
#                                             template  \
# 1  I have only see three episodes of Hack, starri...
# 2  I have only see three episodes of Hack, starri...
# 3  I have only see three episodes of Hack, starri...
# 4  I have only see three episodes of Hack, starri...
# 5  I have only see three episodes of Hack, starri...
#
#                                             original identifier  type gender  \
# 1  I have only see three episodes of Hack, starri...       Roen  name   male
# 2  I have only see three episodes of Hack, starri...       Jeet  name   male
# 3  I have only see three episodes of Hack, starri...      Hagen  name   male
# 4  I have only see three episodes of Hack, starri...     Willow  name   male
# 5  I have only see three episodes of Hack, starri...      Belal  name   male
#
#   country  prediction
# 1      UK           1
# 2      UK           1
# 3      UK           1
# 4      UK           1
# 5      UK           1

# %% [markdown]
# ### Use Groupby to Group the text by Template

# %%
df["template"] = df["template"].astype("category")
df["template_id"] = df["template"].cat.codes
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
gb = df.groupby("template_id")

# %%
gb.count()
# Out:
#              label  mutant  template  original  identifier  type  gender  \
# template_id
# 0              310     310       310       310         310   310     310
# 1               26      26        26        26          26    26      26
# 2              310     310       310       310         310   310     310
# 3              310     310       310       310         310   310     310
# 4              310     310       310       310         310   310     310
# ...            ...     ...       ...       ...         ...   ...     ...
# 3995           310     310       310       310         310   310     310
# 3996           310     310       310       310         310   310     310
# 3997           310     310       310       310         310   310     310
# 3998            26      26        26        26          26    26      26
# 3999           310     310       310       310         310   310     310
#
#              country  prediction
# template_id
# 0                310         310
# 1                  0          26
# 2                310         310
# 3                310         310
# 4                310         310
# ...              ...         ...
# 3995             310         310
# 3996             310         310
# 3997             310         310
# 3998               0          26
# 3999             310         310
#
# [4000 rows x 9 columns]

# %%
len(gb.size())
# Out:
# 4000

# %% [markdown]
# #### Create Discordant Pairs based on Country
#
# You can create another discordant pairs from another column by changing the `identifier`.
#
# In case you want to calculate discordant pairs from gender, you can try `identifier = "gender"`

# %%
start = time.time()

identifier = "country"

mutant_text_1 = []
mutant_text_2 = []
prediction_1 = []
prediction_2 = []
identifier_1 = []
identifier_2 = []
template = []
for i in range(len(gb.size())) :
    data = gb.get_group(i)
    dc = data.groupby(identifier)
    for k1, v1 in dict(iter(dc)).items() :
        for k2, v2 in dict(iter(dc)).items() :
            if k1 != k2 :
                for m_1, p_1, i_1, t in zip(v1["mutant"].values, v1["prediction"].values, v1[identifier].values, v1["template"].values) :
                    for m_2, p_2, i_2 in zip(v2["mutant"].values, v2["prediction"].values, v2[identifier].values) :
                        mutant_text_1.append(m_1)
                        prediction_1.append(p_1)
                        identifier_1.append(i_1)
                        mutant_text_2.append(m_2)
                        prediction_2.append(p_2)
                        identifier_2.append(i_2)
                        template.append(t)

end = time.time()
print("Execution time: ", end-start)
# Out:
# Execution time:  5631.942308187485

# %%
df = pd.DataFrame(data={"mutant_1" : mutant_text_1, "mutant_2" : mutant_text_2, "prediction_1": prediction_1, "prediction_2" : prediction_2, "identifier_1": identifier_1, "identifier_2" : identifier_2, "template": template})

df

# %%
df["discordant"] = df["prediction_1"] != df["prediction_2"]
df

# %%
print("Number of Discordant Pairs: ", len(df[df["discordant"] == True]))

# %%
print("Discordant Pairs Rate: ", len(df[df["discordant"] == True]) / len(df) )

# %%
d = df[df["discordant"] == True]
d = d.drop(columns=["discordant"])

# %%
for id, rows in d.iloc[100:101].iterrows():
    print()
    print("Mutant 1:")
    print(rows["mutant_1"])
    print("Mutant 2:")
    print(rows["mutant_2"])
    print("Prediction 1:")
    print(rows["prediction_1"])
    print("Prediction 2:")
    print(rows["prediction_2"])
    print("Identifier 1:")
    print(rows["identifier_1"])
